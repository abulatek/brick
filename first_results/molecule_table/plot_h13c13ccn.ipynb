# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 53508
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name         Lab
#    MHz       MHz   MHz nm2        1 / cm         u                           ...
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18         bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ -----
# 87841.1018  0.0108 -2.3294     2 13.1855    21    53   508   101    10    -- ...    --    --     9    --    --    --    --    -- HC-13-C-13-CN, v=0 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name         Lab
#    MHz       MHz   MHz nm2        1 / cm         u                           ...
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18         bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ -----
# 96624.7435  0.0108 -2.2117     2 16.1155    23    53   508   101    11    -- ...    --    --    10    --    --    --    --    -- HC-13-C-13-CN, v=0 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name         Lab
#     MHz       MHz   MHz nm2        1 / cm         u                           ...
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18         bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ -----
# 114191.6131  0.0099 -2.0087     2 22.8546    27    53   508   101    13    -- ...    --    --    12    --    --    --    --    -- HC-13-C-13-CN, v=0 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name        Lab
#    MHz       MHz   MHz nm2        1 / cm         u                           ...
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18        bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ ----
# 131757.848   0.015 -1.8393     2 30.7656    31    53   508   101    15    -- ...    --    --    14    --    --    --    --    -- HC-13-C-13-CN, v=0 True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name        Lab
#    MHz       MHz   MHz nm2        1 / cm         u                           ...
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18        bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ ----
# 140540.711   0.015 -1.7647     2 35.1606    33    53   508   101    16    -- ...    --    --    15    --    --    --    --    -- HC-13-C-13-CN, v=0 True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name        Lab
#    MHz       MHz   MHz nm2        1 / cm         u                           ...
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18        bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ ----
# 140540.711   0.015 -1.7647     2 35.1606    33    53   508   101    16    -- ...    --    --    15    --    --    --    --    -- HC-13-C-13-CN, v=0 True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name        Lab
#    MHz       MHz   MHz nm2        1 / cm         u                           ...
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18        bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ ----
# 149323.355   0.015 -1.6958     2 39.8485    35    53   508   101    17    -- ...    --    --    16    --    --    --    --    -- HC-13-C-13-CN, v=0 True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name         Lab
#     MHz       MHz   MHz nm2        1 / cm          u                           ...
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18         bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ -----
# 245916.2459  0.0661 -1.1968     2 110.7493    57    53   508   101    28    -- ...    --    --    27    --    --    --    --    -- HC-13-C-13-CN, v=0 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name         Lab
#     MHz       MHz   MHz nm2        1 / cm          u                           ...
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18         bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ -----
# 254695.6171  0.0766 -1.1684     2 118.9522    59    53   508   101    29    -- ...    --    --    28    --    --    --    --    -- HC-13-C-13-CN, v=0 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name         Lab
#     MHz       MHz   MHz nm2        1 / cm          u                           ...
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18         bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ -----
# 263474.6355  0.0879 -1.1423     2 127.4479    61    53   508   101    30    -- ...    --    --    29    --    --    --    --    -- HC-13-C-13-CN, v=0 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku  ...  F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l         name         Lab
#     MHz       MHz   MHz nm2        1 / cm          u                           ...
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 ... int64 int64 int64 int64 int64 int64 int64 int64       str18         bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ... ----- ----- ----- ----- ----- ----- ----- ----- ------------------ -----
# 272253.2889     0.1 -1.1182     2 136.2365    63    53   508   101    31    -- ...    --    --    30    --    --    --    --    -- HC-13-C-13-CN, v=0 False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
               nrows=2, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-5)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
                       nrows=2, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-5)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=2, ncols=5, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=2, ncols=5, name_for_plot=mol_str)
