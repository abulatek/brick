# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 51004
catalog = 'JPL'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=6>
#   FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#   MHz      MHz   MHz nm2        1 / cm
# float64  float64 float64 int64 float64 int64 int64  int64 str4 str3
# -------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 99354.25   0.015   -4.86     2 14.9137    19 -51004   102 10 9  9 9
# 99354.25   0.015  -7.461     2 14.9137    19 -51004   102 10 9  910
# 99354.25   0.015 -2.8205     2 14.9137    23 -51004   102 1011  910
# 99354.25   0.015 -2.8644     2 14.9137    21 -51004   102 1010  9 9
# 99354.25   0.015 -2.9083     2 14.9137    19 -51004   102 10 9  9 8
# 99354.25   0.015   -4.86     2 14.9137    21 -51004   102 1010  910, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'  QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 int64 str4
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- ----
# 109289.095   0.015 -4.8259     2 18.2278    21 -51004   102  1110 1010
# 109289.095   0.015 -7.5098     2 18.2278    21 -51004   102  1110 1011
# 109289.095   0.015 -2.7069     2 18.2278    25 -51004   102  1112 1011
# 109289.095   0.015 -2.7467     2 18.2278    23 -51004   102  1111 1010
# 109289.095   0.015 -2.7866     2 18.2278    21 -51004   102  1110 10 9
# 109289.095   0.015 -4.8259     2 18.2278    23 -51004   102  1111 1011, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 int64 int64
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 129158.262   0.015 -4.7699     2 25.8501    25 -51004   102  1312  1212
# 129158.262   0.015 -7.5992     2 25.8501    25 -51004   102  1312  1213
# 129158.262   0.015  -2.511     2 25.8501    29 -51004   102  1314  1213
# 129158.262   0.015 -2.5446     2 25.8501    27 -51004   102  1313  1212
# 129158.262   0.015 -2.5782     2 25.8501    25 -51004   102  1312  1211
# 129158.262   0.015 -4.7699     2 25.8501    27 -51004   102  1313  1213, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 139092.2219  0.0113  -4.747     2 30.1584    27 51004   102  1413  1313
# 139092.5648  0.0047 -7.6408     2 30.1584    27 51004   102  1413  1314
# 139092.5894  0.0047 -2.4258     2 30.1584    31 51004   102  1415  1314
# 139092.5902  0.0047  -2.457     2 30.1584    29 51004   102  1414  1313
# 139092.5912  0.0047 -2.4882     2 30.1584    27 51004   102  1413  1312
# 139092.9331  0.0108  -4.747     2 30.1584    29 51004   102  1414  1314, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 int64 int64
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 149026.664   0.015 -4.7271     2  34.798    29 -51004   102  1514  1414
# 149026.664   0.015 -7.6809     2  34.798    29 -51004   102  1514  1415
# 149026.664   0.015 -2.3477     2  34.798    33 -51004   102  1516  1415
# 149026.664   0.015 -2.3768     2  34.798    31 -51004   102  1515  1414
# 149026.664   0.015 -2.4059     2  34.798    29 -51004   102  1514  1413
# 149026.664   0.015 -4.7271     2  34.798    31 -51004   102  1515  1415, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 int64 int64
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 149026.664   0.015 -4.7271     2  34.798    29 -51004   102  1514  1414
# 149026.664   0.015 -7.6809     2  34.798    29 -51004   102  1514  1415
# 149026.664   0.015 -2.3477     2  34.798    33 -51004   102  1516  1415
# 149026.664   0.015 -2.3768     2  34.798    31 -51004   102  1515  1414
# 149026.664   0.015 -2.4059     2  34.798    29 -51004   102  1514  1413
# 149026.664   0.015 -4.7271     2  34.798    31 -51004   102  1515  1415, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 int64 int64
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 248352.734   0.015 -4.6433     2  99.418    49 -51004   102  2524  2424
# 248352.734   0.015 -8.0411     2  99.418    49 -51004   102  2524  2425
# 248352.734   0.015 -1.8308     2  99.418    53 -51004   102  2526  2425
# 248352.734   0.015 -1.8482     2  99.418    51 -51004   102  2525  2424
# 248352.734   0.015 -1.8656     2  99.418    49 -51004   102  2524  2423
# 248352.734   0.015 -4.6433     2  99.418    51 -51004   102  2525  2425, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64  int64 int64 int64
# ---------- ------- ------- ----- -------- ----- ------ ----- ----- -----
# 258283.547   0.015 -4.6439     2 107.7022    51 -51004   102  2625  2525
# 258283.547   0.015 -8.0758     2 107.7022    51 -51004   102  2625  2526
# 258283.547   0.015 -1.7979     2 107.7022    55 -51004   102  2627  2526
# 258283.547   0.015 -1.8146     2 107.7022    53 -51004   102  2626  2525
# 258283.547   0.015 -1.8314     2 107.7022    51 -51004   102  2625  2524
# 258283.547   0.015 -4.6439     2 107.7022    53 -51004   102  2626  2526, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- -----
# 268213.5461  0.0125 -4.6458     2 116.3176    53 51004   102  2726  2626
# 268213.8948   0.007 -8.1105     2 116.3176    53 51004   102  2726  2627
# 268213.9077   0.007 -1.7676     2 116.3176    57 51004   102  2728  2627
# 268213.9079   0.007 -1.7837     2 116.3176    55 51004   102  2727  2626
# 268213.9082   0.007 -1.7998     2 116.3176    53 51004   102  2726  2625
# 268214.2566   0.012 -4.6458     2 116.3176    55 51004   102  2727  2627]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
               nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-5)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
                       nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-5)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
