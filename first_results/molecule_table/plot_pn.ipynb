# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 45511
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=2>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 90632.1953  0.1028  -16.02     2 6478.411     5    45  5111   202     2     5    --    --    --    --     1     5    --    --    --    -- PN, v=0-5 False
# 91306.0685  0.0293 -13.371     2 5210.868     5    45  5111   202     2     4    --    --    --    --     1     4    --    --    --    -- PN, v=0-5 False, <Table length=2>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 91977.5792  0.0155 -10.693     2 3929.3868     5    45  5111   202     2     3    --    --    --    --     1     3    --    --    --    -- PN, v=0-5 False
# 92646.9106  0.0108 -7.9857     2 2633.9927     5    45  5111   202     2     2    --    --    --    --     1     2    --    --    --    -- PN, v=0-5 False, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#    MHz      MHz   MHz nm2        1 / cm         u
#  float64  float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# --------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 93979.769  0.0011  -2.485     2  1.5674     5    45  5111   202     2     0    --    --    --    --     1     0    --    --    --    -- PN, v=0-5 False, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
#  135946.298  0.1541   -15.5     2 6481.4342     7    45  5111   202     3     5    --    --    --    --     2     5    --    --    --    -- PN, v=0-5 False
# 136957.1156  0.0438 -12.851     2 5213.9136     7    45  5111   202     3     4    --    --    --    --     2     4    --    --    --    -- PN, v=0-5 False, <Table length=2>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 137964.389  0.0232 -10.173     2 3932.4548     7    45  5111   202     3     3    --    --    --    --     2     3    --    --    --    -- PN, v=0-5 False
#  138968.33    0.06 -7.4655     2 2637.0831     7    45  5111   202     3     2    --    --    --    --     2     2    --    --    --    -- PN, v=0-5  True, <Table length=2>
#    FREQ     ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name   Lab
#    MHz      MHz   MHz nm2         1 / cm          u
#  float64  float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9   bool
# --------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- ----
# 138968.33    0.06 -7.4655     2 2637.0831     7    45  5111   202     3     2    --    --    --    --     2     2    --    --    --    -- PN, v=0-5 True
# 139969.38    0.03 -4.7296     2 1327.8238     7    45  5111   202     3     1    --    --    --    --     2     1    --    --    --    -- PN, v=0-5 True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 140967.6923  0.0016 -1.9649     2  4.7023     7    45  5111   202     3     0    --    --    --    --     2     0    --    --    --    -- PN, v=0-5 False, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 271871.0505  0.3077 -14.639     2 6499.5724    13    45  5111   202     6     5    --    --    --    --     5     5    --    --    --    -- PN, v=0-5 False, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 273892.7709  0.0866 -11.991     2 5232.1868    13    45  5111   202     6     4    --    --    --    --     5     4    --    --    --    -- PN, v=0-5 False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
freqs_mom0 = model_and_plot(cubes, temp = 6., N_tot = 1.4e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
                            mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=15, fig_height=5, 
                            nrows=1, ncols=2, parse_loc=False, line_by_line=True, name_for_plot=f'PN', extr_type="coord", crd=crd,
                            show_2_sigma=True, EU_cutoff_K=700, aij_cutoff=-10, return_freqs=True)

# %%
# Get subcubes based on mask
cubes_masked, reg = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False, return_mask=True)

# %%
# Generate the model and plot the model and data spectra
EUs, log_N_upper_gs = model_and_plot(cubes_masked, temp = 6., N_tot = 1.9e+12, v_cen = 13.*u.km/u.s, v_disp = 3.*u.km/u.s,
                                     mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=15, fig_height=5, 
                                     nrows=1, ncols=2, parse_loc=False, line_by_line=True, name_for_plot=f'PN', extr_type="reg", just_data=False,
                                     show_2_sigma=True, EU_cutoff_K=700, aij_cutoff=-10, calc_N_uppers=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs_mom0, v_cen=40*u.km/u.s, fig_width=10, fig_height=5, nrows=1, ncols=2, name_for_plot=f'PN', reg=reg)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs_mom0, v_cen=13*u.km/u.s, fig_width=10, fig_height=5, nrows=1, ncols=2, name_for_plot=f'PN', reg=reg)
