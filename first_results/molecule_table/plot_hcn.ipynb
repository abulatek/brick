# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 27501 # 27001
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name    Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str8    bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -------- -----
# 88631.6022  0.0001  -2.514     2     0.0     9    27   501   101     1    --    --    --    --    --     0    --    --    --    --    -- HCN, v=0 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
# ...

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 5.1e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=10, fig_height=5, 
               nrows=1, ncols=2, parse_loc=False, line_by_line=True, name_for_plot=f'HCN',
               extr_type="coord", crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=True)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 1.2e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=10, fig_height=5, 
                       nrows=1, ncols=2, parse_loc=False, line_by_line=True, name_for_plot=f'HCN', extr_type="reg", 
                       just_data=False, return_freqs=True, show_2_sigma=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=10, fig_height=6, nrows=1, ncols=2, name_for_plot=f'HCN')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=10, fig_height=6, nrows=1, ncols=2, name_for_plot=f'HCN')

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 2, cubes, plot_region=True)

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes_masked, temp = 150., N_tot = 1.0e+14, v_cen = 60.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=10, fig_height=5, 
               nrows=2, ncols=2, parse_loc=False, line_by_line=True, name_for_plot=f'HCN', extr_type="reg", just_data=False)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 3, cubes, plot_region=True)

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes_masked, temp = 150., N_tot = 1.0e+14, v_cen = 60.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=10, fig_height=5, 
               nrows=2, ncols=2, parse_loc=False, line_by_line=True, name_for_plot=f'HCN', extr_type="reg", just_data=False)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 4, cubes, plot_region=True)

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes_masked, temp = 150., N_tot = 1.0e+14, v_cen = 60.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=10, fig_height=5, 
               nrows=2, ncols=2, parse_loc=False, line_by_line=True, name_for_plot=f'HCN', extr_type="reg", just_data=False)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 5, cubes, plot_region=True)

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes_masked, temp = 150., N_tot = 1.0e+14, v_cen = 60.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=10, fig_height=5, 
               nrows=2, ncols=2, parse_loc=False, line_by_line=True, name_for_plot=f'HCN', extr_type="reg", just_data=False)
