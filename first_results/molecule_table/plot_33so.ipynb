# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 49501
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=19>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  98288.945  0.1928 -5.9936     2 23.3442    12    49   501   113     5     4     6    --    --    --     4     4     5    --    --    -- S-33-O False
# 98298.0134  0.0997  -4.755     2 23.3439    12    49   501   113     5     4     6    --    --    --     4     4     6    --    --    -- S-33-O False
# 98335.0019  0.0776 -5.8773     2 23.3446    10    49   501   113     5     4     5    --    --    --     4     4     4    --    --    -- S-33-O False
# 98346.3293  0.0579 -4.8808     2 23.3442    10    49   501   113     5     4     5    --    --    --     4     4     5    --    --    -- S-33-O False
# 98355.3978  0.1552  -5.993     2 23.3439    10    49   501   113     5     4     5    --    --    --     4     4     6    --    --    -- S-33-O False
# 98374.7619  0.1582 -6.0013     2  23.345     8    49   501   113     5     4     4    --    --    --     4     4     3    --    --    -- S-33-O False
# 98386.0043  0.1236 -4.9965     2 23.3446     8    49   501   113     5     4     4    --    --    --     4     4     4    --    --    -- S-33-O False
# 98397.3317  0.1565 -5.8767     2 23.3442     8    49   501   113     5     4     4    --    --    --     4     4     5    --    --    -- S-33-O False
# 98409.8101  0.1241 -5.9846     2  3.0809     6    49   501   113     2     3     3    --    --    --     1     2     4    --    --    -- S-33-O False
# 98416.9524  0.1865 -5.0804     2  23.345     6    49   501   113     5     4     3    --    --    --     4     4     3    --    --    -- S-33-O False
# 98428.1948  0.1915 -6.0008     2 23.3446     6    49   501   113     5     4     3    --    --    --     4     4     4    --    --    -- S-33-O False
# 98433.4064  0.2169 -5.8383     2  3.0794     4    49   501   113     2     3     2    --    --    --     1     2     3    --    --    -- S-33-O False
# 98443.8426  0.0703 -4.6833     2  3.0809     8    49   501   113     2     3     4    --    --    --     1     2     4    --    --    -- S-33-O False
# 98455.1943  0.0981  -4.576     2  3.0794     6    49   501   113     2     3     3    --    --    --     1     2     3    --    --    -- S-33-O False
#  98460.488  0.1129 -4.6919     2  3.0785     4    49   501   113     2     3     2    --    --    --     1     2     2    --    --    -- S-33-O False
#  98474.602    0.03 -4.2939     2   3.078     4    49   501   113     2     3     2    --    --    --     1     2     1    --    --    -- S-33-O  True
#  98482.302    0.03 -4.0897     2  3.0785     6    49   501   113     2     3     3    --    --    --     1     2     2    --    --    -- S-33-O  True
#  98489.232    0.03 -3.9048     2  3.0794     8    49   501   113     2     3     4    --    --    --     1     2     3    --    --    -- S-33-O  True
#  98493.642    0.03 -3.7409     2  3.0809    10    49   501   113     2     3     5    --    --    --     1     2     4    --    --    -- S-33-O  True, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 107925.9974  0.0932 -4.5985     2  10.981     4    49   501   113     3     2     2    --    --    --     2     1     1    --    --    -- S-33-O False
# 107927.2214  0.0692 -4.1972     2 10.9793     6    49   501   113     3     2     3    --    --    --     2     1     2    --    --    -- S-33-O False
# 107953.7971  0.0346 -3.9174     2 10.9762     8    49   501   113     3     2     4    --    --    --     2     1     3    --    --    -- S-33-O False
# 107957.3216  0.0883 -4.5984     2  10.981     2    49   501   113     3     2     1    --    --    --     2     1     1    --    --    -- S-33-O False
# 107977.3607   0.094 -4.4912     2 10.9793     4    49   501   113     3     2     2    --    --    --     2     1     2    --    --    -- S-33-O False
# 108008.6849  0.1379 -5.2973     2 10.9793     2    49   501   113     3     2     1    --    --    --     2     1     2    --    --    -- S-33-O False
# 108019.6674  0.1856  -4.565     2 10.9762     6    49   501   113     3     2     3    --    --    --     2     1     3    --    --    -- S-33-O False
# 108069.8067   0.288  -5.519     2 10.9762     4    49   501   113     3     2     2    --    --    --     2     1     3    --    --    -- S-33-O False, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  127825.464    0.03 -4.1312     2 13.3959     4    49   501   113     3     3     2    --    --    --     2     2     1    --    --    -- S-33-O  True
#  127826.361    0.03 -3.9271     2 13.3955     6    49   501   113     3     3     3    --    --    --     2     2     2    --    --    -- S-33-O  True
#   127832.08    0.03 -3.7422     2 13.3948     8    49   501   113     3     3     4    --    --    --     2     2     3    --    --    -- S-33-O  True
# 127838.7396  0.0584 -4.5291     2 13.3955     4    49   501   113     3     3     2    --    --    --     2     2     2    --    --    -- S-33-O False
#  127842.532    0.03 -3.5784     2  13.394    10    49   501   113     3     3     5    --    --    --     2     2     4    --    --    -- S-33-O  True
# 127846.6417  0.0493 -4.4131     2 13.3948     6    49   501   113     3     3     3    --    --    --     2     2     3    --    --    -- S-33-O False
#  127856.548   0.116 -4.5204     2  13.394     8    49   501   113     3     3     4    --    --    --     2     2     4    --    --    -- S-33-O False
# 127859.0128  0.1078 -5.6752     2 13.3948     4    49   501   113     3     3     2    --    --    --     2     2     3    --    --    -- S-33-O False
# 127871.1157  0.1532 -5.8213     2  13.394     6    49   501   113     3     3     3    --    --    --     2     2     4    --    --    -- S-33-O False, <Table length=10>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 134399.7943  0.2039 -6.0206     2 30.4508    14    49   501   113     6     5     7    --    --    --     5     5     6    --    --    -- S-33-O False
# 134406.0042  0.1099  -4.623     2 30.4506    14    49   501   113     6     5     7    --    --    --     5     5     7    --    --    -- S-33-O False
# 134446.5186  0.0857  -5.901     2 30.4511    12    49   501   113     6     5     6    --    --    --     5     5     5    --    --    -- S-33-O False
# 134455.7693  0.0655 -4.7205     2 30.4508    12    49   501   113     6     5     6    --    --    --     5     5     6    --    --    -- S-33-O False
# 134461.9792    0.16 -6.0202     2 30.4506    12    49   501   113     6     5     6    --    --    --     5     5     7    --    --    -- S-33-O False
# 134487.6932  0.1674 -6.0247     2 30.4514    10    49   501   113     6     5     5    --    --    --     5     5     4    --    --    -- S-33-O False
# 134497.9869  0.1303 -4.8095     2 30.4511    10    49   501   113     6     5     5    --    --    --     5     5     5    --    --    -- S-33-O False
# 134507.2376  0.1666 -5.9006     2 30.4508    10    49   501   113     6     5     5    --    --    --     5     5     6    --    --    -- S-33-O False
# 134532.6028     0.2 -4.8786     2 30.4514     8    49   501   113     6     5     4    --    --    --     5     5     4    --    --    -- S-33-O False
# 134542.8965  0.2073 -6.0243     2 30.4511     8    49   501   113     6     5     4    --    --    --     5     5     5    --    --    -- S-33-O False, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 136855.5131  0.1332 -6.0678     2  6.3663     8    49   501   113     3     4     4    --    --    --     2     3     5    --    --    -- S-33-O False
# 136878.2684  0.2211 -5.9586     2  6.3647     6    49   501   113     3     4     3    --    --    --     2     3     4    --    --    -- S-33-O False
# 136893.8628  0.0753 -4.5236     2  6.3663    10    49   501   113     3     4     5    --    --    --     2     3     5    --    --    -- S-33-O False
# 136905.3197  0.0946 -4.4075     2  6.3647     8    49   501   113     3     4     4    --    --    --     2     3     4    --    --    -- S-33-O False
# 136912.3009  0.1262  -4.527     2  6.3635     6    49   501   113     3     4     3    --    --    --     2     3     3    --    --    -- S-33-O False
#  136934.082    0.03 -3.7329     2  6.3628     6    49   501   113     3     4     3    --    --    --     2     3     2    --    --    -- S-33-O  True
#  136939.357    0.03  -3.606     2  6.3635     8    49   501   113     3     4     4    --    --    --     2     3     3    --    --    -- S-33-O  True
#  136943.672    0.03 -3.4819     2  6.3647    10    49   501   113     3     4     5    --    --    --     2     3     4    --    --    -- S-33-O  True
#  136946.194    0.03 -3.3649     2  6.3663    12    49   501   113     3     4     6    --    --    --     2     3     5    --    --    -- S-33-O  True, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 246155.0045  0.8567 -5.3348     2  6.3663     8    49   501   113     3     2     4    --    --    --     2     3     5    --    --    -- S-33-O False
# 246270.6814  0.7902 -5.4987     2  6.3647     6    49   501   113     3     2     3    --    --    --     2     3     4    --    --    -- S-33-O False
# 246304.7139  0.7709 -6.1689     2  6.3635     6    49   501   113     3     2     3    --    --    --     2     3     3    --    --    -- S-33-O False
# 246354.8532  0.7744 -5.6835     2  6.3635     4    49   501   113     3     2     2    --    --    --     2     3     3    --    --    -- S-33-O False
# 246407.9652  0.7846 -5.8875     2  6.3628     2    49   501   113     3     2     1    --    --    --     2     3     2    --    --    -- S-33-O False, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  249159.167    0.15 -2.9135     2 26.6247    12    49   501   113     6     5     6    --    --    --     5     4     5    --    --    -- S-33-O  True
#  249159.167    0.15 -3.0081     2 26.6264    10    49   501   113     6     5     5    --    --    --     5     4     4    --    --    -- S-33-O  True
#  249160.501    0.07 -2.8222     2 26.6228    14    49   501   113     6     5     7    --    --    --     5     4     6    --    --    -- S-33-O  True
#  249162.273    0.07  -3.103     2 26.6278     8    49   501   113     6     5     4    --    --    --     5     4     3    --    --    -- S-33-O  True
# 249204.4518  0.1174 -4.1541     2 26.6264     8    49   501   113     6     5     4    --    --    --     5     4     4    --    --    -- S-33-O False
# 249210.5445   0.136 -4.0328     2 26.6247    10    49   501   113     6     5     5    --    --    --     5     4     5    --    --    -- S-33-O False
# 249216.4607  0.2142 -4.1523     2 26.6228    12    49   501   113     6     5     6    --    --    --     5     4     6    --    --    -- S-33-O False
# 249255.4542  0.2359 -5.7974     2 26.6247     8    49   501   113     6     5     4    --    --    --     5     4     5    --    --    -- S-33-O False
# 249267.9289  0.3391 -5.8845     2 26.6228    10    49   501   113     6     5     5    --    --    --     5     4     6    --    --    -- S-33-O False, <Table length=10>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 250905.5914   0.253 -6.1569     2  60.296    20    49   501   113     9     8    10    --    --    --     8     8     9    --    --    -- S-33-O False
# 250907.6869  0.1605 -4.4091     2  60.296    20    49   501   113     9     8    10    --    --    --     8     8    10    --    --    -- S-33-O False
# 250953.2361  0.1441  -6.034     2 60.2962    18    49   501   113     9     8     9    --    --    --     8     8     8    --    --    -- S-33-O False
#  250959.163  0.1224 -4.4673     2  60.296    18    49   501   113     9     8     9    --    --    --     8     8     9    --    --    -- S-33-O False
# 250961.2585  0.1947 -6.1567     2  60.296    18    49   501   113     9     8     9    --    --    --     8     8    10    --    --    -- S-33-O False
#  250996.868  0.1988  -6.158     2 60.2965    16    49   501   113     9     8     8    --    --    --     8     8     7    --    --    -- S-33-O False
# 251005.2757  0.1662 -4.5209     2 60.2962    16    49   501   113     9     8     8    --    --    --     8     8     8    --    --    -- S-33-O False
# 251011.2026   0.211 -6.0337     2  60.296    16    49   501   113     9     8     8    --    --    --     8     8     9    --    --    -- S-33-O False
# 251046.0066  0.2364 -4.5671     2 60.2965    14    49   501   113     9     8     7    --    --    --     8     8     7    --    --    -- S-33-O False
# 251054.4143  0.2567 -6.1577     2 60.2962    14    49   501   113     9     8     7    --    --    --     8     8     8    --    --    -- S-33-O False, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  255649.354    0.07 -2.9696     2 30.4514    10    49   501   113     6     6     5    --    --    --     5     5     4    --    --    -- S-33-O  True
#  255649.354    0.07 -2.8929     2 30.4511    12    49   501   113     6     6     6    --    --    --     5     5     5    --    --    -- S-33-O  True
#  255651.184    0.07 -2.8161     2 30.4508    14    49   501   113     6     6     7    --    --    --     5     5     6    --    --    -- S-33-O  True
#  255653.034    0.07 -2.7411     2 30.4506    16    49   501   113     6     6     8    --    --    --     5     5     7    --    --    -- S-33-O  True
# 255657.3932  0.1252 -4.2141     2 30.4506    14    49   501   113     6     6     7    --    --    --     5     5     7    --    --    -- S-33-O False
# 255658.9898  0.0725 -4.0927     2 30.4508    12    49   501   113     6     6     6    --    --    --     5     5     6    --    --    -- S-33-O False
# 255659.2693  0.0959 -4.2151     2 30.4511    10    49   501   113     6     6     5    --    --    --     5     5     5    --    --    -- S-33-O False
# 255665.1997  0.1727 -6.1005     2 30.4506    12    49   501   113     6     6     6    --    --    --     5     5     7    --    --    -- S-33-O False
#   255668.52  0.1513 -6.0279     2 30.4508    10    49   501   113     6     6     5    --    --    --     5     5     6    --    --    -- S-33-O False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 266388.3088  0.8589 -5.4135     2 10.9343    10    49   501   113     4     3     5    --    --    --     3     4     6    --    --    -- S-33-O False
# 266500.4592  0.7844 -5.5305     2 10.9326     8    49   501   113     4     3     4    --    --    --     3     4     5    --    --    -- S-33-O False
# 266589.2042  0.7687 -5.6546     2 10.9313     6    49   501   113     4     3     3    --    --    --     3     4     4    --    --    -- S-33-O False
# 266654.3244  0.7851 -5.7814     2 10.9304     4    49   501   113     4     3     2    --    --    --     3     4     3    --    --    -- S-33-O False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 10., N_tot = 2.0e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=20, 
               nrows=5, ncols=5, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'$^{{33}}$SO', extr_type="coord", crd=crd,
               show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 10., N_tot = 9.3e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=20, 
                       nrows=5, ncols=5, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'$^{{33}}$SO', extr_type="reg", 
                       show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=15, fig_height=15, nrows=6, ncols=5, name_for_plot=f'$^{{33}}$SO')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=15, fig_height=15, nrows=6, ncols=5, name_for_plot=f'$^{{33}}$SO')
