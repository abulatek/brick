# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 57001
catalog = 'JPL'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=3>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
#  86631.078  0.0453 -3.3836     2 14.7407    14 57001   113 7 7 7 6 6 6
# 86631.4383  0.0352 -3.3208     2 14.7406    16 57001   113 7 7 8 6 6 7
# 86633.7543  0.5425 -5.3377     2 14.7406    14 57001   113 7 7 7 6 6 7, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ---------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 88493.4136  0.4577  -5.118     2 38.2705    26 57001   113 131213 121213
# 88524.4817   0.568 -5.1526     2 38.2705    24 57001   113 131212 121212, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 89848.2927  0.8266  -5.348     2 10.2613    16 57001   113 7 8 8 6 7 8
# 89873.9881  0.0306 -3.2722     2 10.2605    16 57001   113 7 8 8 6 7 7
# 89875.5162  0.0287 -3.2174     2 10.2613    18 57001   113 7 8 9 6 7 8, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 95182.2743  0.0236 -3.2408     2 15.7528    16 57001   113 8 7 8 7 6 7
# 95183.7837  0.0307 -3.3035     2 15.7537    14 57001   113 8 7 7 7 6 6
# 95210.2857  1.2535 -5.2577     2 15.7528    14 57001   113 8 7 7 7 6 7, <Table length=5>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str6   str6
# ---------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 99006.2727  0.0344 -3.2091     2 17.6304    16 57001   113  8 8 8  7 7 7
# 99006.5472  0.0282 -3.1544     2 17.6303    18 57001   113  8 8 9  7 7 8
# 99008.5887  0.4748 -5.2845     2 17.6303    16 57001   113  8 8 8  7 7 8
# 99281.3681  0.4692 -5.0725     2 43.6368    28 57001   113 141314 131314
# 99313.0323  0.5807 -5.1046     2 43.6368    26 57001   113 141313 131313, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 101749.5273  0.8718  -5.298     2 13.2593    18 57001   113 8 9 9 7 8 9
# 101776.7507  0.0261 -3.1158     2 13.2583    18 57001   113 8 9 9 7 8 8
# 101778.0024  0.0247 -3.0672     2 13.2593    20 57001   113 8 910 7 8 9, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 101749.5273  0.8718  -5.298     2 13.2593    18 57001   113 8 9 9 7 8 9
# 101776.7507  0.0261 -3.1158     2 13.2583    18 57001   113 8 9 9 7 8 8
# 101778.0024  0.0247 -3.0672     2 13.2593    20 57001   113 8 910 7 8 9, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 108136.3719  0.0194 -3.0801     2 18.9278    18 57001   113 9 8 9 8 7 8
# 108137.6255  0.0239 -3.1349     2 18.9287    16 57001   113 9 8 8 8 7 7
# 108165.6369  1.2444 -5.2103     2 18.9278    16 57001   113 9 8 8 8 7 8, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str6   str6
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 110252.9317  0.4794 -5.0337     2 49.4157    30 57001   113 151415 141415
# 110285.0997  0.5918 -5.0635     2 49.4158    28 57001   113 151414 141414
# 111381.1484  0.0273 -3.0579     2 20.9329    18 57001   113  9 9 9  8 8 8
# 111381.3646  0.0235 -3.0093     2 20.9328    20 57001   113  9 910  8 8 9
#   111383.19  0.4222 -5.2396     2 20.9328    18 57001   113  9 9 9  8 8 9, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 113736.4966  0.9094 -5.2545     2 16.6542    20 57001   113 91010 8 910
# 113764.9717  0.0224 -2.9778     2 16.6533    20 57001   113 91010 8 9 9
# 113766.0017  0.0215 -2.9341     2 16.6542    22 57001   113 91011 8 910, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ -----
# 125791.9115  0.9407 -5.2168     2  20.449    22 57001   113 101111 91011
# 125821.4166  0.0196 -2.8548     2  20.448    22 57001   113 101111 91010
# 125822.2692   0.019 -2.8152     2  20.449    24 57001   113 101112 91011, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64   str6
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 132637.8495  0.4978 -4.9721     2 62.2118    34 57001   113 171617 161617
# 132670.8135  0.6109 -4.9983     2 62.2118    32 57001   113 171616 161616
#   133744.26  0.0145 -2.8176     2 26.5704    22 57001   113 111011 10 910
# 133745.1153  0.0169 -2.8612     2 26.5714    20 57001   113 111010 10 9 9, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64   str6
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
#   133744.26  0.0145 -2.8176     2 26.5704    22 57001   113 111011 10 910
# 133745.1153  0.0169 -2.8612     2 26.5714    20 57001   113 111010 10 9 9
# 133775.4158  1.2398 -5.1377     2 26.5704    20 57001   113 111010 10 910, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 136129.8164  0.0196 -2.8068     2 28.7762    22 57001   113 111111 101010
# 136129.9605  0.0182 -2.7671     2 28.7761    24 57001   113 111112 101011
# 136131.4671  0.3457 -5.1683     2 28.7761    22 57001   113 111111 101011, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 137901.9001  0.9672 -5.1839     2  24.646    24 57001   113 111212 101112
# 137932.2578  0.0174 -2.7444     2  24.645    24 57001   113 111212 101111
# 137932.9682  0.0171  -2.708     2  24.646    26 57001   113 111213 101112, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 144008.8598  0.5065  -4.948     2 69.2288    36 57001   113 181718 171718
# 144042.1405  0.6194 -4.9727     2 69.2288    34 57001   113 181717 171717, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 144008.8598  0.5065  -4.948     2 69.2288    36 57001   113 181718 171718
# 144042.1405  0.6194 -4.9727     2 69.2288    34 57001   113 181717 171717, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 146436.0929  0.0133 -2.7081     2 31.0316    24 57001   113 121112 111011
# 146436.8014  0.0151 -2.7478     2 31.0327    22 57001   113 121111 111010
# 146467.9572    1.24 -5.1095     2 31.0316    22 57001   113 121111 111011, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 148503.5392  0.0174 -2.7008     2  33.317    24 57001   113 121212 111111
# 148503.6601  0.0168 -2.6645     2 33.3169    26 57001   113 121213 111112
# 148505.0458   0.317   -5.14     2 33.3169    24 57001   113 121212 111112, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 150055.4779  0.9896 -5.1554     2  29.247    26 57001   113 121313 111213
#  150086.546  0.0157 -2.6446     2 29.2459    26 57001   113 121313 111212
# 150087.1422  0.0157 -2.6111     2  29.247    28 57001   113 121314 111213, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 246656.6408  0.0161 -2.1325     2 81.8446    40 57001   113 201920 191819
# 246656.8323  0.0162 -2.1554     2 81.8457    38 57001   113 201919 191818
#  246691.323  1.2431 -5.0018     2 81.8446    38 57001   113 201919 191819, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 247473.7936  0.0123 -2.1355     2 84.5007    40 57001   113 202020 191919
#  247473.837  0.0124 -2.1137     2 84.5007    42 57001   113 202021 191920
#  247474.681  0.1904 -5.0268     2 84.5007    40 57001   113 202020 191920
# 248116.4871  1.0889 -5.0374     2  80.724    42 57001   113 202121 192021
#  248150.492  0.0116 -2.1028     2 80.7228    42 57001   113 202121 192020
# 248150.6773  0.0118 -2.0821     2  80.724    44 57001   113 202122 192021
# 248317.3455  1.5663 -6.1309     2 58.3531    34 57001   113 171617 161718
# 248384.6392  1.4817 -6.1565     2  58.352    32 57001   113 171616 161717, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64  int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 249505.9199  0.6059 -4.8679     2 150.9474    54 57001   113 272627 262627
# 249540.7728  0.7044 -4.8842     2 150.9474    52 57001   113 272626 262626
# 249639.9355  1.3105 -4.6553     2   20.449    22 57001   113 101011  91011
# 249671.0913  1.2021 -4.6969     2   20.448    20 57001   113 101010  91010, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 256657.6252  1.4773 -5.0204     2  2.1565    10 57001   113 5 4 5 2 3 4
# 256695.7361  1.4312 -5.1333     2   2.156     8 57001   113 5 4 4 2 3 3, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 259842.0732  0.0125 -2.0889     2 92.7555    42 57001   113 212121 202020
# 259842.1125  0.0126 -2.0682     2 92.7555    44 57001   113 212122 202021
# 259842.9172  0.1813 -5.0232     2 92.7555    42 57001   113 212121 202021
# 259947.6268  1.3066 -4.6361     2  24.646    24 57001   113 111112 101112
# 259979.4911  1.1969  -4.674     2  24.645    22 57001   113 111111 101111
# 260427.6713  1.0959 -5.0332     2 89.0014    44 57001   113 212222 202122
# 260461.8614  0.0121 -2.0576     2 89.0003    44 57001   113 212222 202121
# 260462.0255  0.0122 -2.0379     2 89.0014    46 57001   113 212223 202122, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64  int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 261448.0896  0.6217 -4.8704     2 162.0895    56 57001   113 282728 272728
# 261483.0377  0.7173 -4.8861     2 162.0896    54 57001   113 282727 272727, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 270518.3188  1.3042 -4.6201     2  29.247    26 57001   113 121213 111213
# 270550.7726  1.1936  -4.655     2 29.2459    24 57001   113 121212 111212, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64  int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 271530.6778  0.0186 -2.0424     2  98.7148    44 57001   113 222122 212021
# 271530.8237  0.0186 -2.0632     2  98.7159    42 57001   113 222121 212020
# 271565.6727  1.2425 -4.9977     2  98.7148    42 57001   113 222121 212021
# 272209.5602  0.0132 -2.0462     2 101.4229    44 57001   113 222222 212121
#  272209.596  0.0131 -2.0264     2 101.4229    46 57001   113 222223 212122
#  272210.365   0.173 -5.0214     2 101.4229    44 57001   113 222222 212122
# 272744.6582  1.1022 -5.0309     2  97.6895    46 57001   113 222323 212223
# 272779.0124   0.013 -2.0162     2  97.6883    46 57001   113 222323 212222
# 272779.1584   0.013 -1.9973     2  97.6895    48 57001   113 222324 212223, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64  int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 273418.0561  0.6387 -4.8747     2 173.6441    58 57001   113 292829 282829
# 273453.0906  0.7313 -4.8898     2 173.6441    56 57001   113 292828 282828]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
               nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-4)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
                       nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-4)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
