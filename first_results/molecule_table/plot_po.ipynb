# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 47507
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=6>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- ----
# 108707.192    0.02 -4.4479     2  2.2178     5    47  5071   325     3    -1     0     3     2    --     2     1     0     2     2    -- PO, v=0 True
# 108998.445    0.02 -3.3032     2  2.1953     7    47  5071   325     3     1     0     3     3    --     2    -1     0     2     2    -- PO, v=0 True
# 109045.396    0.02 -3.4951     2  2.2028     5    47  5071   325     3     1     0     3     2    --     2    -1     0     2     1    -- PO, v=0 True
#   109206.2    0.02 -3.3018     2  2.2178     7    47  5071   325     3    -1     0     3     3    --     2     1     0     2     2    -- PO, v=0 True
# 109271.376    0.02 -4.4493     2  2.1953     5    47  5071   325     3     1     0     3     2    --     2    -1     0     2     2    -- PO, v=0 True
# 109281.189    0.02 -3.4936     2  2.1987     5    47  5071   325     3    -1     0     3     2    --     2     1     0     2     1    -- PO, v=0 True, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 109589.1009  0.0471 -5.0822     2  224.742     5    47  5071   325     2    -1     0     3     2    --     1     1     0     2     2    -- PO, v=0 False
# 109589.1924  0.0471 -5.0822     2  224.742     5    47  5071   325     2     1     0     3     2    --     1    -1     0     2     2    -- PO, v=0 False
#  109829.923    0.02 -3.9361     2  224.742     7    47  5071   325     2    -1     0     3     3    --     1     1     0     2     2    -- PO, v=0  True
#  109829.923    0.02 -3.9361     2  224.742     7    47  5071   325     2     1     0     3     3    --     1    -1     0     2     2    -- PO, v=0  True
#  109966.036    0.02  -4.128     2 224.7295     5    47  5071   325     2    -1     0     3     2    --     1     1     0     2     1    -- PO, v=0  True
#  109966.036    0.02  -4.128     2 224.7295     5    47  5071   325     2     1     0     3     2    --     1    -1     0     2     1    -- PO, v=0  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- ----
# 152389.058    0.01 -4.3111     2  5.8605     7    47  5071   325     4     1     0     4     3    --     3    -1     0     3     3    -- PO, v=0 True, <Table length=11>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  152656.979    0.02 -2.8807     2   5.8311     9    47  5071   325     4    -1     0     4     4    --     3     1     0     3     3    -- PO, v=0  True
#  152680.282    0.02 -3.0111     2   5.8402     7    47  5071   325     4    -1     0     4     3    --     3     1     0     3     2    -- PO, v=0  True
#  152855.454    0.02 -2.8797     2   5.8605     9    47  5071   325     4     1     0     4     4    --     3    -1     0     3     3    -- PO, v=0  True
#  152888.128    0.02   -3.01     2   5.8439     7    47  5071   325     4     1     0     4     3    --     3    -1     0     3     2    -- PO, v=0  True
#  152953.247    0.01 -4.3121     2   5.8311     7    47  5071   325     4    -1     0     4     3    --     3     1     0     3     3    -- PO, v=0  True
# 153616.3125  0.0405 -4.8484     2 228.4056     7    47  5071   325     3     1     0     4     3    --     2    -1     0     3     3    -- PO, v=0 False
# 153616.4953  0.0405 -4.8484     2 228.4056     7    47  5071   325     3    -1     0     4     3    --     2     1     0     3     3    -- PO, v=0 False
#   153793.52    0.01  -3.417     2 228.4056     9    47  5071   325     3     1     0     4     4    --     2    -1     0     3     3    -- PO, v=0  True
#   153793.52    0.01  -3.417     2 228.4056     9    47  5071   325     3    -1     0     4     4    --     2     1     0     3     3    -- PO, v=0  True
#  153857.155    0.01 -3.5473     2 228.3975     7    47  5071   325     3     1     0     4     3    --     2    -1     0     3     2    -- PO, v=0  True
#  153857.155    0.01 -3.5473     2 228.3975     7    47  5071   325     3    -1     0     4     3    --     2     1     0     3     2    -- PO, v=0  True, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- ----
#  241688.35    0.01 -2.8175     2 240.1316    13    47  5071   325     5     1     0     6     6    --     4    -1     0     5     5    -- PO, v=0 True
#  241688.35    0.01 -2.8175     2 240.1316    13    47  5071   325     5    -1     0     6     6    --     4     1     0     5     5    -- PO, v=0 True
# 241713.168    0.01  -2.898     2 240.1269    11    47  5071   325     5     1     0     6     5    --     4    -1     0     5     4    -- PO, v=0 True
# 241713.168    0.01  -2.898     2 240.1269    11    47  5071   325     5    -1     0     6     5    --     4     1     0     5     4    -- PO, v=0 True]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
freqs_mom0 = model_and_plot(cubes, temp = 50., N_tot = 6.1e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
                            mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=10, 
                            nrows=3, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'PO', extr_type="coord", crd=crd,
                            show_2_sigma=True, EU_cutoff_K=100, aij_cutoff=-10, return_freqs=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
EUs, log_N_upper_gs = model_and_plot(cubes_masked, temp = 50., N_tot = 6.5e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                                     mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=10, 
                                     nrows=3, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'PO', extr_type="reg", just_data=False,
                                     show_2_sigma=True, EU_cutoff_K=100, aij_cutoff=-10, calc_N_uppers=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs_mom0, v_cen=40*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=f'PO')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs_mom0, v_cen=12*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=f'PO')
