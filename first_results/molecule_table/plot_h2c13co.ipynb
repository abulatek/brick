# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 43505
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 87087.4985  0.2427 -5.9024     3 163.2834   129    43   505   303    21     1    20    --    --    --    21     1    21    --    --    -- H2CC-13-O False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 95367.6522  0.2974  -5.874     3 177.965   135    43   505   303    22     1    21    --    --    --    22     1    22    --    --    -- H2CC-13-O False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
#  100097.638    0.03 -3.7629     3  15.7496    33    43   505   303     5     1     5    --    --    --     4     1     4    --    --    -- H2CC-13-O  True
# 100970.5051  0.0044 -4.9417     3 151.7008    11    43   505   303     5     4     1    --    --    --     4     4     0    --    --    -- H2CC-13-O False
# 100970.5051  0.0044 -4.9417     3 151.7008    11    43   505   303     5     4     2    --    --    --     4     4     1    --    --    -- H2CC-13-O False
#  101005.406    0.05 -4.0824     3  88.3288    33    43   505   303     5     3     3    --    --    --     4     3     2    --    --    -- H2CC-13-O  True
#  101005.406    0.05 -4.0824     3  88.3288    33    43   505   303     5     3     2    --    --    --     4     3     1    --    --    -- H2CC-13-O  True
# 101027.5453  0.0045 -4.3468     3  43.0175    11    43   505   303     5     2     4    --    --    --     4     2     3    --    --    -- H2CC-13-O False
# 101035.3481  0.0045 -4.3467     3  43.0177    11    43   505   303     5     2     3    --    --    --     4     2     2    --    --    -- H2CC-13-O False
#  101039.646    0.05 -4.1954     3    6.741    11    43   505   303     5     0     5    --    --    --     4     0     4    --    --    -- H2CC-13-O  True, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 100970.5051  0.0044 -4.9417     3 151.7008    11    43   505   303     5     4     1    --    --    --     4     4     0    --    --    -- H2CC-13-O False
# 100970.5051  0.0044 -4.9417     3 151.7008    11    43   505   303     5     4     2    --    --    --     4     4     1    --    --    -- H2CC-13-O False
#  101005.406    0.05 -4.0824     3  88.3288    33    43   505   303     5     3     3    --    --    --     4     3     2    --    --    -- H2CC-13-O  True
#  101005.406    0.05 -4.0824     3  88.3288    33    43   505   303     5     3     2    --    --    --     4     3     1    --    --    -- H2CC-13-O  True
# 101027.5453  0.0045 -4.3468     3  43.0175    11    43   505   303     5     2     4    --    --    --     4     2     3    --    --    -- H2CC-13-O False
# 101035.3481  0.0045 -4.3467     3  43.0177    11    43   505   303     5     2     3    --    --    --     4     2     2    --    --    -- H2CC-13-O False
#  101039.646    0.05 -4.1954     3    6.741    11    43   505   303     5     0     5    --    --    --     4     0     4    --    --    -- H2CC-13-O  True
# 101984.5436   0.005  -3.747     3  15.8755    33    43   505   303     5     1     4    --    --    --     4     1     3    --    --    -- H2CC-13-O False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 101984.5436   0.005  -3.747     3 15.8755    33    43   505   303     5     1     4    --    --    --     4     1     3    --    --    -- H2CC-13-O False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 101984.5436   0.005  -3.747     3 15.8755    33    43   505   303     5     1     4    --    --    --     4     1     3    --    --    -- H2CC-13-O False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 104020.8085  0.3608 -5.8496     3 193.313   141    43   505   303    23     1    22    --    --    --    23     1    23    --    --    -- H2CC-13-O False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 113046.3052  0.4336 -5.8289     3 209.3272   147    43   505   303    24     1    23    --    --    --    24     1    24    --    --    -- H2CC-13-O False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 113046.3052  0.4336 -5.8289     3 209.3272   147    43   505   303    24     1    23    --    --    --    24     1    24    --    --    -- H2CC-13-O False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 132211.2918   0.611 -5.7981     3 243.3539   159    43   505   303    26     1    25    --    --    --    26     1    26    --    --    -- H2CC-13-O False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 140131.8046  0.0062 -3.3325     3 23.0951    45    43   505   303     7     1     7    --    --    --     6     1     6    --    --    -- H2CC-13-O False, <Table length=11>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 141212.6269  0.0089 -5.0298     3 339.7599    15    43   505   303     7     6     1    --    --    --     6     6     0    --    --    -- H2CC-13-O False
# 141212.6269  0.0089 -5.0298     3 339.7599    15    43   505   303     7     6     2    --    --    --     6     6     1    --    --    -- H2CC-13-O False
# 141293.1436  0.0064 -4.0791     3 240.4769    45    43   505   303     7     5     2    --    --    --     6     5     1    --    --    -- H2CC-13-O False
# 141293.1436  0.0064 -4.0791     3 240.4769    45    43   505   303     7     5     3    --    --    --     6     5     2    --    --    -- H2CC-13-O False
# 141357.2639  0.0056 -4.2481     3 159.1104    15    43   505   303     7     4     4    --    --    --     6     4     3    --    --    -- H2CC-13-O False
#  141357.264  0.0056 -4.2481     3 159.1104    15    43   505   303     7     4     3    --    --    --     6     4     2    --    --    -- H2CC-13-O False
#  141406.855  0.0056 -3.5551     3   95.741    45    43   505   303     7     3     5    --    --    --     6     3     4    --    --    -- H2CC-13-O False
# 141406.8864  0.0056 -3.5551     3   95.741    45    43   505   303     7     3     4    --    --    --     6     3     3    --    --    -- H2CC-13-O False
# 141434.5684  0.0056 -3.8866     3  50.4313    15    43   505   303     7     2     6    --    --    --     6     2     5    --    --    -- H2CC-13-O False
# 141442.3955  0.0065  -3.774     3  14.1556    15    43   505   303     7     0     7    --    --    --     6     0     6    --    --    -- H2CC-13-O False
# 141456.4144  0.0057 -3.8864     3  50.4322    15    43   505   303     7     2     5    --    --    --     6     2     4    --    --    -- H2CC-13-O False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 142349.0604  0.7174 -5.7876     3 261.3661   165    43   505   303    27     1    26    --    --    --    27     1    27    --    --    -- H2CC-13-O False
# 142773.2961  0.0062 -3.3169     3  23.3595    45    43   505   303     7     1     6    --    --    --     6     1     5    --    --    -- H2CC-13-O False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 152855.7146  0.8368 -5.7803     3 280.044   171    43   505   303    28     1    27    --    --    --    28     1    28    --    --    -- H2CC-13-O False, <Table length=15>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 241688.0928   0.055 -4.5991     3 621.9035    25    43   505   303    12     8     4    --    --    --    11     8     3    --    --    -- H2CC-13-O False
# 241688.0928   0.055 -4.5991     3 621.9035    25    43   505   303    12     8     5    --    --    --    11     8     4    --    --    -- H2CC-13-O False
#  241896.026    0.03 -3.7659     3 487.1211    75    43   505   303    12     7     5    --    --    --    11     7     4    --    --    -- H2CC-13-O  True
#  241896.026    0.03 -3.7659     3 487.1211    75    43   505   303    12     7     6    --    --    --    11     7     5    --    --    -- H2CC-13-O  True
#   242066.44    0.03 -3.9428     3 370.0401    25    43   505   303    12     6     6    --    --    --    11     6     5    --    --    -- H2CC-13-O  True
#   242066.44    0.03 -3.9428     3 370.0401    25    43   505   303    12     6     7    --    --    --    11     6     6    --    --    -- H2CC-13-O  True
#  242205.283    0.03 -3.2164     3 270.7744    75    43   505   303    12     5     7    --    --    --    11     5     6    --    --    -- H2CC-13-O  True
#  242205.283    0.03 -3.2164     3 270.7744    75    43   505   303    12     5     8    --    --    --    11     5     7    --    --    -- H2CC-13-O  True
#  242316.949    0.03  -3.492     3 189.4217    25    43   505   303    12     4     9    --    --    --    11     4     8    --    --    -- H2CC-13-O  True
#  242316.949    0.03  -3.492     3 189.4217    25    43   505   303    12     4     8    --    --    --    11     4     7    --    --    -- H2CC-13-O  True
#  242383.162    0.03 -3.1387     3  44.4812    25    43   505   303    12     0    12    --    --    --    11     0    11    --    --    -- H2CC-13-O  True
#  242405.979    0.03 -2.8594     3 126.0631    75    43   505   303    12     3    10    --    --    --    11     3     9    --    --    -- H2CC-13-O  True
#  242406.497    0.03 -2.8594     3 126.0631    75    43   505   303    12     3     9    --    --    --    11     3     8    --    --    -- H2CC-13-O  True
#   242432.16    0.03 -3.2263     3  80.7583    25    43   505   303    12     2    11    --    --    --    11     2    10    --    --    -- H2CC-13-O  True
#  242543.659    0.03 -3.2259     3  80.7676    25    43   505   303    12     2    10    --    --    --    11     2     9    --    --    -- H2CC-13-O  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- ----
# 244719.714    0.03 -2.6761     3 53.9732    75    43   505   303    12     1    11    --    --    --    11     1    10    --    --    -- H2CC-13-O True, <Table length=5>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
#  260200.043    0.03 -2.6031     3   61.1545    81    43   505   303    13     1    13    --    --    --    12     1    12    --    --    -- H2CC-13-O  True
# 260784.8191    1.05 -5.3905     3 1139.1156    81    43   505   303    13    11     2    --    --    --    12    11     1    --    --    -- H2CC-13-O False
# 260784.8191    1.05 -5.3905     3 1139.1156    81    43   505   303    13    11     3    --    --    --    12    11     2    --    --    -- H2CC-13-O False
# 261210.0648  0.4912  -5.319     3  952.0807    27    43   505   303    13    10     3    --    --    --    12    10     2    --    --    -- H2CC-13-O False
# 261210.0648  0.4912  -5.319     3  952.0807    27    43   505   303    13    10     4    --    --    --    12    10     3    --    --    -- H2CC-13-O False, <Table length=19>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 261210.0648  0.4912  -5.319     3 952.0807    27    43   505   303    13    10     3    --    --    --    12    10     2    --    --    -- H2CC-13-O False
# 261210.0648  0.4912  -5.319     3 952.0807    27    43   505   303    13    10     4    --    --    --    12    10     3    --    --    -- H2CC-13-O False
# 261549.7589  0.1957 -4.3816     3 782.3107    81    43   505   303    13     9     4    --    --    --    12     9     3    --    --    -- H2CC-13-O False
# 261549.7589  0.1957 -4.3816     3 782.3107    81    43   505   303    13     9     5    --    --    --    12     9     4    --    --    -- H2CC-13-O False
#   261825.13  0.0589 -4.4638     3 629.9653    27    43   505   303    13     8     5    --    --    --    12     8     4    --    --    -- H2CC-13-O False
#   261825.13  0.0589 -4.4638     3 629.9653    27    43   505   303    13     8     6    --    --    --    12     8     5    --    --    -- H2CC-13-O False
#  262050.428    0.03 -3.6472     3 495.1899    81    43   505   303    13     7     6    --    --    --    12     7     5    --    --    -- H2CC-13-O  True
#  262050.428    0.03 -3.6472     3 495.1899    81    43   505   303    13     7     7    --    --    --    12     7     6    --    --    -- H2CC-13-O  True
#  262235.139    0.03 -3.8352     3 378.1145    27    43   505   303    13     6     7    --    --    --    12     6     6    --    --    -- H2CC-13-O  True
#  262235.139    0.03 -3.8352     3 378.1145    27    43   505   303    13     6     8    --    --    --    12     6     7    --    --    -- H2CC-13-O  True
#  262385.782    0.03 -3.1163     3 278.8535    81    43   505   303    13     5     8    --    --    --    12     5     7    --    --    -- H2CC-13-O  True
#  262385.782    0.03 -3.1163     3 278.8535    81    43   505   303    13     5     9    --    --    --    12     5     8    --    --    -- H2CC-13-O  True
#  262507.258    0.03 -3.3973     3 197.5046    27    43   505   303    13     4    10    --    --    --    12     4     9    --    --    -- H2CC-13-O  True
#  262507.258    0.03 -3.3973     3 197.5046    27    43   505   303    13     4     9    --    --    --    12     4     8    --    --    -- H2CC-13-O  True
#  262556.256    0.03  -3.052     3  52.5662    27    43   505   303    13     0    13    --    --    --    12     0    12    --    --    -- H2CC-13-O  True
#  262604.825    0.05 -2.7684     3 134.1489    81    43   505   303    13     3    11    --    --    --    12     3    10    --    --    -- H2CC-13-O  True
#  262605.566    0.05 -2.7684     3  134.149    81    43   505   303    13     3    10    --    --    --    12     3     9    --    --    -- H2CC-13-O  True
#    262627.1    0.03 -3.1378     3   88.845    27    43   505   303    13     2    12    --    --    --    12     2    11    --    --    -- H2CC-13-O  True
#  262768.983    0.03 -3.1373     3   88.858    27    43   505   303    13     2    11    --    --    --    12     2    10    --    --    -- H2CC-13-O  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- ----
# 265103.143    0.03 -2.5891     3 62.1362    81    43   505   303    13     1    12    --    --    --    12     1    11    --    --    -- H2CC-13-O True]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
               nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-5)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
                       nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-5)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [8], in <cell line: 2>()
#       1 # Plot moment maps
# ----> 2 plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
#
# File /blue/adamginsburg/abulatek/brick/first_results/molecule_table/mol_model.py:289, in plot_mom0s(cubes, freqs, v_cen, fig_width, fig_height, nrows, ncols, name_for_plot, reg, y, v_half)
#     287 for freq in freqs:
#     288     if molcube.spectral_axis.min() <= freq <= molcube.spectral_axis.max():
# --> 289         ax = plt.subplot(nrows, ncols, ind+1)
#     290         # Make moment map of line
#     291         # molcube = molcube - molcube.median(axis=0, iterate_rays=True) # Continuum subtraction
#     292         molcube_slice = molcube.with_spectral_unit(unit=u.km/u.s, velocity_convention='radio',
#     293                                                    rest_value=freq).spectral_slab(v_cen - v_half*u.km/u.s, v_cen + v_half*u.km/u.s)
#
# File /blue/adamginsburg/abulatek/miniconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File /blue/adamginsburg/abulatek/miniconda3/lib/python3.9/site-packages/matplotlib/gridspec.py:598, in SubplotSpec._from_subplot_args(figure, args)
#     596 else:
#     597     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 598         raise ValueError(
#     599             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     600             f"not {num!r}"
#     601         )
#     602     i = j = num
#     603 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 12, not 13

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
