# %%
# %run full_model-Copy2.py
# Out:
# ...
#   0%|          | 0/2 [00:00<?, ?it/s]
# This molecule is producing all NaNs: HC5N
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /blue/adamginsburg/abulatek/brick/first_results/molecule_table/full_model-Copy2.py:362
#     360 from scipy import stats
#     361 kde_c_L = stats.gaussian_kde(rs_freqs_c_L, bw_method=0.01)
# --> 362 kde_c_U = stats.gaussian_kde(rs_freqs_c_U, bw_method=0.01)
#     363 kde_f_L = stats.gaussian_kde(rs_freqs_f_L, bw_method=0.01)
#     364 kde_f_U = stats.gaussian_kde(rs_freqs_f_U, bw_method=0.01)
#
# File /blue/adamginsburg/adamginsburg/miniconda3/envs/python312/lib/python3.12/site-packages/scipy/stats/_kde.py:202, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     200 self.dataset = atleast_2d(asarray(dataset))
#     201 if not self.dataset.size > 1:
# --> 202     raise ValueError("`dataset` input should have multiple elements.")
# ...
