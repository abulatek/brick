# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 38508
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=3>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  85656.431   0.017 -3.7068     3  17.3465    27    38   508   303     4     3     2    --    --    --     4     2     3    --    --    -- c-C3H2  True
# 86125.9322  0.0028 -3.7959     3 224.1423    29    38   508   303    14    11     3    --    --    --    14    10     4    --    --    -- c-C3H2 False
# 87385.4191  0.0039 -3.8933     3 119.2255    21    38   508   303    10     9     1    --    --    --    10     8     2    --    --    -- c-C3H2 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 87435.3181  0.0019 -4.0439     3 28.5379    11    38   508   303     5     4     2    --    --    --     5     3     3    --    --    -- c-C3H2 False, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 89790.6516   0.003 -3.2677     3 138.2092    69    38   508   303    11     8     3    --    --    --    11     7     4    --    --    -- c-C3H2 False
# 90344.0819  0.0018 -3.4688     3  41.9623    39    38   508   303     6     5     2    --    --    --     6     4     3    --    --    -- c-C3H2 False, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  92814.098   0.004 -3.3103     3 257.0692    93    38   508   303    15    12     3    --    --    --    15    11     4    --    --    -- c-C3H2 False
# 93147.5341   0.004 -4.0833     3    79.29    17    38   508   303     8     8     0    --    --    --     8     7     1    --    --    -- c-C3H2 False
# 93162.0082  0.0025 -4.0775     3  60.7785    15    38   508   303     7     7     1    --    --    --     7     6     2    --    --    -- c-C3H2 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 94613.9847  0.0017 -3.8696     3 57.6225    15    38   508   303     7     6     2    --    --    --     7     5     3    --    --    -- c-C3H2 False, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 95971.8012  0.0043 -3.3003     3 196.1635    81    38   508   303    13    11     2    --    --    --    13    10     3    --    --    -- c-C3H2 False
# 95975.1825  0.0035 -3.7193     3 113.8264    21    38   508   303    10     7     3    --    --    --    10     6     4    --    --    -- c-C3H2 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 100400.778   0.006 -3.3295     3 75.5237    51    38   508   303     8     7     2    --    --    --     8     6     3    --    --    -- c-C3H2 True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 100400.778   0.006 -3.3295     3 75.5237    51    38   508   303     8     7     2    --    --    --     8     6     3    --    --    -- c-C3H2 True, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 102505.9563  0.0036 -3.2251     3  91.5975    57    38   508   303     9     6     3    --    --    --     9     5     4    --    --    -- c-C3H2 False
# 103127.1093  0.0033 -3.2967     3 326.0726   105    38   508   303    17    13     4    --    --    --    17    12     5    --    --    -- c-C3H2 False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 102505.9563  0.0036 -3.2251     3  91.5975    57    38   508   303     9     6     3    --    --    --     9     5     4    --    --    -- c-C3H2 False
# 103127.1093  0.0033 -3.2967     3 326.0726   105    38   508   303    17    13     4    --    --    --    17    12     5    --    --    -- c-C3H2 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 103943.9084  0.0051 -3.7681     3 292.1802    33    38   508   303    16    13     3    --    --    --    16    12     4    --    --    -- c-C3H2 False
# 104654.7038  0.0043 -3.3278     3 143.6053    69    38   508   303    11    10     1    --    --    --    11     9     2    --    --    -- c-C3H2 False
#  104904.155   0.009 -3.5226     3  78.8727    51    38   508   303     8     8     1    --    --    --     8     7     2    --    --    -- c-C3H2  True
# 104990.8379  0.0032 -3.7246     3 288.6781    33    38   508   303    16    12     4    --    --    --    16    11     5    --    --    -- c-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 105633.1492  0.0043 -3.8096     3 365.5836    37    38   508   303    18    14     4    --    --    --    18    13     5    --    --    -- c-C3H2 False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 107767.7369   0.002 -3.7536     3 95.6739    19    38   508   303     9     8     2    --    --    --     9     7     3    --    --    -- c-C3H2 False
# 108226.8682  0.0034 -3.7018     3 71.5448    17    38   508   303     8     5     3    --    --    --     8     4     4    --    --    -- c-C3H2 False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 109873.8163  0.0046   -3.51     3  99.5386    57    38   508   303     9     9     0    --    --    --     9     8     1    --    --    -- c-C3H2 False
# 110324.6151  0.0036 -3.1892     3 253.3892    93    38   508   303    15    11     4    --    --    --    15    10     5    --    --    -- c-C3H2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  112490.769  0.0031 -3.2499     3  53.6879    45    38   508   303     7     4     3    --    --    --     7     3     4    --    --    -- c-C3H2 False
# 112813.5178  0.0049 -3.7209     3 227.0151    29    38   508   303    14    12     2    --    --    --    14    11     3    --    --    -- c-C3H2 False
# 112961.5606  0.0056  -3.354     3 407.2365   117    38   508   303    19    15     4    --    --    --    19    14     5    --    --    -- c-C3H2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  112490.769  0.0031 -3.2499     3  53.6879    45    38   508   303     7     4     3    --    --    --     7     3     4    --    --    -- c-C3H2 False
# 112813.5178  0.0049 -3.7209     3 227.0151    29    38   508   303    14    12     2    --    --    --    14    11     3    --    --    -- c-C3H2 False
# 112961.5606  0.0056  -3.354     3 407.2365   117    38   508   303    19    15     4    --    --    --    19    14     5    --    --    -- c-C3H2 False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 114428.3711  0.0024 -5.4585     3 13.5296    27    38   508   303     4     2     3    --    --    --     3     3     0    --    --    -- c-C3H2 False
# 115231.8909  0.0029 -3.7887     3 38.0415    13    38   508   303     6     3     3    --    --    --     6     2     4    --    --    -- c-C3H2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 126062.5419  0.0042 -3.0711     3 189.1633    81    38   508   303    13     9     4    --    --    --    13     8     5    --    --    -- c-C3H2 False
# 126178.4393  0.0052 -3.9156     3 122.1403    21    38   508   303    10    10     0    --    --    --    10     9     1    --    --    -- c-C3H2 False
# 126753.9792   0.002 -3.5638     3  138.535    23    38   508   303    11     9     3    --    --    --    11     8     4    --    --    -- c-C3H2 False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 126753.9792   0.002 -3.5638     3  138.535    23    38   508   303    11     9     3    --    --    --    11     8     4    --    --    -- c-C3H2 False
# 127011.5461  0.0031 -3.6727     3 142.7631    23    38   508   303    11    10     2    --    --    --    11     9     3    --    --    -- c-C3H2 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 129904.589    0.02 -3.2522     3 402.9033   117    38   508   303    19    14     5    --    --    --    19    13     6    --    --    -- c-C3H2 True, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
#  130924.25    0.02 -3.4097     3 121.9753    63    38   508   303    10    10     1    --    --    --    10     9     2    --    --    -- c-C3H2 True
# 131444.599    0.02 -3.1962     3 260.1652    93    38   508   303    15    13     2    --    --    --    15    12     3    --    --    -- c-C3H2 True, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 132381.515    0.02 -3.0736     3 165.3091    75    38   508   303    12    10     3    --    --    --    12     9     4    --    --    -- c-C3H2 True
# 132481.568    0.02 -3.5196     3  591.626   141    38   508   303    23    18     5    --    --    --    23    17     6    --    --    -- c-C3H2 True
# 133675.079    0.02 -3.5013     3 160.2672    25    38   508   303    12     8     4    --    --    --    12     7     5    --    --    -- c-C3H2 True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 133675.079    0.02 -3.5013     3 160.2672    25    38   508   303    12     8     4    --    --    --    12     7     5    --    --    -- c-C3H2 True, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 137243.878    0.02 -3.7219     3 369.1071    37    38   508   303    18    15     3    --    --    --    18    14     4    --    --    -- c-C3H2 True
# 138548.221    0.02 -3.6409     3 360.9621    37    38   508   303    18    13     5    --    --    --    18    12     6    --    --    -- c-C3H2 True
# 138566.055    0.02 -3.1677     3 169.7249    75    38   508   303    12    11     2    --    --    --    12    10     3    --    --    -- c-C3H2 True, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 139620.1116  0.0026 -3.5424     3 194.3224    27    38   508   303    13    11     3    --    --    --    13    10     4    --    --    -- c-C3H2 False
# 139838.0682  0.0036 -2.9928     3 133.5447    69    38   508   303    11     7     4    --    --    --    11     6     5    --    --    -- c-C3H2 False
# 139902.9536  0.0075 -3.6358     3 694.2196   153    38   508   303    25    19     6    --    --    --    25    18     7    --    --    -- c-C3H2 False
# 140459.7959  0.0048 -3.2043     3 199.3647    81    38   508   303    13    12     1    --    --    --    13    11     2    --    --    -- c-C3H2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 141384.4604  0.0068 -3.3707     3 497.1159   129    38   508   303    21    17     4    --    --    --    21    16     5    --    --    -- c-C3H2 False
# 141959.3003  0.0058 -3.3884     3 147.0962    69    38   508   303    11    11     0    --    --    --    11    10     1    --    --    -- c-C3H2 False
# 142165.7228  0.0065 -4.0156     3 639.4064    49    38   508   303    24    18     6    --    --    --    24    17     7    --    --    -- c-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 142857.0324  0.0089 -4.1972     3 751.1206    53    38   508   303    26    20     6    --    --    --    26    19     7    --    --    -- c-C3H2 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 144306.0037  0.0032 -3.4582     3 109.0129    21    38   508   303    10     6     4    --    --    --    10     5     5    --    --    -- c-C3H2 False
# 144750.3117  0.0056   -3.85     3 146.9997    23    38   508   303    11    11     1    --    --    --    11    10     2    --    --    -- c-C3H2 False
# 145089.6055  0.0021 -3.3757     3   6.3153    21    38   508   303     3     1     2    --    --    --     2     2     1    --    --    -- c-C3H2 False
# 145505.8568  0.0074 -4.0338     3 644.1485    49    38   508   303    24    19     5    --    --    --    24    18     6    --    --    -- c-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 147281.5539  0.0029 -2.9913     3 86.6847    57    38   508   303     9     5     4    --    --    --     9     4     5    --    --    -- c-C3H2 False, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 148253.7398  0.0053  -3.077     3 321.1274   105    38   508   303    17    12     5    --    --    --    17    11     6    --    --    -- c-C3H2 False
#  148436.749   0.003 -3.0617     3 225.5857    87    38   508   303    14    12     3    --    --    --    14    11     4    --    --    -- c-C3H2 False
# 148769.6885  0.0023 -3.4268     3 133.5726    23    38   508   303    11     8     4    --    --    --    11     7     5    --    --    -- c-C3H2 False
# 148778.9737  0.0063 -3.4312     3 586.6633   141    38   508   303    23    17     6    --    --    --    23    16     7    --    --    -- c-C3H2 False
# 148931.0766  0.0024 -2.9584     3 109.0237    63    38   508   303    10     7     4    --    --    --    10     6     5    --    --    -- c-C3H2 False
# 149150.7704  0.0029 -3.5037     3  66.5697    17    38   508   303     8     4     4    --    --    --     8     3     5    --    --    -- c-C3H2 False, <Table length=11>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 149150.7704  0.0029 -3.5037     3  66.5697    17    38   508   303     8     4     4    --    --    --     8     3     5    --    --    -- c-C3H2 False
# 149208.3189  0.0023 -2.9509     3  160.332    75    38   508   303    12     9     4    --    --    --    12     8     5    --    --    -- c-C3H2 False
# 149419.7551  0.0026 -3.4579     3  86.6884    19    38   508   303     9     6     4    --    --    --     9     5     5    --    --    -- c-C3H2 False
# 150019.3819  0.0027 -3.0223     3  66.5707    51    38   508   303     8     5     4    --    --    --     8     4     5    --    --    -- c-C3H2 False
# 150283.4849  0.0029 -3.0944     3   48.675    45    38   508   303     7     3     4    --    --    --     7     2     5    --    --    -- c-C3H2 False
# 150436.5547  0.0025 -4.1068     3   1.7292     5    38   508   303     2     2     0    --    --    --     1     1     1    --    --    -- c-C3H2 False
# 150546.4173  0.0024 -3.4366     3 189.3007    27    38   508   303    13    10     4    --    --    --    13     9     5    --    --    -- c-C3H2 False
# 150584.6228  0.0028   -3.57     3  48.6752    15    38   508   303     7     4     4    --    --    --     7     3     5    --    --    -- c-C3H2 False
# 150642.8758   0.005  -3.639     3 295.6474    33    38   508   303    16    14     2    --    --    --    16    13     3    --    --    -- c-C3H2 False
#  150820.665   0.018 -3.3816     3   8.3885     9    38   508   303     4     0     4    --    --    --     3     1     3    --    --    -- c-C3H2  True
#  150851.908   0.007 -2.9042     3   8.3875    27    38   508   303     4     1     4    --    --    --     3     0     3    --    --    -- c-C3H2  True, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  150820.665   0.018 -3.3816     3   8.3885     9    38   508   303     4     0     4    --    --    --     3     1     3    --    --    -- c-C3H2  True
#  150851.908   0.007 -2.9042     3   8.3875    27    38   508   303     4     1     4    --    --    --     3     0     3    --    --    -- c-C3H2  True
# 150954.6912   0.003  -3.692     3  33.0062    13    38   508   303     6     2     4    --    --    --     6     1     5    --    --    -- c-C3H2 False
#  151039.173   0.014 -3.2145     3  33.0063    39    38   508   303     6     3     4    --    --    --     6     2     5    --    --    -- c-C3H2  True
# 151107.0986  0.0043 -3.6256     3 198.9796    27    38   508   303    13    12     2    --    --    --    13    11     3    --    --    -- c-C3H2 False
# 151343.8779  0.0032 -3.4586     3  19.5679    33    38   508   303     5     1     4    --    --    --     5     0     5    --    --    -- c-C3H2 False
# 151360.9763  0.0099 -3.7913     3  810.142   165    38   508   303    27    21     6    --    --    --    27    20     7    --    --    -- c-C3H2 False
# 151361.1053  0.0032 -3.9356     3  19.5679    11    38   508   303     5     2     4    --    --    --     5     1     5    --    --    -- c-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 153072.0974  0.0026 -2.9734     3 220.4797    87    38   508   303    14    11     4    --    --    --    14    10     5    --    --    -- c-C3H2 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 241817.6234  0.0122 -3.8656     3 703.6297    51    38   508   303    25    21     5    --    --    --    25    20     6    --    --    -- c-C3H2 False
#  242076.807    0.03 -3.2469     3  346.299    37    38   508   303    18    11     7    --    --    --    18    10     8    --    --    -- c-C3H2  True
#   243204.34    0.02 -2.7661     3 346.3017   111    38   508   303    18    12     7    --    --    --    18    11     8    --    --    -- c-C3H2  True
# 243235.5394   0.015 -3.9777     3 762.0014    53    38   508   303    26    22     4    --    --    --    26    21     5    --    --    -- c-C3H2 False, <Table length=5>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 244007.7114  0.0314 -4.5045     3 1118.4256    65    38   508   303    32    23     9    --    --    --    32    22    10    --    --    -- c-C3H2 False
# 244222.1505  0.0042 -3.6608     3    4.4798    21    38   508   303     3     2     1    --    --    --     2     1     2    --    --    -- c-C3H2 False
#  244461.198    0.02 -2.7173     3  306.1904   105    38   508   303    17    10     7    --    --    --    17     9     8    --    --    -- c-C3H2  True
#  244988.078    0.02 -3.1927     3  306.1914    35    38   508   303    17    11     7    --    --    --    17    10     8    --    --    -- c-C3H2  True
# 245215.2329  0.0155 -4.0058     3  813.5763    55    38   508   303    27    22     6    --    --    --    27    21     7    --    --    -- c-C3H2 False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 245215.2329  0.0155 -4.0058     3 813.5763    55    38   508   303    27    22     6    --    --    --    27    21     7    --    --    -- c-C3H2 False
# 245324.4361  0.0201 -3.8916     3 387.2901    37    38   508   303    18    18     0    --    --    --    18    17     1    --    --    -- c-C3H2 False
#   245358.58    0.03 -3.4144     3 387.2889   111    38   508   303    18    18     1    --    --    --    18    17     2    --    --    -- c-C3H2  True
# 245435.5721  0.0068  -4.391     3  95.0167    57    38   508   303     9     9     0    --    --    --     9     6     3    --    --    -- c-C3H2 False
#  245627.243    0.05 -3.5896     3 867.4917   171    38   508   303    28    22     7    --    --    --    28    21     8    --    --    -- c-C3H2  True
# 246138.4187  0.0125  -3.827     3 736.9847    53    38   508   303    26    18     8    --    --    --    26    17     9    --    --    -- c-C3H2 False
#  246326.853    0.05 -3.1518     3 268.2804    33    38   508   303    16     9     7    --    --    --    16     8     8    --    --    -- c-C3H2  True
#  246557.769    0.02 -2.6739     3 268.2808    99    38   508   303    16    10     7    --    --    --    16     9     8    --    --    -- c-C3H2  True, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 247807.193    0.02 -2.6422     3 232.5747    93    38   508   303    15     8     7    --    --    --    15     7     8    --    --    -- c-C3H2 True
# 247901.483    0.02  -3.119     3 232.5748    31    38   508   303    15     9     7    --    --    --    15     8     8    --    --    -- c-C3H2 True, <Table length=11>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 248856.5544  0.0908 -4.7066     3 1493.3911   225    38   508   303    37    27    10    --    --    --    37    26    11    --    --    -- c-C3H2 False
#    248991.7    0.02 -3.0981     3  199.0781    29    38   508   303    14     7     7    --    --    --    14     6     8    --    --    -- c-C3H2  True
#  249008.043  0.1119 -4.4893     3 1355.3246   213    38   508   303    35    28     7    --    --    --    35    27     8    --    --    -- c-C3H2 False
#  249027.195    0.02 -2.6209     3  199.0781    87    38   508   303    14     8     7    --    --    --    14     7     8    --    --    -- c-C3H2  True
#  249045.831    0.08 -3.7688     3  940.8395   177    38   508   303    29    24     5    --    --    --    29    23     6    --    --    -- c-C3H2  True
#  249054.368    0.02 -2.6581     3   20.2037    33    38   508   303     5     2     3    --    --    --     4     3     2    --    --    -- c-C3H2  True
# 249245.4543  0.0041 -4.3746     3  113.8264    21    38   508   303    10     9     1    --    --    --    10     6     4    --    --    -- c-C3H2 False
#  249888.758    0.06 -3.7458     3  468.5275    41    38   508   303    20    19     1    --    --    --    20    18     2    --    --    -- c-C3H2  True
#  249941.555    0.02 -2.6127     3  167.7951    81    38   508   303    13     6     7    --    --    --    13     5     8    --    --    -- c-C3H2  True
#  249953.727    0.02 -3.0898     3  167.7951    27    38   508   303    13     7     7    --    --    --    13     6     8    --    --    -- c-C3H2  True
#  250116.834    0.05 -3.2679     3  468.5196   123    38   508   303    20    19     2    --    --    --    20    18     3    --    --    -- c-C3H2  True, <Table length=13>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 250534.8904  0.0145 -3.8314     3 655.7769    49    38   508   303    24    21     3    --    --    --    24    20     4    --    --    -- c-C3H2 False
#  250700.606    0.02 -3.0974     3 138.7299    25    38   508   303    12     5     7    --    --    --    12     4     8    --    --    -- c-C3H2  True
#  250704.357    0.02 -2.6203     3 138.7299    75    38   508   303    12     6     7    --    --    --    12     5     8    --    --    -- c-C3H2  True
# 250901.9321  0.0537 -4.5773     3  1138.62    65    38   508   303    32    26     6    --    --    --    32    25     7    --    --    -- c-C3H2 False
# 251302.2577  0.0034 -2.6488     3 111.8861    69    38   508   303    11     4     7    --    --    --    11     3     8    --    --    -- c-C3H2 False
# 251303.2657  0.0034 -3.1259     3 111.8861    23    38   508   303    11     5     7    --    --    --    11     4     8    --    --    -- c-C3H2 False
#  251314.367   0.005 -2.2306     3  26.8337    45    38   508   303     7     0     7    --    --    --     6     1     6    --    --    -- c-C3H2  True
#  251314.367   0.005 -2.7077     3  26.8337    15    38   508   303     7     1     7    --    --    --     6     0     6    --    --    -- c-C3H2  True
# 251508.7085  0.0017 -2.8659     3  24.6168    13    38   508   303     6     1     5    --    --    --     5     2     4    --    --    -- c-C3H2 False
#  251527.311   0.005 -2.3887     3  24.6162    39    38   508   303     6     2     5    --    --    --     5     1     4    --    --    -- c-C3H2  True
# 251773.1988   0.004 -3.1851     3  87.2673    21    38   508   303    10     3     7    --    --    --    10     2     8    --    --    -- c-C3H2 False
# 251773.4266   0.004 -2.7079     3  87.2673    63    38   508   303    10     4     7    --    --    --    10     3     8    --    --    -- c-C3H2 False
# 252016.1696  0.0145 -3.7489     3 557.9954    45    38   508   303    22    20     2    --    --    --    22    19     3    --    --    -- c-C3H2 False, <Table length=7>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 252016.1696  0.0145 -3.7489     3 557.9954    45    38   508   303    22    20     2    --    --    --    22    19     3    --    --    -- c-C3H2 False
# 252135.9321  0.0047 -2.8204     3  64.8765    57    38   508   303     9     2     7    --    --    --     9     1     8    --    --    -- c-C3H2 False
# 252135.9728  0.0047 -3.2975     3  64.8765    19    38   508   303     9     3     7    --    --    --     9     2     8    --    --    -- c-C3H2 False
# 252409.8369  0.0055 -3.5361     3  44.7167    17    38   508   303     8     1     7    --    --    --     8     0     8    --    --    -- c-C3H2 False
#  252409.842  0.0055  -3.059     3  44.7167    51    38   508   303     8     2     7    --    --    --     8     1     8    --    --    -- c-C3H2 False
# 252694.6002  0.0176 -4.1665     3 931.6223    59    38   508   303    29    23     7    --    --    --    29    22     8    --    --    -- c-C3H2 False
# 253096.4257  0.0143 -3.2682     3 557.9571   135    38   508   303    22    20     3    --    --    --    22    19     4    --    --    -- c-C3H2 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 254535.9855  0.0143 -3.3411     3 655.6315   147    38   508   303    24    21     4    --    --    --    24    20     5    --    --    -- c-C3H2 False
# 254562.8035  0.0104 -3.2293     3 679.3957   153    38   508   303    25    17     8    --    --    --    25    16     9    --    --    -- c-C3H2 False
# 254987.6522   0.002 -3.0919     3  20.0324    11    38   508   303     5     3     3    --    --    --     4     2     2    --    --    -- c-C3H2 False
# 255244.8446  0.0153 -3.4614     3 761.5503   159    38   508   303    26    22     5    --    --    --    26    21     6    --    --    -- c-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 256811.7416  0.0204  -3.615     3 875.685   171    38   508   303    28    23     6    --    --    --    28    22     7    --    --    -- c-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 257609.9446  0.0307 -3.8628     3 1047.904   189    38   508   303    31    22     9    --    --    --    31    21    10    --    --    -- c-C3H2 False, <Table length=7>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 259746.5099  0.0275 -3.4561     3 430.9163   117    38   508   303    19    19     0    --    --    --    19    18     1    --    --    -- c-C3H2 False
# 259763.7514  0.0275 -3.9331     3 430.9158    39    38   508   303    19    19     1    --    --    --    19    18     2    --    --    -- c-C3H2 False
#    260204.3  0.0114 -3.5177     3 858.8122   171    38   508   303    28    21     8    --    --    --    28    20     9    --    --    -- c-C3H2 False
#  260479.746    0.02 -3.0948     3  22.3944    33    38   508   303     5     3     2    --    --    --     4     4     1    --    --    -- c-C3H2  True
# 260683.7125   0.012 -4.1078     3 922.9269    59    38   508   303    29    22     8    --    --    --    29    21     9    --    --    -- c-C3H2 False
# 260868.5908  0.0105 -3.8849     3 796.8593    55    38   508   303    27    20     8    --    --    --    27    19     9    --    --    -- c-C3H2 False
# 261124.5575  0.0089 -3.5974     3 623.9551    49    38   508   303    24    16     8    --    --    --    24    15     9    --    --    -- c-C3H2 False, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 261124.5575  0.0089 -3.5974     3 623.9551    49    38   508   303    24    16     8    --    --    --    24    15     9    --    --    -- c-C3H2 False
# 261433.7667  0.0258 -3.7916     3 997.9642   183    38   508   303    30    24     7    --    --    --    30    23     8    --    --    -- c-C3H2 False
# 261530.2675   0.024 -3.5643     3 822.0418   165    38   508   303    27    23     4    --    --    --    27    22     5    --    --    -- c-C3H2 False
# 261831.8114  0.0037 -4.3123     3   4.4676     7    38   508   303     3     3     1    --    --    --     2     0     2    --    --    -- c-C3H2 False
#  262387.197    0.02 -3.3016     3 737.0676   159    38   508   303    26    19     8    --    --    --    26    18     9    --    --    -- c-C3H2  True
#    262567.1    0.03 -3.7462     3 989.2059   183    38   508   303    30    23     8    --    --    --    30    22     9    --    --    -- c-C3H2  True, <Table length=4>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  264467.138    0.06 -3.3192     3  516.3056   129    38   508   303    21    20     1    --    --    --    21    19     2    --    --    -- c-C3H2  True
# 264472.7553  0.0085  -3.677     3  679.4389    51    38   508   303    25    18     8    --    --    --    25    17     9    --    --    -- c-C3H2 False
# 264548.4668   0.071 -4.9918     3 1412.1725    73    38   508   303    36    26    10    --    --    --    36    25    11    --    --    -- c-C3H2 False
# 264588.8234  0.0241 -3.7959     3  516.3014    43    38   508   303    21    20     2    --    --    --    21    19     3    --    --    -- c-C3H2 False, <Table length=5>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 264548.4668   0.071 -4.9918     3 1412.1725    73    38   508   303    36    26    10    --    --    --    36    25    11    --    --    -- c-C3H2 False
# 264588.8234  0.0241 -3.7959     3  516.3014    43    38   508   303    21    20     2    --    --    --    21    19     3    --    --    -- c-C3H2 False
#  265759.481   0.005 -2.5176     3   13.5296    27    38   508   303     4     4     1    --    --    --     3     3     0    --    --    -- c-C3H2  True
# 266055.9467  0.0175 -4.3409     3 1057.6548    63    38   508   303    31    24     8    --    --    --    31    23     9    --    --    -- c-C3H2 False
#  266190.313    0.03 -3.0218     3  570.6751   141    38   508   303    23    15     8    --    --    --    23    14     9    --    --    -- c-C3H2  True, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 266426.3758  0.0051 -3.8769     3 138.2092    69    38   508   303    11    10     1    --    --    --    11     7     4    --    --    -- c-C3H2 False
#  266639.231    0.03 -3.4175     3 711.7824   153    38   508   303    25    22     3    --    --    --    25    21     4    --    --    -- c-C3H2  True
#  266867.115    0.03 -3.1032     3 623.9768   147    38   508   303    24    17     8    --    --    --    24    16     9    --    --    -- c-C3H2  True
# 267043.9912  0.0252   -3.33     3 609.9051   141    38   508   303    23    21     2    --    --    --    23    20     3    --    --    -- c-C3H2 False
# 267653.7888  0.0251 -3.8052     3 609.8836    47    38   508   303    23    21     3    --    --    --    23    20     4    --    --    -- c-C3H2 False, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 268729.6381  0.3557 -5.0376     3 1676.0353   237    38   508   303    39    31     8    --    --    --    39    30     9    --    --    -- c-C3H2 False
# 269035.7919  0.0245 -3.8871     3  711.6959    51    38   508   303    25    22     4    --    --    --    25    21     5    --    --    -- c-C3H2 False
# 269201.3232  0.0454 -4.3195     3 1007.2062    61    38   508   303    30    25     5    --    --    --    30    24     6    --    --    -- c-C3H2 False
# 269236.7153   0.023 -4.0174     3  821.7558    55    38   508   303    27    23     5    --    --    --    27    22     6    --    --    -- c-C3H2 False
# 269324.3063  0.0282 -4.1856     3  979.4772    61    38   508   303    30    21     9    --    --    --    30    20    10    --    --    -- c-C3H2 False
# 269359.7175  0.0073 -3.4896     3  570.6855    47    38   508   303    23    16     8    --    --    --    23    15     9    --    --    -- c-C3H2 False
# 269467.0186  0.0275  -4.183     3  940.0513    59    38   508   303    29    24     6    --    --    --    29    23     7    --    --    -- c-C3H2 False, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
#  270127.641    0.03   -3.41     3  519.5655    45    38   508   303    22    14     8    --    --    --    22    13     9    --    --    -- c-C3H2  True
# 271270.2399  0.0267 -3.9834     3 1128.2813   195    38   508   303    32    25     8    --    --    --    32    24     9    --    --    -- c-C3H2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 271697.2337  0.0365 -4.3739     3 1066.5294    63    38   508   303    31    25     7    --    --    --    31    24     8    --    --    -- c-C3H2 False
#  271795.226    0.03  -2.928     3  519.5703   135    38   508   303    22    15     8    --    --    --    22    14     9    --    --    -- c-C3H2  True
# 273061.0168  0.0897 -4.1833     3 1211.2683   201    38   508   303    33    27     6    --    --    --    33    26     7    --    --    -- c-C3H2 False, <Table length=5>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 273061.0168  0.0897 -4.1833     3 1211.2683   201    38   508   303    33    27     6    --    --    --    33    26     7    --    --    -- c-C3H2 False
#  273235.958    0.05 -2.8528     3  470.6344   129    38   508   303    21    13     8    --    --    --    21    12     9    --    --    -- c-C3H2  True
#  274071.906    0.05 -3.3275     3  470.6365    43    38   508   303    21    14     8    --    --    --    21    13     9    --    --    -- c-C3H2  True
# 274135.4661  0.0395 -3.9824     3  476.8629    41    38   508   303    20    20     0    --    --    --    20    19     1    --    --    -- c-C3H2 False
#  274144.163    0.12 -3.5053     3  476.8626   123    38   508   303    20    20     1    --    --    --    20    19     2    --    --    -- c-C3H2  True]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 10., N_tot = 5.0e+13, v_cen = 40.5*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=15,
               nrows=4, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'c-C$_3$H$_2$',
               print_diag=False, extr_type="coord", crd=crd, show_2_sigma=True, EU_cutoff_K=50)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 8., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=15, 
                       nrows=4, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'c-C$_3$H$_2$', 
                       extr_type="reg", show_2_sigma=True, return_freqs=True, EU_cutoff_K=50)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 8., N_tot = 2.0e+13, v_cen = 40.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=15, 
                       nrows=4, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'c-C$_3$H$_2$', 
                       extr_type="reg", show_2_sigma=True, return_freqs=True, EU_cutoff_K=50)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=15, fig_height=10, nrows=4, ncols=5, name_for_plot=f'c-C$_3$H$_2$')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=15, fig_height=10, nrows=4, ncols=5, name_for_plot=f'c-C$_3$H$_2$')
