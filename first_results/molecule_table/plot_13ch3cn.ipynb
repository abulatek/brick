# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 42508
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name       Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str14       bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -------------- -----
# 107146.1725  0.0003 -3.6645     3 133.2671    26    42   508   202     6     5    --    --    --    --     5     5    --    --    --    -- C-13-H3CN, v=0 False
# 107164.3096  0.0003 -3.3115     3  88.5227    26    42   508   202     6     4    --    --    --    --     5     4    --    --    --    -- C-13-H3CN, v=0 False
#  107178.424  0.0003 -2.8076     3  53.7109    52    42   508   202     6     3    --    --    --    --     5     3    --    --    --    -- C-13-H3CN, v=0 False
#    107188.5     0.1 -2.9829     3  28.8397    26    42   508   202     6     2    --    --    --    --     5     2    --    --    --    -- C-13-H3CN, v=0  True
#   107194.55     0.1 -2.9129     3  13.9148    26    42   508   202     6     1    --    --    --    --     5     1    --    --    --    -- C-13-H3CN, v=0  True
#   107196.57     0.1 -2.8902     3   8.9394    26    42   508   202     6     0    --    --    --    --     5     0    --    --    --    -- C-13-H3CN, v=0  True, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name       Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str14       bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -------------- -----
# 142793.9416  0.0007  -3.671     3 260.2511    34    42   508   202     8     7    --    --    --    --     7     7    --    --    --    -- C-13-H3CN, v=0 False
# 142828.8088  0.0005 -2.9642     3  195.676    68    42   508   202     8     6    --    --    --    --     7     6    --    --    --    -- C-13-H3CN, v=0 False
# 142858.3361  0.0004 -3.0073     3 141.0107    34    42   508   202     8     5    --    --    --    --     7     5    --    --    --    -- C-13-H3CN, v=0 False
# 142882.5114  0.0003 -2.8238     3  96.2676    34    42   508   202     8     4    --    --    --    --     7     4    --    --    --    -- C-13-H3CN, v=0 False
#  142901.396    0.12  -2.391     3  61.4569    68    42   508   202     8     3    --    --    --    --     7     3    --    --    --    -- C-13-H3CN, v=0  True
#   142914.85    0.12 -2.6024     3  36.5864    34    42   508   202     8     2    --    --    --    --     7     2    --    --    --    -- C-13-H3CN, v=0  True
#  142922.844    0.12   -2.55     3  21.6619    34    42   508   202     8     1    --    --    --    --     7     1    --    --    --    -- C-13-H3CN, v=0  True
#    142925.6    0.12 -2.5328     3  16.6867    34    42   508   202     8     0    --    --    --    --     7     0    --    --    --    -- C-13-H3CN, v=0  True, <Table length=14>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name       Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str14       bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -------------- -----
# 249303.0481  0.0085 -4.4948     3 892.2553    58    42   508   202    14    13    --    --    --    --    13    13    --    --    --    -- C-13-H3CN, v=0 False
# 249419.3172  0.0061 -3.6512     3 768.6242   116    42   508   202    14    12    --    --    --    --    13    12    --    --    --    -- C-13-H3CN, v=0 False
# 249526.4577  0.0043 -3.5557     3 654.7803    58    42   508   202    14    11    --    --    --    --    13    11    --    --    --    -- C-13-H3CN, v=0 False
# 249624.4271   0.003 -3.2315     3 550.7495    58    42   508   202    14    10    --    --    --    --    13    10    --    --    --    -- C-13-H3CN, v=0 False
# 249713.1865  0.0021 -2.6555     3 456.5551   116    42   508   202    14     9    --    --    --    --    13     9    --    --    --    -- C-13-H3CN, v=0 False
#    249792.7  0.0015 -2.7207     3 372.2185    58    42   508   202    14     8    --    --    --    --    13     8    --    --    --    -- C-13-H3CN, v=0 False
# 249862.9356  0.0011 -2.5187     3 297.7588    58    42   508   202    14     7    --    --    --    --    13     7    --    --    --    -- C-13-H3CN, v=0 False
# 249923.8648  0.0008 -2.0461     3 233.1929   116    42   508   202    14     6    --    --    --    --    13     6    --    --    --    -- C-13-H3CN, v=0 False
# 249975.4626  0.0006 -2.2043     3 178.5353    58    42   508   202    14     5    --    --    --    --    13     5    --    --    --    -- C-13-H3CN, v=0 False
#  250017.708  0.0005 -2.0887     3 133.7986    58    42   508   202    14     4    --    --    --    --    13     4    --    --    --    -- C-13-H3CN, v=0 False
# 250050.5836  0.0004 -1.6985     3  98.9928   116    42   508   202    14     3    --    --    --    --    13     3    --    --    --    -- C-13-H3CN, v=0 False
# 250074.0759  0.0005 -1.9362     3  74.1259    58    42   508   202    14     2    --    --    --    --    13     2    --    --    --    -- C-13-H3CN, v=0 False
# 250088.1751  0.0005 -1.8983     3  59.2034    58    42   508   202    14     1    --    --    --    --    13     1    --    --    --    -- C-13-H3CN, v=0 False
# 250092.8755  0.0005 -1.8857     3  54.2289    58    42   508   202    14     0    --    --    --    --    13     0    --    --    --    -- C-13-H3CN, v=0 False, <Table length=15>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name       Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str14       bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -------------- -----
# 266970.1069  0.0122   -4.73     3 1033.9575    62    42   508   202    15    14    --    --    --    --    14    14    --    --    --    -- C-13-H3CN, v=0 False
#   267104.37  0.0089  -4.166     3  900.5712    62    42   508   202    15    13    --    --    --    --    14    13    --    --    --    -- C-13-H3CN, v=0 False
# 267228.9044  0.0063 -3.4467     3  776.9439   124    42   508   202    15    12    --    --    --    --    14    12    --    --    --    -- C-13-H3CN, v=0 False
# 267343.6614  0.0045 -3.4017     3  663.1037    62    42   508   202    15    11    --    --    --    --    14    11    --    --    --    -- C-13-H3CN, v=0 False
# 267448.5954  0.0031 -3.1049     3  559.0761    62    42   508   202    15    10    --    --    --    --    14    10    --    --    --    -- C-13-H3CN, v=0 False
# 267543.6645  0.0022 -2.5459     3  464.8846   124    42   508   202    15     9    --    --    --    --    14     9    --    --    --    -- C-13-H3CN, v=0 False
# 267628.8305  0.0015 -2.6225     3  380.5507    62    42   508   202    15     8    --    --    --    --    14     8    --    --    --    -- C-13-H3CN, v=0 False
#  267704.059  0.0011 -2.4285     3  306.0934    62    42   508   202    15     7    --    --    --    --    14     7    --    --    --    -- C-13-H3CN, v=0 False
# 267769.3194  0.0008 -1.9618     3  241.5294   124    42   508   202    15     6    --    --    --    --    14     6    --    --    --    -- C-13-H3CN, v=0 False
# 267824.5852  0.0006 -2.1243     3  186.8736    62    42   508   202    15     5    --    --    --    --    14     5    --    --    --    -- C-13-H3CN, v=0 False
# 267869.8337  0.0005 -2.0118     3  142.1383    62    42   508   202    15     4    --    --    --    --    14     4    --    --    --    -- C-13-H3CN, v=0 False
# 267905.0463  0.0004 -1.6239     3  107.3336   124    42   508   202    15     3    --    --    --    --    14     3    --    --    --    -- C-13-H3CN, v=0 False
# 267930.2086  0.0005 -1.8631     3   82.4674    62    42   508   202    15     2    --    --    --    --    14     2    --    --    --    -- C-13-H3CN, v=0 False
# 267945.3101  0.0005 -1.8261     3   67.5455    62    42   508   202    15     1    --    --    --    --    14     1    --    --    --    -- C-13-H3CN, v=0 False
# 267950.3447  0.0005 -1.8138     3   62.5711    62    42   508   202    15     0    --    --    --    --    14     0    --    --    --    -- C-13-H3CN, v=0 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name       Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str14       bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -------------- -----
# 267905.0463  0.0004 -1.6239     3 107.3336   124    42   508   202    15     3    --    --    --    --    14     3    --    --    --    -- C-13-H3CN, v=0 False
# 267930.2086  0.0005 -1.8631     3  82.4674    62    42   508   202    15     2    --    --    --    --    14     2    --    --    --    -- C-13-H3CN, v=0 False
# 267945.3101  0.0005 -1.8261     3  67.5455    62    42   508   202    15     1    --    --    --    --    14     1    --    --    --    -- C-13-H3CN, v=0 False
# 267950.3447  0.0005 -1.8138     3  62.5711    62    42   508   202    15     0    --    --    --    --    14     0    --    --    --    -- C-13-H3CN, v=0 False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 3.6e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=12,
               nrows=3, ncols=4, parse_loc=False, ret_tbl=True, line_by_line=True, name_for_plot=f'$^{{13}}$CH$_3$CN', 
               print_diag=False, extr_type="coord", crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 1.9e+12, v_cen = 12.*u.km/u.s, v_disp = 3*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=12, 
                       nrows=3, ncols=4, parse_loc=False, ret_tbl=True, line_by_line=True, name_for_plot=f'$^{{13}}$CH$_3$CN', 
                       extr_type="reg", just_data=False, show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=6, nrows=3, ncols=4, name_for_plot=f'$^{{13}}$CH$_3$CN')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=6, nrows=3, ncols=4, name_for_plot=f'$^{{13}}$CH$_3$CN')
