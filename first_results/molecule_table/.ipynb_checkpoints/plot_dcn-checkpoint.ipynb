# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 28004 # 28509
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=6>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64 str3 str3
# ----------- ------- ------- ----- ------- ----- ------ ----- ---- ----
#  144826.573   0.002 -2.9315     2  2.4155     5 -28004   102  2 2  1 2
#  144826.825    0.02 -2.8065     2  2.4155     3 -28004   102  2 1  1 0
# 144827.9913  0.0026 -4.1075     2  2.4155     3  28004   102  2 1  1 2
# 144827.9913  0.0026 -2.9314     2  2.4155     3  28004   102  2 1  1 1
# 144827.9913  0.0026 -2.4543     2  2.4155     5  28004   102  2 2  1 1
# 144827.9913  0.0026 -2.1833     2  2.4155     7  28004   102  2 3  1 2]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 6e+12, v_cen = 41.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=10, fig_height=5, 
               nrows=2, ncols=3, parse_loc=False, line_by_line=True, name_for_plot=f'DCN', extr_type="coord", crd=crd,
               show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 40., N_tot = 5.5e+11, v_cen = 15.*u.km/u.s, v_disp = 1.5*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=10, fig_height=5, 
                       nrows=2, ncols=3, parse_loc=False, line_by_line=True, name_for_plot=f'DCN', extr_type="reg", 
                       just_data=False, show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=41*u.km/u.s, fig_width=10, fig_height=5, nrows=1, ncols=3, name_for_plot=f'DCN')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=15*u.km/u.s, fig_width=10, fig_height=5, nrows=1, ncols=3, name_for_plot=f'DCN')
