# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 59505
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  ...  F1l   F2l   F3l  name  Lab
#    MHz       MHz   nm2 MHz        1 / cm       ...
#  float64   float64 float64 int64 float64 int64 ... int64 int64 int64 str4  bool
# ---------- ------- ------- ----- ------- ----- ... ----- ----- ----- ---- -----
# 91271.6114  0.0019 -3.3141     3 20.1309    17 ...    --    --    -- HSCN False, <Table length=14>
#    FREQ      ERR    LGINT    DR    ELO     GUP  ...  F1l   F2l   F3l  name  Lab
#    MHz       MHz   nm2 MHz        1 / cm        ...
#  float64   float64 float64 int64 float64  int64 ... int64 int64 int64 str4  bool
# ---------- ------- ------- ----- -------- ----- ... ----- ----- ----- ---- -----
# 91620.2412  0.0562 -4.8749     3 471.8325    17 ...    --    --    -- HSCN False
# 91620.2412  0.0562 -4.8749     3 471.8325    17 ...    --    --    -- HSCN False
# 91659.8448  0.0197 -4.3499     3 350.1181    17 ...    --    --    -- HSCN False
# 91659.8448  0.0197 -4.3499     3 350.1181    17 ...    --    --    -- HSCN False
# 91690.5927  0.0149 -3.9905     3 246.7773    17 ...    --    --    -- HSCN False
# 91690.5927  0.0149 -3.9905     3 246.7773    17 ...    --    --    -- HSCN False
# 91714.3177  0.0094 -3.7235     3 161.9859    17 ...    --    --    -- HSCN False
# 91714.3177  0.0094 -3.7235     3 161.9859    17 ...    --    --    -- HSCN False
# 91732.1889   0.007 -3.5265     3  95.8878    17 ...    --    --    -- HSCN False
# 91732.1908   0.007 -3.5265     3  95.8878    17 ...    --    --    -- HSCN False
# 91743.6244   0.004 -3.3901     3  48.5947    17 ...    --    --    -- HSCN False
# 91746.7853   0.004 -3.3901     3  48.5948    17 ...    --    --    -- HSCN False
# 91750.6357  0.0017 -3.2831     3  10.7121    17 ...    --    --    -- HSCN False
# 92229.6569  0.0019 -3.3053     3  20.2428    17 ...    --    --    -- HSCN False, <Table length=16>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 102679.3248  0.0022 -3.1659     3  23.1754 ...    --    --    -- HSCN False
# 103014.1098  0.2318  -5.068     3 614.7677 ...    --    --    -- HSCN False
# 103014.1098  0.2318  -5.068     3 614.7677 ...    --    --    -- HSCN False
# 103071.7879   0.063 -4.5014     3 474.8887 ...    --    --    -- HSCN False
# 103071.7879   0.063 -4.5014     3 474.8887 ...    --    --    -- HSCN False
# 103116.3451  0.0217 -4.0995     3 353.1755 ...    --    --    -- HSCN False
# 103116.3451  0.0217 -4.0995     3 353.1755 ...    --    --    -- HSCN False
# 103150.9457  0.0165  -3.789     3 249.8358 ...    --    --    -- HSCN False
# 103150.9457  0.0165  -3.789     3 249.8358 ...    --    --    -- HSCN False
# 103177.6575  0.0104 -3.5474     3 165.0452 ...    --    --    -- HSCN False
# 103177.6575  0.0104 -3.5474     3 165.0452 ...    --    --    -- HSCN False
#  103197.816  0.0077 -3.3652     3  98.9476 ...    --    --    -- HSCN False
# 103197.8194  0.0077 -3.3652     3  98.9476 ...    --    --    -- HSCN False
# 103210.4015  0.0044 -3.2374     3  51.6549 ...    --    --    -- HSCN False
# 103214.9168  0.0044 -3.2374     3  51.6552 ...    --    --    -- HSCN False
# 103217.4801  0.0019 -3.1364     3  13.7726 ...    --    --    -- HSCN False, <Table length=17>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 102679.3248  0.0022 -3.1659     3  23.1754 ...    --    --    -- HSCN False
# 103014.1098  0.2318  -5.068     3 614.7677 ...    --    --    -- HSCN False
# 103014.1098  0.2318  -5.068     3 614.7677 ...    --    --    -- HSCN False
# 103071.7879   0.063 -4.5014     3 474.8887 ...    --    --    -- HSCN False
# 103071.7879   0.063 -4.5014     3 474.8887 ...    --    --    -- HSCN False
# 103116.3451  0.0217 -4.0995     3 353.1755 ...    --    --    -- HSCN False
# 103116.3451  0.0217 -4.0995     3 353.1755 ...    --    --    -- HSCN False
# 103150.9457  0.0165  -3.789     3 249.8358 ...    --    --    -- HSCN False
# 103150.9457  0.0165  -3.789     3 249.8358 ...    --    --    -- HSCN False
# 103177.6575  0.0104 -3.5474     3 165.0452 ...    --    --    -- HSCN False
# 103177.6575  0.0104 -3.5474     3 165.0452 ...    --    --    -- HSCN False
#  103197.816  0.0077 -3.3652     3  98.9476 ...    --    --    -- HSCN False
# 103197.8194  0.0077 -3.3652     3  98.9476 ...    --    --    -- HSCN False
# 103210.4015  0.0044 -3.2374     3  51.6549 ...    --    --    -- HSCN False
# 103214.9168  0.0044 -3.2374     3  51.6552 ...    --    --    -- HSCN False
# 103217.4801  0.0019 -3.1364     3  13.7726 ...    --    --    -- HSCN False
# 103757.0808  0.0022 -3.1572     3  23.3192 ...    --    --    -- HSCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm       ...
#   float64   float64 float64 int64 float64 int64 ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ... ----- ----- ----- ---- -----
# 103757.0808  0.0022 -3.1572     3 23.3192    19 ...    --    --    -- HSCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm       ...
#   float64   float64 float64 int64 float64 int64 ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ... ----- ----- ----- ---- -----
# 114086.6016  0.0024 -3.0352     3 26.6004    21 ...    --    --    -- HSCN False, <Table length=19>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 114086.6016  0.0024 -3.0352     3  26.6004 ...    --    --    -- HSCN False
# 114375.0782  0.7053 -5.3108     3 776.0074 ...    --    --    -- HSCN False
# 114375.0782  0.7053 -5.3108     3 776.0074 ...    --    --    -- HSCN False
# 114458.9007  0.2577 -4.7039     3 618.2039 ...    --    --    -- HSCN False
# 114458.9007  0.2577 -4.7039     3 618.2039 ...    --    --    -- HSCN False
# 114522.9874  0.0698 -4.2608     3 478.3268 ...    --    --    -- HSCN False
# 114522.9874  0.0698 -4.2608     3 478.3268 ...    --    --    -- HSCN False
# 114572.4995  0.0235 -3.9083     3 356.6151 ...    --    --    -- HSCN False
# 114572.4995  0.0235 -3.9083     3 356.6151 ...    --    --    -- HSCN False
# 114610.9558  0.0179 -3.6239     3 253.2766 ...    --    --    -- HSCN False
# 114610.9558  0.0179 -3.6239     3 253.2766 ...    --    --    -- HSCN False
# 114640.6621  0.0114 -3.3979     3 168.4868 ...    --    --    -- HSCN False
# 114640.6621  0.0114 -3.3979     3 168.4868 ...    --    --    -- HSCN False
# 114663.1265  0.0084 -3.2253     3 102.3899 ...    --    --    -- HSCN False
# 114663.1323  0.0084 -3.2253     3 102.3899 ...    --    --    -- HSCN False
# 114676.7636  0.0048 -3.1034     3  55.0977 ...    --    --    -- HSCN False
# 114682.9718  0.0048 -3.1034     3  55.0981 ...    --    --    -- HSCN False
#  114683.624  0.0021 -3.0068     3  17.2155 ...    --    --    -- HSCN False
# 115284.0517  0.0024 -3.0265     3  26.7802 ...    --    --    -- HSCN False, <Table length=19>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 125493.3933  0.0027 -2.9186     3  30.4059 ...    --    --    -- HSCN False
# 125811.1046  0.7762 -4.9544     3 779.8225 ...    --    --    -- HSCN False
# 125811.1046  0.7762 -4.9544     3 779.8225 ...    --    --    -- HSCN False
#  125903.306  0.2836 -4.4713     3 622.0219 ...    --    --    -- HSCN False
#  125903.306  0.2836 -4.4713     3 622.0219 ...    --    --    -- HSCN False
# 125973.8013  0.0766  -4.078     3 482.1468 ...    --    --    -- HSCN False
# 125973.8013  0.0766  -4.078     3 482.1468 ...    --    --    -- HSCN False
# 126028.2695  0.0251 -3.7521     3 360.4369 ...    --    --    -- HSCN False
# 126028.2695  0.0251 -3.7521     3 360.4369 ...    --    --    -- HSCN False
# 126070.5852  0.0192 -3.4837     3 257.0996 ...    --    --    -- HSCN False
# 126070.5852  0.0192 -3.4837     3 257.0996 ...    --    --    -- HSCN False
# 126103.2941  0.0122 -3.2679     3 172.3108 ...    --    --    -- HSCN False
# 126103.2941  0.0122 -3.2679     3 172.3108 ...    --    --    -- HSCN False
# 126128.0851  0.0091 -3.1021     3 106.2147 ...    --    --    -- HSCN False
# 126128.0945  0.0091 -3.1021     3 106.2147 ...    --    --    -- HSCN False
# 126142.6645  0.0052 -2.9845     3  58.9229 ...    --    --    -- HSCN False
# 126148.9898  0.0024  -2.891     3   21.041 ...    --    --    -- HSCN False
# 126150.9415  0.0052 -2.9845     3  58.9235 ...    --    --    -- HSCN False
# 126810.5191  0.0027   -2.91     3  30.6256 ...    --    --    -- HSCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm       ...
#   float64   float64 float64 int64 float64 int64 ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ... ----- ----- ----- ---- -----
# 126810.5191  0.0027   -2.91     3 30.6256    23 ...    --    --    -- HSCN False, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 136899.6516   0.003 -2.8138     3  34.5919 ...    --    --    -- HSCN False
#  137113.708   1.925 -5.2507     3 959.4703 ...    --    --    -- HSCN False
#  137113.708   1.925 -5.2507     3 959.4703 ...    --    --    -- HSCN False, <Table length=18>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 137246.7078  0.8472 -4.7285     3 784.0191 ...    --    --    -- HSCN False
# 137246.7078  0.8472 -4.7285     3 784.0191 ...    --    --    -- HSCN False
# 137347.2871  0.3096 -4.2955     3 626.2215 ...    --    --    -- HSCN False
# 137347.2871  0.3096 -4.2955     3 626.2215 ...    --    --    -- HSCN False
# 137424.1909  0.0833  -3.929     3 486.3489 ...    --    --    -- HSCN False
# 137424.1909  0.0833  -3.929     3 486.3489 ...    --    --    -- HSCN False
# 137483.6167  0.0266 -3.6194     3 364.6407 ...    --    --    -- HSCN False
# 137483.6167  0.0266 -3.6194     3 364.6407 ...    --    --    -- HSCN False
# 137529.7956  0.0204 -3.3618     3 261.3048 ...    --    --    -- HSCN False
# 137529.7956  0.0204 -3.3618     3 261.3048 ...    --    --    -- HSCN False
# 137565.5163   0.013 -3.1533     3 176.5172 ...    --    --    -- HSCN False
# 137565.5163   0.013 -3.1533     3 176.5172 ...    --    --    -- HSCN False
# 137592.6563  0.0097 -2.9923     3 110.4219 ...    --    --    -- HSCN False
# 137592.6709  0.0097 -2.9923     3 110.4219 ...    --    --    -- HSCN False
# 137608.0582  0.0056  -2.878     3  63.1305 ...    --    --    -- HSCN False
# 137613.4996  0.0027 -2.7868     3  25.2488 ...    --    --    -- HSCN False
# 137618.8175  0.0056 -2.8779     3  63.1314 ...    --    --    -- HSCN False
# 138336.4326   0.003 -2.8053     3  34.8556 ...    --    --    -- HSCN False, <Table length=20>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 148305.3281  0.0035 -2.7189     3  39.1584 ...    --    --    -- HSCN False
# 148537.7743   2.086 -5.0305     3 964.0439 ...    --    --    -- HSCN False
# 148537.7743   2.086 -5.0305     3 964.0439 ...    --    --    -- HSCN False
# 148681.8492  0.9184 -4.5586     3 788.5972 ...    --    --    -- HSCN False
# 148681.8492  0.9184 -4.5586     3 788.5972 ...    --    --    -- HSCN False
# 148790.8054  0.3356 -4.1526     3  630.803 ...    --    --    -- HSCN False
# 148790.8054  0.3356 -4.1526     3  630.803 ...    --    --    -- HSCN False
# 148874.1177  0.0899 -3.8027     3 490.9329 ...    --    --    -- HSCN False
# 148874.1177  0.0899 -3.8027     3 490.9329 ...    --    --    -- HSCN False
# 148938.5025  0.0278 -3.5042     3 369.2267 ...    --    --    -- HSCN False
# 148938.5025  0.0278 -3.5042     3 369.2267 ...    --    --    -- HSCN False
#  148988.549  0.0215 -3.2542     3 265.8923 ...    --    --    -- HSCN False
#  148988.549  0.0215 -3.2542     3 265.8923 ...    --    --    -- HSCN False
# 149027.2915  0.0137  -3.051     3 181.1059 ...    --    --    -- HSCN False
# 149027.2915  0.0137  -3.051     3 181.1059 ...    --    --    -- HSCN False
# 149056.8049  0.0103 -2.8938     3 115.0115 ...    --    --    -- HSCN False
# 149056.8268  0.0103 -2.8938     3 115.0115 ...    --    --    -- HSCN False
# 149072.8986   0.006 -2.7818     3  67.7206 ...    --    --    -- HSCN False
# 149077.0758  0.0031 -2.6925     3  29.8391 ...    --    --    -- HSCN False
#  149086.591  0.0059 -2.7817     3  67.7219 ...    --    --    -- HSCN False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 149027.2915  0.0137  -3.051     3 181.1059 ...    --    --    -- HSCN False
# 149027.2915  0.0137  -3.051     3 181.1059 ...    --    --    -- HSCN False
# 149056.8049  0.0103 -2.8938     3 115.0115 ...    --    --    -- HSCN False
# 149056.8268  0.0103 -2.8938     3 115.0115 ...    --    --    -- HSCN False
# 149072.8986   0.006 -2.7818     3  67.7206 ...    --    --    -- HSCN False
# 149077.0758  0.0031 -2.6925     3  29.8391 ...    --    --    -- HSCN False
#  149086.591  0.0059 -2.7817     3  67.7219 ...    --    --    -- HSCN False
# 149861.7416  0.0033 -2.7106     3    39.47 ...    --    --    -- HSCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm       ...
#   float64   float64 float64 int64 float64 int64 ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ... ----- ----- ----- ---- -----
# 242036.3783  0.0096 -2.1932     3 90.2231    43 ...    --    --    -- HSCN False, <Table length=15>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ---- -----
# 250567.1341   13.15 -5.0753     3 1424.7818 ...    --    --    -- HSCN False
# 250567.1341   13.15 -5.0753     3 1424.7818 ...    --    --    -- HSCN False
# 250922.2974  0.0121 -2.1568     3   97.3742 ...    --    --    -- HSCN False
# 251002.4301    7.13 -4.6086     3 1215.0727 ...    --    --    -- HSCN False
# 251002.4301    7.13 -4.6086     3 1215.0727 ...    --    --    -- HSCN False
# 251327.3491   3.549 -4.1816     3 1022.3522 ...    --    --    -- HSCN False
# 251327.3491   3.549 -4.1816     3 1022.3522 ...    --    --    -- HSCN False
# 251570.9945   1.567 -3.7945     3   846.962 ...    --    --    -- HSCN False
# 251570.9945   1.567 -3.7945     3   846.962 ...    --    --    -- HSCN False
#   251755.28  0.5748 -3.4474     3  689.2106 ...    --    --    -- HSCN False
#   251755.28  0.5748 -3.4474     3  689.2106 ...    --    --    -- HSCN False
# 251896.2668  0.1499 -3.1404     3  549.3732 ...    --    --    -- HSCN False
# 251896.2668  0.1499 -3.1404     3  549.3732 ...    --    --    -- HSCN False
# 252005.3732  0.0274 -2.8738     3  427.6923 ...    --    --    -- HSCN False
# 252005.3732  0.0274 -2.8738     3  427.6923 ...    --    --    -- HSCN False, <Table length=12>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 252005.3732  0.0274 -2.8738     3 427.6923 ...    --    --    -- HSCN False
# 252005.3732  0.0274 -2.8738     3 427.6923 ...    --    --    -- HSCN False
#  252090.478  0.0239 -2.6478     3 324.3776 ...    --    --    -- HSCN False
#  252090.478  0.0239 -2.6478     3 324.3776 ...    --    --    -- HSCN False
#  252157.002  0.0159 -2.4626     3 239.6065 ...    --    --    -- HSCN False
# 252157.0025  0.0159 -2.4626     3 239.6065 ...    --    --    -- HSCN False
# 252194.4666  0.0112 -2.1328     3  88.3544 ...    --    --    -- HSCN False
# 252209.2572  0.0134 -2.3183     3 173.5239 ...    --    --    -- HSCN False
#  252209.567  0.0135 -2.3183     3 173.5239 ...    --    --    -- HSCN False
# 252223.9592  0.0141 -2.2152     3 126.2381 ...    --    --    -- HSCN False
# 252290.4851  0.0126  -2.215     3 126.2492 ...    --    --    -- HSCN False
# 253553.9672   0.011 -2.1498     3  98.2966 ...    --    --    -- HSCN False, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ---- -----
# 261950.0136   13.76 -5.0198     3 1433.1399 ...    --    --    -- HSCN False
# 261950.0136   13.76 -5.0198     3 1433.1399 ...    --    --    -- HSCN False
# 262319.5131  0.0138 -2.1167     3  105.7441 ...    --    --    -- HSCN False
# 262405.0542   7.457 -4.5564     3 1223.4453 ...    --    --    -- HSCN False
# 262405.0542   7.457 -4.5564     3 1223.4453 ...    --    --    -- HSCN False
# 262744.7078   3.713 -4.1321     3 1030.7356 ...    --    --    -- HSCN False
# 262744.7078   3.713 -4.1321     3 1030.7356 ...    --    --    -- HSCN False, <Table length=17>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
#  262999.402    1.64 -3.7471     3 855.3535 ...    --    --    -- HSCN False
#  262999.402    1.64 -3.7471     3 855.3535 ...    --    --    -- HSCN False
# 263192.0489  0.6022 -3.4018     3 697.6082 ...    --    --    -- HSCN False
# 263192.0489  0.6022 -3.4018     3 697.6082 ...    --    --    -- HSCN False
# 263339.4437   0.157 -3.0963     3 557.7755 ...    --    --    -- HSCN False
# 263339.4437   0.157 -3.0963     3 557.7755 ...    --    --    -- HSCN False
# 263453.5315  0.0263 -2.8308     3 436.0982 ...    --    --    -- HSCN False
# 263453.5315  0.0263 -2.8308     3 436.0982 ...    --    --    -- HSCN False
# 263542.5659  0.0235 -2.6058     3 332.7864 ...    --    --    -- HSCN False
# 263542.5659  0.0235 -2.6058     3 332.7864 ...    --    --    -- HSCN False
# 263612.2569  0.0159 -2.4213     3 248.0175 ...    --    --    -- HSCN False
# 263612.2576  0.0159 -2.4213     3 248.0175 ...    --    --    -- HSCN False
# 263644.4507  0.0127 -2.0928     3  96.7667 ...    --    --    -- HSCN False
# 263667.2207  0.0136 -2.2776     3 181.9367 ...    --    --    -- HSCN False
# 263667.6079  0.0137 -2.2776     3 181.9367 ...    --    --    -- HSCN False
# 263680.7322  0.0158 -2.1749     3 134.6514 ...    --    --    -- HSCN False
# 263756.7437  0.0141 -2.1747     3 134.6647 ...    --    --    -- HSCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ---- -----
# 265070.4439  0.0125 -2.1098     3 106.7543 ...    --    --    -- HSCN False, <Table length=13>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l  name  Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ---- -----
# 273332.0217   14.36 -4.9699     3 1441.8776 ...    --    --    -- HSCN False
# 273332.0217   14.36 -4.9699     3 1441.8776 ...    --    --    -- HSCN False
# 273715.6198  0.0157 -2.0798     3  114.4941 ...    --    --    -- HSCN False
# 273806.8013   7.786 -4.5092     3 1232.1982 ...    --    --    -- HSCN False
# 273806.8013   7.786 -4.5092     3 1232.1982 ...    --    --    -- HSCN False
# 274161.1849   3.877 -4.0871     3 1039.4998 ...    --    --    -- HSCN False
# 274161.1849   3.877 -4.0871     3 1039.4998 ...    --    --    -- HSCN False
# 274426.9245   1.714  -3.704     3  864.1262 ...    --    --    -- HSCN False
# 274426.9245   1.714  -3.704     3  864.1262 ...    --    --    -- HSCN False
# 274627.9307  0.6299 -3.3602     3  706.3873 ...    --    --    -- HSCN False
# 274627.9307  0.6299 -3.3602     3  706.3873 ...    --    --    -- HSCN False
# 274781.7334  0.1643 -3.0559     3  566.5596 ...    --    --    -- HSCN False
# 274781.7334  0.1643 -3.0559     3  566.5596 ...    --    --    -- HSCN False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 5.6e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
               nrows=2, ncols=3, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-2.8)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 3.6e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
                       nrows=2, ncols=3, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-2.8)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
