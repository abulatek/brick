# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 45522
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=2>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 85852.8356  0.0019 -3.4072     3 30.2515     9    45   522   303     4     1     3    --    --    --     3     1     2    --    --    -- HOCO+ False
# 86632.6424  0.2194 -5.9561     3 400.942    65    45   522   303    32     1    31    --    --    --    32     1    32    --    --    -- HOCO+ False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 90768.0676  0.2052 -4.0313     3 525.1661    77    45   522   303    38     0    38    --    --    --    37     1    37    --    --    -- HOCO+ False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 92039.0323  0.2514 -5.9657     3 424.3694    67    45   522   303    33     1    32    --    --    --    33     1    33    --    --    -- HOCO+ False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 101245.3679  0.0644 -3.6456     3 331.5362    59    45   522   303    29     1    29    --    --    --    30     0    30    --    --    -- HOCO+ False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 101245.3679  0.0644 -3.6456     3 331.5362    59    45   522   303    29     1    29    --    --    --    30     0    30    --    --    -- HOCO+ False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 106493.8987  0.0024 -3.1194     3  33.0604    11    45   522   303     5     1     5    --    --    --     4     1     4    --    --    -- HOCO+ False
# 106877.1473  0.0033 -3.3356     3 110.5105    11    45   522   303     5     2     4    --    --    --     4     2     3    --    --    -- HOCO+ False
# 106877.6542  0.0032 -3.3356     3 110.5106    11    45   522   303     5     2     3    --    --    --     4     2     2    --    --    -- HOCO+ False
# 106913.5453  0.0026 -3.0442     3   7.1326    11    45   522   303     5     0     5    --    --    --     4     0     4    --    --    -- HOCO+ False
# 107315.3561  0.0024 -3.1128     3  33.1152    11    45   522   303     5     1     4    --    --    --     4     1     3    --    --    -- HOCO+ False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 115072.1799  0.2328 -3.8698     3 552.1364    79    45   522   303    39     0    39    --    --    --    38     1    38    --    --    -- HOCO+ False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
#  127791.696  0.0028 -2.8845     3  36.6127    13    45   522   303     6     1     6    --    --    --     5     1     5    --    --    -- HOCO+ False
# 128251.6088  0.0039 -3.0816     3 114.0756    13    45   522   303     6     2     5    --    --    --     5     2     4    --    --    -- HOCO+ False
# 128252.4958  0.0038 -3.0816     3 114.0756    13    45   522   303     6     2     4    --    --    --     5     2     3    --    --    -- HOCO+ False
#  128295.063    0.05 -2.8149     3  10.6988    13    45   522   303     6     0     6    --    --    --     5     0     5    --    --    -- HOCO+  True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 128777.4176  0.0028  -2.878     3 36.6949    13    45   522   303     6     1     5    --    --    --     5     1     4    --    --    -- HOCO+ False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 139440.636  0.2631 -3.7493     3 579.8151    81    45   522   303    40     0    40    --    --    --    39     1    39    --    --    -- HOCO+ False, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5 bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----
# 148547.352    0.08  -3.259     3 289.485    55    45   522   303    27     1    27    --    --    --    28     0    28    --    --    -- HOCO+ True
# 149088.992    0.06   -2.69     3 40.8753    15    45   522   303     7     1     7    --    --    --     6     1     6    --    --    -- HOCO+ True, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
#  149088.992    0.06   -2.69     3  40.8753    15    45   522   303     7     1     7    --    --    --     6     1     6    --    --    -- HOCO+  True
# 149625.5423  0.0044 -2.8763     3 118.3536    15    45   522   303     7     2     6    --    --    --     6     2     5    --    --    -- HOCO+ False
# 149626.9615  0.0044 -2.8763     3 118.3537    15    45   522   303     7     2     5    --    --    --     6     2     4    --    --    -- HOCO+ False
#  149675.871    0.06 -2.6237     3  14.9783    15    45   522   303     7     0     7    --    --    --     6     0     6    --    --    -- HOCO+  True
# 150238.9283  0.0032 -2.6836     3  40.9904    15    45   522   303     7     1     6    --    --    --     6     1     5    --    --    -- HOCO+ False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 242269.3107  0.0292 -2.7521     3 213.9246    47    45   522   303    23     1    23    --    --    --    24     0    24    --    --    -- HOCO+ False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
#  255564.146    0.05 -2.0521     3  72.8442    25    45   522   303    12     1    12    --    --    --    11     1    11    --    --    -- HOCO+  True
# 256484.2087  0.0065 -2.2199     3 150.4376    25    45   522   303    12     2    11    --    --    --    11     2    10    --    --    -- HOCO+ False
#  256491.405    0.06 -2.2198     3 150.4382    25    45   522   303    12     2    10    --    --    --    11     2     9    --    --    -- HOCO+  True
#  256566.323    0.05 -1.9921     3  47.0729    25    45   522   303    12     0    12    --    --    --    11     0    11    --    --    -- HOCO+  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5 bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----
# 257534.991    0.06 -2.0463     3 73.2059    25    45   522   303    12     1    11    --    --    --    11     1    10    --    --    -- HOCO+ True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 262215.4058   0.458 -3.4582     3 728.8278    91    45   522   303    45     0    45    --    --    --    44     1    44    --    --    -- HOCO+ False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str5  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- -----
# 265512.2679  0.0268 -2.6576     3 196.8147    45    45   522   303    22     1    22    --    --    --    23     0    23    --    --    -- HOCO+ False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 3.5e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=10,
               nrows=3, ncols=4, parse_loc=False, ret_tbl=True, line_by_line=True, name_for_plot=f'HOCO$^+$',
               print_diag=False, extr_type="coord", crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 10., N_tot = 1.0e+13, v_cen = 13.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=8, 
                       nrows=3, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'HOCO$^+$', 
                       extr_type="reg", show_2_sigma=True, return_freqs=True)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 10., N_tot = 1.0e+13, v_cen = 40.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=8, 
                       nrows=3, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'HOCO$^+$', 
                       extr_type="reg", show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=10, fig_height=10, nrows=3, ncols=4, name_for_plot=f'HOCO$^+$')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=13*u.km/u.s, fig_width=10, fig_height=10, nrows=3, ncols=4, name_for_plot=f'HOCO$^+$')
