# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 41501
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=9>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 108959.3631  0.0026 -5.2423     3  192.526    30    41   501   202     7    -6    --    --    --    --     6     6    --    --    --    -- CH3CCD False
# 108959.3631  0.0026 -5.2423     3  192.526    30    41   501   202     7     6    --    --    --    --     6    -6    --    --    --    -- CH3CCD False
# 108981.3011  0.0027 -4.8603     3 137.0592    30    41   501   202     7     5    --    --    --    --     6     5    --    --    --    -- CH3CCD False
# 108999.2612  0.0029 -4.6273     3  91.6598    30    41   501   202     7     4    --    --    --    --     6     4    --    --    --    -- CH3CCD False
# 109013.2368  0.0031 -4.4701     3  56.3383    30    41   501   202     7    -3    --    --    --    --     6     3    --    --    --    -- CH3CCD False
# 109013.2368  0.0031 -4.4701     3  56.3383    30    41   501   202     7     3    --    --    --    --     6    -3    --    --    --    -- CH3CCD False
#  109023.223  0.0033 -4.3663     3  31.1028    30    41   501   202     7     2    --    --    --    --     6     2    --    --    --    -- CH3CCD False
# 109029.2162  0.0034 -4.3067     3  15.9591    30    41   501   202     7     1    --    --    --    --     6     1    --    --    --    -- CH3CCD False
# 109031.2141  0.0034 -4.2872     3  10.9108    30    41   501   202     7     0    --    --    --    --     6     0    --    --    --    -- CH3CCD False, <Table length=11>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 140016.3006  0.0039 -5.3283     3 341.3921    38    41   501   202     9     8    --    --    --    --     8     8    --    --    --    -- CH3CCD False
# 140054.6909  0.0034 -4.8959     3 265.8336    38    41   501   202     9     7    --    --    --    --     8     7    --    --    --    -- CH3CCD False
# 140087.9905  0.0032 -4.6112     3 200.3142    38    41   501   202     9    -6    --    --    --    --     8     6    --    --    --    -- CH3CCD False
# 140087.9905  0.0032 -4.6112     3 200.3142    38    41   501   202     9     6    --    --    --    --     8    -6    --    --    --    -- CH3CCD False
# 140116.1874  0.0033 -4.4005     3  144.849    38    41   501   202     9     5    --    --    --    --     8     5    --    --    --    -- CH3CCD False

#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 264515.7221  0.0048 -3.8572     3 317.7389    70    41   501   202    17     7    --    --    --    --    16     7    --    --    --    -- CH3CCD False
# 264578.4901  0.0045 -3.6976     3 252.2318    70    41   501   202    17    -6    --    --    --    --    16     6    --    --    --    -- CH3CCD False
# 264578.4901  0.0045 -3.6976     3 252.2318    70    41   501   202    17     6    --    --    --    --    16    -6    --    --    --    -- CH3CCD False
#   264631.64  0.0046 -3.5635     3  196.777    70    41   501   202    17     5    --    --    --    --    16     5    --    --    --    -- CH3CCD False
# 264675.1524   0.005 -3.4542     3 151.3874    70    41   501   202    17     4    --    --    --    --    16     4    --    --    --    -- CH3CCD False
# 264709.0117  0.0054 -3.3696     3 116.0735    70    41   501   202    17    -3    --    --    --    --    16     3    --    --    --    -- CH3CCD False
# 264709.0117  0.0054 -3.3696     3 116.0735    70    41   501   202    17     3    --    --    --    --    16    -3    --    --    --    -- CH3CCD False
# 264733.2057  0.0057 -3.3093     3  90.8435    70    41   501   202    17     2    --    --    --    --    16     2    --    --    --    -- CH3CCD False
# 264747.7256  0.0059 -3.2731     3  75.7031    70    41   501   202    17     1    --    --    --    --    16     1    --    --    --    -- CH3CCD False
# 264752.5661   0.006 -3.2611     3  70.6559    70    41   501   202    17     0    --    --    --    --    16     0    --    --    --    -- CH3CCD False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 9.5e+13, v_cen = 41.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
               nrows=2, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-5)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 15., N_tot = 2.1e+13, v_cen = 13.*u.km/u.s, v_disp = 2.5*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
                       nrows=2, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-5)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
