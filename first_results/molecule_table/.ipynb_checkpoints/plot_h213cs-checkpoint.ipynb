# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 47001 # 47505
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=4>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 97633.7024  1.2886  -3.684     3 12.4346    21 47001   303 3 1 3 2 1 2
# 99076.2939  0.7779 -4.0782     3  3.3051     7 47001   303 3 0 3 2 0 2
# 99086.4992  0.7743 -4.4099     3 40.0166     7 47001   303 3 2 2 2 2 1
# 99096.7046  0.7709 -4.4098     3 40.0167     7 47001   303 3 2 1 2 2 0, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 100536.1069  0.9368 -3.6588     3 12.5314    21 47001   303 3 1 2 2 1 1, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 100536.1069  0.9368 -3.6588     3 12.5314    21 47001   303 3 1 2 2 1 1, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 130175.3031  1.7208  -3.294     3 15.6913    27 47001   303 4 1 4 3 1 3, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 132089.8198  1.0416 -3.7115     3  6.6099     9 47001   303 4 0 4 3 0 3
# 132113.3479  1.0331 -3.9128     3 43.3218     9 47001   303 4 2 3 3 2 2
# 132120.4224  1.0307 -3.7653     3 89.2112    27 47001   303 4 3 2 3 3 1
# 132120.4477  1.0307 -3.7653     3 89.2112    27 47001   303 4 3 1 3 3 0
# 132138.8605  1.0246 -3.9126     3 43.3222     9 47001   303 4 2 2 3 2 1, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 134045.1561   1.247  -3.269     3  15.885    27 47001   303 4 1 3 3 1 2, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 260310.2873  3.4788 -2.4241     3 39.5719    51 47001   303 8 1 8 7 1 7, <Table length=13>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str5  str5
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- -----
# 264016.4993  2.1511  -2.864     3  30.8375    17 47001   303 8 0 8 7 0 7
#  264199.482  2.0759 -2.9679     3  67.5584    17 47001   303 8 2 7 7 2 6
# 264238.6022  2.0622 -3.9529     3 480.5639    51 47001   303 8 7 2 7 7 1
# 264238.6022  2.0622 -3.9529     3 480.5639    51 47001   303 8 7 1 7 7 0
# 264240.2869  2.0616 -3.9105     3 361.2519    17 47001   303 8 6 3 7 6 2
# 264240.2869  2.0616 -3.9105     3 361.2519    17 47001   303 8 6 2 7 6 1
#  264243.138  2.0606 -3.0792     3 260.2956    51 47001   303 8 5 4 7 5 3
#  264243.138  2.0606 -3.0792     3 260.2956    51 47001   303 8 5 3 7 5 2
# 264248.5801  2.0588 -3.2941     3 177.6951    17 47001   303 8 4 5 7 4 4
#  264248.582  2.0588 -3.2941     3 177.6951    17 47001   303 8 4 4 7 4 3
# 264260.7528  2.0549  -2.624     3 113.4507    51 47001   303 8 3 6 7 3 5
# 264261.8124  2.0543  -2.624     3 113.4508    51 47001   303 8 3 5 7 3 4
# 264413.6454  2.0114 -2.9672     3  67.5691    17 47001   303 8 2 6 7 2 5, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 268048.9842  2.4654 -2.4008     3 40.4755    51 47001   303 8 1 7 7 1 6, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 268048.9842  2.4654 -2.4008     3 40.4755    51 47001   303 8 1 7 7 1 6]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 7.9e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=10, 
               nrows=3, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'H$_2^{{13}}$CS', extr_type="coord", crd=crd,
               show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 4.9e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=10, 
                       nrows=3, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'H$_2^{{13}}$CS', extr_type="reg", just_data=False,
                       show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=10, fig_height=6, nrows=3, ncols=6, name_for_plot=f'H$_2^{{13}}$CS')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=10, fig_height=6, nrows=3, ncols=6, name_for_plot=f'H$_2^{{13}}$CS')
