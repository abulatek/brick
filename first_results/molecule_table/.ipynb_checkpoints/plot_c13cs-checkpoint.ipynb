# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 57002
catalog = 'JPL'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=3>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 85736.2399  0.3651 -5.2607     2 13.3173    12 57002   113 7 6 6 6 5 6
#  85744.504  0.0417 -3.4479     2  13.317    12 57002   113 7 6 6 6 5 5
# 85746.1897  0.0397 -3.3743     2 13.3173    14 57002   113 7 6 7 6 5 6, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 90255.2149  0.0142 -3.3311     2 15.0877    14 57002   113 7 7 7 6 6 6
# 90255.5953  0.0133 -3.2683     2 15.0876    16 57002   113 7 7 8 6 6 7
# 90258.0409   0.105 -5.2857     2 15.0876    14 57002   113 7 7 7 6 6 7, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ---------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 94227.7863   0.415 -5.0884     2 39.6019    24 57002   113 131212 121212
# 94244.0706  0.3746 -5.0532     2 39.6018    26 57002   113 131213 121213, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 99356.3305  0.4241 -5.2035     2 16.1775    14 57002   113 8 7 7 7 6 7
# 99366.2803  0.0338 -3.2494     2 16.1771    14 57002   113 8 7 7 7 6 6
# 99367.5963  0.0329 -3.1866     2 16.1775    16 57002   113 8 7 8 7 6 7, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 103148.0806  0.0141 -3.1569     2 18.0983    16 57002   113 8 8 8 7 7 7
# 103148.3704  0.0138 -3.1021     2 18.0982    18 57002   113 8 8 9 7 7 8
# 103150.5262  0.0923 -5.2328     2 18.0982    16 57002   113 8 8 8 7 7 8, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 103148.0806  0.0141 -3.1569     2 18.0983    16 57002   113 8 8 8 7 7 7
# 103148.3704  0.0138 -3.1021     2 18.0982    18 57002   113 8 8 9 7 7 8
# 103150.5262  0.0923 -5.2328     2 18.0982    16 57002   113 8 8 8 7 7 8, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str6   str6
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 105582.5547  0.4252 -5.0419     2 45.1926    26 57002   113 141313 131313
# 105599.1094  0.3852 -5.0093     2 45.1926    28 57002   113 141314 131314
# 105863.0709  0.0257 -3.0165     2 13.7656    20 57002   113  8 910  7 8 9
#  105863.676  0.0258 -3.0651     2 13.7661    18 57002   113  8 9 9  7 8 8
# 105878.1389  0.5895 -5.2468     2 13.7656    18 57002   113  8 9 9  7 8 9, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 112836.4115  0.4706 -5.1567     2  19.492    16 57002   113 9 8 8 8 7 8
# 112847.6773  0.0279 -3.0814     2 19.4916    16 57002   113 9 8 8 8 7 7
# 112848.7186  0.0275 -3.0266     2  19.492    18 57002   113 9 8 9 8 7 8, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 112836.4115  0.4706 -5.1567     2  19.492    16 57002   113 9 8 8 8 7 8
# 112847.6773  0.0279 -3.0814     2 19.4916    16 57002   113 9 8 8 8 7 7
# 112848.7186  0.0275 -3.0266     2  19.492    18 57002   113 9 8 9 8 7 8, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str6   str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ -----
# 126203.9739  0.5077 -5.1179     2 23.2562    18 57002   113 10 9 9 9 8 9
# 126216.2811  0.0234 -2.9362     2 23.2558    18 57002   113 10 9 9 9 8 8
# 126217.1145  0.0234 -2.8876     2 23.2562    20 57002   113 10 910 9 8 9, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64   str6
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 128804.5012  0.4435 -4.9684     2  57.664    30 57002   113 161515 151515
# 128821.4698  0.4043 -4.9401     2  57.664    32 57002   113 161516 151516
# 128932.7377  0.0152 -2.8734     2 25.4096    20 57002   113 101010  9 9 9
# 128932.9221  0.0151 -2.8297     2 25.4095    22 57002   113 101011  9 910
# 128934.6652  0.0747 -5.1502     2 25.4095    20 57002   113 101010  9 910, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ -----
# 130943.8051  0.0213 -2.7646     2 21.2451    24 57002   113 101112 91011
# 130944.2042  0.0215 -2.8043     2 21.2457    22 57002   113 101111 91010
# 130959.7621   0.629 -5.1658     2 21.2451    22 57002   113 101111 91011, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64   str6
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
#  139482.081  0.5376 -5.0852     2 27.4664    20 57002   113 111010 10 910
# 139495.2216  0.0202 -2.8089     2  27.466    20 57002   113 111010 10 9 9
# 139495.8958  0.0203 -2.7653     2 27.4664    22 57002   113 111011 10 910, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 140619.9696  0.4524 -4.9397     2 64.5446    32 57002   113 171616 161616
# 140637.0974  0.4137 -4.9131     2 64.5446    34 57002   113 171617 161617
#  141824.458  0.0157 -2.7556     2 29.7103    22 57002   113 111111 101010
# 141824.6102  0.0157 -2.7159     2 29.7103    24 57002   113 111112 101011
# 141826.2011  0.0683 -5.1176     2 29.7103    22 57002   113 111111 101011, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 143574.7057  0.0199 -2.6577     2  25.613    26 57002   113 111213 101112
#  143575.033  0.0201  -2.694     2 25.6135    24 57002   113 111212 101111
# 143590.9899  0.6435 -5.1332     2  25.613    24 57002   113 111212 101112, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 152545.1661  0.4617 -4.9154     2 71.8551    34 57002   113 181717 171717
# 152562.4291  0.4234 -4.8903     2 71.8551    36 57002   113 181718 171718
# 152689.3073   0.562 -5.0577     2 32.1195    22 57002   113 121111 111011
# 152703.1221  0.0181 -2.6961     2  32.119    22 57002   113 121111 111010
# 152703.6733  0.0183 -2.6564     2 32.1195    24 57002   113 121112 111011, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 152545.1661  0.4617 -4.9154     2 71.8551    34 57002   113 181717 171717
# 152562.4291  0.4234 -4.8903     2 71.8551    36 57002   113 181718 171718, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 243200.8012  1.4292  -4.677     2 17.2973    18 57002   113 9 9 9 8 9 9
# 243213.9418  1.4351  -4.631     2 17.2968    20 57002   113 9 910 8 910, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
#  244054.647  0.6505 -4.9593     2  76.944    36 57002   113 191818 181718
# 244070.8657  0.0166 -2.1608     2 76.9435    36 57002   113 191818 181717
# 244071.0378  0.0166 -2.1366     2  76.944    38 57002   113 191819 181718
# 244715.5507  1.3939 -6.1096     2 53.7976    30 57002   113 161515 151616
# 244748.4677   1.385 -6.0824     2 53.7971    32 57002   113 161516 151617
# 244938.4062  0.0179 -2.1394     2 79.5955    38 57002   113 191919 181818
#  244938.457  0.0179 -2.1165     2 79.5955    40 57002   113 191920 181819
#  244939.394  0.0424  -4.986     2 79.5955    38 57002   113 191919 181819, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
#  245650.084  0.0162 -2.0835     2 75.8156    42 57002   113 192021 181920
# 245650.1698  0.0162 -2.1053     2 75.8162    40 57002   113 192020 181919
# 245667.6478  0.6992 -4.9966     2 75.8156    40 57002   113 192020 181920, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64  int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 250482.2261  0.5771 -4.8366     2 145.8129    50 57002   113 262525 252525
#  250500.081  0.5443 -4.8194     2 145.8129    52 57002   113 262526 252526, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ -----
# 253764.7044   1.422 -4.6499     2 21.2457    20 57002   113 101010 91010, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ -----
# 253764.7044   1.422 -4.6499     2 21.2457    20 57002   113 101010 91010
# 253778.5192  1.4282 -4.6085     2 21.2451    22 57002   113 101011 91011, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 255603.6722  1.3991 -6.1224     2 60.7097    34 57002   113 171617 161718
# 257022.7605   0.657 -4.9551     2 85.0854    38 57002   113 201919 191819
# 257039.1514  0.0177  -2.109     2 85.0848    38 57002   113 201919 191818
# 257039.3014  0.0177 -2.0861     2 85.0854    40 57002   113 201920 191819, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 257022.7605   0.657 -4.9551     2 85.0854    38 57002   113 201919 191819
# 257039.1514  0.0177  -2.109     2 85.0848    38 57002   113 201919 191818
# 257039.3014  0.0177 -2.0861     2 85.0854    40 57002   113 201920 191819
# 257824.5636   0.019 -2.0893     2 87.7658    40 57002   113 202020 191919
# 257824.6094   0.019 -2.0675     2 87.7658    42 57002   113 202021 191920
# 257825.5007  0.0411 -4.9811     2 87.7658    40 57002   113 202020 191920
# 258473.6373  0.0173 -2.0361     2 84.0096    44 57002   113 202122 192021
# 258473.7118  0.0173 -2.0568     2 84.0102    42 57002   113 202121 192020
# 258491.2756  0.7023 -4.9911     2 84.0096    42 57002   113 202121 192021, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 260330.8554  1.4858 -5.0821     2  2.2333     8 57002   113 5 4 4 2 3 3
#  260345.341  1.4842 -4.9694     2   2.233    10 57002   113 5 4 5 2 3 4, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64  int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 262929.5581   0.599 -4.8378     2 156.9914    52 57002   113 272626 262626
# 262947.4523   0.567 -4.8212     2 156.9914    54 57002   113 272627 262627, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64  int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 262929.5581   0.599 -4.8378     2 156.9914    52 57002   113 272626 262626
# 262947.4523   0.567 -4.8212     2 156.9914    54 57002   113 272627 262627
# 264644.9583  1.4174 -4.6275     2  25.6135    22 57002   113 111111 101111
# 264659.3243  1.4238 -4.5897     2   25.613    24 57002   113 111112 101112, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 264644.9583  1.4174 -4.6275     2 25.6135    22 57002   113 111111 101111
# 264659.3243  1.4238 -4.5897     2  25.613    24 57002   113 111112 101112, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
#  269979.399  0.6627 -4.9529     2 93.6593    40 57002   113 212020 201920
#   269995.94  0.0194 -2.0616     2 93.6587    40 57002   113 212020 201919
# 269996.0716  0.0193 -2.0398     2 93.6593    42 57002   113 212021 201920
# 270709.8988  0.0207 -2.0434     2 96.3659    42 57002   113 212121 202020
# 270709.9403  0.0207 -2.0227     2 96.3659    44 57002   113 212122 202021
# 270710.7901  0.0403 -4.9782     2 96.3659    42 57002   113 212121 202021
# 271303.9198  0.0192 -1.9926     2 92.6314    46 57002   113 212223 202122
# 271303.9848  0.0192 -2.0124     2  92.632    44 57002   113 212222 202121
# 271321.6232  0.7051 -4.9877     2 92.6314    44 57002   113 212222 202122, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64  int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 271321.6232  0.7051 -4.9877     2 92.6314    44 57002   113 212222 202122]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
               nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-4)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
                       nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-4)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
