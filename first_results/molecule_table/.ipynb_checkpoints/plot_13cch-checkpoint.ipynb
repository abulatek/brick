# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 26502
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=15>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  252422.933   0.016 -3.0699     2  8.4494    10    26   502   154     3     4     4     5    --    --     2     3     3     4    --    -- C-13-CH  True
#  252424.122   0.016 -3.1778     2  8.4486     8    26   502   154     3     4     4     4    --    --     2     3     3     3    --    -- C-13-CH  True
# 252437.4492  0.0157 -4.3775     2  8.4538     6    26   502   154     3     3     3     3    --    --     2     2     1     2    --    -- C-13-CH False
# 252444.7495  0.0055 -4.4685     2  8.4211     6    26   502   154     3     4     3     3    --    --     2     3     2     3    --    -- C-13-CH False
#  252447.991   0.016 -3.3224     2  8.4209     6    26   502   154     3     4     3     3    --    --     2     3     2     2    --    -- C-13-CH  True
#  252449.265   0.016 -3.1675     2  8.4211     8    26   502   154     3     4     3     4    --    --     2     3     2     3    --    -- C-13-CH  True
#  252457.865   0.016 -3.2239     2  8.4535     8    26   502   154     3     3     3     4    --    --     2     2     2     3    --    -- C-13-CH  True
#  252468.774   0.016  -3.381     2  8.4527     6    26   502   154     3     3     3     3    --    --     2     2     2     2    --    -- C-13-CH  True
#  252480.925   0.016 -3.4674     2  8.4538     6    26   502   154     3     3     2     3    --    --     2     2     1     2    --    -- C-13-CH  True
#  252489.308   0.017 -3.6225     2  8.4538     4    26   502   154     3     3     2     2    --    --     2     2     1     1    --    -- C-13-CH  True
#  252490.623    0.15 -4.0269     2  8.4538     4    26   502   154     3     3     2     2    --    --     2     2     1     2    --    -- C-13-CH  True
#  252490.623    0.15 -3.9811     2  8.4535     6    26   502   154     3     3     2     3    --    --     2     2     2     3    --    -- C-13-CH  True
# 252512.3085  0.0177 -4.2242     2  8.4527     6    26   502   154     3     3     2     3    --    --     2     2     2     2    --    -- C-13-CH False
#  252578.574  0.0173 -4.0982     2  8.4494     8    26   502   154     3     3     3     4    --    --     2     3     3     4    --    -- C-13-CH False
# 252593.8694  0.0202 -4.3527     2  8.4486     6    26   502   154     3     3     3     3    --    --     2     3     3     3    --    -- C-13-CH False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 1.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=8, 
               nrows=3, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'$^{{13}}$CCH', extr_type="coord", crd=crd,
               show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 1.4e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=8, 
                       nrows=3, ncols=4, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'$^{{13}}$CCH', 
                       extr_type="reg", show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=f'$^{{13}}$CCH')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=f'$^{{13}}$CCH')
