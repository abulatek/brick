# %%
# Package imports# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 29004
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=4>
#   FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT    QN'       QN"
#   MHz      MHz   MHz nm2        1 / cm
# float64  float64 float64 int64 float64 int64 int64  int64    str9      str9
# -------- ------- ------- ----- ------- ----- ------ ----- --------- ---------
# 86670.76    0.06  -4.294     3  0.0129     5 -29004   325 1 0 1 2 2 0 0 0 1 1
# 86708.36    0.04 -4.5248     3     0.0     3 -29004   325 1 0 1 2 1 0 0 0 1 0
# 86777.46    0.04 -4.5241     3  0.0129     3 -29004   325 1 0 1 1 1 0 0 0 1 1
# 86805.78  0.1001 -4.9915     3  0.0129     1 -29004   325 1 0 1 1 0 0 0 0 1 1, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'        QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64 int64   str10      str10
# ---------- ------- ------- ----- -------- ----- ----- ----- ---------- ----------
#  88093.932 37.0874 -5.7957     3 697.4763    45 29004   325 21 1202222 20 2192121
# 88273.2356 36.6638 -5.9666     3 697.4615    43 29004   325 21 1202221 20 2192020
# 88513.4401 37.2025 -5.9646     3 697.4749    43 29004   325 21 1202121 20 2192120
# 88695.7901 36.7755 -5.8322     3 697.4729    41 29004   325 21 1202120 20 2192019, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64    str9      str9
# ----------- ------- ------- ----- -------- ----- ----- ----- --------- ---------
# 101332.7267  1.5393  -5.754     3  125.262    17 29004   325 8 1 7 8 8 8 1 8 8 8
# 101564.0509  1.5413 -5.3195     3 125.2617    15 29004   325 8 1 7 8 7 8 1 8 8 7
# 101725.6904  1.5403 -5.4326     3 125.2489    17 29004   325 8 1 7 8 8 8 1 8 9 8, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64    str9      str9
# ----------- ------- ------- ----- -------- ----- ----- ----- --------- ---------
# 101564.0509  1.5413 -5.3195     3 125.2617    15 29004   325 8 1 7 8 7 8 1 8 8 7
# 101725.6904  1.5403 -5.4326     3 125.2489    17 29004   325 8 1 7 8 8 8 1 8 9 8
# 102337.7755   1.664  -5.444     3  125.262    17 29004   325 8 1 7 9 8 8 1 8 8 8
# 102507.8695  1.6635 -5.2196     3 125.2619    19 29004   325 8 1 7 9 9 8 1 8 9 9
# 102730.7392  1.6561 -5.7509     3 125.2489    17 29004   325 8 1 7 9 8 8 1 8 9 8, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64    str9      str9
# ----------- ------- ------- ----- -------- ----- ----- ----- --------- ---------
# 102337.7755   1.664  -5.444     3  125.262    17 29004   325 8 1 7 9 8 8 1 8 8 8
# 102507.8695  1.6635 -5.2196     3 125.2619    19 29004   325 8 1 7 9 9 8 1 8 9 9
# 102730.7392  1.6561 -5.7509     3 125.2489    17 29004   325 8 1 7 9 8 8 1 8 9 8, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'       QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64 int64    str9      str9
# ---------- ------- ------- ----- -------- ----- ----- ----- --------- ---------
# 126834.933  2.5993 -5.4012     3 150.8528    19 29004   325 9 1 8 9 9 9 1 9 9 9, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64    str9      str9
# ----------- ------- ------- ----- -------- ----- ----- ----- --------- ---------
#  126834.933  2.5993 -5.4012     3 150.8528    19 29004   325 9 1 8 9 9 9 1 9 9 9
# 126982.6613  2.5935 -5.2216     3 150.8556    17 29004   325 9 1 8 9 8 9 1 9 9 8
# 127331.9959  2.5948 -5.5577     3 150.8362    19 29004   325 9 1 8 9 9 9 1 910 9
# 127686.7956  2.7453 -5.5714     3 150.8528    19 29004   325 9 1 810 9 9 1 9 9 9
# 128044.6478  2.7454 -5.1335     3 150.8461    21 29004   325 9 1 81010 9 1 91010
# 128183.8586  2.7349 -5.4042     3 150.8362    19 29004   325 9 1 810 9 9 1 910 9, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'        QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str10      str10
# ----------- ------- ------- ----- -------- ----- ----- ----- ---------- ----------
# 137611.5105 23.4518 -5.5564     3 580.3983    37 29004   325 18 2171818 19 1181919
# 137773.7541  23.458 -5.2705     3 580.4012    35 29004   325 18 2171817 19 1181918
# 138090.8016 23.2575  -5.538     3 580.3823    37 29004   325 18 2171818 19 1182019
# 138265.7833 23.9932 -5.5382     3 580.3983    37 29004   325 18 2171918 19 1181919
#  138578.898 23.7575 -5.2188     3 580.3922    39 29004   325 18 2171919 19 1182020
# 138745.0744  23.762 -5.5478     3 580.3823    37 29004   325 18 2171918 19 1182019, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'        QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str10      str10
# ----------- ------- ------- ----- -------- ----- ----- ----- ---------- ----------
# 138745.0744  23.762 -5.5478     3 580.3823    37 29004   325 18 2171918 19 1182019, <Table length=7>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64    str9      str9
# ----------- ------- ------- ----- -------- ----- ------ ----- --------- ---------
# 142947.2799  0.1781 -4.8334     3  125.262    19  29004   325 9 0 910 9 8 1 8 8 8
#  143080.025  0.1001 -4.4676     3  60.7376    11 -29004   325 5 1 5 5 5 6 0 6 6 6
#  143161.676  0.1001  -4.464     3  60.7416     9 -29004   325 5 1 5 5 4 6 0 6 6 5
#  143191.199  0.1001  -4.251     3 125.2619    21 -29004   325 9 0 91010 8 1 8 9 9
#  143340.336  0.1001 -4.4448     3 125.2489    19 -29004   325 9 0 910 9 8 1 8 9 8
# 143837.8694  0.1462  -5.126     3  60.7123    11  29004   325 5 1 5 5 5 6 0 6 7 6
#   143985.56  0.1001 -4.4455     3  125.262    19 -29004   325 9 0 9 9 9 8 1 8 8 8, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64    str9      str9
# ----------- ------- ------- ----- -------- ----- ------ ----- --------- ---------
#   143985.56  0.1001 -4.4455     3  125.262    19 -29004   325 9 0 9 9 9 8 1 8 8 8
#   144138.27  0.1001 -4.3435     3 125.2617    17 -29004   325 9 0 9 9 8 8 1 8 8 7
# 144284.2414   0.154 -5.1484     3  60.7376    11  29004   325 5 1 5 6 5 6 0 6 6 6
#  144378.482  0.1756 -4.8213     3 125.2489    19  29004   325 9 0 9 9 9 8 1 8 9 8
#  144956.679  0.1001 -4.3021     3   60.721    13 -29004   325 5 1 5 6 6 6 0 6 7 7
#  145042.054  0.1001 -4.4514     3  60.7123    11 -29004   325 5 1 5 6 5 6 0 6 7 6, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT    QN'        QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64  int64   str10       str9
# ---------- ------- ------- ----- -------- ----- ------ ----- ---------- ---------
# 242117.059  0.1001  -3.878     3 150.8528    21 -29004   325 10 0101010 9 1 9 9 9
# 242181.559  0.1001 -3.8879     3 150.8556    19 -29004   325 10 01010 9 9 1 9 9 8
# 242614.207  0.2249 -4.9484     3 150.8362    21  29004   325 10 0101010 9 1 910 9, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64    str9      str9
# ----------- ------- ------- ----- ------- ----- ----- ----- --------- ---------
# 245482.1152  0.6221 -4.7612     3 99.9733     7 29004   325 3 2 2 3 3 2 2 1 3 3
# 245515.8059  0.6229 -4.7611     3 99.9736     7 29004   325 3 2 1 3 3 2 2 0 3 3
# 245883.1417  0.6459 -4.8937     3 99.9655     5 29004   325 3 2 2 3 2 2 2 1 3 2
# 245916.8677  0.6467 -4.8936     3 99.9658     5 29004   325 3 2 1 3 2 2 2 0 3 2, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'        QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str10      str10
# ----------- ------- ------- ----- -------- ----- ----- ----- ---------- ----------
# 249174.4936 18.3124 -4.9537     3 524.7415    35 29004   325 17 2161717 18 1171818
# 249338.1545 18.3617  -4.677     3 524.7438    33 29004   325 17 2161716 18 1171817
# 249612.0637 18.1774 -4.9515     3 524.7269    35 29004   325 17 2161717 18 1171918
# 250028.6719 18.8616 -4.9513     3 524.7415    35 29004   325 17 2161817 18 1171818
# 250298.6305 18.6339 -4.6244     3 524.7375    37 29004   325 17 2161818 18 1171919, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT    QN'        QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str10      str10
# ----------- ------- ------- ----- -------- ----- ----- ----- ---------- ----------
# 250298.6305 18.6339 -4.6244     3 524.7375    37 29004   325 17 2161818 18 1171919
#  250466.242 18.6886 -4.9476     3 524.7269    35 29004   325 17 2161817 18 1171918, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64    str9      str9
# ----------- ------- ------- ----- ------- ----- ----- ----- --------- ---------
# 252494.9741   0.131 -4.4733     3 31.4566     7 29004   325 3 1 3 3 3 2 1 2 3 3
# 252890.9887  0.2104  -4.522     3 31.4492     5 29004   325 3 1 3 3 2 2 1 2 3 2, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64    str9      str9
# ----------- ------- ------- ----- ------- ----- ------ ----- --------- ---------
# 255136.9741  0.0936 -4.4742     3 31.4566     7  29004   325 3 1 3 4 3 2 1 2 3 3
#  255341.122  0.1001 -3.1119     3 31.4566     9 -29004   325 3 1 3 4 4 2 1 2 3 3
#   255358.43  0.1001 -3.2463     3 31.4492     7 -29004   325 3 1 3 4 3 2 1 2 3 2, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT    QN'        QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64   str10      str10
# ----------- ------- ------- ----- -------- ----- ------ ----- ---------- ----------
#  255341.122  0.1001 -3.1119     3  31.4566     9 -29004   325  3 1 3 4 4  2 1 2 3 3
#   255358.43  0.1001 -3.2463     3  31.4492     7 -29004   325  3 1 3 4 3  2 1 2 3 2
# 256650.5701  12.375 -5.0241     3 281.5953    25  29004   325 13 1121312 13 1131312
#  256875.347  0.1001 -3.2486     3  31.3105     7 -29004   325  3 1 3 3 3  2 1 2 2 2
#  256892.171  0.1001 -3.4425     3  31.3157     5 -29004   325  3 1 3 3 2  2 1 2 2 1
# 257049.9302  0.0967 -4.4313     3  31.3105     5  29004   325  3 1 3 3 2  2 1 2 2 2, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT    QN'        QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64   str10      str10
# ----------- ------- ------- ----- -------- ----- ------ ----- ---------- ----------
# 257049.9302  0.0967 -4.4313     3  31.3105     5  29004   325  3 1 3 3 2  2 1 2 2 2
# 257947.6535  0.1753 -4.8601     3  99.9733     7  29004   325  3 2 2 4 3  2 2 1 3 3
# 257983.1397  0.1752   -4.86     3  99.9736     7  29004   325  3 2 1 4 3  2 2 0 3 3
# 258162.7715 12.6157  -4.963     3 281.5537    29  29004   325 13 1121414 13 1131414
#  258166.583  0.1001  -3.444     3  99.9733     9 -29004   325  3 2 2 4 4  2 2 1 3 3
#   258180.46  0.1001 -3.5751     3  99.9655     7 -29004   325  3 2 2 4 3  2 2 1 3 2
#  258202.056  0.1001 -3.4439     3  99.9736     9 -29004   325  3 2 1 4 4  2 2 0 3 3
#  258216.096  0.1001  -3.575     3  99.9658     7 -29004   325  3 2 1 4 3  2 2 0 3 2, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64    str9      str9
# ----------- ------- ------- ----- ------- ----- ------ ----- --------- ---------
# 259760.1671  0.1266 -5.0715     3  8.6872     7  29004   325 3 0 3 4 3 2 0 2 3 3
#  260060.329  0.1001 -2.9992     3  8.6872     9 -29004   325 3 0 3 4 4 2 0 2 3 3
#  260082.192  0.1001 -3.1147     3  8.6765     7 -29004   325 3 0 3 4 3 2 0 2 3 2
#  260133.586  0.1001 -3.1581     3   8.693     7 -29004   325 3 0 3 3 3 2 0 2 2 2
#  260155.769  0.1001   -3.33     3  8.6949     5 -29004   325 3 0 3 3 2 2 0 2 2 1
#  260215.378  0.0623 -4.0872     3   8.693     5  29004   325 3 0 3 3 2 2 0 2 2 2
# 260305.8487  0.0582 -4.1058     3  8.6872     7  29004   325 3 0 3 3 3 2 0 2 3 3
# 260670.3437  0.2494 -4.4451     3 31.7443     7  29004   325 3 1 2 3 3 2 1 1 3 3
# 261073.6797  0.3157  -4.505     3 31.7368     5  29004   325 3 1 2 3 2 2 1 1 3 2, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64    str9      str9
# ----------- ------- ------- ----- ------- ----- ------ ----- --------- ---------
# 263702.0188  0.0938 -4.4558     3 31.7443     7  29004   325 3 1 2 4 3 2 1 1 3 3
#  263911.659  0.1001  -3.084     3 31.7443     9 -29004   325 3 1 2 4 4 2 1 1 3 3
#  263927.215  0.1001 -3.2177     3 31.7368     7 -29004   325 3 1 2 4 3 2 1 1 3 2
#  264309.081  0.1001 -3.5822     3 99.3453     7 -29004   325 3 2 2 3 3 2 2 1 2 2
#  264316.003  0.1001 -3.7746     3 99.3506     5 -29004   325 3 2 2 3 2 2 2 1 2 1
#   264343.22  0.1001 -3.5821     3 99.3455     7 -29004   325 3 2 1 3 3 2 2 0 2 2
#  264350.121  0.1001 -3.7745     3 99.3509     5 -29004   325 3 2 1 3 2 2 2 0 2 1
# 264477.1462  0.1461 -4.7361     3 99.3453     5  29004   325 3 2 2 3 2 2 2 1 2 2
# 264511.3742  0.1461  -4.736     3 99.3455     5  29004   325 3 2 1 3 2 2 2 0 2 2, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT    QN'       QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64    str9      str9
# ----------- ------- ------- ----- ------- ----- ------ ----- --------- ---------
# 264511.3742  0.1461  -4.736     3 99.3455     5  29004   325 3 2 1 3 2 2 2 0 2 2
#  265334.325  0.1001 -3.2211     3 31.5887     7 -29004   325 3 1 2 3 3 2 1 1 2 2
#  265348.661  0.1001  -3.415     3 31.5942     5 -29004   325 3 1 2 3 2 2 1 1 2 1
#  265512.391  0.0997 -4.4008     3 31.5887     5  29004   325 3 1 2 3 2 2 1 1 2 2]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.0e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=15, 
               nrows=4, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'HCO', extr_type="coord", crd=crd, 
               EU_cutoff_K=100, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 6.3e+12, v_cen = 12.*u.km/u.s, v_disp = 1.5*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=15, 
                       nrows=4, ncols=5, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'HCO', extr_type="reg", 
                       return_freqs=True, show_2_sigma=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=20, fig_height=15, nrows=4, ncols=5, name_for_plot=f'HCO')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=20, fig_height=15, nrows=4, ncols=5, name_for_plot=f'HCO')
