# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 31501
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=2>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 86433.1021  0.0036 -7.9909     3 1268.0528    61    31   501   303    30     7    24    --    --    --    31     6    25    --    --    -- HDCO False
# 87221.1717  0.0046 -5.9169     3  139.1309    21    31   501   303    10     2     8    --    --    --    11     0    11    --    --    -- HDCO False, <Table length=3>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
#  87478.167   0.004 -7.2831     3 895.6858    51    31   501   303    25     6    20    --    --    --    26     5    21    --    --    -- HDCO False
#  88854.473  0.0082 -6.9089     3 283.3012    31    31   501   303    15     2    13    --    --    --    16     1    16    --    --    -- HDCO False
# 89054.0317  0.0025 -4.7747     3 418.4964    37    31   501   303    18     3    15    --    --    --    18     3    16    --    --    -- HDCO False, <Table length=4>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 90106.8545  0.0029 -6.1535     3  189.1676    23    31   501   303    11     3     8    --    --    --    12     2    11    --    --    -- HDCO False
# 90914.4962  0.0033 -6.9377     3    733.24    49    31   501   303    24     4    21    --    --    --    23     5    18    --    --    -- HDCO False
# 90969.8333  0.0036 -7.2933     3  654.0001    49    31   501   303    24     2    23    --    --    --    23     3    20    --    --    -- HDCO False
# 91255.7633  0.0036 -7.9438     3 1267.8974    61    31   501   303    30     7    23    --    --    --    31     6    26    --    --    -- HDCO False, <Table length=2>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 94408.1817  0.0059 -6.4996     3 1350.0164    67    31   501   303    33     5    28    --    --    --    33     5    29    --    --    -- HDCO False
# 94439.2103  0.0031 -6.3648     3  418.3168    37    31   501   303    18     3    15    --    --    --    17     4    14    --    --    -- HDCO False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 96749.6281  0.0046 -6.6141     3 632.4631    45    31   501   303    22     4    18    --    --    --    23     2    21    --    --    -- HDCO False, <Table length=3>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 97603.4092  0.0035 -6.1418     3   79.5401    15    31   501   303     7     2     5    --    --    --     8     1     8    --    --    -- HDCO False
# 98630.1205  0.0038 -7.1793     3  895.3266    51    31   501   303    25     6    19    --    --    --    26     5    22    --    --    -- HDCO False
# 98719.0728  0.0387  -8.889     3 1468.4939    73    31   501   303    36     3    34    --    --    --    35     4    31    --    --    -- HDCO False, <Table length=1>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 99743.5739  0.0157  -7.871     3 2057.7223    83    31   501   303    41     6    35    --    --    --    41     6    36    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
#  105807.218  0.0079 -6.1346     3 282.7357    31    31   501   303    15     2    13    --    --    --    16     0    16    --    --    -- HDCO False
# 106194.6446  0.0014 -5.6485     3   17.898     9    31   501   303     4     0     4    --    --    --     3     1     3    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 107869.6291  0.0035 -6.5564     3 586.9815    41    31   501   303    20     5    15    --    --    --    21     4    18    --    --    -- HDCO False
# 109290.0365  0.0033 -5.4145     3 846.5925    53    31   501   303    26     4    22    --    --    --    26     4    23    --    --    -- HDCO False, <Table length=4>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 109552.0751  0.0036 -7.3992     3 1073.4967    59    31   501   303    29     5    25    --    --    --    28     6    22    --    --    -- HDCO False
# 109754.2357  0.0029 -5.7656     3   82.2652    17    31   501   303     8     1     7    --    --    --     7     2     6    --    --    -- HDCO False
# 110218.2992  0.0063 -7.8082     3  877.3553    55    31   501   303    27     3    24    --    --    --    28     2    27    --    --    -- HDCO False
# 111201.2811  0.0032 -5.9263     3  305.9099    31    31   501   303    15     3    12    --    --    --    16     1    15    --    --    -- HDCO False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 111717.1688  0.0052 -6.6348     3 793.1413    53    31   501   303    26     2    24    --    --    --    25     4    21    --    --    -- HDCO False
#   111997.81     0.1 -4.2747     3 189.1676    25    31   501   303    12     2    10    --    --    --    12     2    11    --    --    -- HDCO  True
#    112066.6     0.1 -4.2441     3  48.7562    13    31   501   303     6     1     5    --    --    --     6     1     6    --    --    -- HDCO  True
# 112291.7264   0.004 -5.6977     3 116.2819    19    31   501   303     9     2     7    --    --    --    10     0    10    --    --    -- HDCO False
# 113251.1812  0.0038 -6.2104     3 344.6118    35    31   501   303    17     2    16    --    --    --    16     3    13    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 112291.7264   0.004 -5.6977     3 116.2819    19    31   501   303     9     2     7    --    --    --    10     0    10    --    --    -- HDCO False
# 113251.1812  0.0038 -6.2104     3 344.6118    35    31   501   303    17     2    16    --    --    --    16     3    13    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 114492.9052  0.0027 -6.3445     3 498.6695    41    31   501   303    20     3    18    --    --    --    19     4    15    --    --    -- HDCO False
# 115369.4502  0.0105 -7.3235     3 1074.299    59    31   501   303    29     5    24    --    --    --    30     3    27    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 127021.8354  0.0243  -7.873     3 2148.6327    85    31   501   303    42     6    36    --    --    --    42     6    37    --    --    -- HDCO False
# 127238.7398  0.0061 -7.0325     3  876.7875    55    31   501   303    27     3    24    --    --    --    28     1    27    --    --    -- HDCO False, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name Lab
#    MHz      MHz   MHz nm2        1 / cm         u
#  float64  float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4 bool
# --------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- ----
# 128812.86     0.1 -3.2189     3  2.1505     5    31   501   303     2     0     2    --    --    --     1     0     1    --    --    -- HDCO True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 132374.7304  0.0031 -5.8826     3 63.1309    13    31   501   303     6     2     4    --    --    --     7     1     7    --    --    -- HDCO False, <Table length=2>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
#  134284.83     0.1 -3.3195     3    7.7725     5    31   501   303     2     1     1    --    --    --     1     1     0    --    --    -- HDCO  True
# 135125.352   0.005 -7.9893     3 1477.9135    69    31   501   303    34     6    28    --    --    --    33     7    27    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 135593.2624   0.004 -6.1462     3 381.8899    37    31   501   303    18     2    17    --    --    --    17     3    14    --    --    -- HDCO False
# 135859.1388  0.0025 -5.8785     3  39.0947     9    31   501   303     4     2     3    --    --    --     5     1     4    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 137508.6796  0.0083 -6.0316     3  317.31    33    31   501   303    16     2    14    --    --    --    17     0    17    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 139338.4128  0.0031  -5.752     3 142.0403    19    31   501   303     9     3     7    --    --    --    10     2     8    --    --    -- HDCO False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 140666.9999   0.004 -5.3471     3  904.9701    55    31   501   303    27     4    23    --    --    --    27     4    24    --    --    -- HDCO False
# 140857.5901  0.0037 -7.1795     3 1073.4488    59    31   501   303    29     5    24    --    --    --    28     6    23    --    --    -- HDCO False
# 141671.6555   0.004 -6.6016     3  554.0657    45    31   501   303    22     2    21    --    --    --    21     3    18    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 143770.6892  0.0029 -5.7397     3 163.5677    21    31   501   303    10     3     7    --    --    --    11     2    10    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 146080.6596  0.0036 -5.5057     3  95.4112    17    31   501   303     8     2     6    --    --    --     9     0     9    --    --    -- HDCO False
# 146723.7396  0.0033 -4.1437     3 216.8611    27    31   501   303    13     2    11    --    --    --    13     2    12    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 149214.2258  0.0026 -4.0872     3 63.1309    15    31   501   303     7     1     6    --    --    --     7     1     7    --    --    -- HDCO False
# 150094.6212  0.0041 -6.1634     3 421.467    39    31   501   303    19     2    18    --    --    --    18     3    15    --    --    -- HDCO False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 150912.7518  0.0027 -5.8475     3 309.6191    29    31   501   303    14     4    11    --    --    --    15     3    12    --    --    -- HDCO False
# 151821.9614  0.0031 -4.5591     3 502.4886    41    31   501   303    20     3    17    --    --    --    20     3    18    --    --    -- HDCO False, <Table length=4>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 153038.3994  0.0057 -8.1946     3  1626.802    69    31   501   303    34     8    27    --    --    --    35     7    28    --    --    -- HDCO False
#  153252.571  0.0683 -8.4877     3 1709.9475    77    31   501   303    38     4    34    --    --    --    39     2    37    --    --    -- HDCO False
# 153453.2609  0.0041 -6.3919     3  507.5528    43    31   501   303    21     2    20    --    --    --    20     3    17    --    --    -- HDCO False
#   154264.73  0.0104 -6.4362     3 1499.4025    71    31   501   303    35     5    30    --    --    --    35     5    31    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 242532.2162  0.0036  -5.734     3 498.3001    37    31   501   303    18     5    13    --    --    --    19     4    16    --    --    -- HDCO False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
#  243626.735    0.05 -5.3107     3  238.2981    27    31   501   303    13     3    10    --    --    --    14     1    13    --    --    -- HDCO  True
# 243661.7063   0.004  -6.164     3  785.0136    51    31   501   303    25     4    21    --    --    --    24     5    20    --    --    -- HDCO False
# 244697.7847  0.0779 -7.9725     3 2434.2066    91    31   501   303    45     6    39    --    --    --    45     6    40    --    --    -- HDCO False, <Table length=1>
#   FREQ     ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name Lab
#   MHz      MHz   MHz nm2        1 / cm         u
# float64  float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4 bool
# -------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- ----
# 246924.6     0.1 -2.4175     3  17.898     9    31   501   303     4     1     4    --    --    --     3     1     3    --    --    -- HDCO True, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
#    246924.6     0.1 -2.4175     3    17.898     9    31   501   303     4     1     4    --    --    --     3     1     3    --    --    -- HDCO  True
# 247082.5634  0.0055 -6.9306     3 1201.0075    63    31   501   303    31     5    27    --    --    --    30     6    24    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 249485.3831  0.0027 -5.3949     3 276.1411    27    31   501   303    13     4     9    --    --    --    14     3    12    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 251587.3048  0.0099 -7.4483     3 999.3527    59    31   501   303    29     3    26    --    --    --    30     2    29    --    --    -- HDCO False, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4 bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- ----
# 252726.561    0.05  -4.442     3 59.6781    15    31   501   303     7     1     6    --    --    --     7     0     7    --    --    -- HDCO True
# 252964.142    0.05 -4.6793     3 36.4223    13    31   501   303     6     0     6    --    --    --     5     1     5    --    --    -- HDCO True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4 bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- ----
# 256585.538    0.05 -2.3464     3 12.8815     9    31   501   303     4     0     4    --    --    --     3     0     3    --    --    -- HDCO True, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
#  257748.701    0.05 -2.5132     3  35.0289     9    31   501   303     4     2     3    --    --    --     3     2     2    --    --    -- HDCO  True
#  258070.936    0.05 -2.8037     3  62.6723     9    31   501   303     4     3     2    --    --    --     3     3     1    --    --    -- HDCO  True
#  258082.574    0.05 -2.8037     3  62.6724     9    31   501   303     4     3     1    --    --    --     3     3     0    --    --    -- HDCO  True
# 258187.2295  0.0031 -5.9024     3 635.6904    47    31   501   303    23     3    21    --    --    --    22     4    18    --    --    -- HDCO False
#  258813.203    0.05 -5.2644     3 118.6821    17    31   501   303     8     3     5    --    --    --     9     2     8    --    --    -- HDCO  True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 261796.1954  0.0097 -6.7567     3 999.0121    59    31   501   303    29     3    26    --    --    --    30     1    29    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 263894.7048  0.0109 -7.6938     3 1626.802    73    31   501   303    36     6    31    --    --    --    35     7    28    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 267291.4639  0.0024 -5.5563     3 26.1345     7    31   501   303     3     2     1    --    --    --     4     1     4    --    --    -- HDCO False, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name Lab
#    MHz      MHz   MHz nm2        1 / cm         u
#  float64  float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4 bool
# --------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- ----
# 268292.02     0.1 -2.3484     3 18.9678     9    31   501   303     4     1     3    --    --    --     3     1     2    --    --    -- HDCO True, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 270405.0584   0.021 -7.4008     3 1241.7358    67    31   501   303    33     3    31    --    --    --    32     4    28    --    --    -- HDCO False
# 271092.8678  0.0045 -5.6914     3  533.0566    41    31   501   303    20     4    16    --    --    --    21     2    19    --    --    -- HDCO False, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 271999.8067  0.0075 -5.2595     3 1092.8664    61    31   501   303    30     4    26    --    --    --    30     4    27    --    --    -- HDCO False, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz      MHz   MHz nm2        1 / cm          u
#  float64  float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# --------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 273791.68  0.0087 -6.4971     3 432.9502    39    31   501   303    19     2    17    --    --    --    20     1    20    --    --    -- HDCO False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 25., N_tot = 5.0e+12, v_cen = 41.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=8, 
               nrows=2, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'HDCO', extr_type="coord", 
               crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 25., N_tot = 1.6e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=8, 
                       nrows=2, ncols=4, parse_loc=False, ret_tbl=True, line_by_line=True, name_for_plot=f'HDCO', extr_type="reg", 
                       just_data=False, show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=41*u.km/u.s, fig_width=15, fig_height=8, nrows=2, ncols=4, name_for_plot=f'HDCO')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=15, fig_height=8, nrows=2, ncols=4, name_for_plot=f'HDCO')
