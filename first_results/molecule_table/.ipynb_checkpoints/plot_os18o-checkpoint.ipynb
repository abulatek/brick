# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 66502
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=5>
#    FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#    MHz       MHz   nm2 MHz        1 / cm  ...
#  float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ---------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 86674.2637  0.0003 -7.7105     3   7.4583 ...    --    --    -- SOO-18 False
# 86720.4741   0.001 -4.6935     3  87.5002 ...    --    --    -- SOO-18 False
# 87195.3691  0.0013 -5.8984     3 875.2796 ...    --    --    -- SOO-18 False
# 87393.1566  0.0017 -6.1554     3  998.922 ...    --    --    -- SOO-18 False
# 87407.0122  0.0017 -6.1553     3 998.9215 ...    --    --    -- SOO-18 False, <Table length=8>
#    FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#    MHz       MHz   nm2 MHz         1 / cm  ...
#  float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ---------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 87752.6771  0.0004 -4.4285     3   13.8163 ...    --    --    -- SOO-18 False
# 87885.7083  0.0009 -5.2796     3  529.7284 ...    --    --    -- SOO-18 False
# 88201.7437  0.0004 -4.1933     3   26.7944 ...    --    --    -- SOO-18 False
# 88869.5192  0.0009 -4.8979     3  223.8752 ...    --    --    -- SOO-18 False
# 88950.6214  0.0008 -4.8899     3  238.2093 ...    --    --    -- SOO-18 False
# 89035.0551  0.0049 -7.4733     3 1696.8939 ...    --    --    -- SOO-18 False
# 89035.7619  0.0049 -7.4733     3 1696.8939 ...    --    --    -- SOO-18 False
#  89289.517  0.0026 -6.6902     3  1306.739 ...    --    --    -- SOO-18 False, <Table length=13>
#    FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#    MHz       MHz   nm2 MHz         1 / cm  ...
#  float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ---------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 89582.1542  0.0026 -6.6873     3 1306.7385 ...    --    --    -- SOO-18 False
# 89700.8694  0.0003 -7.6605     3    6.0083 ...    --    --    -- SOO-18 False
# 90082.4214  0.0006 -4.9642     3   33.7385 ...    --    --    -- SOO-18 False
# 90093.6371  0.0008  -4.879     3  238.1722 ...    --    --    -- SOO-18 False
# 90217.8674  0.0003 -7.7447     3   12.7021 ...    --    --    -- SOO-18 False
# 90359.9099  0.0003  -8.153     3    32.728 ...    --    --    -- SOO-18 False
# 90359.9427  0.0003  -8.153     3    32.728 ...    --    --    -- SOO-18 False
# 90383.7465  0.0003 -7.8786     3   21.0517 ...    --    --    -- SOO-18 False
# 90391.6973  0.0003 -7.8785     3   21.0518 ...    --    --    -- SOO-18 False
# 90795.0365  0.0003 -7.7392     3   12.7166 ...    --    --    -- SOO-18 False
#  90833.645  0.0007 -4.5758     3   39.7365 ...    --    --    -- SOO-18 False
#  91008.596  0.0008 -4.8181     3   78.5804 ...    --    --    -- SOO-18 False
# 91331.4402  0.0022 -5.8013     3  146.4629 ...    --    --    -- SOO-18 False, <Table length=7>
#    FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#    MHz       MHz   nm2 MHz         1 / cm  ...
#  float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ---------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 91855.5027  0.0004 -5.6987     3    5.4227 ...    --    --    -- SOO-18 False
# 92341.5001   0.001  -5.441     3  626.9704 ...    --    --    -- SOO-18 False
# 92422.5797   0.001 -5.4402     3  626.9678 ...    --    --    -- SOO-18 False
# 92490.3466  0.0061 -7.6645     3  1823.793 ...    --    --    -- SOO-18 False
# 92536.4043   0.006 -7.6641     3 1823.7929 ...    --    --    -- SOO-18 False
# 92948.3847  0.0206 -7.9151     3 1603.0536 ...    --    --    -- SOO-18 False
# 93024.8501   0.001 -5.5338     3  705.1726 ...    --    --    -- SOO-18 False, <Table length=6>
#    FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#    MHz       MHz   nm2 MHz         1 / cm  ...
#  float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ---------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 93629.7758  0.0003 -7.6447     3    7.9228 ...    --    --    -- SOO-18 False
# 94186.5845  0.0019 -5.8753     3   337.496 ...    --    --    -- SOO-18 False
# 94343.8247  0.0015  -5.357     3   369.545 ...    --    --    -- SOO-18 False
# 94402.6013  0.0023 -6.4665     3   1199.63 ...    --    --    -- SOO-18 False
# 94407.2194  0.0023 -6.4664     3 1199.6299 ...    --    --    -- SOO-18 False
# 94940.4212   0.001 -4.6851     3  166.3679 ...    --    --    -- SOO-18 False, <Table length=7>
#    FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#    MHz       MHz   nm2 MHz         1 / cm  ...
#  float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ---------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 95583.4803  0.0008 -4.7779     3   78.4311 ...    --    --    -- SOO-18 False
#  95725.877  0.0088 -7.9177     3 1955.2773 ...    --    --    -- SOO-18 False
# 95726.1016  0.0088 -7.9177     3 1955.2773 ...    --    --    -- SOO-18 False
# 96441.6462  0.0008 -4.8659     3  305.0698 ...    --    --    -- SOO-18 False
# 96817.4029  0.0008 -4.9485     3  341.1174 ...    --    --    -- SOO-18 False
# 97247.2173  0.0008 -4.9447     3  341.1035 ...    --    --    -- SOO-18 False
# 97271.8462   0.001 -4.8616     3  239.8098 ...    --    --    -- SOO-18 False, <Table length=6>
#    FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#    MHz       MHz   nm2 MHz         1 / cm  ...
#  float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ---------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  97636.703  0.0018 -6.2126     3 1097.0211 ...    --    --    -- SOO-18 False
# 98201.0797  0.0005 -4.1039     3   32.6714 ...    --    --    -- SOO-18 False
# 98466.9397  0.0019 -6.2053     3 1097.0198 ...    --    --    -- SOO-18 False
# 98563.3952  0.0024 -6.2257     3  605.8687 ...    --    --    -- SOO-18 False
# 98878.9106  0.0009 -4.7761     3  270.3187 ...    --    --    -- SOO-18 False
# 99012.3742  0.0009 -5.2157     3  553.4115 ...    --    --    -- SOO-18 False, <Table length=10>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  99544.8576  0.0012 -5.6606     3  788.0419 ...    --    --    -- SOO-18 False
#  99572.9005  0.0012 -5.6604     3  788.0409 ...    --    --    -- SOO-18 False
# 100072.2364  0.0002 -4.5574     3    1.8059 ...    --    --    -- SOO-18 False
# 100151.9921  0.0008 -4.7209     3   141.585 ...    --    --    -- SOO-18 False
# 100241.6951  0.0004 -5.6591     3    5.1439 ...    --    --    -- SOO-18 False
#  100897.244  0.0037  -7.101     3 1574.6225 ...    --    --    -- SOO-18 False
# 101034.2007  0.0037 -7.0998     3 1574.6223 ...    --    --    -- SOO-18 False
#  101189.973  0.0006 -4.9346     3   28.5337 ...    --    --    -- SOO-18 False
# 101273.4154  0.0032 -6.8249     3 1418.6026 ...    --    --    -- SOO-18 False
# 101274.9292  0.0032 -6.8249     3 1418.6026 ...    --    --    -- SOO-18 False, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 100241.6951  0.0004 -5.6591     3    5.1439 ...    --    --    -- SOO-18 False
#  100897.244  0.0037  -7.101     3 1574.6225 ...    --    --    -- SOO-18 False
# 101034.2007  0.0037 -7.0998     3 1574.6223 ...    --    --    -- SOO-18 False
#  101189.973  0.0006 -4.9346     3   28.5337 ...    --    --    -- SOO-18 False
# 101273.4154  0.0032 -6.8249     3 1418.6026 ...    --    --    -- SOO-18 False
# 101274.9292  0.0032 -6.8249     3 1418.6026 ...    --    --    -- SOO-18 False
# 101385.4847  0.0008 -4.9798     3  420.0309 ...    --    --    -- SOO-18 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 102098.8024  0.0008 -4.7047     3 141.5216 ...    --    --    -- SOO-18 False
# 102105.3858  0.0014 -5.2052     3  349.054 ...    --    --    -- SOO-18 False
#  103558.815  0.0009  -4.924     3 399.3338 ...    --    --    -- SOO-18 False
# 103761.6085   0.001 -4.8541     3 256.3892 ...    --    --    -- SOO-18 False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 102098.8024  0.0008 -4.7047     3 141.5216 ...    --    --    -- SOO-18 False
# 102105.3858  0.0014 -5.2052     3  349.054 ...    --    --    -- SOO-18 False, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  103558.815  0.0009  -4.924     3  399.3338 ...    --    --    -- SOO-18 False
# 103761.6085   0.001 -4.8541     3  256.3892 ...    --    --    -- SOO-18 False
# 103803.1778   0.014 -8.1829     3 2137.6238 ...    --    --    -- SOO-18 False
# 103823.9006   0.014 -8.1827     3 2137.6238 ...    --    --    -- SOO-18 False
#  103933.826  0.0003 -7.4748     3   10.3494 ...    --    --    -- SOO-18 False
# 104024.5117  0.0024 -5.9827     3  703.5783 ...    --    --    -- SOO-18 False
# 104059.7608  0.0036 -6.7778     3  951.3177 ...    --    --    -- SOO-18 False
# 104329.7947  0.0009 -5.0673     3  462.4318 ...    --    --    -- SOO-18 False
#  104485.904  0.0009  -5.066     3  462.4267 ...    --    --    -- SOO-18 False, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 105807.9474  0.0013 -5.7846     3 905.5867 ...    --    --    -- SOO-18 False
# 106602.8012  0.0016 -5.9295     3 967.4428 ...    --    --    -- SOO-18 False
# 106612.3118  0.0016 -5.9294     3 967.4424 ...    --    --    -- SOO-18 False
# 107207.7856  0.0006 -4.8914     3  28.3356 ...    --    --    -- SOO-18 False
# 107329.2661  0.0003 -7.4325     3   9.0004 ...    --    --    -- SOO-18 False
#  107341.346  0.0013  -5.083     3 329.2145 ...    --    --    -- SOO-18 False, <Table length=16>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 107999.2806  0.0047 -7.2293     3  1655.805 ...    --    --    -- SOO-18 False
# 107999.7689  0.0047 -7.2293     3  1655.805 ...    --    --    -- SOO-18 False
# 108087.9036  0.0013 -5.7659     3  905.5829 ...    --    --    -- SOO-18 False
# 108156.8079  0.0011 -4.8733     3   273.617 ...    --    --    -- SOO-18 False
# 108206.6971  0.0003   -7.49     3   15.7114 ...    --    --    -- SOO-18 False
# 108397.1461  0.0008 -4.7131     3  223.0429 ...    --    --    -- SOO-18 False
# 108437.1146  0.0003 -8.0248     3   50.7435 ...    --    --    -- SOO-18 False
#  108437.115  0.0003 -8.0248     3   50.7435 ...    --    --    -- SOO-18 False
# 108451.5847  0.0003 -7.7338     3   35.7421 ...    --    --    -- SOO-18 False
# 108451.7323  0.0003 -7.7338     3   35.7421 ...    --    --    -- SOO-18 False
# 108493.1398  0.0003 -7.5788     3   24.0666 ...    --    --    -- SOO-18 False
# 108514.3139  0.0003 -7.5786     3   24.0669 ...    --    --    -- SOO-18 False
# 108695.3447  0.0004 -4.1663     3   17.8576 ...    --    --    -- SOO-18 False
# 109057.6852  0.0118 -7.5207     3 1373.5413 ...    --    --    -- SOO-18 False
# 109165.5617  0.0008 -4.7071     3  223.0179 ...    --    --    -- SOO-18 False
# 109209.4103  0.0003  -7.482     3   15.7452 ...    --    --    -- SOO-18 False, <Table length=6>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 109636.2075  0.0006 -4.0197     3   39.1094 ...    --    --    -- SOO-18 False
# 109811.7446  0.0027 -6.5799     3 1343.6594 ...    --    --    -- SOO-18 False
# 110056.1464  0.0013 -4.9877     3  310.0283 ...    --    --    -- SOO-18 False
# 110297.8254  0.0012 -4.9179     3  291.4961 ...    --    --    -- SOO-18 False
# 110462.3835  0.0009 -5.1189     3  553.3897 ...    --    --    -- SOO-18 False
# 110819.3995  0.0008 -4.6825     3    70.065 ...    --    --    -- SOO-18 False, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 111625.2698   0.001 -5.2401     3  602.1287 ...    --    --    -- SOO-18 False
# 111680.4632   0.001 -5.2397     3  602.1269 ...    --    --    -- SOO-18 False
#  111746.692  0.0008 -4.7698     3  323.3456 ...    --    --    -- SOO-18 False
# 112268.0219  0.0003 -7.4095     3   11.0459 ...    --    --    -- SOO-18 False
# 112285.2272  0.0069 -7.5803     3 1867.3036 ...    --    --    -- SOO-18 False
# 112348.0214  0.0069 -7.5798     3 1867.3035 ...    --    --    -- SOO-18 False
# 113254.6645   0.001 -5.4101     3  732.4678 ...    --    --    -- SOO-18 False, <Table length=8>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 112268.0219  0.0003 -7.4095     3   11.0459 ...    --    --    -- SOO-18 False
# 112285.2272  0.0069 -7.5803     3 1867.3036 ...    --    --    -- SOO-18 False
# 112348.0214  0.0069 -7.5798     3 1867.3035 ...    --    --    -- SOO-18 False
# 113254.6645   0.001 -5.4101     3  732.4678 ...    --    --    -- SOO-18 False
# 113519.9097  0.0022 -6.2456     3 1165.1444 ...    --    --    -- SOO-18 False
# 113523.0788  0.0022 -6.2456     3 1165.1443 ...    --    --    -- SOO-18 False
# 113802.2492  0.0008 -4.6609     3   69.9672 ...    --    --    -- SOO-18 False
# 113985.3174   0.001 -4.4316     3   97.1738 ...    --    --    -- SOO-18 False, <Table length=4>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 114572.0648  0.0082 -7.6786     3 1911.1995 ...    --    --    -- SOO-18 False
#   114572.22  0.0082 -7.6786     3 1911.1995 ...    --    --    -- SOO-18 False
# 115401.9979  0.0003 -4.3351     3    3.6089 ...    --    --    -- SOO-18 False
# 115795.7846  0.0007 -4.3092     3   46.3281 ...    --    --    -- SOO-18 False, <Table length=20>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 125372.8136  0.0025  -6.103     3  632.2481 ...    --    --    -- SOO-18 False
#   125451.46   0.001 -4.5874     3  287.3114 ...    --    --    -- SOO-18 False
# 125568.4556  0.0003 -3.7742     3   50.1906 ...    --    --    -- SOO-18 False
# 125738.5252  0.0015 -5.7343     3  936.5733 ...    --    --    -- SOO-18 False
# 125744.9988  0.0015 -5.7343     3   936.573 ...    --    --    -- SOO-18 False
# 125887.4149  0.0003 -3.8059     3   42.7664 ...    --    --    -- SOO-18 False
# 126042.6339  0.0009 -4.7012     3  342.2517 ...    --    --    -- SOO-18 False
# 126165.7675  0.0003 -7.2836     3   19.3208 ...    --    --    -- SOO-18 False
# 126212.8778  0.0014 -5.6872     3   936.504 ...    --    --    -- SOO-18 False
# 126353.8236  0.0002 -3.7435     3    58.215 ...    --    --    -- SOO-18 False
# 126520.9264  0.0003 -7.9315     3   72.6784 ...    --    --    -- SOO-18 False
# 126520.9264  0.0003 -7.9315     3   72.6784 ...    --    --    -- SOO-18 False
# 126526.1687  0.0003  -7.627     3   54.3605 ...    --    --    -- SOO-18 False
#  126526.171  0.0003  -7.627     3   54.3605 ...    --    --    -- SOO-18 False
#  126553.917  0.0003 -7.4573     3   39.3597 ...    --    --    -- SOO-18 False
# 126554.4085  0.0003 -7.4573     3   39.3597 ...    --    --    -- SOO-18 False
# 126617.0414  0.0003  -7.349     3   27.6855 ...    --    --    -- SOO-18 False
# 126664.5852  0.0003 -7.3487     3   27.6866 ...    --    --    -- SOO-18 False
# 126913.6753  0.0045 -7.0144     3 1615.3213 ...    --    --    -- SOO-18 False
# 126914.0106  0.0045 -7.0144     3 1615.3213 ...    --    --    -- SOO-18 False, <Table length=8>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 126913.6753  0.0045 -7.0144     3 1615.3213 ...    --    --    -- SOO-18 False
# 126914.0106  0.0045 -7.0144     3 1615.3213 ...    --    --    -- SOO-18 False
# 127149.9358  0.0003   -3.84     3    35.947 ...    --    --    -- SOO-18 False
# 127644.2083  0.0008 -4.5694     3  208.4921 ...    --    --    -- SOO-18 False
# 127751.5072  0.0004 -7.2729     3    19.388 ...    --    --    -- SOO-18 False
# 128151.3368  0.0008  -4.566     3  208.4756 ...    --    --    -- SOO-18 False
# 128344.9267  0.0009 -4.7676     3   419.972 ...    --    --    -- SOO-18 False
# 128384.4744  0.0003 -3.7129     3   66.8343 ...    --    --    -- SOO-18 False, <Table length=8>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  128661.667  0.0022 -5.6568     3  173.1296 ...    --    --    -- SOO-18 False
# 129175.4664  0.0003 -3.8778     3   29.7365 ...    --    --    -- SOO-18 False
# 129257.2386  0.0014 -5.6663     3  936.4986 ...    --    --    -- SOO-18 False
# 129583.9896  0.0005 -3.9478     3    22.472 ...    --    --    -- SOO-18 False
# 129649.4754  0.0028 -6.5066     3 1381.1904 ...    --    --    -- SOO-18 False
# 130142.7334  0.0003 -4.1483     3    6.0083 ...    --    --    -- SOO-18 False
# 130185.1408  0.0028  -6.503     3 1381.1895 ...    --    --    -- SOO-18 False
# 130201.2061  0.0008 -4.5866     3   62.1708 ...    --    --    -- SOO-18 False, <Table length=8>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 130185.1408  0.0028  -6.503     3 1381.1895 ...    --    --    -- SOO-18 False
# 130201.2061  0.0008 -4.5866     3   62.1708 ...    --    --    -- SOO-18 False
# 130812.0494   0.001 -5.0681     3  577.8989 ...    --    --    -- SOO-18 False
# 130849.2171   0.001 -5.0679     3  577.8977 ...    --    --    -- SOO-18 False
#  130854.942  0.0004 -7.2147     3   14.7908 ...    --    --    -- SOO-18 False
#  131300.436  0.0038 -6.4933     3 1071.7781 ...    --    --    -- SOO-18 False
# 131766.9996  0.0003 -3.9211     3   24.1384 ...    --    --    -- SOO-18 False
#  131783.388  0.0003 -3.6816     3   76.0428 ...    --    --    -- SOO-18 False, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 132076.0799  0.0008 -4.5751     3   62.1091 ...    --    --    -- SOO-18 False
# 132168.0651   0.008 -7.5243     3 1911.4198 ...    --    --    -- SOO-18 False
# 132253.2314   0.008 -7.5238     3 1911.4197 ...    --    --    -- SOO-18 False
# 132573.4483   0.002 -6.0518     3  1131.267 ...    --    --    -- SOO-18 False
# 132575.6064   0.002 -6.0518     3  1131.267 ...    --    --    -- SOO-18 False
# 133375.2452  0.0077  -7.465     3 1867.7252 ...    --    --    -- SOO-18 False
# 133375.3518  0.0077  -7.465     3 1867.7252 ...    --    --    -- SOO-18 False
# 133515.8405  0.0011 -5.3162     3  760.3781 ...    --    --    -- SOO-18 False
# 133712.7209   0.001 -4.9928     3  577.6655 ...    --    --    -- SOO-18 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 133712.7209   0.001 -4.9928     3 577.6655 ...    --    --    -- SOO-18 False
#  134019.096   0.004 -6.6522     3 984.3431 ...    --    --    -- SOO-18 False
# 134717.9339  0.0004  -3.972     3  19.1557 ...    --    --    -- SOO-18 False
# 135306.6454  0.0008 -4.6284     3  305.355 ...    --    --    -- SOO-18 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 135306.6454  0.0008 -4.6284     3  305.355 ...    --    --    -- SOO-18 False
# 135498.0782  0.0008 -4.6272     3 305.3487 ...    --    --    -- SOO-18 False
# 136657.2489  0.0004 -3.6492     3  85.8345 ...    --    --    -- SOO-18 False
# 136749.4126  0.0008 -3.8672     3  53.6535 ...    --    --    -- SOO-18 False, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 137479.7218  0.0009 -4.7877     3  463.2051 ...    --    --    -- SOO-18 False
# 137821.3687  0.0004 -4.0332     3   14.7908 ...    --    --    -- SOO-18 False
# 137885.8286  0.0012 -5.2912     3  732.9377 ...    --    --    -- SOO-18 False
# 137898.6928  0.0012 -5.2911     3  732.9373 ...    --    --    -- SOO-18 False
# 138288.2605   0.001 -5.0088     3  602.5986 ...    --    --    -- SOO-18 False
# 138336.0478  0.0004  -7.113     3   17.8576 ...    --    --    -- SOO-18 False
#  138366.463   0.002 -6.0367     3 1165.4749 ...    --    --    -- SOO-18 False
# 138730.3769  0.0008 -4.4688     3  119.1426 ...    --    --    -- SOO-18 False
# 138752.2791  0.0021 -5.5328     3  646.9233 ...    --    --    -- SOO-18 False, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 138752.2791  0.0021 -5.5328     3  646.9233 ...    --    --    -- SOO-18 False
# 139149.9945  0.0009 -4.6557     3  361.7915 ...    --    --    -- SOO-18 False
# 139256.3178  0.0029 -6.4142     3 1344.2348 ...    --    --    -- SOO-18 False
# 139257.0257  0.0029 -6.4142     3 1344.2348 ...    --    --    -- SOO-18 False
# 139548.8288  0.0008 -4.4639     3  119.1158 ...    --    --    -- SOO-18 False
# 139668.4977  0.0146 -7.9587     3 2138.2869 ...    --    --    -- SOO-18 False
# 139668.5311  0.0146 -7.9587     3 2138.2869 ...    --    --    -- SOO-18 False
# 139864.0851   0.002 -6.0272     3 1165.4723 ...    --    --    -- SOO-18 False
# 140259.4358  0.0006 -4.9034     3    19.388 ...    --    --    -- SOO-18 False, <Table length=10>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 140678.3418  0.0019 -5.6856     3  377.4927 ...    --    --    -- SOO-18 False
# 140879.9804  0.0004 -4.1092     3   11.0459 ...    --    --    -- SOO-18 False
# 141009.7869  0.0008 -4.0874     3   53.5114 ...    --    --    -- SOO-18 False
# 141030.7454  0.0044 -6.9668     3 1656.2767 ...    --    --    -- SOO-18 False
# 141281.5144  0.0043 -6.9653     3 1656.2763 ...    --    --    -- SOO-18 False
# 141372.9371  0.0136 -7.3987     3 1413.1932 ...    --    --    -- SOO-18 False
# 141444.4498  0.0011 -5.2653     3  760.3628 ...    --    --    -- SOO-18 False
# 141890.0348   0.001 -4.2187     3   107.451 ...    --    --    -- SOO-18 False
#  142098.306  0.0004 -7.0816     3   16.7434 ...    --    --    -- SOO-18 False
# 142284.9007  0.0006 -4.8932     3   19.3208 ...    --    --    -- SOO-18 False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 142284.9007  0.0006 -4.8932     3  19.3208 ...    --    --    -- SOO-18 False
# 142706.1756  0.0008 -4.7464     3 420.6245 ...    --    --    -- SOO-18 False
# 142775.9439  0.0008  -4.746     3 420.6222 ...    --    --    -- SOO-18 False
# 143096.2155  0.0004 -3.6158     3  96.2028 ...    --    --    -- SOO-18 False
# 143714.7197  0.0004 -4.2077     3   7.9228 ...    --    --    -- SOO-18 False, <Table length=14>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 144090.2467  0.0004 -7.1107     3  23.5293 ...    --    --    -- SOO-18 False
# 144375.6901  0.0004 -3.9869     3   9.0004 ...    --    --    -- SOO-18 False
# 144609.0972  0.0004 -7.5496     3  76.8987 ...    --    --    -- SOO-18 False
# 144609.0973  0.0004 -7.5496     3  76.8987 ...    --    --    -- SOO-18 False
# 144612.1288  0.0004 -7.8657     3  98.5228 ...    --    --    -- SOO-18 False
# 144612.1288  0.0004 -7.8657     3  98.5228 ...    --    --    -- SOO-18 False
# 144622.6928  0.0004 -7.3675     3   58.581 ...    --    --    -- SOO-18 False
# 144622.7016  0.0004 -7.3675     3   58.581 ...    --    --    -- SOO-18 False
# 144668.5684  0.0004 -7.2458     3  43.5811 ...    --    --    -- SOO-18 False
# 144669.9183  0.0004 -7.2458     3  43.5811 ...    --    --    -- SOO-18 False
# 144755.2462  0.0004 -7.1619     3   31.909 ...    --    --    -- SOO-18 False
# 144804.0145  0.0015 -5.5617     3 906.3132 ...    --    --    -- SOO-18 False
# 144808.3827  0.0015 -5.5617     3 906.3131 ...    --    --    -- SOO-18 False
# 144850.0436  0.0004 -7.1613     3  31.9117 ...    --    --    -- SOO-18 False, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 145780.1436  0.0043 -6.8207     3 1575.4429 ...    --    --    -- SOO-18 False
# 145780.3723  0.0043 -6.8207     3 1575.4429 ...    --    --    -- SOO-18 False
# 146171.2836  0.0004 -4.3469     3    5.4227 ...    --    --    -- SOO-18 False
# 146428.1367  0.0004  -7.097     3   23.6494 ...    --    --    -- SOO-18 False
# 146705.1745  0.0014 -5.6141     3  968.0347 ...    --    --    -- SOO-18 False
# 146720.7422  0.0008   -4.45     3  194.5555 ...    --    --    -- SOO-18 False
# 147048.8212  0.0008 -4.4481     3  194.5448 ...    --    --    -- SOO-18 False, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO   ...  F1l   F2l   F3l   name   Lab
#    MHz       MHz   nm2 MHz        1 / cm ...
#  float64   float64 float64 int64 float64 ... int64 int64 int64  str6   bool
# ---------- ------- ------- ----- ------- ... ----- ----- ----- ------ -----
# 148124.161  0.0004 -4.5874     3  3.5468 ...    --    --    -- SOO-18 False
# 148983.858  0.0022 -5.6023     3 187.297 ...    --    --    -- SOO-18 False, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 149240.8592  0.0008 -4.5228     3   54.8944 ...    --    --    -- SOO-18 False
# 149379.0711  0.0004 -7.0494     3   19.1557 ...    --    --    -- SOO-18 False
# 149908.4502   0.001 -4.9175     3  554.2806 ...    --    --    -- SOO-18 False
# 149933.1972   0.001 -4.9174     3  554.2798 ...    --    --    -- SOO-18 False
# 149996.0553   0.003 -6.4524     3 1419.3304 ...    --    --    -- SOO-18 False
#  150298.691   0.014 -3.7619     3    27.658 ...    --    --    -- SOO-18  True
#  150370.386   0.013 -4.5168     3   54.8571 ...    --    --    -- SOO-18  True
# 150714.2774  0.0029 -6.4483     3 1419.3292 ...    --    --    -- SOO-18 False
# 150740.8446  0.0015 -5.5902     3  968.0272 ...    --    --    -- SOO-18 False, <Table length=14>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 150714.2774  0.0029 -6.4483     3 1419.3292 ...    --    --    -- SOO-18 False
# 150740.8446  0.0015 -5.5902     3  968.0272 ...    --    --    -- SOO-18 False
#  150877.267   0.014 -4.6304     3   381.969 ...    --    --    -- SOO-18  True
#  151170.884   0.013 -3.5816     3  107.1415 ...    --    --    -- SOO-18  True
#  151524.094   0.014 -4.2823     3  193.6543 ...    --    --    -- SOO-18  True
# 151566.0694  0.0019  -5.878     3 1097.9978 ...    --    --    -- SOO-18 False
# 151567.5273  0.0019  -5.878     3 1097.9978 ...    --    --    -- SOO-18 False
# 152136.9703  0.0073 -7.2705     3 1824.8545 ...    --    --    -- SOO-18 False
# 152137.0431  0.0073 -7.2705     3 1824.8545 ...    --    --    -- SOO-18 False
# 152141.9605  0.0094 -7.4892     3 1956.1417 ...    --    --    -- SOO-18 False
# 152256.8794  0.0093 -7.4886     3 1956.1415 ...    --    --    -- SOO-18 False
#  152273.967   0.013 -4.5812     3    3.4074 ...    --    --    -- SOO-18  True
#  152277.031   0.013  -3.799     3   61.7549 ...    --    --    -- SOO-18  True
# 152485.6812   0.002 -5.3538     3  619.5598 ...    --    --    -- SOO-18 False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 152485.6812   0.002 -5.3538     3 619.5598 ...    --    --    -- SOO-18 False
# 152648.0796  0.0026 -6.0167     3 659.1816 ...    --    --    -- SOO-18 False
#  153223.759   0.014 -4.4334     3 304.9173 ...    --    --    -- SOO-18  True
# 153778.0256  0.0011 -5.2445     3 788.9043 ...    --    --    -- SOO-18 False
#  154183.389   0.013 -4.6403     3 441.2248 ...    --    --    -- SOO-18  True, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 241981.6201  0.0028 -5.8965     3 1347.3223 ...    --    --    -- SOO-18 False
#  242215.546   0.013  -3.455     3   88.1234 ...    --    --    -- SOO-18  True
# 242872.9967  0.0006 -6.4541     3   53.6535 ...    --    --    -- SOO-18 False
#  243063.794   0.013 -3.3765     3  293.3523 ...    --    --    -- SOO-18  True
# 243228.9401   0.009 -6.9113     3  1871.051 ...    --    --    -- SOO-18 False
#  243286.851   0.015 -3.8808     3  239.1501 ...    --    --    -- SOO-18  True
#  243374.938   0.013 -3.5321     3  110.5263 ...    --    --    -- SOO-18  True, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
#  243805.784   0.014 -4.0955     3 361.4125 ...    --    --    -- SOO-18  True
#  243962.767   0.014 -3.4828     3  34.0454 ...    --    --    -- SOO-18  True
#  244229.047   0.013  -4.364     3 445.3439 ...    --    --    -- SOO-18  True
#  244231.722   0.013  -4.364     3 445.3438 ...    --    --    -- SOO-18  True
# 244264.8895  0.0088 -6.9076     3 1871.049 ...    --    --    -- SOO-18 False
#   244570.64   0.014 -5.2357     3   146.41 ...    --    --    -- SOO-18  True, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 245375.0034  0.0057 -6.4768     3 1619.5547 ...    --    --    -- SOO-18 False
# 245375.0131  0.0057 -6.4768     3 1619.5547 ...    --    --    -- SOO-18 False
#   245670.75   0.013 -4.7057     3  661.1404 ...    --    --    -- SOO-18  True
#  245707.092   0.013 -5.1958     3  940.7674 ...    --    --    -- SOO-18  True
#  245707.092   0.013 -5.1958     3  940.7674 ...    --    --    -- SOO-18  True
#  246119.338   0.013 -3.5256     3   28.5337 ...    --    --    -- SOO-18  True
# 246199.1431  0.0011 -5.3609     3   61.7549 ...    --    --    -- SOO-18 False, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  247697.431   0.013 -3.5805     3   23.6494 ...    --    --    -- SOO-18  True
# 247837.7278  0.0027 -5.8754     3 1347.3097 ...    --    --    -- SOO-18 False
#  248074.531   0.013   -3.72     3   11.0459 ...    --    --    -- SOO-18  True
#  248124.627   0.013 -4.0839     3  212.7502 ...    --    --    -- SOO-18  True
#  248135.593   0.013 -4.0839     3  212.7499 ...    --    --    -- SOO-18  True
#  248252.755   0.014 -4.8061     3  765.0808 ...    --    --    -- SOO-18  True
#  248330.429   0.014 -3.4994     3   79.8399 ...    --    --    -- SOO-18  True
#  248345.262   0.025 -5.1953     3   836.869 ...    --    --    -- SOO-18  True
#   248435.81   0.013  -3.826     3    7.4583 ...    --    --    -- SOO-18  True, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
#  248771.501   0.013 -3.1435     3  62.1093 ...    --    --    -- SOO-18  True
#  248784.351   0.013 -3.6517     3   19.388 ...    --    --    -- SOO-18  True
#  249479.447   0.013 -3.7475     3  15.7452 ...    --    --    -- SOO-18  True
# 249813.4777   0.002 -5.4653     3 1134.912 ...    --    --    -- SOO-18 False
#  249882.798   0.014 -3.8876     3  12.7166 ...    --    --    -- SOO-18  True
#  250086.391   0.013 -4.1392     3  10.2985 ...    --    --    -- SOO-18  True
#  250231.199   0.014 -4.1388     3  10.2936 ...    --    --    -- SOO-18  True
#  250315.129   0.014 -3.8865     3  12.7021 ...    --    --    -- SOO-18  True
#  250345.539   0.014 -4.2222     3  66.5147 ...    --    --    -- SOO-18  True, <Table length=16>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  250231.199   0.014 -4.1388     3   10.2936 ...    --    --    -- SOO-18  True
#  250315.129   0.014 -3.8865     3   12.7021 ...    --    --    -- SOO-18  True
#  250345.539   0.014 -4.2222     3   66.5147 ...    --    --    -- SOO-18  True
#  250371.875   0.013 -4.2221     3   66.5139 ...    --    --    -- SOO-18  True
#  250481.001   0.013 -3.7451     3   15.7114 ...    --    --    -- SOO-18  True
# 250660.1249  0.0006 -6.4503     3   61.2846 ...    --    --    -- SOO-18 False
#  250723.686   0.013 -5.2387     3  159.4773 ...    --    --    -- SOO-18  True
#  250767.427   0.013 -3.6469     3   19.3208 ...    --    --    -- SOO-18  True
# 251075.1712  0.0102 -6.9493     3 1872.1741 ...    --    --    -- SOO-18 False
# 251075.1743  0.0102 -6.9493     3 1872.1741 ...    --    --    -- SOO-18 False
#  251187.661   0.013 -4.5559     3  582.2624 ...    --    --    -- SOO-18  True
#  251188.632   0.014 -4.5559     3  582.2624 ...    --    --    -- SOO-18  True
#  251218.709   0.013  -3.572     3   23.5293 ...    --    --    -- SOO-18  True
#  251883.708   0.013 -3.5119     3   28.3356 ...    --    --    -- SOO-18  True
#  252000.194   0.013 -5.5347     3 1135.6892 ...    --    --    -- SOO-18  True
#  252000.194   0.013 -5.5347     3 1135.6892 ...    --    --    -- SOO-18  True, <Table length=29>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  252000.194   0.013 -5.5347     3 1135.6892 ...    --    --    -- SOO-18  True
#  252000.194   0.013 -5.5347     3 1135.6892 ...    --    --    -- SOO-18  True
#   252184.57   0.013 -4.7542     3  688.7789 ...    --    --    -- SOO-18  True
#  252312.248   0.014 -3.3671     3  340.6378 ...    --    --    -- SOO-18  True
# 252395.4833  0.0061 -6.4686     3 1121.9578 ...    --    --    -- SOO-18 False
#  252599.032   0.013  -3.391     3  361.1192 ...    --    --    -- SOO-18  True
#  252627.522   0.013 -3.3566     3  199.2688 ...    --    --    -- SOO-18  True
#  252814.788   0.013 -3.4619     3   33.7385 ...    --    --    -- SOO-18  True
# 253192.3239  0.0006 -6.8126     3  161.4372 ...    --    --    -- SOO-18 False
#         ...     ...     ...   ...       ... ...   ...   ...   ...    ...   ...
# 253405.7927  0.0048 -6.3825     3 1619.1849 ...    --    --    -- SOO-18 False
# 253417.8273  0.0006 -6.5643     3   96.5913 ...    --    --    -- SOO-18 False
# 253419.7546  0.0006 -6.5643     3   96.5913 ...    --    --    -- SOO-18 False
#  253469.714   0.014 -5.0944     3  940.8101 ...    --    --    -- SOO-18  True
# 253493.1985  0.0011 -5.4206     3   53.6535 ...    --    --    -- SOO-18 False
#  253497.388   0.013 -3.1454     3   53.6535 ...    --    --    -- SOO-18  True
# 253688.9441  0.0006 -6.5099     3   81.6161 ...    --    --    -- SOO-18 False
# 253739.7653  0.0006  -6.469     3   69.9672 ...    --    --    -- SOO-18 False
# 253766.8687  0.0006 -6.5097     3   81.6194 ...    --    --    -- SOO-18 False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
# 253688.9441  0.0006 -6.5099     3  81.6161 ...    --    --    -- SOO-18 False
# 253739.7653  0.0006  -6.469     3  69.9672 ...    --    --    -- SOO-18 False
# 253766.8687  0.0006 -6.5097     3  81.6194 ...    --    --    -- SOO-18 False
#  253792.684   0.013 -3.3416     3 320.7489 ...    --    --    -- SOO-18  True
#  254066.505   0.014 -3.4196     3  39.7365 ...    --    --    -- SOO-18  True
#  254413.352   0.014 -5.0796     3 805.9255 ...    --    --    -- SOO-18  True
#  254792.746   0.013 -3.4132     3 382.1853 ...    --    --    -- SOO-18  True
# 255285.7014  0.0006  -6.464     3   70.065 ...    --    --    -- SOO-18 False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz        1 / cm  ...
#   float64   float64 float64 int64 float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ... ----- ----- ----- ------ -----
#  255656.599   0.014 -4.1514     3 309.8684 ...    --    --    -- SOO-18  True
#  255660.951   0.014 -4.1514     3 309.8683 ...    --    --    -- SOO-18  True
#  255694.408   0.014 -3.3831     3  46.3281 ...    --    --    -- SOO-18  True
# 256262.8475  0.0046 -6.3726     3 1619.179 ...    --    --    -- SOO-18 False
#  256480.986   0.013 -4.8156     3 717.0739 ...    --    --    -- SOO-18  True
#  256636.258   0.013 -5.0847     3 263.9523 ...    --    --    -- SOO-18  True
#  256860.281   0.014 -5.0687     3 246.9612 ...    --    --    -- SOO-18  True
#  256869.416   0.013  -3.315     3 301.4601 ...    --    --    -- SOO-18  True, <Table length=17>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 257355.4529  0.0006 -6.3925     3   62.1093 ...    --    --    -- SOO-18 False
#  257732.008   0.014  -4.978     3  775.6454 ...    --    --    -- SOO-18  True
#  257753.561   0.013 -3.3514     3   53.5114 ...    --    --    -- SOO-18  True
#  257780.339   0.014 -3.6216     3   154.568 ...    --    --    -- SOO-18  True
# 257827.5895  0.0086 -6.3052     3 1351.3493 ...    --    --    -- SOO-18 False
# 257905.4027  0.0012 -4.7969     3  737.5371 ...    --    --    -- SOO-18 False
# 257905.7393  0.0012 -4.7969     3  737.5371 ...    --    --    -- SOO-18 False
#  257966.378   0.013 -3.3691     3   312.144 ...    --    --    -- SOO-18  True
#  258050.878   0.013 -5.1021     3  281.4917 ...    --    --    -- SOO-18  True
# 258064.4182  0.0017 -5.2433     3  173.0982 ...    --    --    -- SOO-18 False
# 258071.5768  0.0032 -5.9171     3 1348.8799 ...    --    --    -- SOO-18 False
# 258071.5967  0.0032 -5.9171     3 1348.8799 ...    --    --    -- SOO-18 False
#  258381.247   0.015 -4.8901     3  746.0287 ...    --    --    -- SOO-18  True
# 258400.6075  0.0006 -6.4117     3    58.215 ...    --    --    -- SOO-18 False
#  258702.998   0.014 -4.0601     3  123.7707 ...    --    --    -- SOO-18  True
#   258717.05   0.013 -4.0601     3  123.7702 ...    --    --    -- SOO-18  True
#  258800.442   0.014 -5.0548     3  230.5174 ...    --    --    -- SOO-18  True, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 259395.8935  0.0006 -6.3844     3   61.7549 ...    --    --    -- SOO-18 False
# 259408.2521  0.0126 -7.1505     3 1563.1903 ...    --    --    -- SOO-18 False
#  259653.413   0.013 -5.0793     3   24.0669 ...    --    --    -- SOO-18  True
#  259664.021   0.013 -5.0793     3   24.0666 ...    --    --    -- SOO-18  True
#  260297.575   0.014 -3.3235     3   61.2846 ...    --    --    -- SOO-18  True
# 260431.2583  0.0006 -6.4192     3   62.4297 ...    --    --    -- SOO-18 False
#  260479.521   0.014 -3.4705     3   89.5469 ...    --    --    -- SOO-18  True
#  260782.561  0.0096 -6.9918     3 1479.7624 ...    --    --    -- SOO-18 False
#  261021.299   0.014 -5.1203     3  299.5801 ...    --    --    -- SOO-18  True, <Table length=11>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  261340.908   0.013 -3.2877     3  282.7787 ...    --    --    -- SOO-18  True
# 261647.0427  0.0145 -7.2258     3 1605.7028 ...    --    --    -- SOO-18 False
#  261972.275   0.013 -3.6324     3   14.7908 ...    --    --    -- SOO-18  True
# 261997.5958  0.0031 -5.8727     3  772.4471 ...    --    --    -- SOO-18 False
#  262017.183   0.014 -5.0006     3  909.1161 ...    --    --    -- SOO-18  True
# 262401.5657   0.001 -5.4998     3   46.1044 ...    --    --    -- SOO-18 False
#  262526.374   0.014 -5.0437     3  214.6202 ...    --    --    -- SOO-18  True
#  262894.299   0.013 -4.2809     3  425.3847 ...    --    --    -- SOO-18  True
#  262895.941   0.013 -4.2809     3  425.3847 ...    --    --    -- SOO-18  True
# 262932.9092   0.003 -5.8983     3  1385.532 ...    --    --    -- SOO-18 False
#  262954.968   0.014 -3.4931     3  121.9349 ...    --    --    -- SOO-18  True, <Table length=14>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  262894.299   0.013 -4.2809     3  425.3847 ...    --    --    -- SOO-18  True
#  262895.941   0.013 -4.2809     3  425.3847 ...    --    --    -- SOO-18  True
# 262932.9092   0.003 -5.8983     3  1385.532 ...    --    --    -- SOO-18 False
#  262954.968   0.014 -3.4931     3  121.9349 ...    --    --    -- SOO-18  True
#  263377.224   0.013  -3.299     3   69.6457 ...    --    --    -- SOO-18  True
#  263768.338   0.013 -4.6295     3  708.2756 ...    --    --    -- SOO-18  True
# 263918.1757  0.0055 -6.3423     3 1580.3056 ...    --    --    -- SOO-18 False
# 263918.1821  0.0055 -6.3423     3 1580.3056 ...    --    --    -- SOO-18 False
#  264001.896  0.0106 -6.9281     3 1915.8312 ...    --    --    -- SOO-18 False
#  264285.759   0.014 -4.8119     3  794.3586 ...    --    --    -- SOO-18  True
#  264387.747   0.014 -5.0848     3  911.1434 ...    --    --    -- SOO-18  True
#  264387.747   0.014 -5.0848     3  911.1434 ...    --    --    -- SOO-18  True
# 264527.5494  0.0022 -5.5014     3  487.1946 ...    --    --    -- SOO-18 False
# 264655.1795  0.0085 -6.9083     3 1438.8433 ...    --    --    -- SOO-18 False, <Table length=8>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
# 264527.5494  0.0022 -5.5014     3  487.1946 ...    --    --    -- SOO-18 False
# 264655.1795  0.0085 -6.9083     3 1438.8433 ...    --    --    -- SOO-18 False
# 264688.7789  0.0021 -5.4137     3 1134.8766 ...    --    --    -- SOO-18 False
#  265303.211   0.013 -3.4517     3  426.0401 ...    --    --    -- SOO-18  True
# 265356.8064  0.0104 -6.9236     3 1915.8285 ...    --    --    -- SOO-18 False
# 265461.1653  0.0013 -5.1393     3  318.2183 ...    --    --    -- SOO-18 False
# 265662.5201  0.0167 -7.2987     3 1648.7498 ...    --    --    -- SOO-18 False
# 265857.0479  0.0234 -7.2578     3 1577.2873 ...    --    --    -- SOO-18 False, <Table length=11>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  266516.486    0.02 -5.2494     3   187.273 ...    --    --    -- SOO-18  True
#  266645.945   0.013  -4.031     3  199.4498 ...    --    --    -- SOO-18  True
#  266652.241   0.014  -4.031     3  199.4496 ...    --    --    -- SOO-18  True
#  266977.771   0.015 -3.2601     3  264.7116 ...    --    --    -- SOO-18  True
#  266993.908   0.013 -3.3392     3   98.2355 ...    --    --    -- SOO-18  True
#  267039.459   0.014 -3.2772     3   78.5927 ...    --    --    -- SOO-18  True
# 267211.5977  0.0038 -6.2924     3 1110.8472 ...    --    --    -- SOO-18 False
#  267322.273   0.013 -3.0614     3   70.6937 ...    --    --    -- SOO-18  True
#  267593.735   0.015 -5.2703     3  481.9629 ...    --    --    -- SOO-18  True
# 267832.6923  0.0044 -6.3562     3  1146.738 ...    --    --    -- SOO-18 False
#  267979.846   0.013 -3.0747     3   61.7549 ...    --    --    -- SOO-18  True, <Table length=10>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  267979.846   0.013 -3.0747     3   61.7549 ...    --    --    -- SOO-18  True
#  268096.367   0.013 -5.0368     3  199.2688 ...    --    --    -- SOO-18  True
# 268223.1655  0.0006 -6.3785     3   69.6457 ...    --    --    -- SOO-18 False
#  268319.085   0.014 -5.2358     3  458.8408 ...    --    --    -- SOO-18  True
# 268552.9322  0.0034 -6.2265     3 1075.4922 ...    --    --    -- SOO-18 False
#  268618.375   0.013 -4.2516     3    59.873 ...    --    --    -- SOO-18  True
#  268630.658   0.013 -4.2516     3   59.8725 ...    --    --    -- SOO-18  True
#  268639.451   0.014 -5.3046     3  505.6293 ...    --    --    -- SOO-18  True
# 269535.9832  0.0097 -6.8095     3 1829.9292 ...    --    --    -- SOO-18 False
# 269535.9853  0.0097 -6.8095     3 1829.9292 ...    --    --    -- SOO-18 False, <Table length=31>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  269795.292   0.014  -4.298     3  532.3866 ...    --    --    -- SOO-18  True
#  269860.256   0.014 -4.4648     3   559.281 ...    --    --    -- SOO-18  True
#  269860.899   0.015 -4.4648     3   559.281 ...    --    --    -- SOO-18  True
# 270293.7589   0.005 -6.4181     3 1183.1661 ...    --    --    -- SOO-18 False
#  270350.469   0.016 -5.4647     3 1170.1377 ...    --    --    -- SOO-18  True
# 270459.7371   0.002 -5.6856     3  764.3401 ...    --    --    -- SOO-18 False
# 270485.8289   0.003 -5.8732     3  1385.515 ...    --    --    -- SOO-18 False
#  270636.375   0.013 -5.4176     3 1103.0535 ...    --    --    -- SOO-18  True
#  270636.375   0.013 -5.4176     3 1103.0535 ...    --    --    -- SOO-18  True
#         ...     ...     ...   ...       ... ...   ...   ...   ...    ...   ...
# 271333.5886  0.0006 -6.6238     3   144.965 ...    --    --    -- SOO-18 False
# 271333.5892  0.0006 -6.6238     3   144.965 ...    --    --    -- SOO-18 False
# 271357.3306  0.0007 -7.1007     3  264.2664 ...    --    --    -- SOO-18 False
# 271357.3306  0.0007 -7.1007     3  264.2664 ...    --    --    -- SOO-18 False
# 271357.3909  0.0015 -5.3387     3   529.841 ...    --    --    -- SOO-18 False
# 271407.1651  0.0007 -7.2881     3  302.2103 ...    --    --    -- SOO-18 False
# 271407.1651  0.0007 -7.2881     3  302.2103 ...    --    --    -- SOO-18 False
# 271418.3595  0.0006 -6.5476     3  123.3465 ...    --    --    -- SOO-18 False
# 271418.4208  0.0006 -6.5476     3  123.3465 ...    --    --    -- SOO-18 False, <Table length=23>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  271320.269  0.0006 -6.9486     3   229.551 ...    --    --    -- SOO-18 False
#  271320.269  0.0006 -6.9486     3   229.551 ...    --    --    -- SOO-18 False
# 271325.8454  0.0192 -7.3695     3 1692.3327 ...    --    --    -- SOO-18 False
#  271326.437   0.014 -3.2579     3   88.1234 ...    --    --    -- SOO-18  True
# 271333.5886  0.0006 -6.6238     3   144.965 ...    --    --    -- SOO-18 False
# 271333.5892  0.0006 -6.6238     3   144.965 ...    --    --    -- SOO-18 False
# 271357.3306  0.0007 -7.1007     3  264.2664 ...    --    --    -- SOO-18 False
# 271357.3306  0.0007 -7.1007     3  264.2664 ...    --    --    -- SOO-18 False
# 271357.3909  0.0015 -5.3387     3   529.841 ...    --    --    -- SOO-18 False
#         ...     ...     ...   ...       ... ...   ...   ...   ...    ...   ...
# 271595.9689  0.0006 -6.4843     3  105.0444 ...    --    --    -- SOO-18 False
# 271599.6177  0.0006 -6.4843     3  105.0445 ...    --    --    -- SOO-18 False
# 271885.3872  0.0006 -6.3946     3   78.4311 ...    --    --    -- SOO-18 False
# 271920.8458  0.0006  -6.433     3   90.0783 ...    --    --    -- SOO-18 False
# 271976.7842  0.0031 -6.1588     3 1040.6712 ...    --    --    -- SOO-18 False
# 272047.4779  0.0006 -6.4326     3   90.0841 ...    --    --    -- SOO-18 False
#  272235.782   0.013 -3.3318     3  214.6202 ...    --    --    -- SOO-18  True
#  272618.611   0.014 -5.0941     3  973.0553 ...    --    --    -- SOO-18  True
# 272869.0835   0.001 -5.6029     3   39.1094 ...    --    --    -- SOO-18 False, <Table length=12>
#     FREQ      ERR    LGINT    DR     ELO    ...  F1l   F2l   F3l   name   Lab
#     MHz       MHz   nm2 MHz         1 / cm  ...
#   float64   float64 float64 int64  float64  ... int64 int64 int64  str6   bool
# ----------- ------- ------- ----- --------- ... ----- ----- ----- ------ -----
#  273213.793   0.013 -3.4443     3   99.8135 ...    --    --    -- SOO-18  True
#  273527.861   0.014 -3.2327     3  247.2653 ...    --    --    -- SOO-18  True
#  273740.411   0.014 -3.4682     3  448.8136 ...    --    --    -- SOO-18  True
# 273875.3327  0.0023 -5.7835     3  824.4516 ...    --    --    -- SOO-18 False
# 274026.8607  0.0006 -6.3882     3   78.5804 ...    --    --    -- SOO-18 False
# 274196.4412  0.0006 -6.3277     3   70.6937 ...    --    --    -- SOO-18 False
#  274232.847   0.013 -4.0854     3  293.5422 ...    --    --    -- SOO-18  True
#   274235.42   0.013 -4.0854     3  293.5422 ...    --    --    -- SOO-18  True
#  274402.962  0.0056 -6.3951     3 1660.9889 ...    --    --    -- SOO-18 False
# 274471.8738  0.0058 -6.4782     3  1220.133 ...    --    --    -- SOO-18 False
# 274545.0735  0.0018 -5.5834     3  706.3889 ...    --    --    -- SOO-18 False
#  274568.003   0.013  -3.362     3  331.4792 ...    --    --    -- SOO-18  True]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 5.3e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
               nrows=2, ncols=3, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-3.5)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 4.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
                       nrows=2, ncols=3, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-3.5)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
