# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 29003
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=3>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ---------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 85951.7868  0.1322 -5.9777     3 888.8789    51 29003   304 25 62025 26 52126
# 85951.9069  0.1322  -5.961     3 888.8789    53 29003   304 25 62026 26 52127
# 85951.9117  0.1322 -5.9944     3 888.8789    49 29003   304 25 62024 26 52125, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ---------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 87527.2695  0.0152 -4.9073     3 187.7136    21 29003   304 11 3 810 12 21111
# 87527.3079  0.0152 -4.8344     3 187.7136    25 29003   304 11 3 812 12 21113
# 87527.7714  0.0154 -4.8708     3 187.7136    23 29003   304 11 3 811 12 21112
# 88169.8158  0.0275 -5.7738     3 415.2895    35 29003   304 18 31517 18 31617
# 88169.8482  0.0275 -5.7266     3 415.2895    39 29003   304 18 31519 18 31619
# 88170.4315  0.0277 -5.7508     3 415.2895    37 29003   304 18 31518 18 31618, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ---------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 91838.6927  0.1042 -5.6107     3 727.6111    49 29003   304 24 42124 23 51823
# 91838.7087  0.1042 -5.5925     3 727.6111    51 29003   304 24 42125 23 51824
# 91838.7093  0.1042 -5.6288     3 727.6111    47 29003   304 24 42123 23 51822
# 93226.1851  0.0365 -5.9546     3 649.0446    49 29003   304 24 22324 23 32023
# 93227.9433  0.0352 -5.9364     3 649.0446    51 29003   304 24 22325 23 32024
# 93228.0178  0.0353 -5.9727     3 649.0446    47 29003   304 24 22323 23 32022, <Table length=5>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ---------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 95306.1421  0.0159 -4.9153     3  78.946    13 29003   304 7 2 5 6 8 1 8 7
# 95306.3066  0.0219 -6.6593     3  78.946    15 29003   304 7 2 5 7 8 1 8 7
# 95306.3553  0.0152 -4.8048     3  78.946    17 29003   304 7 2 5 8 8 1 8 9
#  95307.884  0.0227 -6.6593     3  78.946    17 29003   304 7 2 5 8 8 1 8 8
# 95308.0277  0.0181 -4.8599     3  78.946    15 29003   304 7 2 5 7 8 1 8 8, <Table length=6>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ---------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 95508.2729  0.0241 -5.0663     3 415.0447    35 29003   304 18 31517 17 41416
# 95508.3002   0.024 -5.0178     3 415.0447    39 29003   304 18 31519 17 41418
# 95508.7866  0.0242  -5.042     3 415.0447    37 29003   304 18 31518 17 41417
# 97015.8637  0.1486 -5.8729     3 888.5225    51 29003   304 25 61925 26 52226
# 97015.9181  0.1486 -5.8562     3 888.5225    53 29003   304 25 61926 26 52227
# 97015.9204  0.1486 -5.8896     3 888.5225    49 29003   304 25 61924 26 52225, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 105793.4649  0.0269 -5.5477     3 17.7524     9 29003   304 4 0 4 4 3 1 3 4
# 105793.5997  0.0225 -4.4897     3 17.7524     7 29003   304 4 0 4 3 3 1 3 2
# 105793.9239  0.0221 -4.2564     3 17.7524    11 29003   304 4 0 4 5 3 1 3 4
# 105794.7282  0.0228 -4.3716     3 17.7524     9 29003   304 4 0 4 4 3 1 3 3
# 105795.3052  0.0297 -5.5477     3 17.7524     7 29003   304 4 0 4 3 3 1 3 3, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 108338.5908  0.1268 -6.3977     3 840.1897    51 29003   304 26 42225 26 42325
# 108338.6084  0.1268 -6.3649     3 840.1897    55 29003   304 26 42227 26 42327
# 108339.0656  0.1268 -6.3816     3 840.1897    53 29003   304 26 42226 26 42326, <Table length=15>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ------ ----- -------- --------
#   109892.05    0.18 -4.4069     3  81.6001    19 -29003   304  8 1 7 9  7 2 6 8
#   109892.05    0.18 -4.5174     3  81.6001    15 -29003   304  8 1 7 7  7 2 6 6
#  109892.401  0.1807 -6.2614     3  81.6001    15  29003   304  8 1 7 7  7 2 6 7
# 109892.8036  0.1806 -6.2614     3  81.6001    17  29003   304  8 1 7 8  7 2 6 8
#   109892.99    0.27 -4.4621     3  81.6001    17 -29003   304  8 1 7 8  7 2 6 7
#   110836.28    0.36 -5.2215     3 187.7136    27 -29003   304 12 21013 12 21113
#   110836.28    0.36 -5.2916     3 187.7136    23 -29003   304 12 21011 12 21111
#   110837.18    0.36 -5.2579     3 187.7136    25 -29003   304 12 21012 12 21112
#   110896.94    0.25 -5.1708     3   48.386    15 -29003   304  6 1 5 7  6 1 6 7
#   110896.94    0.25 -5.3088     3   48.386    11 -29003   304  6 1 5 5  6 1 6 5
# 110897.6289  0.2506 -6.8529     3   48.386    13  29003   304  6 1 5 6  6 1 6 5
# 110897.8723  0.2504 -6.8521     3   48.386    13  29003   304  6 1 5 6  6 1 6 7
#  110898.489  0.2507 -6.8529     3   48.386    11  29003   304  6 1 5 5  6 1 6 6
# 110898.6082  0.2506 -6.8521     3   48.386    15  29003   304  6 1 5 7  6 1 6 6
#   110899.28    0.25  -5.245     3   48.386    13 -29003   304  6 1 5 6  6 1 6 6, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 114549.5659  0.0356 -4.8886     3 341.9443    35 29003   304 17 21617 16 31316
# 114550.5317  0.0351 -4.8629     3 341.9443    37 29003   304 17 21618 16 31317
# 114550.5895  0.0352 -4.9142     3 341.9443    33 29003   304 17 21616 16 31315
#  115614.678  0.0542 -5.0216     3 494.8079    41 29003   304 20 31820 19 41519
# 115614.9237  0.0542 -4.9998     3 494.8079    43 29003   304 20 31821 19 41520
#  115614.936  0.0542 -5.0433     3 494.8079    39 29003   304 20 31819 19 41518, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 127856.5535  0.0324  -4.799     3  2.1346     5 29003   304 2 0 2 2 1 0 1 2
# 127856.6481  0.0314 -4.6741     3  2.1346     3 29003   304 2 0 2 1 1 0 1 0
# 127856.8246  0.0292 -4.3219     3  2.1346     5 29003   304 2 0 2 2 1 0 1 1
# 127856.8758  0.0292 -4.0508     3  2.1346     7 29003   304 2 0 2 3 1 0 1 2
#  127857.326  0.0373  -4.799     3  2.1346     3 29003   304 2 0 2 1 1 0 1 1, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
#  129903.875  0.0172 -4.6624     3  62.656    11 29003   304 6 2 4 5 7 1 7 6
# 129904.1019  0.0165 -4.5355     3  62.656    15 29003   304 6 2 4 7 7 1 7 8
# 129905.6628  0.0191 -4.5988     3  62.656    13 29003   304 6 2 4 6 7 1 7 7, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 133270.6051  0.0347 -4.8996     3  7.7002     3 29003   304 2 1 1 1 1 1 0 1
#   133271.92  0.0338 -4.4225     3  7.7002     5 29003   304 2 1 1 2 1 1 0 1
# 133272.1348  0.0319 -4.1514     3  7.7002     7 29003   304 2 1 1 3 1 1 0 2
# 133272.9801   0.033 -4.8996     3  7.7002     5 29003   304 2 1 1 2 1 1 0 2
# 133273.2553  0.0375 -4.7747     3  7.7002     3 29003   304 2 1 1 1 1 1 0 0
# 133734.2856  0.0244 -4.6013     3 38.7863     9 29003   304 4 2 3 4 5 1 4 5
# 133735.1518  0.0233  -4.511     3 38.7863    11 29003   304 4 2 3 5 5 1 4 6
# 133735.3352  0.0237 -4.6927     3 38.7863     7 29003   304 4 2 3 3 5 1 4 4, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 133734.2856  0.0244 -4.6013     3 38.7863     9 29003   304 4 2 3 4 5 1 4 5
# 133735.1518  0.0233  -4.511     3 38.7863    11 29003   304 4 2 3 5 5 1 4 6
# 133735.3352  0.0237 -4.6927     3 38.7863     7 29003   304 4 2 3 3 5 1 4 4, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 136607.8226  0.0212 -4.4633     3 140.9276    19 29003   304  9 3 7 9 10 2 810
#  136608.358  0.0209 -4.4194     3 140.9276    21 29003   304  9 3 710 10 2 811
# 136608.4133  0.0209 -4.5072     3 140.9276    17 29003   304  9 3 7 8 10 2 8 9
# 136807.5002  0.0497 -4.8258     3 378.9464    37 29003   304 18 21718 17 31417
# 136808.5892  0.0493 -4.8016     3 378.9464    39 29003   304 18 21719 17 31418
# 136808.6508  0.0494 -4.8501     3 378.9464    35 29003   304 18 21717 17 31416, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 140810.1755  0.0153 -4.4907     3 162.3024    19 29003   304 10 3 7 9 11 21010
# 140810.2109  0.0153  -4.411     3 162.3024    23 29003   304 10 3 711 11 21012
# 140810.6057  0.0155 -4.4508     3 162.3024    21 29003   304 10 3 710 11 21011, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ----- ----- -------- --------
#  147817.459  0.0472 -4.5546     3 307.2105    29 29003   304 14 41114 15 31215
# 147817.7442  0.0471 -4.5255     3 307.2105    31 29003   304 14 41115 15 31216
# 147817.7638  0.0471 -4.5837     3 307.2105    27 29003   304 14 41113 15 31214, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ----- ----- -------- --------
#  151295.705  0.0627 -4.8431     3 418.2306    39 29003   304 19 21819 18 31518
#  151296.919  0.0623 -4.8202     3 418.2306    41 29003   304 19 21820 18 31519
# 151296.9842  0.0623  -4.866     3 418.2306    37 29003   304 19 21818 18 31517, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 243275.9549  0.2559 -4.8637     3 779.0091    49 29003   304 25 42124 24 52023
# 243275.9703  0.2559 -4.8289     3 779.0091    53 29003   304 25 42126 24 52025
# 243276.3526  0.2559 -4.8463     3 779.0091    51 29003   304 25 42125 24 52024, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 245124.6763  0.0772 -4.5993     3 17.7524     9 29003   304 4 1 4 4 3 1 3 4
# 245125.9165  0.0752 -3.5413     3 17.7524     7 29003   304 4 1 4 3 3 1 3 2
# 245125.9396  0.0752 -3.4232     3 17.7524     9 29003   304 4 1 4 4 3 1 3 3
# 245126.0145  0.0752  -3.308     3 17.7524    11 29003   304 4 1 4 5 3 1 3 4
# 245127.6219  0.0783 -4.5993     3 17.7524     7 29003   304 4 1 4 3 3 1 3 3, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str7    str7
# ----------- ------- ------- ----- -------- ----- ----- ----- ------- -------
# 245124.6763  0.0772 -4.5993     3  17.7524     9 29003   304 4 1 4 4 3 1 3 4
# 245125.9165  0.0752 -3.5413     3  17.7524     7 29003   304 4 1 4 3 3 1 3 2
# 245125.9396  0.0752 -3.4232     3  17.7524     9 29003   304 4 1 4 4 3 1 3 3
# 245126.0145  0.0752  -3.308     3  17.7524    11 29003   304 4 1 4 5 3 1 3 4
# 245127.6219  0.0783 -4.5993     3  17.7524     7 29003   304 4 1 4 3 3 1 3 3
# 245540.5446  0.0967 -3.6192     3 273.9823    81 29003   303  13 4 9  14 312, <Table length=7>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 250161.2367  0.1121 -3.2127     3  59.237    13 29003   304 7 1 6 6 7 0 7 6
# 250161.4447   0.112  -3.094     3  59.237    17 29003   304 7 1 6 8 7 0 7 8
# 250162.0052  0.1134 -4.8939     3  59.237    15 29003   304 7 1 6 7 7 0 7 6
# 250162.1163   0.113 -4.8934     3  59.237    15 29003   304 7 1 6 7 7 0 7 8
# 250162.1184  0.1134 -4.8939     3  59.237    13 29003   304 7 1 6 6 7 0 7 7
# 250162.2153  0.1131 -4.8934     3  59.237    17 29003   304 7 1 6 8 7 0 7 7
# 250162.8869  0.1123 -3.1572     3  59.237    15 29003   304 7 1 6 7 7 0 7 7, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 251420.5243  0.0676 -4.9323     3 36.1417    13 29003   304 6 0 6 6 5 1 5 6
# 251421.0049  0.0655 -3.4632     3 36.1417    11 29003   304 6 0 6 5 5 1 5 4
# 251421.1784  0.0654 -3.3139     3 36.1417    15 29003   304 6 0 6 7 5 1 5 6
# 251421.9184  0.0656 -3.3882     3 36.1417    13 29003   304 6 0 6 6 5 1 5 5
#  251422.683  0.0687 -4.9323     3 36.1417    11 29003   304 6 0 6 5 5 1 5 5, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 254684.8138  0.0684 -4.5284     3 12.7859     9 29003   304 4 0 4 4 3 0 3 4
# 254685.1973  0.0666 -3.3523     3 12.7859     9 29003   304 4 0 4 4 3 0 3 3
# 254685.2566  0.0666 -3.4704     3 12.7859     7 29003   304 4 0 4 3 3 0 3 2
# 254685.2728  0.0666 -3.2371     3 12.7859    11 29003   304 4 0 4 5 3 0 3 4
# 254685.7743  0.0696 -4.5284     3 12.7859     7 29003   304 4 0 4 3 3 0 3 3
# 255015.9185  0.0406 -4.0216     3 117.748    15 29003   304 8 3 5 7 9 2 8 8
# 255015.9501  0.0406 -3.9238     3 117.748    19 29003   304 8 3 5 9 9 2 810
# 255016.2446  0.0407 -3.9726     3 117.748    17 29003   304 8 3 5 8 9 2 8 9, <Table length=20>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 255840.3344  0.1063 -4.6947     3 34.7133     9 29003   304 4 2 3 4 3 2 2 4
# 255840.3344  0.1063 -3.5186     3 34.7133     9 29003   304 4 2 3 4 3 2 2 3
# 255840.4655  0.1062 -3.4034     3 34.7133    11 29003   304 4 2 3 5 3 2 2 4
# 255840.4992  0.1063 -4.6947     3 34.7133     7 29003   304 4 2 3 3 3 2 2 3
# 255840.4992  0.1063 -3.6367     3 34.7133     7 29003   304 4 2 3 3 3 2 2 2
# 256165.0789  0.1601 -4.9847     3 62.0889     7 29003   304 4 3 2 3 3 3 1 3
# 256165.2469  0.1595 -3.8086     3 62.0889     9 29003   304 4 3 2 4 3 3 1 3
#    256165.5  0.1592 -3.6934     3 62.0889    11 29003   304 4 3 2 5 3 3 1 4
#  256165.601  0.1594 -3.9267     3 62.0889     7 29003   304 4 3 2 3 3 3 1 2
# 256165.6336  0.1594 -4.9847     3 62.0889     9 29003   304 4 3 2 4 3 3 1 4
# 256176.6244  0.1601 -4.9847     3 62.0889     7 29003   304 4 3 1 3 3 3 0 3
# 256176.7944  0.1595 -3.8086     3 62.0889     9 29003   304 4 3 1 4 3 3 0 3
# 256177.0463  0.1592 -3.6934     3 62.0889    11 29003   304 4 3 1 5 3 3 0 4
#  256177.147  0.1594 -3.9267     3 62.0889     7 29003   304 4 3 1 3 3 3 0 2
# 256177.1814  0.1594 -4.9847     3 62.0889     9 29003   304 4 3 1 4 3 3 0 4
# 257112.6822  0.1058 -4.6905     3 34.7346     7 29003   304 4 2 2 3 3 2 1 3
# 257112.7071  0.1058 -3.5144     3 34.7346     9 29003   304 4 2 2 4 3 2 1 3
# 257112.7695  0.1058 -3.3992     3 34.7346    11 29003   304 4 2 2 5 3 2 1 4
# 257112.7893  0.1058 -4.6905     3 34.7346     9 29003   304 4 2 2 4 3 2 1 4
# 257112.7932  0.1058 -3.6325     3 34.7346     7 29003   304 4 2 2 3 3 2 1 2, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT   QN'      QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64   str8     str8
# ----------- ------- ------- ----- -------- ----- ----- ----- -------- --------
# 257112.6822  0.1058 -4.6905     3  34.7346     7 29003   304  4 2 2 3  3 2 1 3
# 257112.7071  0.1058 -3.5144     3  34.7346     9 29003   304  4 2 2 4  3 2 1 3
# 257112.7695  0.1058 -3.3992     3  34.7346    11 29003   304  4 2 2 5  3 2 1 4
# 257112.7893  0.1058 -4.6905     3  34.7346     9 29003   304  4 2 2 4  3 2 1 4
# 257112.7932  0.1058 -3.6325     3  34.7346     7 29003   304  4 2 2 3  3 2 1 2
# 258222.9541  0.3062 -4.5855     3 630.8249    47 29003   304 23 32123 22 41822
# 258223.4114  0.3062 -4.5665     3 630.8249    49 29003   304 23 32124 22 41823
# 258223.4315  0.3062 -4.6044     3 630.8249    45 29003   304 23 32122 22 41821, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 263985.3961   0.043 -4.4047     3 25.9289     5 29003   304 3 2 1 2 4 1 4 3
#  263985.769  0.0421 -4.1714     3 25.9289     9 29003   304 3 2 1 4 4 1 4 5
# 263987.1895   0.044 -4.2866     3 25.9289     7 29003   304 3 2 1 3 4 1 4 4, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 266269.1464  0.0771 -4.5304     3  18.811     7 29003   304 4 1 3 3 3 1 2 3
# 266270.1036  0.0751 -3.3543     3  18.811     9 29003   304 4 1 3 4 3 1 2 3
#  266270.133   0.075 -3.2391     3  18.811    11 29003   304 4 1 3 5 3 1 2 4
#  266270.214   0.075 -3.4724     3  18.811     7 29003   304 4 1 3 3 3 1 2 2
# 266270.8944  0.0764 -4.5304     3  18.811     9 29003   304 4 1 3 4 3 1 2 4, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT   QN'     QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64   str7    str7
# ----------- ------- ------- ----- ------- ----- ----- ----- ------- -------
# 266269.1464  0.0771 -4.5304     3  18.811     7 29003   304 4 1 3 3 3 1 2 3
# 266270.1036  0.0751 -3.3543     3  18.811     9 29003   304 4 1 3 4 3 1 2 3
#  266270.133   0.075 -3.2391     3  18.811    11 29003   304 4 1 3 5 3 1 2 4
#  266270.214   0.075 -3.4724     3  18.811     7 29003   304 4 1 3 3 3 1 2 2
# 266270.8944  0.0764 -4.5304     3  18.811     9 29003   304 4 1 3 4 3 1 2 4]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 20., N_tot = 6.0e+13, v_cen = 41.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=30, fig_height=25, 
               nrows=10, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'CH$_2$NH', extr_type="coord", crd=crd, 
               EU_cutoff_K=100, aij_cutoff=-5, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked, reg = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False, return_mask=True)

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes_masked, temp = 5., N_tot = 3.5e+14, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=30, fig_height=25, 
               nrows=10, ncols=5, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'CH$_2$NH', extr_type="reg", 
               just_data=False, EU_cutoff_K=100, aij_cutoff=-5, show_2_sigma=True)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 5., N_tot = 8.0e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=30, fig_height=25, 
                       nrows=10, ncols=5, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'CH$_2$NH', extr_type="reg", 
                       just_data=False, EU_cutoff_K=100, aij_cutoff=-5, show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=41*u.km/u.s, fig_width=15, fig_height=15, nrows=10, ncols=5, name_for_plot=f'CH$_2$NH', reg=reg)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=15, fig_height=15, nrows=10, ncols=5, name_for_plot=f'CH$_2$NH', reg=reg)
