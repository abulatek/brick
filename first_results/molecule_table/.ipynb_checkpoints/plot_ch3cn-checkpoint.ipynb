# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 41505
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=6>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name     Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str10     bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---------- -----
# 91958.7263  0.0001 -3.8674     3 85.5791    22    41  5051   303     5     4     0    --    --    --     4     4     0    --    --    -- CH3CN, v=0 False
# 91971.1307  0.0001  -3.545     3  50.829    22    41  5051   303     5     3     0    --    --    --     4    -3     0    --    --    -- CH3CN, v=0 False
# 91971.1307  0.0001  -3.545     3  50.829    22    41  5051   303     5    -3     0    --    --    --     4     3     0    --    --    -- CH3CN, v=0 False
# 91979.9946  0.0001 -3.3752     3 26.0019    22    41  5051   303     5     2     0    --    --    --     4     2     0    --    --    -- CH3CN, v=0 False
# 91985.3144  0.0001 -3.2861     3 11.1034    22    41  5051   303     5     1     0    --    --    --     4     1     0    --    --    -- CH3CN, v=0 False
# 91987.0879  0.0001  -3.258     3  6.1368    22    41  5051   303     5     0     0    --    --    --     4     0     0    --    --    -- CH3CN, v=0 False, <Table length=7>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name     Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str10     bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---------- -----
# 110330.3454  0.0001 -3.8013     3 133.3111    26    41  5051   303     6     5     0    --    --    --     5     5     0    --    --    -- CH3CN, v=0 False
# 110349.4707  0.0001 -3.4485     3  88.6465    26    41  5051   303     6     4     0    --    --    --     5     4     0    --    --    -- CH3CN, v=0 False
#  110364.354  0.0001 -3.2456     3  53.8969    26    41  5051   303     6     3     0    --    --    --     5    -3     0    --    --    -- CH3CN, v=0 False
#  110364.354  0.0001 -3.2456     3  53.8969    26    41  5051   303     6    -3     0    --    --    --     5     3     0    --    --    -- CH3CN, v=0 False
# 110374.9894  0.0001 -3.1201     3    29.07    26    41  5051   303     6     2     0    --    --    --     5     2     0    --    --    -- CH3CN, v=0 False
# 110381.3723  0.0001 -3.0501     3  14.1717    26    41  5051   303     6     1     0    --    --    --     5     1     0    --    --    -- CH3CN, v=0 False
# 110383.5002  0.0001 -3.0275     3   9.2052    26    41  5051   303     6     0     0    --    --    --     5     0     0    --    --    -- CH3CN, v=0 False, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name     Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str10     bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---------- -----
#  128690.111  0.0001 -3.7839     3 191.5599    30    41  5051   303     7     6     0    --    --    --     6    -6     0    --    --    -- CH3CN, v=0 False
#  128690.111  0.0001 -3.7839     3 191.5599    30    41  5051   303     7    -6     0    --    --    --     6     6     0    --    --    -- CH3CN, v=0 False
# 128717.3596  0.0001 -3.4039     3 136.9913    30    41  5051   303     7     5     0    --    --    --     6     5     0    --    --    -- CH3CN, v=0 False
# 128739.6691  0.0001 -3.1724     3  92.3274    30    41  5051   303     7     4     0    --    --    --     6     4     0    --    --    -- CH3CN, v=0 False
bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---------- -----
# 257033.4443  0.0002 -3.3699     3 551.4724    58    41  5051   303    14    10     0    --    --    --    13    10     0    --    --    -- CH3CN, v=0 False
#  257127.036  0.0002 -3.0952     3 457.4462    58    41  5051   303    14     9     0    --    --    --    13    -9     0    --    --    -- CH3CN, v=0 False
#  257127.036  0.0002 -3.0952     3 457.4462    58    41  5051   303    14    -9     0    --    --    --    13     9     0    --    --    -- CH3CN, v=0 False
# 257210.8775  0.0002 -2.8598     3 373.2605    58    41  5051   303    14     8     0    --    --    --    13     8     0    --    --    -- CH3CN, v=0 False
# 257284.9354  0.0002  -2.658     3 298.9343    58    41  5051   303    14     7     0    --    --    --    13     7     0    --    --    -- CH3CN, v=0 False
# 257349.1798  0.0002 -2.4867     3 234.4841    58    41  5051   303    14     6     0    --    --    --    13    -6     0    --    --    -- CH3CN, v=0 False
# 257349.1798  0.0002 -2.4867     3 234.4841    58    41  5051   303    14    -6     0    --    --    --    13     6     0    --    --    -- CH3CN, v=0 False
# 257403.5848  0.0002  -2.344     3 179.9246    58    41  5051   303    14     5     0    --    --    --    13     5     0    --    --    -- CH3CN, v=0 False
# 257448.1282  0.0002 -2.2286     3 135.2681    58    41  5051   303    14     4     0    --    --    --    13     4     0    --    --    -- CH3CN, v=0 False
# 257482.7919  0.0002 -2.1395     3 100.5247    58    41  5051   303    14     3     0    --    --    --    13    -3     0    --    --    -- CH3CN, v=0 False
# 257482.7919  0.0002 -2.1395     3 100.5247    58    41  5051   303    14    -3     0    --    --    --    13     3     0    --    --    -- CH3CN, v=0 False
# 257507.5619  0.0002 -2.0763     3  75.7024    58    41  5051   303    14     2     0    --    --    --    13     2     0    --    --    -- CH3CN, v=0 False
# 257522.4279  0.0002 -2.0384     3  60.8067    58    41  5051   303    14     1     0    --    --    --    13     1     0    --    --    -- CH3CN, v=0 False
# 257527.3839  0.0002 -2.0259     3  55.8411    58    41  5051   303    14     0     0    --    --    --    13     0     0    --    --    -- CH3CN, v=0 False, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name     Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str10     bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---------- -----
# 274881.9792  0.0003 -4.8672     3 1034.0912    62    41  5051   303    15    14     0    --    --    --    14    14     0    --    --    -- CH3CN, v=0 False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 30., N_tot = 3.5e+13, v_cen = 41.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=12,
               nrows=5, ncols=5, parse_loc=False, ret_tbl=True, line_by_line=True, name_for_plot=f'CH$_3$CN', 
               print_diag=False, extr_type="coord", crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 10., N_tot = 2.5e+13, v_cen = 13.*u.km/u.s, v_disp = 3*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=12, 
                       nrows=5, ncols=5, parse_loc=False, ret_tbl=True, line_by_line=True, name_for_plot=f'CH$_3$CN', 
                       extr_type="reg", just_data=False, show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=41.*u.km/u.s, fig_width=10, fig_height=10, nrows=5, ncols=5, name_for_plot=f'CH$_3$CN')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=13.*u.km/u.s, fig_width=10, fig_height=10, nrows=5, ncols=5, name_for_plot=f'CH$_3$CN')
