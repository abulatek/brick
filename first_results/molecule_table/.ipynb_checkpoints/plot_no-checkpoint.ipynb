# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 30517
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=18>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 149745.2665  0.0005 -6.8699     2  0.0144     6    30   517   234     2    -1     2     3    --    --     1    -1     1     2    --    -- NO, v=0 False
#  149787.552  0.0005 -7.3977     2  0.0144     4    30   517   234     2    -1     2     2    --    --     1    -1     1     2    --    -- NO, v=0 False
#  149814.445  0.0005 -8.3005     2  0.0144     2    30   517   234     2    -1     2     1    --    --     1    -1     1     2    --    -- NO, v=0 False
# 149992.8068  0.0005 -7.2999     2  0.0075     4    30   517   234     2    -1     2     2    --    --     1    -1     1     1    --    -- NO, v=0 False
# 150019.6997  0.0005 -7.3965     2  0.0075     2    30   517   234     2    -1     2     1    --    --     1    -1     1     1    --    -- NO, v=0 False
#   150176.48    0.04 -5.1908     2     0.0     6    30   517   234     2    -1     2     3    --    --     1     1     1     2    --    -- NO, v=0  True
#   150198.76    0.04 -5.6222     2  0.0007     4    30   517   234     2    -1     2     2    --    --     1     1     1     1    --    -- NO, v=0  True
#   150218.73    0.04 -5.7191     2     0.0     4    30   517   234     2    -1     2     2    --    --     1     1     1     2    --    -- NO, v=0  True
#   150225.66    0.04 -5.7191     2  0.0007     2    30   517   234     2    -1     2     1    --    --     1     1     1     1    --    -- NO, v=0  True
# 150245.6356  0.0005 -6.6222     2     0.0     2    30   517   234     2    -1     2     1    --    --     1     1     1     2    --    -- NO, v=0 False
# 150375.2987  0.0005 -6.6202     2  0.0144     2    30   517   234     2     1     2     1    --    --     1    -1     1     2    --    -- NO, v=0 False
#   150439.12    0.04 -5.7171     2  0.0144     4    30   517   234     2     1     2     2    --    --     1    -1     1     2    --    -- NO, v=0  True
#   150546.52    0.04 -5.1888     2  0.0144     6    30   517   234     2     1     2     3    --    --     1    -1     1     2    --    -- NO, v=0  True
#   150580.56    0.04 -5.7171     2  0.0075     2    30   517   234     2     1     2     1    --    --     1    -1     1     1    --    -- NO, v=0  True
#   150644.34    0.04 -5.6201     2  0.0075     4    30   517   234     2     1     2     2    --    --     1    -1     1     1    --    -- NO, v=0  True
# 150786.5045  0.0005 -7.3919     2  0.0007     2    30   517   234     2     1     2     1    --    --     1     1     1     1    --    -- NO, v=0 False
# 150806.4894  0.0005 -8.2935     2     0.0     2    30   517   234     2     1     2     1    --    --     1     1     1     2    --    -- NO, v=0 False
# 150850.3003  0.0005 -7.2953     2  0.0007     4    30   517   234     2     1     2     2    --    --     1     1     1     1    --    -- NO, v=0 False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 150786.5045  0.0005 -7.3919     2  0.0007     2    30   517   234     2     1     2     1    --    --     1     1     1     1    --    -- NO, v=0 False
# 150806.4894  0.0005 -8.2935     2     0.0     2    30   517   234     2     1     2     1    --    --     1     1     1     2    --    -- NO, v=0 False
# 150850.3003  0.0005 -7.2953     2  0.0007     4    30   517   234     2     1     2     2    --    --     1     1     1     1    --    -- NO, v=0 False
# 150870.2852  0.0005 -7.3908     2     0.0     4    30   517   234     2     1     2     2    --    --     1     1     1     2    --    -- NO, v=0 False
# 150977.6533  0.0005  -6.863     2     0.0     6    30   517   234     2     1     2     3    --    --     1     1     1     2    --    -- NO, v=0 False, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 249635.6463  0.0009 -6.2355     2  5.0361     8    30   517   234     3     1     3     4    --    --     2     1     2     3    --    -- NO, v=0 False
# 249681.7433  0.0009  -7.156     2  5.0361     6    30   517   234     3     1     3     3    --    --     2     1     2     3    --    -- NO, v=0 False
# 249716.5085  0.0009 -8.5359     2  5.0361     4    30   517   234     3     1     3     2    --    --     2     1     2     3    --    -- NO, v=0 False
# 249789.1114  0.0009 -6.4356     2  5.0325     6    30   517   234     3     1     3     3    --    --     2     1     2     2    --    -- NO, v=0 False
# 249823.8766  0.0009 -7.1555     2  5.0325     4    30   517   234     3     1     3     2    --    --     2     1     2     2    --    -- NO, v=0 False
# 249887.6724  0.0009 -6.6605     2  5.0304     4    30   517   234     3     1     3     2    --    --     2     1     2     1    --    -- NO, v=0 False, <Table length=18>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  250436.848    0.02 -4.5565     2  5.0093     8    30   517   234     3     1     3     4    --    --     2    -1     2     3    --    -- NO, v=0  True
#  250440.659    0.02 -4.7571     2  5.0108     6    30   517   234     3     1     3     3    --    --     2    -1     2     2    --    -- NO, v=0  True
#   250448.53    0.02 -4.9824     2  5.0117     4    30   517   234     3     1     3     2    --    --     2    -1     2     1    --    -- NO, v=0  True
#  250475.414    0.02 -5.4773     2  5.0108     4    30   517   234     3     1     3     2    --    --     2    -1     2     2    --    -- NO, v=0  True
#  250482.939    0.02 -5.4773     2  5.0093     6    30   517   234     3     1     3     3    --    --     2    -1     2     3    --    -- NO, v=0  True
#  250517.703    0.05 -6.8575     2  5.0093     4    30   517   234     3     1     3     2    --    --     2    -1     2     3    --    -- NO, v=0  True
#    250645.8    0.05 -6.8563     2  5.0361     4    30   517   234     3    -1     3     2    --    --     2     1     2     3    --    -- NO, v=0  True
#  250708.245    0.03 -5.4761     2  5.0361     6    30   517   234     3    -1     3     3    --    --     2     1     2     3    --    -- NO, v=0  True
#  257825.025    0.04 -4.9569     2 124.9152     8    30   517   234     2    -1     3     4    --    --     1     1     2     3    --    -- NO, v=0  True
# 257825.3207  0.0009 -7.2529     2 124.9127     4    30   517   234     2    -1     3     2    --    --     1    -1     2     2    --    -- NO, v=0 False
# 257826.0732  0.0009 -6.3323     2 124.9152     8    30   517   234     2    -1     3     4    --    --     1    -1     2     3    --    -- NO, v=0 False
# 257852.1528  0.0009 -6.5329     2 124.9127     6    30   517   234     2     1     3     3    --    --     1     1     2     2    --    -- NO, v=0 False
#  257852.746    0.02 -5.1576     2 124.9127     6    30   517   234     2     1     3     3    --    --     1    -1     2     2    --    -- NO, v=0  True
#  257855.289    0.02 -5.1576     2 124.9127     6    30   517   234     2    -1     3     3    --    --     1     1     2     2    --    -- NO, v=0  True
# 257855.8853  0.0009 -6.5329     2 124.9127     6    30   517   234     2    -1     3     3    --    --     1    -1     2     2    --    -- NO, v=0 False
# 257866.2107  0.0009 -6.7582     2 124.9112     4    30   517   234     2     1     3     2    --    --     1     1     2     1    --    -- NO, v=0 False
#  257867.355    0.02 -5.3829     2 124.9112     4    30   517   234     2     1     3     2    --    --     1    -1     2     1    --    -- NO, v=0  True
#   257870.04    0.02 -5.3829     2 124.9112     4    30   517   234     2    -1     3     2    --    --     1     1     2     1    --    -- NO, v=0  True
# 257871.1669  0.0009 -6.7581     2 124.9112     4    30   517   234     2    -1     3     2    --    --     1    -1     2     1    --    -- NO, v=0 False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
freqs_mom0 = model_and_plot(cubes, temp = 50., N_tot = 7.8e+14, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
                            mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=15, fig_height=8, 
                            nrows=2, ncols=3, parse_loc=False, line_by_line=True, name_for_plot=f'NO', extr_type="coord", crd=crd,
                            show_2_sigma=True, EU_cutoff_K=100, aij_cutoff=-6, return_freqs=True)

# %%
# Get subcubes based on mask
cubes_masked, reg = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False, return_mask=True)

# %%
# Generate the model and plot the model and data spectra
EUs, log_N_upper_gs = model_and_plot(cubes_masked, temp = 50., N_tot = 4.7e+14, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                                     mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=15, fig_height=8, 
                                     nrows=2, ncols=3, parse_loc=False, line_by_line=True, name_for_plot=f'NO', extr_type="reg", just_data=False,
                                     show_2_sigma=True, EU_cutoff_K=100, aij_cutoff=-6, calc_N_uppers=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs_mom0, v_cen=40*u.km/u.s, fig_width=10, fig_height=8, nrows=2, ncols=3, name_for_plot=f'CP', reg=reg)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs_mom0, v_cen=12*u.km/u.s, fig_width=10, fig_height=8, nrows=2, ncols=3, name_for_plot=f'CP', reg=reg)
