# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 56007 # 56502
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64 str3 str3
# --------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 86181.391    0.02 -3.0991     2 13.3512    13 -56007   102  7 6  6 5, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64 str3 str3
# --------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 90686.381    0.02 -2.9892     2 15.1266    15 -56007   102  7 7  6 6, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 str4 str4
# ---------- ------- ------- ----- ------- ----- ------ ----- ---- ----
#  93870.107    0.02 -2.8847     2 10.6944    17 -56007   102  7 8  6 7
# 94939.4807  0.0568 -4.7604     2 39.7579    25  56007   102 1312 1212, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64 str3 str3
# --------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 99866.521    0.02 -2.9073     2 16.2259    15 -56007   102  8 7  7 6, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 str3 str3
# ---------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 103640.759    0.02 -2.8199     2 18.1516    17 -56007   102  8 8  7 7, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 str3 str3
# ---------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 103640.759    0.02 -2.8199     2 18.1516    17 -56007   102  8 8  7 7, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64 str4 str4
# ----------- ------- ------- ----- ------- ----- ------ ----- ---- ----
#  106347.726    0.02 -2.7319     2 13.8255    19 -56007   102  8 9  7 8
# 106362.6554  0.0656 -4.7157     2 45.3753    27  56007   102 1413 1313, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 str3 str3
# ---------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 113410.186    0.02 -2.7441     2 19.5571    17 -56007   102  9 8  8 7, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64 str4 str3
# ---------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 126840.489  0.0078 -2.6027     2 23.3401    19 56007   102 10 9  9 8, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64 str4 str3
# ---------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 126840.489  0.0078 -2.6027     2 23.3401    19 56007   102 10 9  9 8, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 str4
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----
# 129548.4543  0.0058 -2.5429     2 25.4979    21 56007   102  1010  9 9
# 129719.8916  0.0838 -4.6451     2 57.9063    31 56007   102  1615 1515, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 131551.9738  0.0063 -2.4762     2 21.3395    23 56007   102  1011   910, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 str4
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----
# 140180.7509  0.0082 -2.4784     2  27.571    21 56007   102  1110 10 9, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 141602.2974  0.0932 -4.6175     2 64.8197    33 56007   102  1716  1616, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 142501.703  0.0061 -2.4274     2 29.8191    23 56007   102  1111  1010, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 144244.8364  0.0065 -2.3679     2 25.7276    25 56007   102  1112  1011, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 153449.7818  0.0084 -2.3679     2 32.2469    23 56007   102  1211  1110
#  153594.005  0.1029 -4.5942     2 72.1652    35 56007   102  1817  1717, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64 str4 str4
# ----------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 243579.9751  0.5835 -4.3445     2 17.3729    19  56007   102  9 9  8 9
#  245244.865    0.02 -1.8417     2 77.2885    37 -56007   102 1918 1817, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ------ ----- ----- -----
#  245244.865    0.02 -1.8417     2 77.2885    37 -56007   102  1918  1817
# 245504.2963  0.6687 -5.7936     2 54.0441    31  56007   102  1615  1516
#  246107.804    0.02  -1.821     2 79.9425    39 -56007   102  1919  1818
#  246815.631    0.02 -1.7876     2  76.167    41 -56007   102  1920  1819, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 int64 int64
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 246815.631    0.02 -1.7876     2  76.167    41 -56007   102  1920  1819, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 252051.5964  0.1985  -4.521     2 146.476    51 56007   102  2625  2525, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 252051.5964  0.1985  -4.521     2 146.476    51 56007   102  2625  2525, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 254213.7722  0.5898 -4.3203     2 21.3395    21 56007   102  1010   910, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 256431.0708  0.6761 -5.8329     2 60.9895    33 56007   102  1716  1617, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 int64 int64
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 258274.287    0.02 -1.7907     2  85.469    39 -56007   102  2019  1918, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64 str4 str4
# ----------- ------- ------- ----- ------- ----- ------ ----- ---- ----
#  259700.955    0.02 -1.7397     2 84.3998    43 -56007   102 2021 1920
# 260721.0872  0.5625 -4.7083     2   2.242     9  56007   102  5 4  2 3, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- -----
# 264562.9229  0.2152 -4.5227     2 157.7079    53 56007   102  2726  2626
# 265163.5014  0.5963 -4.3002     2  25.7276    23 56007   102  1111  1011, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- -----
# 264562.9229  0.2152 -4.5227     2 157.7079    53 56007   102  2726  2626, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 267561.8128  0.6818 -5.8721     2 68.3636    35 56007   102  1817  1718, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64 int64 int64
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 271292.24    0.02  -1.744     2 94.0841    41 -56007   102  2120  2019, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64 int64 int64
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 272002.261    0.02 -1.7264     2  96.793    43 -56007   102  2121  2020
# 272592.967    0.02 -1.6959     2 93.0625    45 -56007   102  2122  2021]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 5.5e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=15, 
               nrows=4, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'CCS', 
               extr_type="coord", crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 10., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 1.5*u.km/u.s, 
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=15,
                       nrows=4, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'CCS', extr_type="reg",  
                       show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=4, ncols=5, name_for_plot=f'CCS')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=4, ncols=5, name_for_plot=f'CCS')
