# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 46003 # 46509
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ---------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 95108.2334  0.1045 -5.1507     3 111.7947    81 46003   303 13 112 13 113, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64  str5  str5
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 101477.62    0.12 -3.6341     3 12.5521    21 -46003   303 3 1 3 2 1 2, <Table length=3>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64  str5  str5
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 103039.99     0.1 -4.3594     3 40.0668     7 -46003   303 3 2 2 2 2 1
# 103040.22    0.15 -4.0278     3  3.4374     7 -46003   303 3 0 3 2 0 2
# 103051.81    0.28 -4.3593     3 40.0669     7 -46003   303 3 2 1 2 2 0, <Table length=3>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64  str5  str5
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 103039.99     0.1 -4.3594     3 40.0668     7 -46003   303 3 2 2 2 2 1
# 103040.22    0.15 -4.0278     3  3.4374     7 -46003   303 3 0 3 2 0 2
# 103051.81    0.28 -4.3593     3 40.0669     7 -46003   303 3 2 1 2 2 0, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64  str5  str5
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 104617.04    0.07 -3.6079     3 12.6568    21 -46003   303 3 1 2 2 1 1, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 109709.3633  0.1725 -5.0909     3 127.5742    87 46003   303 14 113 14 114, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 125341.2339  0.2735 -5.0397     3 144.4779    93 46003   303 15 114 15 115, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 135297.811    0.25 -3.2444     3  15.937    27 -46003   303 4 1 4 3 1 3, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 135297.811    0.25 -3.2444     3  15.937    27 -46003   303 4 1 4 3 1 3, <Table length=5>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64  int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ------ ----- ----- -----
#  137369.17    0.25 -3.7147     3 89.1451    27 -46003   303 4 3 2 3 3 1
#  137369.17    0.25 -3.7147     3 89.1451    27 -46003   303 4 3 1 3 3 0
# 137371.051     0.3 -3.6615     3  6.8745     9 -46003   303 4 0 4 3 0 3
# 137382.029    0.32 -3.8626     3 43.5038     9 -46003   303 4 2 3 3 2 2
#  137411.77    0.25 -3.8624     3 43.5043     9 -46003   303 4 2 2 3 2 1, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64  str5  str5
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 139483.41    0.28 -3.2185     3 16.1465    27 -46003   303 4 1 3 3 1 2, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 142000.0259   0.419 -4.9962     3 162.5056    99 46003   303 16 115 16 116, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64  str5  str5
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 244047.84    0.59 -2.5104     3 33.5928    45 -46003   303 7 1 6 6 1 5, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 263208.3174  3.2309 -4.8693     3 294.2374   135 46003   303 22 121 22 122, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 270520.7397  0.3169 -2.3767     3 40.7563    51 46003   303 8 1 8 7 1 7, <Table length=12>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str5  str5
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- -----
#  274370.276  1.5891 -3.8895     3   473.65    51 46003   303 8 7 2 7 7 1
#  274370.276  1.5891 -3.8895     3   473.65    51 46003   303 8 7 1 7 7 0
# 274481.9679  0.4154 -3.8543     3 358.0058    17 46003   303 8 6 3 7 6 2
# 274481.9679  0.4154 -3.8543     3 358.0058    17 46003   303 8 6 2 7 6 1
# 274520.8698  0.3318 -2.8163     3   32.069    17 46003   303 8 0 8 7 0 7
# 274577.7104  0.3822 -3.0274     3 259.3034    51 46003   303 8 5 4 7 5 3
# 274577.7104  0.3822 -3.0274     3 259.3034    51 46003   303 8 5 3 7 5 2
#  274659.389  0.4416 -3.2447     3 177.9678    17 46003   303 8 4 5 7 4 4
# 274659.3915  0.4416 -3.2447     3 177.9678    17 46003   303 8 4 4 7 4 3
# 274702.0548  0.2753 -2.9201     3  68.7058    17 46003   303 8 2 7 7 2 6
# 274731.9806  0.3289 -2.5757     3 114.3466    51 46003   303 8 3 6 7 3 5
# 274733.3198  0.3276 -2.5757     3 114.3467    51 46003   303 8 3 5 7 3 4]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 35., N_tot = 1.0e+14, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=10, 
               nrows=4, ncols=4, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'H$_2$CS', 
               extr_type="coord", crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes_masked, temp = 10., N_tot = 8.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=10, 
               nrows=4, ncols=4, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'H$_2$CS', 
               extr_type="reg", just_data=False, show_2_sigma=True)

# %%
freqs = model_and_plot(cubes_masked, temp = 10., N_tot = 5.0e+13, v_cen = 39.5*u.km/u.s, v_disp = 2.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=10, 
                       nrows=4, ncols=4, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'H$_2$CS', 
                       extr_type="reg", just_data=False, return_freqs=True, show_2_sigma=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=8, fig_height=8, nrows=4, ncols=4, name_for_plot=f'H$_2$CS')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=8, fig_height=8, nrows=4, ncols=4, name_for_plot=f'H$_2$CS')
