# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 37501
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=6>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 86423.6579  0.0844 -5.1026     2  181.448    41    37  5011   325    20     0     1    20    20    --    21     1     0    21    21    -- C3H, v4=0,1mS False
# 86427.5997  0.0907 -5.1237     2 181.4478    39    37  5011   325    20     0     1    20    19    --    21     1     0    21    20    -- C3H, v4=0,1mS False
# 86874.1742   8.301 -5.4536     2 472.1342    73    37  5011   325    35     1     0    36    36    --    34     0     1    35    35    -- C3H, v4=0,1mS False
# 86874.5175   8.312 -5.4658     2 472.1344    71    37  5011   325    35     1     0    36    35    --    34     0     1    35    34    -- C3H, v4=0,1mS False
# 87163.7501  0.2697 -5.6672     2  181.448    43    37  5011   325    20     0     1    21    21    --    21     1     0    21    21    -- C3H, v4=0,1mS False
# 87175.1588  0.2726  -5.688     2 181.4478    41    37  5011   325    20     0     1    21    20    --    21     1     0    21    20    -- C3H, v4=0,1mS False, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 88675.9432   8.402 -7.8184     2 423.4704    65    37  5011   325    33    -1     0    33    32    --    33     1     0    34    33    -- C3H, v4=0,1mS False
# 88692.2338   8.402 -7.8053     2 423.4703    67    37  5011   325    33    -1     0    33    33    --    33     1     0    34    34    -- C3H, v4=0,1mS False
# 88776.9984   8.253 -5.2432     2 286.6026    53    37  5011   325    26     0     1    27    26    --    27     1     0    28    27    -- C3H, v4=0,1mS False
# 88777.9326   8.244 -5.2274     2 286.6025    55    37  5011   325    26     0     1    27    27    --    27     1     0    28    28    -- C3H, v4=0,1mS False, <Table length=12>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
#   89730.57    0.05  -3.349     2  31.6799    11    37  5011   325     4     0     1     5     5    --     3     0     1     4     4    -- C3H, v4=0,1mS  True
#   89730.57    0.05 -3.4478     2    31.68     9    37  5011   325     4     0     1     5     4    --     3     0     1     4     3    -- C3H, v4=0,1mS  True
# 89733.2737  0.0694 -5.0138     2  31.6799     9    37  5011   325     4     0     1     5     4    --     3     0     1     4     4    -- C3H, v4=0,1mS False
# 89754.1855   0.091 -4.8632     2  31.6836     7    37  5011   325     4     0     1     4     3    --     3     0     1     3     3    -- C3H, v4=0,1mS False
#  89759.353    0.05 -3.4524     2  31.6836     9    37  5011   325     4     0     1     4     4    --     3     0     1     3     3    -- C3H, v4=0,1mS  True
#  89759.894    0.05  -3.582     2  31.6835     7    37  5011   325     4     0     1     4     3    --     3     0     1     3     2    -- C3H, v4=0,1mS  True
# 89863.6841   0.131 -5.0346     2    31.68     7    37  5011   325     4     0     1     4     3    --     3     0     1     4     3    -- C3H, v4=0,1mS False
# 89866.2259   0.107 -6.4383     2  31.6799     7    37  5011   325     4     0     1     4     3    --     3     0     1     4     4    -- C3H, v4=0,1mS False
#  89868.856  0.0997 -6.3027     2    31.68     9    37  5011   325     4     0     1     4     4    --     3     0     1     4     3    -- C3H, v4=0,1mS False
# 89871.3979  0.1141 -4.8776     2  31.6799     9    37  5011   325     4     0     1     4     4    --     3     0     1     4     4    -- C3H, v4=0,1mS False
# 89874.2228  0.6645 -5.2742     2 352.6164    59    37  5011   325    30    -1     0    30    29    --    29     0     1    29    28    -- C3H, v4=0,1mS False
# 89878.3497  0.6626 -5.2594     2 352.6166    61    37  5011   325    30    -1     0    30    30    --    29     0     1    29    29    -- C3H, v4=0,1mS False, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 91714.1369  0.3227 -6.7863     2 181.2963    43    37  5011   325    20     0     1    21    21    --    21    -1     0    21    21    -- C3H, v4=0,1mS False
# 91728.3919  0.3259  -6.807     2 181.2959    41    37  5011   325    20     0     1    21    20    --    21    -1     0    21    20    -- C3H, v4=0,1mS False
# 92562.9734   8.343 -7.7035     2 398.8032    63    37  5011   325    32     1     0    32    31    --    32    -1     0    33    32    -- C3H, v4=0,1mS False
# 92579.0478   8.343   -7.69     2 398.8031    65    37  5011   325    32     1     0    32    32    --    32    -1     0    33    33    -- C3H, v4=0,1mS False, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 93932.6883  0.5324 -6.0543     2 352.4811    59    37  5011   325    30    -1     0    30    29    --    29     0     1    30    29    -- C3H, v4=0,1mS False
# 93944.2216  0.5237 -6.0397     2 352.4809    61    37  5011   325    30    -1     0    30    30    --    29     0     1    30    30    -- C3H, v4=0,1mS False
# 95192.8708  0.6752 -7.4238     2  374.924    61    37  5011   325    31    -1     0    31    30    --    30     0     1    31    30    -- C3H, v4=0,1mS False
# 95208.6546  0.6732 -7.4098     2 374.9239    63    37  5011   325    31    -1     0    31    31    --    30     0     1    31    31    -- C3H, v4=0,1mS False, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 95494.1522   7.307 -7.8359     2 557.9431    75    37  5011   325    38    -1     0    38    37    --    38    -1     0    39    38    -- C3H, v4=0,1mS False
# 95506.9255   7.306 -7.8246     2  557.943    77    37  5011   325    38    -1     0    38    38    --    38    -1     0    39    39    -- C3H, v4=0,1mS False
# 96560.1825   8.303 -7.5904     2 374.8784    61    37  5011   325    31    -1     0    31    30    --    31     1     0    32    31    -- C3H, v4=0,1mS False
#  96576.026   8.303 -7.5765     2 374.8783    63    37  5011   325    31    -1     0    31    31    --    31     1     0    32    32    -- C3H, v4=0,1mS False, <Table length=10>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 97727.1269    7.44 -7.7081     2 529.5637    73    37  5011   325    37     1     0    37    36    --    37     1     0    38    37    -- C3H, v4=0,1mS False
# 97739.8001   7.439 -7.6964     2 529.5636    75    37  5011   325    37     1     0    37    37    --    37     1     0    38    38    -- C3H, v4=0,1mS False
#  97995.166    0.05  -3.219     2   5.4486    11    37  5011   325     4     1     0     5     5    --     4    -1     0     4     4    -- C3H, v4=0,1mS  True
#  97995.913    0.05 -3.3184     2   5.4489     9    37  5011   325     4     1     0     5     4    --     4    -1     0     4     3    -- C3H, v4=0,1mS  True
# 98005.1714  0.0044 -4.8624     2   5.4486     9    37  5011   325     4     1     0     5     4    --     4    -1     0     4     4    -- C3H, v4=0,1mS False
# 98005.4653  0.0046 -4.8622     2   5.4454     9    37  5011   325     4    -1     0     5     4    --     4     1     0     4     4    -- C3H, v4=0,1mS False
#  98011.611    0.05 -3.2188     2   5.4454    11    37  5011   325     4    -1     0     5     5    --     4     1     0     4     4    -- C3H, v4=0,1mS  True
#  98012.524    0.05 -3.3182     2   5.4452     9    37  5011   325     4    -1     0     5     4    --     4     1     0     4     3    -- C3H, v4=0,1mS  True
# 99375.2985   8.179  -7.627     2  286.249    53    37  5011   325    26     0     1    27    26    --    27    -1     0    28    27    -- C3H, v4=0,1mS False
# 99388.8863    8.17 -7.6112     2 286.2485    55    37  5011   325    26     0     1    27    27    --    27    -1     0    28    28    -- C3H, v4=0,1mS False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
#  100075.986   7.562 -7.5758     2 501.9268    71    37  5011   325    36    -1     0    36    35    --    36    -1     0    37    36    -- C3H, v4=0,1mS False
# 100088.5506   7.561 -7.5639     2 501.9266    73    37  5011   325    36    -1     0    36    36    --    36    -1     0    37    37    -- C3H, v4=0,1mS False
# 100677.8659   8.278 -7.4792     2  351.696    59    37  5011   325    30     1     0    30    29    --    30    -1     0    31    30    -- C3H, v4=0,1mS False
#  100693.468   8.278 -7.4649     2 351.6959    61    37  5011   325    30     1     0    30    30    --    30    -1     0    31    31    -- C3H, v4=0,1mS False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 100677.8659   8.278 -7.4792     2  351.696    59    37  5011   325    30     1     0    30    29    --    30    -1     0    31    30    -- C3H, v4=0,1mS False
#  100693.468   8.278 -7.4649     2 351.6959    61    37  5011   325    30     1     0    30    30    --    30    -1     0    31    31    -- C3H, v4=0,1mS False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
#  102551.512   7.672 -7.4381     2 475.0322    69    37  5011   325    35     1     0    35    34    --    35     1     0    36    35    -- C3H, v4=0,1mS False
#  102563.958   7.672 -7.4259     2 475.0321    71    37  5011   325    35     1     0    35    35    --    35     1     0    36    36    -- C3H, v4=0,1mS False
# 103311.8121  0.1051 -4.8903     2  19.4368     9    37  5011   325     5    -1     0     5     4    --     3     1     0     4     4    -- C3H, v4=0,1mS False
#  103319.276    0.05 -3.2469     2  19.4368    11    37  5011   325     5    -1     0     5     5    --     3     1     0     4     4    -- C3H, v4=0,1mS  True
#  103319.786    0.05 -3.3462     2  19.4365     9    37  5011   325     5    -1     0     5     4    --     3     1     0     4     3    -- C3H, v4=0,1mS  True
# 103365.2961  0.1053 -4.8899     2  19.4386     9    37  5011   325     5     1     0     5     4    --     3    -1     0     4     4    -- C3H, v4=0,1mS False
#  103372.483    0.05 -3.2464     2  19.4386    11    37  5011   325     5     1     0     5     5    --     3    -1     0     4     4    -- C3H, v4=0,1mS  True
#  103373.094    0.05 -3.3458     2  19.4383     9    37  5011   325     5     1     0     5     4    --     3    -1     0     4     3    -- C3H, v4=0,1mS  True, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
#  102551.512   7.672 -7.4381     2 475.0322    69    37  5011   325    35     1     0    35    34    --    35     1     0    36    35    -- C3H, v4=0,1mS False
#  102563.958   7.672 -7.4259     2 475.0321    71    37  5011   325    35     1     0    35    35    --    35     1     0    36    36    -- C3H, v4=0,1mS False
# 103311.8121  0.1051 -4.8903     2  19.4368     9    37  5011   325     5    -1     0     5     4    --     3     1     0     4     4    -- C3H, v4=0,1mS False
#  103319.276    0.05 -3.2469     2  19.4368    11    37  5011   325     5    -1     0     5     5    --     3     1     0     4     4    -- C3H, v4=0,1mS  True
#  103319.786    0.05 -3.3462     2  19.4365     9    37  5011   325     5    -1     0     5     4    --     3     1     0     4     3    -- C3H, v4=0,1mS  True
# 103365.2961  0.1053 -4.8899     2  19.4386     9    37  5011   325     5     1     0     5     4    --     3    -1     0     4     4    -- C3H, v4=0,1mS False
#  103372.483    0.05 -3.2464     2  19.4386    11    37  5011   325     5     1     0     5     5    --     3    -1     0     4     4    -- C3H, v4=0,1mS  True
#  103373.094    0.05 -3.3458     2  19.4383     9    37  5011   325     5     1     0     5     4    --     3    -1     0     4     3    -- C3H, v4=0,1mS  True, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 104636.0456  0.0674 -4.9249     2 165.8782    39    37  5011   325    19     0     1    19    19    --    20    -1     0    20    20    -- C3H, v4=0,1mS False
# 104640.0133  0.0731  -4.947     2 165.8779    37    37  5011   325    19     0     1    19    18    --    20    -1     0    20    19    -- C3H, v4=0,1mS False
# 104644.0883  0.0718 -7.7262     2 165.8779    39    37  5011   325    19     0     1    19    19    --    20    -1     0    20    19    -- C3H, v4=0,1mS False
# 104927.2774   8.264 -7.3698     2  329.256    57    37  5011   325    29    -1     0    29    28    --    29     1     0    30    29    -- C3H, v4=0,1mS False
# 104942.6216   8.264  -7.355     2 329.2559    59    37  5011   325    29    -1     0    29    29    --    29     1     0    30    30    -- C3H, v4=0,1mS False
# 105028.2988  0.2736 -5.4658     2 165.8782    41    37  5011   325    19     0     1    20    20    --    20    -1     0    20    20    -- C3H, v4=0,1mS False
# 105039.8132  0.2768 -5.4879     2 165.8779    39    37  5011   325    19     0     1    20    19    --    20    -1     0    20    19    -- C3H, v4=0,1mS False
# 105166.7985   7.772 -7.2934     2 448.8801    67    37  5011   325    34    -1     0    34    33    --    34    -1     0    35    34    -- C3H, v4=0,1mS False
# 105179.1139   7.771 -7.2808     2 448.8799    69    37  5011   325    34    -1     0    34    34    --    34    -1     0    35    35    -- C3H, v4=0,1mS False, <Table length=9>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 107938.3872   7.861 -7.1396     2 423.4704    65    37  5011   325    33     1     0    33    32    --    33     1     0    34    33    -- C3H, v4=0,1mS False
# 107950.5566    7.86 -7.1266     2 423.4703    67    37  5011   325    33     1     0    33    33    --    33     1     0    34    34    -- C3H, v4=0,1mS False
# 108067.7887   8.265 -5.1487     2  266.389    51    37  5011   325    25     0     1    26    25    --    26    -1     0    27    26    -- C3H, v4=0,1mS False
# 108070.7105   8.258 -5.1322     2 266.3889    53    37  5011   325    25     0     1    26    26    --    26    -1     0    27    27    -- C3H, v4=0,1mS False
# 108749.4409   8.365 -5.3005     2 498.2991    75    37  5011   325    36    -1     0    37    37    --    35     0     1    36    36    -- C3H, v4=0,1mS False
#  108749.862   8.376 -5.3124     2 498.2993    73    37  5011   325    36    -1     0    37    36    --    35     0     1    36    35    -- C3H, v4=0,1mS False
# 108933.9443  0.7947 -5.1356     2  375.049    61    37  5011   325    31     1     0    31    30    --    30     0     1    30    29    -- C3H, v4=0,1mS False
# 108938.1807  0.7931 -5.1213     2 375.0491    63    37  5011   325    31     1     0    31    31    --    30     0     1    30    30    -- C3H, v4=0,1mS False
#  109292.223  0.3225 -6.7673     2  165.736    41    37  5011   325    19     0     1    20    20    --    20     1     0    20    20    -- C3H, v4=0,1mS False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 110888.3268   7.939 -6.9738     2 398.8032    63    37  5011   325    32    -1     0    32    31    --    32    -1     0    33    32    -- C3H, v4=0,1mS False
# 110900.3299   7.938 -6.9604     2 398.8031    65    37  5011   325    32    -1     0    32    32    --    32    -1     0    33    33    -- C3H, v4=0,1mS False, <Table length=12>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
#  112166.938    0.05 -3.0798     2   34.673    13    37  5011   325     5     0     1     6     6    --     4     0     1     5     5    -- C3H, v4=0,1mS  True
#  112166.938    0.05   -3.16     2  34.6731    11    37  5011   325     5     0     1     6     5    --     4     0     1     5     4    -- C3H, v4=0,1mS  True
# 112169.8481  0.0694 -4.9102     2   34.673    11    37  5011   325     5     0     1     6     5    --     4     0     1     5     5    -- C3H, v4=0,1mS False
# 112189.1755  0.0864  -4.789     2  34.6777     9    37  5011   325     5     0     1     5     4    --     4     0     1     4     4    -- C3H, v4=0,1mS False
#  112194.054    0.05 -3.1623     2  34.6777    11    37  5011   325     5     0     1     5     5    --     4     0     1     4     4    -- C3H, v4=0,1mS  True
# 112194.3475  0.0129 -3.2613     2  34.6775     9    37  5011   325     5     0     1     5     4    --     4     0     1     4     3    -- C3H, v4=0,1mS False
# 112327.2997  0.1484 -4.9223     2  34.6731     9    37  5011   325     5     0     1     5     4    --     4     0     1     5     4    -- C3H, v4=0,1mS False
#   112330.09  0.1272 -6.5446     2   34.673     9    37  5011   325     5     0     1     5     4    --     4     0     1     5     5    -- C3H, v4=0,1mS False
# 112332.1864  0.1208 -6.4087     2  34.6731    11    37  5011   325     5     0     1     5     5    --     4     0     1     5     4    -- C3H, v4=0,1mS False
# 112334.9767  0.1345 -4.7979     2   34.673    11    37  5011   325     5     0     1     5     5    --     4     0     1     5     5    -- C3H, v4=0,1mS False
# 112680.8906  0.6655 -5.9526     2  374.924    61    37  5011   325    31     1     0    31    30    --    30     0     1    31    30    -- C3H, v4=0,1mS False
# 112692.6366  0.6564 -5.9386     2 374.9239    63    37  5011   325    31     1     0    31    31    --    30     0     1    31    31    -- C3H, v4=0,1mS False, <Table length=12>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 112327.2997  0.1484 -4.9223     2  34.6731     9    37  5011   325     5     0     1     5     4    --     4     0     1     5     4    -- C3H, v4=0,1mS False
#   112330.09  0.1272 -6.5446     2   34.673     9    37  5011   325     5     0     1     5     4    --     4     0     1     5     5    -- C3H, v4=0,1mS False
# 112332.1864  0.1208 -6.4087     2  34.6731    11    37  5011   325     5     0     1     5     5    --     4     0     1     5     4    -- C3H, v4=0,1mS False
# 112334.9767  0.1345 -4.7979     2   34.673    11    37  5011   325     5     0     1     5     5    --     4     0     1     5     5    -- C3H, v4=0,1mS False
# 112680.8906  0.6655 -5.9526     2  374.924    61    37  5011   325    31     1     0    31    30    --    30     0     1    31    30    -- C3H, v4=0,1mS False
# 112692.6366  0.6564 -5.9386     2 374.9239    63    37  5011   325    31     1     0    31    31    --    30     0     1    31    31    -- C3H, v4=0,1mS False
# 113347.0469  0.8533 -7.4628     2 398.1099    63    37  5011   325    32     1     0    32    31    --    31     0     1    32    31    -- C3H, v4=0,1mS False
#  113363.004  0.8516 -7.4492     2 398.1098    65    37  5011   325    32     1     0    32    32    --    31     0     1    32    32    -- C3H, v4=0,1mS False
# 113871.6099   8.258 -7.1563     2 286.6026    53    37  5011   325    27    -1     0    27    26    --    27     1     0    28    27    -- C3H, v4=0,1mS False
# 113886.3893   8.258 -7.1404     2 286.6025    55    37  5011   325    27    -1     0    27    27    --    27     1     0    28    28    -- C3H, v4=0,1mS False
# 114048.2024   8.007 -6.7918     2 374.8784    61    37  5011   325    31     1     0    31    30    --    31     1     0    32    31    -- C3H, v4=0,1mS False
# 114060.0081   8.007  -6.778     2 374.8783    63    37  5011   325    31     1     0    31    31    --    31     1     0    32    32    -- C3H, v4=0,1mS False, <Table length=7>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 114048.2024   8.007 -6.7918     2 374.8784    61    37  5011   325    31     1     0    31    30    --    31     1     0    32    31    -- C3H, v4=0,1mS False
# 114060.0081   8.007  -6.778     2 374.8783    63    37  5011   325    31     1     0    31    31    --    31     1     0    32    32    -- C3H, v4=0,1mS False
# 114591.6687  0.2588 -7.6212     2  44.3202    17    37  5011   325     7     0     1     8     8    --     9     1     0     9     9    -- C3H, v4=0,1mS False
# 114601.8645  0.2604 -7.6727     2    44.32    15    37  5011   325     7     0     1     8     7    --     9     1     0     9     8    -- C3H, v4=0,1mS False
# 115187.5755  0.2672 -5.3277     2  44.3004    17    37  5011   325     7     0     1     8     8    --     9    -1     0     9     9    -- C3H, v4=0,1mS False
# 115195.3723  0.2649 -7.5098     2  44.3001    17    37  5011   325     7     0     1     8     8    --     9    -1     0     9     8    -- C3H, v4=0,1mS False
# 115198.5362  0.2684 -5.3792     2  44.3001    15    37  5011   325     7     0     1     8     7    --     9    -1     0     9     8    -- C3H, v4=0,1mS False, <Table length=12>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 125534.7024   8.156 -6.0672     2 307.5582    55    37  5011   325    28    -1     0    28    27    --    28    -1     0    29    28    -- C3H, v4=0,1mS False
# 125545.4272   8.155 -6.0521     2 307.5581    57    37  5011   325    28    -1     0    28    28    --    28    -1     0    29    29    -- C3H, v4=0,1mS False
# 126219.1849  0.0869 -4.7957     2  22.8831    11    37  5011   325     6     1     0     6     5    --     5    -1     0     5     5    -- C3H, v4=0,1mS False
# 126226.5444  0.0136 -2.9828     2  22.8831    13    37  5011   325     6     1     0     6     6    --     5    -1     0     5     5    -- C3H, v4=0,1mS False
# 126226.6928  0.0135 -3.0633     2  22.8829    11    37  5011   325     6     1     0     6     5    --     5    -1     0     5     4    -- C3H, v4=0,1mS False
# 126297.3426  0.0871 -4.7952     2  22.8867    11    37  5011   325     6    -1     0     6     5    --     5     1     0     5     5    -- C3H, v4=0,1mS False
# 126304.3383  0.0142 -2.9823     2  22.8867    13    37  5011   325     6    -1     0     6     6    --     5     1     0     5     5    -- C3H, v4=0,1mS False
#  126304.595  0.0139 -3.0628     2  22.8865    11    37  5011   325     6    -1     0     6     5    --     5     1     0     5     4    -- C3H, v4=0,1mS False
# 126509.8067   7.685 -7.4548     2 398.2821    63    37  5011   325    32    -1     0    32    31    --    32     1     0    33    32    -- C3H, v4=0,1mS False
# 126533.9314   7.685 -7.4413     2 398.2816    65    37  5011   325    32    -1     0    32    32    --    32     1     0    33    33    -- C3H, v4=0,1mS False
# 126885.6023  0.3222 -6.7473     2 150.9267    39    37  5011   325    18     0     1    19    19    --    19    -1     0    19    19    -- C3H, v4=0,1mS False
# 126899.5863  0.3261 -6.7704     2 150.9264    37    37  5011   325    18     0     1    19    18    --    19    -1     0    19    18    -- C3H, v4=0,1mS False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 126885.6023  0.3222 -6.7473     2 150.9267    39    37  5011   325    18     0     1    19    19    --    19    -1     0    19    19    -- C3H, v4=0,1mS False
# 126899.5863  0.3261 -6.7704     2 150.9264    37    37  5011   325    18     0     1    19    18    --    19    -1     0    19    18    -- C3H, v4=0,1mS False
# 128133.3242   0.953 -5.0265     2  398.228    63    37  5011   325    32    -1     0    32    31    --    31     0     1    31    30    -- C3H, v4=0,1mS False
# 128137.6305  0.9519 -5.0126     2 398.2281    65    37  5011   325    32    -1     0    32    32    --    31     0     1    31    31    -- C3H, v4=0,1mS False
# 128593.6677   7.814 -7.3706     2 374.3932    61    37  5011   325    31     1     0    31    30    --    31    -1     0    32    31    -- C3H, v4=0,1mS False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 128593.6677   7.814 -7.3706     2 374.3932    61    37  5011   325    31     1     0    31    30    --    31    -1     0    32    31    -- C3H, v4=0,1mS False
# 128617.6956   7.813 -7.3566     2 374.3927    63    37  5011   325    31     1     0    31    31    --    31    -1     0    32    32    -- C3H, v4=0,1mS False
# 128623.4124   8.274 -6.8491     2 228.1873    47    37  5011   325    24     1     0    24    23    --    24    -1     0    25    24    -- C3H, v4=0,1mS False
#  128637.202   8.275 -6.8313     2 228.1872    49    37  5011   325    24     1     0    24    24    --    24    -1     0    25    25    -- C3H, v4=0,1mS False, <Table length=14>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 130541.6531   8.461 -5.1859     2 525.2092    77    37  5011   325    37     1     0    38    38    --    36     0     1    37    37    -- C3H, v4=0,1mS False
# 130542.1506   8.472 -5.1975     2 525.2093    75    37  5011   325    37     1     0    38    37    --    36     0     1    37    36    -- C3H, v4=0,1mS False
# 130821.8603   8.188 -5.7127     2 286.6026    53    37  5011   325    27     1     0    27    26    --    27     1     0    28    27    -- C3H, v4=0,1mS False
# 130831.5918   8.185  -5.697     2 286.6025    55    37  5011   325    27     1     0    27    27    --    27     1     0    28    28    -- C3H, v4=0,1mS False
# 130972.5792   7.918 -7.2893     2 351.2455    59    37  5011   325    30    -1     0    30    29    --    30     1     0    31    30    -- C3H, v4=0,1mS False
# 130996.4672   7.918 -7.2749     2  351.245    61    37  5011   325    30    -1     0    30    30    --    30     1     0    31    31    -- C3H, v4=0,1mS False
# 131441.3452   8.218 -6.9015     2 246.6223    49    37  5011   325    25     1     0    25    24    --    25    -1     0    26    25    -- C3H, v4=0,1mS False
# 131460.8961   8.215 -6.8845     2 246.6218    51    37  5011   325    25     1     0    25    25    --    25    -1     0    26    26    -- C3H, v4=0,1mS False
# 131560.8984   1.073 -7.5077     2 422.0399    65    37  5011   325    33    -1     0    33    32    --    32     0     1    33    32    -- C3H, v4=0,1mS False
# 131577.0007   1.072 -7.4945     2 422.0398    67    37  5011   325    33    -1     0    33    33    --    32     0     1    33    33    -- C3H, v4=0,1mS False
# 131672.4002  0.8323 -5.8754     2 398.1099    63    37  5011   325    32    -1     0    32    31    --    31     0     1    32    31    -- C3H, v4=0,1mS False
#  131684.286   0.823 -5.8617     2 398.1098    65    37  5011   325    32    -1     0    32    32    --    31     0     1    32    32    -- C3H, v4=0,1mS False
#  131721.216   8.284 -5.6128     2 228.1873    47    37  5011   325    24    -1     0    24    23    --    24    -1     0    25    24    -- C3H, v4=0,1mS False
# 131730.2713   8.283 -5.5948     2 228.1872    49    37  5011   325    24    -1     0    24    24    --    24    -1     0    25    25    -- C3H, v4=0,1mS False, <Table length=14>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 133735.3155   8.002 -7.2134     2  328.839    57    37  5011   325    29     1     0    29    28    --    29    -1     0    30    29    -- C3H, v4=0,1mS False
# 133758.9819   8.001 -7.1985     2 328.8385    59    37  5011   325    29     1     0    29    29    --    29    -1     0    30    30    -- C3H, v4=0,1mS False
#  133966.037    8.28 -6.7502     2 210.1988    45    37  5011   325    23    -1     0    23    22    --    23     1     0    24    23    -- C3H, v4=0,1mS False
# 133979.4527   8.281 -6.7317     2 210.1988    47    37  5011   325    23    -1     0    23    23    --    23     1     0    24    24    -- C3H, v4=0,1mS False
# 134603.0459  0.0151 -2.8612     2  38.4145    15    37  5011   325     6     0     1     7     7    --     5     0     1     6     6    -- C3H, v4=0,1mS False
# 134603.1646  0.0156 -2.9288     2  38.4146    13    37  5011   325     6     0     1     7     6    --     5     0     1     6     5    -- C3H, v4=0,1mS False
# 134606.1207  0.0697 -4.8304     2  38.4145    13    37  5011   325     6     0     1     7     6    --     5     0     1     6     6    -- C3H, v4=0,1mS False
# 134623.3216  0.0837 -4.7287     2  38.4201    11    37  5011   325     6     0     1     6     5    --     5     0     1     5     5    -- C3H, v4=0,1mS False
# 134628.0236  0.0133 -2.9301     2  38.4201    13    37  5011   325     6     0     1     6     6    --     5     0     1     5     5    -- C3H, v4=0,1mS False
# 134628.2084  0.0129 -3.0104     2  38.4199    11    37  5011   325     6     0     1     6     5    --     5     0     1     5     4    -- C3H, v4=0,1mS False
# 134788.4503  0.1669 -4.8379     2  38.4146    11    37  5011   325     6     0     1     6     5    --     5     0     1     6     5    -- C3H, v4=0,1mS False
# 134791.4064   0.148 -6.6336     2  38.4145    11    37  5011   325     6     0     1     6     5    --     5     0     1     6     6    -- C3H, v4=0,1mS False
# 134793.1522  0.1423 -6.5006     2  38.4146    13    37  5011   325     6     0     1     6     6    --     5     0     1     6     5    -- C3H, v4=0,1mS False
# 134796.1084  0.1547 -4.7344     2  38.4145    13    37  5011   325     6     0     1     6     6    --     5     0     1     6     6    -- C3H, v4=0,1mS False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 133735.3155   8.002 -7.2134     2 328.839    57    37  5011   325    29     1     0    29    28    --    29    -1     0    30    29    -- C3H, v4=0,1mS False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
#  137065.632   8.066 -7.1492     2 307.1736    55    37  5011   325    28    -1     0    28    27    --    28     1     0    29    28    -- C3H, v4=0,1mS False
# 137088.8963   8.065 -7.1338     2  307.173    57    37  5011   325    28    -1     0    28    28    --    28     1     0    29    29    -- C3H, v4=0,1mS False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 138342.9675    8.29 -5.9043     2 210.1988    45    37  5011   325    23     1     0    23    22    --    23     1     0    24    23    -- C3H, v4=0,1mS False
# 138352.7376    8.29 -5.8856     2 210.1988    47    37  5011   325    23     1     0    23    23    --    23     1     0    24    24    -- C3H, v4=0,1mS False
# 138408.9114   8.209 -5.2772     2  266.389    51    37  5011   325    26    -1     0    26    25    --    26    -1     0    27    26    -- C3H, v4=0,1mS False
# 138416.2995   8.204  -5.261     2 266.3889    53    37  5011   325    26    -1     0    26    26    --    26    -1     0    27    27    -- C3H, v4=0,1mS False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 139555.1401   8.286 -6.6532     2 192.9516    43    37  5011   325    22     1     0    22    21    --    22    -1     0    23    22    -- C3H, v4=0,1mS False
# 139568.1575   8.287 -6.6338     2 192.9516    45    37  5011   325    22     1     0    22    22    --    22    -1     0    23    23    -- C3H, v4=0,1mS False
# 139743.1091   8.228 -6.7294     2 227.9197    47    37  5011   325    24    -1     0    24    23    --    24     1     0    25    24    -- C3H, v4=0,1mS False
# 139765.1856   8.227 -6.7116     2 227.9192    49    37  5011   325    24    -1     0    24    24    --    24     1     0    25    25    -- C3H, v4=0,1mS False, <Table length=14>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 140923.7769  0.0573 -4.6724     2 136.9858    35    37  5011   325    17     0     1    17    17    --    18    -1     0    18    18    -- C3H, v4=0,1mS False
# 140928.1723  0.0541 -4.6797     2 136.9855    33    37  5011   325    17     0     1    17    16    --    18    -1     0    18    17    -- C3H, v4=0,1mS False
# 140931.7545  0.0635 -6.3715     2 136.9855    35    37  5011   325    17     0     1    17    17    --    18    -1     0    18    17    -- C3H, v4=0,1mS False
# 140936.7565  0.2814  -5.138     2 136.9858    37    37  5011   325    17     0     1    18    18    --    18    -1     0    18    18    -- C3H, v4=0,1mS False
# 140940.7907  0.2844 -6.0526     2 136.9858    35    37  5011   325    17     0     1    18    17    --    18    -1     0    18    18    -- C3H, v4=0,1mS False
# 140948.7683  0.2862 -5.1874     2 136.9855    35    37  5011   325    17     0     1    18    17    --    18    -1     0    18    17    -- C3H, v4=0,1mS False
# 141420.1605   8.114 -7.1158     2  286.249    53    37  5011   325    27     1     0    27    26    --    27    -1     0    28    27    -- C3H, v4=0,1mS False
# 141442.5454   8.112 -7.0998     2 286.2485    55    37  5011   325    27     1     0    27    27    --    27    -1     0    28    28    -- C3H, v4=0,1mS False
#  141635.793    0.05 -2.7645     2  12.7136    15    37  5011   325     6     1     0     7     7    --     5    -1     0     6     6    -- C3H, v4=0,1mS  True
#  141636.431    0.05 -2.8323     2   12.714    13    37  5011   325     6     1     0     7     6    --     5    -1     0     6     5    -- C3H, v4=0,1mS  True
# 141647.0004  0.0065 -4.7188     2  12.7136    13    37  5011   325     6     1     0     7     6    --     5    -1     0     6     6    -- C3H, v4=0,1mS False
# 141704.0789  0.0072 -4.7183     2  12.7124    13    37  5011   325     6    -1     0     7     6    --     5     1     0     6     6    -- C3H, v4=0,1mS False
#  141708.728    0.05 -2.7641     2  12.7124    15    37  5011   325     6    -1     0     7     7    --     5     1     0     6     6    -- C3H, v4=0,1mS  True
#  141709.494    0.05 -2.8318     2  12.7122    13    37  5011   325     6    -1     0     7     6    --     5     1     0     6     5    -- C3H, v4=0,1mS  True, <Table length=10>
# ...
#  251433.892    0.05 -2.0968     2 43.6575    25    37  5011   325    11     1     0    12    12    --    10    -1     0    11    11    -- C3H, v4=0,1mS  True
#  251434.415    0.05 -2.1347     2 43.6575    23    37  5011   325    11     1     0    12    11    --    10    -1     0    11    10    -- C3H, v4=0,1mS  True, <Table length=2>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 252102.583  0.0719 -7.3606     2 43.6352    23    37  5011   325    11     1     0    12    11    --    10     1     0    11    10    -- C3H, v4=0,1mS False
# 252117.286  0.0721 -7.3226     2 43.6347    25    37  5011   325    11     1     0    12    12    --    10     1     0    11    11    -- C3H, v4=0,1mS False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 259565.9146   10.46 -4.8941     2 702.3152    89    37  5011   325    43     1     0    44    44    --    42     0     1    43    43    -- C3H, v4=0,1mS False
# 259566.8155   10.47 -4.9041     2 702.3153    87    37  5011   325    43     1     0    44    43    --    42     0     1    43    42    -- C3H, v4=0,1mS False
# 260870.7006   8.221 -7.0554     2 160.6798    41    37  5011   325    19     0     1    20    20    --    20    -1     0    21    20    -- C3H, v4=0,1mS False
# 260872.1777    8.22 -4.1196     2 160.6798    41    37  5011   325    19     0     1    20    20    --    20    -1     0    21    21    -- C3H, v4=0,1mS False
# 260874.1722   8.231 -4.1408     2 160.6798    39    37  5011   325    19     0     1    20    19    --    20    -1     0    21    20    -- C3H, v4=0,1mS False, <Table length=13>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 261379.2308   8.235 -5.6367     2 29.0843    15    37  5011   325     8     1     0     8     7    --     8    -1     0     9     8    -- C3H, v4=0,1mS False
# 261383.4277   8.241 -5.5852     2 29.0844    17    37  5011   325     8     1     0     8     8    --     8    -1     0     9     9    -- C3H, v4=0,1mS False
# 261979.2225  0.2705 -4.4365     2 59.6089    23    37  5011   325    10     0     1    11    11    --    11     1     0    11    11    -- C3H, v4=0,1mS False
# 261982.5549  0.2707 -7.0841     2 59.6089    21    37  5011   325    10     0     1    11    10    --    11     1     0    11    11    -- C3H, v4=0,1mS False
# 261986.4884  0.2692 -6.8413     2 59.6086    23    37  5011   325    10     0     1    11    11    --    11     1     0    11    10    -- C3H, v4=0,1mS False
# 261989.8208  0.2732 -4.4752     2 59.6086    21    37  5011   325    10     0     1    11    10    --    11     1     0    11    10    -- C3H, v4=0,1mS False
# 262028.1172  0.0582 -6.7483     2 59.6086    23    37  5011   325    12     1     0    12    11    --    11     1     0    11    10    -- C3H, v4=0,1mS False
# 262029.4798  0.0582  -6.713     2 59.6089    25    37  5011   325    12     1     0    12    12    --    11     1     0    11    11    -- C3H, v4=0,1mS False
#  262076.251   8.207 -5.6109     2 29.0753    15    37  5011   325     8    -1     0     8     7    --     8     1     0     9     8    -- C3H, v4=0,1mS False
# 262095.3602   8.213 -5.5594     2 29.0749    17    37  5011   325     8    -1     0     8     8    --     8     1     0     9     9    -- C3H, v4=0,1mS False
# 262237.1386  0.1115 -4.1928     2 59.6089    21    37  5011   325    10     0     1    10    10    --    11     1     0    11    11    -- C3H, v4=0,1mS False
# 262240.0557  0.1039 -4.2348     2 59.6086    19    37  5011   325    10     0     1    10     9    --    11     1     0    11    10    -- C3H, v4=0,1mS False
# 262244.4046  0.1148 -6.6748     2 59.6086    21    37  5011   325    10     0     1    10    10    --    11     1     0    11    10    -- C3H, v4=0,1mS False, <Table length=20>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 263012.7462  0.2845 -6.6826     2  59.5744    23    37  5011   325    10     0     1    11    11    --    11    -1     0    11    11    -- C3H, v4=0,1mS False
#  263021.087   0.283 -6.9805     2  59.5741    23    37  5011   325    10     0     1    11    11    --    11    -1     0    11    10    -- C3H, v4=0,1mS False
# 263024.4193  0.2866 -6.6875     2  59.5741    21    37  5011   325    10     0     1    11    10    --    11    -1     0    11    10    -- C3H, v4=0,1mS False
# 263054.3749  0.0449 -4.5358     2  59.5744    23    37  5011   325    12     1     0    12    11    --    11    -1     0    11    11    -- C3H, v4=0,1mS False
#  263062.936    0.05 -2.1346     2  59.5741    23    37  5011   325    12     1     0    12    11    --    11    -1     0    11    10    -- C3H, v4=0,1mS  True
#  263062.936    0.05 -2.0967     2  59.5744    25    37  5011   325    12     1     0    12    12    --    11    -1     0    11    11    -- C3H, v4=0,1mS  True
# 263270.6623  0.1346 -7.1666     2  59.5744    21    37  5011   325    10     0     1    10    10    --    11    -1     0    11    11    -- C3H, v4=0,1mS False
# 263274.6542  0.1282 -7.2093     2  59.5741    19    37  5011   325    10     0     1    10     9    --    11    -1     0    11    10    -- C3H, v4=0,1mS False
# 263325.0611  0.0449 -4.5353     2  59.6089    23    37  5011   325    12    -1     0    12    11    --    11     1     0    11    11    -- C3H, v4=0,1mS False
#  263332.405    0.05 -2.1338     2  59.6086    23    37  5011   325    12    -1     0    12    11    --    11     1     0    11    10    -- C3H, v4=0,1mS  True
#  263332.405    0.05 -2.0959     2  59.6089    25    37  5011   325    12    -1     0    12    12    --    11     1     0    11    11    -- C3H, v4=0,1mS  True
#  263612.997  0.2555 -7.1943     2  22.8867     9    37  5011   325     3     0     1     4     4    --     5     1     0     5     5    -- C3H, v4=0,1mS False
# 263622.7914  0.2533 -7.2939     2  22.8865     7    37  5011   325     3     0     1     4     3    --     5     1     0     5     4    -- C3H, v4=0,1mS False
# 263721.0001  0.2572 -4.6345     2  22.8831     9    37  5011   325     3     0     1     4     4    --     5    -1     0     5     5    -- C3H, v4=0,1mS False
#  263728.508  0.2519 -6.2782     2  22.8829     9    37  5011   325     3     0     1     4     4    --     5    -1     0     5     4    -- C3H, v4=0,1mS False
# 263731.0499  0.2548 -4.7342     2  22.8829     7    37  5011   325     3     0     1     4     3    --     5    -1     0     5     4    -- C3H, v4=0,1mS False
# 264140.4376   3.304 -4.6878     2 581.3685    77    37  5011   325    39     1     0    39    38    --    38     0     1    38    37    -- C3H, v4=0,1mS False
# 264144.8881   3.304 -4.6765     2 581.3686    79    37  5011   325    39     1     0    39    39    --    38     0     1    38    38    -- C3H, v4=0,1mS False
# 264365.9769  0.0584 -6.7038     2  59.5744    25    37  5011   325    12    -1     0    12    12    --    11    -1     0    11    11    -- C3H, v4=0,1mS False
# 264366.9255  0.0582 -6.7418     2  59.5741    23    37  5011   325    12    -1     0    12    11    --    11    -1     0    11    10    -- C3H, v4=0,1mS False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 267244.2954   3.299 -5.7093     2 581.2649    77    37  5011   325    39     1     0    39    38    --    38     0     1    39    38    -- C3H, v4=0,1mS False
# 267256.5186   3.288 -5.6982     2 581.2648    79    37  5011   325    39     1     0    39    39    --    38     0     1    39    39    -- C3H, v4=0,1mS False, <Table length=10>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 269205.5543  0.0777 -4.5358     2  76.588    23    37  5011   325    12     0     1    12    11    --    11     0     1    11    11    -- C3H, v4=0,1mS False
#  269209.854    0.05  -2.106     2  76.588    25    37  5011   325    12     0     1    12    12    --    11     0     1    11    11    -- C3H, v4=0,1mS  True
#  269209.854    0.05 -2.1439     2 76.5878    23    37  5011   325    12     0     1    12    11    --    11     0     1    11    10    -- C3H, v4=0,1mS  True
#  269215.264    0.05  -2.071     2 76.5793    27    37  5011   325    12     0     1    13    13    --    11     0     1    12    12    -- C3H, v4=0,1mS  True
#  269215.264    0.05 -2.1058     2 76.5794    25    37  5011   325    12     0     1    13    12    --    11     0     1    12    11    -- C3H, v4=0,1mS  True
# 269218.6666  0.0708 -4.5924     2 76.5793    25    37  5011   325    12     0     1    13    12    --    11     0     1    12    12    -- C3H, v4=0,1mS False
# 269462.8585  0.2616 -4.5909     2 76.5794    23    37  5011   325    12     0     1    12    11    --    11     0     1    12    11    -- C3H, v4=0,1mS False
#  269466.226  0.2493 -7.0199     2 76.5793    23    37  5011   325    12     0     1    12    11    --    11     0     1    12    12    -- C3H, v4=0,1mS False
# 269467.1269  0.2453 -7.0854     2 76.5794    25    37  5011   325    12     0     1    12    12    --    11     0     1    12    11    -- C3H, v4=0,1mS False
# 269470.4944  0.2529 -4.5342     2 76.5793    25    37  5011   325    12     0     1    12    12    --    11     0     1    12    12    -- C3H, v4=0,1mS False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
# 272218.0291  0.0832 -7.1441     2 52.0445    27    37  5011   325    12     1     0    13    13    --    11     1     0    12    12    -- C3H, v4=0,1mS False
# 272233.3604  0.0831 -7.1789     2 52.0444    25    37  5011   325    12     1     0    13    12    --    11     1     0    12    11    -- C3H, v4=0,1mS False
#  273161.117    0.05 -2.0079     2  52.013    27    37  5011   325    12     1     0    13    13    --    11    -1     0    12    12    -- C3H, v4=0,1mS  True
#  273161.117    0.05 -2.0428     2 52.0135    25    37  5011   325    12     1     0    13    12    --    11    -1     0    12    11    -- C3H, v4=0,1mS  True
# 273174.4806  0.0134 -4.5185     2  52.013    25    37  5011   325    12     1     0    13    12    --    11    -1     0    12    12    -- C3H, v4=0,1mS False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l       name      Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64     str13      bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------- -----
#  273161.117    0.05 -2.0079     2  52.013    27    37  5011   325    12     1     0    13    13    --    11    -1     0    12    12    -- C3H, v4=0,1mS  True
#  273161.117    0.05 -2.0428     2 52.0135    25    37  5011   325    12     1     0    13    12    --    11    -1     0    12    11    -- C3H, v4=0,1mS  True
# 273174.4806  0.0134 -4.5185     2  52.013    25    37  5011   325    12     1     0    13    12    --    11    -1     0    12    12    -- C3H, v4=0,1mS False
# 273460.0964  0.0147 -4.5175     2 52.0445    25    37  5011   325    12    -1     0    13    12    --    11     1     0    12    12    -- C3H, v4=0,1mS False
#  273461.665    0.05  -2.007     2 52.0445    27    37  5011   325    12    -1     0    13    13    --    11     1     0    12    12    -- C3H, v4=0,1mS  True
#  273461.665    0.05 -2.0419     2 52.0444    25    37  5011   325    12    -1     0    13    12    --    11     1     0    12    11    -- C3H, v4=0,1mS  True
# 274389.7127  0.0862 -7.1881     2 52.0135    25    37  5011   325    12    -1     0    13    12    --    11    -1     0    12    11    -- C3H, v4=0,1mS False
#   274404.28  0.0863 -7.1532     2  52.013    27    37  5011   325    12    -1     0    13    13    --    11    -1     0    12    12    -- C3H, v4=0,1mS False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 4.7e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=15, 
               nrows=4, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'C$_3$H', extr_type="coord", 
               crd=crd, show_2_sigma=True, EU_cutoff_K=40)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.5e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=15, 
                       nrows=4, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'C$_3$H', extr_type="reg",
                       just_data=False, return_freqs=True, show_2_sigma=True, EU_cutoff_K=40)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=10, fig_height=10, nrows=4, ncols=5, name_for_plot=f'C$_3$H')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=10, fig_height=10, nrows=4, ncols=5, name_for_plot=f'C$_3$H')
