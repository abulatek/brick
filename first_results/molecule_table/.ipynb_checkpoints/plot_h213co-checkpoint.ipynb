# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 31002 # 31503
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# cubes = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=3>
#    FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#    MHz       MHz   MHz nm2         1 / cm
#  float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ---------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 85786.6946  0.0242 -8.2033     3 1419.3878   201 31002   303 33 330 34 133
# 86957.1498  0.0191 -9.5234     3 2148.7502   243 31002   303 40 535 41 338
# 87048.9709  0.0011 -5.1008     3  674.1004   135 31002   303 22 319 22 320, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str6   str6
# ---------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 94076.4426  0.0043 -6.5279     3 673.866   135 31002   303 22 319 23 122, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 96375.7508  0.0005  -4.096     3 56.3278    39 31002   303 6 1 5 6 1 6, <Table length=1>
#    FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#    MHz       MHz   MHz nm2         1 / cm
#  float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ---------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 99341.9953  0.0027 -6.8669     3 1384.4252    65 31002   303 32 428 32 429, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 101648.3858  0.0162 -8.3057     3 2346.319   255 31002   303 42 537 42 538, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 101648.3858  0.0162 -8.3057     3 2346.319   255 31002   303 42 537 42 538, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 106133.9762  0.0011 -4.7424     3 280.9073    29 31002   303 14 212 14 213, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 110428.4824  0.0015 -5.0354     3  728.6256   141 31002   303 23 320 23 321
# 110703.0374  0.0238 -9.6418     3 2349.7096   261 31002   303 43 340 42 537, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 126629.3013    0.01 -6.3018     3 355.2823    33 -31002   303 16 214 17 017, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 128431.4301   0.004 -3.9431     3 72.3453    45 -31002   303 7 1 6 7 1 7, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 130311.4174    0.01 -6.3771     3 396.4021    35 -31002   303 17 215 18 018
# 131337.3207   0.008 -6.1853     3 316.3573    31 -31002   303 15 213 16 016, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 130311.4174    0.01 -6.3771     3 396.4021    35 -31002   303 17 215 18 018, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 135465.1712   0.005 -4.6419     3 316.2196    31 -31002   303 15 213 15 214, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ------ ----- ------ ------
# 137449.9503   0.004 -3.0091     3   10.5135    15 -31002   303  2 1 2  1 1 1
# 138093.5908   0.008 -4.9875     3  785.4983   147 -31002   303 24 321 24 322
#  138517.507  0.0408 -7.9912     3 1500.1594   207  31002   303 34 331 35 134, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 139350.8478  0.0127 -8.2692     3 1548.4838    71 31002   303 35 233 34 430, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 141983.7404   0.004 -3.3163     3   2.3691     5 -31002   303  2 0 2  1 0 1
# 142299.0907    0.01 -6.4142     3 439.7146    37 -31002   303 18 216 19 019, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ------ ----- ------ ------
# 142299.0907    0.01 -6.4142     3  439.7146    37 -31002   303 18 216 19 019
# 142487.7423  0.0092 -7.7586     3 1232.1748    61  31002   303 30 426 31 229, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 144399.9431    0.01 -6.0355     3 279.6309    29 -31002   303 14 212 15 015, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64  int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 146635.6717   0.004 -2.9535     3 10.6667    15 -31002   303 2 1 1 1 1 0, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 149145.9718   0.007 -6.0636     3 619.2077   129 -31002   303 21 318 22 121, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 149145.9718   0.007 -6.0636     3 619.2077   129 -31002   303 21 318 22 121, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ------ ----- ------ ------
# 151500.6034   0.015 -6.8761     3 1543.4303    69 -31002   303 34 430 34 431
# 151809.2333  0.0426 -8.4247     3 2552.5857   267  31002   303 44 539 44 540, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str6   str6
# ----------- ------- ------- ----- ------- ----- ----- ----- ------ ------
# 249660.4455  0.0036 -4.9418     3 970.142   165 31002   303 27 324 27 325, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 251440.5415  0.0013 -3.6345     3 134.0477    63 31002   303 10 1 9 10 110
# 251831.9846  0.0027 -4.4589     3  436.061    37 31002   303 18 216 18 217, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 254006.2459  0.0374 -8.2422     3 1808.3409    77 31002   303 38 236 37 433, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 257110.2249  0.1498 -9.0544     3 2189.8097    85 31002   303 42 240 41 437, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 257110.2249  0.1498 -9.0544     3 2189.8097    85 31002   303 42 240 41 437, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 261022.0324  0.1471 -8.6962     3 2879.5087   285 31002   303 47 542 47 543, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 264848.9484  0.0091 -6.9951     3 1799.5065    75 31002   303 37 433 37 434
# 265102.7735  0.1046 -7.8519     3 1668.1968   219 31002   303 36 333 37 136, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ----- ----- ------ ------
# 268521.5123  0.0099 -6.4168     3 634.8796    45 31002   303 22 220 23 023, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 271050.9082  0.0525 -8.3748     3 1899.9666    79 31002   303 39 237 38 434, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP   TAG  QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2         1 / cm
#   float64   float64 float64 int64  float64  int64 int64 int64  str6   str6
# ----------- ------- ------- ----- --------- ----- ----- ----- ------ ------
# 272485.4079   0.105 -8.7823     3 2090.7092    83 31002   303 41 239 40 436, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP   TAG   QNFMT  QN'    QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64  int64 int64  int64  str6   str6
# ----------- ------- ------- ----- -------- ----- ------ ----- ------ ------
# 274529.7969  0.0052 -5.4185     3 154.8535    21  31002   303 10 2 8 11 011
#  274762.112    0.01 -2.0381     3  21.9741    27 -31002   303  4 1 4  3 1 3]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 22., N_tot = 4.0e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=8, 
               nrows=1, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'H$_2^{{13}}$CO', extr_type="coord", 
               crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 7., N_tot = 2.0e+13, v_cen = 13.*u.km/u.s, v_disp = 2.5*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=8, 
                       nrows=1, ncols=4, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'H$_2^{{13}}$CO', extr_type="reg", 
                       show_2_sigma=True, return_freqs=True)

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes_masked, temp = 7., N_tot = 1.0e+13, v_cen = 40.*u.km/u.s, v_disp = 2.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=8, 
               nrows=1, ncols=4, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'H$_2^{{13}}$CO', extr_type="reg", 
               show_2_sigma=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=15, fig_height=4, nrows=1, ncols=4, name_for_plot=f'H$_2^{{13}}$CO')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=13*u.km/u.s, fig_width=15, fig_height=4, nrows=1, ncols=4, name_for_plot=f'H$_2^{{13}}$CO')
