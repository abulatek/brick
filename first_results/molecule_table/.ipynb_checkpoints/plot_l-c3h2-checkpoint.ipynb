# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 38501
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 88760.3228  0.0799 -4.9587     3 167.9512   129    38   501   303    21     1    20    --    --    --    21     1    21    --    --    -- l-C3H2 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 97199.4577  0.0913 -4.9312     3 183.0563   135    38   501   303    22     1    21    --    --    --    22     1    22    --    --    -- l-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 102992.3791   0.004 -2.8021     3  16.156    33    38   501   303     5     1     5    --    --    --     4     1     4    --    --    -- l-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 102992.3791   0.004 -2.8021     3  16.156    33    38   501   303     5     1     5    --    --    --     4     1     4    --    --    -- l-C3H2 False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 103873.4857  0.0057 -3.9876     3 155.3001    11    38   501   303     5     4     1    --    --    --     4     4     0    --    --    -- l-C3H2 False
# 103873.4857  0.0057 -3.9876     3 155.3001    11    38   501   303     5     4     2    --    --    --     4     4     1    --    --    -- l-C3H2 False
# 103914.3537  0.0027 -3.1252     3  90.4403    33    38   501   303     5     3     3    --    --    --     4     3     2    --    --    -- l-C3H2 False
#  103914.359  0.0027 -3.1252     3  90.4403    33    38   501   303     5     3     2    --    --    --     4     3     1    --    --    -- l-C3H2 False
# 103939.1617  0.0029 -3.3874     3  44.0645    11    38   501   303     5     2     4    --    --    --     4     2     3    --    --    -- l-C3H2 False
# 103947.0693   0.003 -3.3874     3  44.0647    11    38   501   303     5     2     3    --    --    --     4     2     2    --    --    -- l-C3H2 False
# 103952.9262  0.0033 -3.2343     3   6.9354    11    38   501   303     5     0     5    --    --    --     4     0     4    --    --    -- l-C3H2 False
# 104915.5832  0.0034 -2.7864     3  16.2843    33    38   501   303     5     1     4    --    --    --     4     1     3    --    --    -- l-C3H2 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 125896.439  0.0039 -2.5513     3 19.7839    39    38   501   303     6     1     5    --    --    --     5     1     4    --    --    -- l-C3H2 False, <Table length=12>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 144183.8038  0.0051 -2.3721     3  23.7139    45    38   501   303     7     1     7    --    --    --     6     1     6    --    --    -- l-C3H2 False
# 145220.7557   0.408 -4.0854     3 347.8005    15    38   501   303     7     6     1    --    --    --     6     6     0    --    --    -- l-C3H2 False
# 145220.7557   0.408 -4.0854     3 347.8005    15    38   501   303     7     6     2    --    --    --     6     6     1    --    --    -- l-C3H2 False
# 145338.9182  0.0775 -3.1297     3 246.1963    45    38   501   303     7     5     2    --    --    --     6     5     1    --    --    -- l-C3H2 False
# 145338.9182  0.0775 -3.1297     3 246.1963    45    38   501   303     7     5     3    --    --    --     6     5     2    --    --    -- l-C3H2 False
#   145420.82   0.022 -3.2946     3 162.9228    15    38   501   303     7     4     3    --    --    --     6     4     2    --    --    -- l-C3H2  True
#   145420.82   0.022 -3.2946     3 162.9228    15    38   501   303     7     4     4    --    --    --     6     4     3    --    --    -- l-C3H2  True
#  145478.692    0.01 -2.5985     3  98.0659    45    38   501   303     7     3     5    --    --    --     6     3     4    --    --    -- l-C3H2  True
#  145478.692    0.01 -2.5985     3  98.0659    45    38   501   303     7     3     4    --    --    --     6     3     3    --    --    -- l-C3H2  True
#  145510.241   0.032 -2.9277     3  51.6919    15    38   501   303     7     2     6    --    --    --     6     2     5    --    --    -- l-C3H2  True
#  145520.092    0.01 -2.8133     3  14.5637    15    38   501   303     7     0     7    --    --    --     6     0     6    --    --    -- l-C3H2  True
#  145532.318   0.027 -2.9275     3  51.6928    15    38   501   303     7     2     5    --    --    --     6     2     4    --    --    -- l-C3H2  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 146876.061   0.009 -2.3567     3 23.9834    45    38   501   303     7     1     6    --    --    --     6     1     5    --    --    -- l-C3H2 True, <Table length=7>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 247134.8762  0.0051  -1.732     3    54.63    75    38   501   303    12     1    12    --    --    --    11     1    11    --    --    -- l-C3H2 False
# 247503.6489   13.66 -3.6234     3 792.4012    75    38   501   303    12     9     3    --    --    --    11     9     2    --    --    -- l-C3H2 False
# 247503.6489   13.66 -3.6234     3 792.4012    75    38   501   303    12     9     4    --    --    --    11     9     3    --    --    -- l-C3H2 False
# 248185.0109   6.082 -3.6699     3 636.6044    25    38   501   303    12     8     4    --    --    --    11     8     3    --    --    -- l-C3H2 False
# 248185.0109   6.082 -3.6699     3 636.6044    25    38   501   303    12     8     5    --    --    --    11     8     4    --    --    -- l-C3H2 False
# 248634.6906   2.327 -2.8294     3 498.7319    75    38   501   303    12     7     5    --    --    --    11     7     4    --    --    -- l-C3H2 False
# 248634.6906   2.327 -2.8294     3 498.7319    75    38   501   303    12     7     6    --    --    --    11     7     5    --    --    -- l-C3H2 False, <Table length=13>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 248634.6906   2.327 -2.8294     3 498.7319    75    38   501   303    12     7     5    --    --    --    11     7     4    --    --    -- l-C3H2 False
# 248634.6906   2.327 -2.8294     3 498.7319    75    38   501   303    12     7     6    --    --    --    11     7     5    --    --    -- l-C3H2 False
# 248933.8942  0.7009 -3.0003     3   378.94    25    38   501   303    12     6     6    --    --    --    11     6     5    --    --    -- l-C3H2 False
# 248933.8942  0.7009 -3.0003     3   378.94    25    38   501   303    12     6     7    --    --    --    11     6     6    --    --    -- l-C3H2 False
# 249137.0694  0.1324 -2.2688     3 277.3611    75    38   501   303    12     5     7    --    --    --    11     5     6    --    --    -- l-C3H2 False
# 249137.0694  0.1324 -2.2688     3 277.3611    75    38   501   303    12     5     8    --    --    --    11     5     7    --    --    -- l-C3H2 False
# 249279.1043  0.0067 -2.5404     3 194.1053    25    38   501   303    12     4     9    --    --    --    11     4     8    --    --    -- l-C3H2 False
# 249279.1052  0.0067 -2.5404     3 194.1053    25    38   501   303    12     4     8    --    --    --    11     4     7    --    --    -- l-C3H2 False
# 249367.9388  0.0037 -2.1799     3  45.7634    25    38   501   303    12     0    12    --    --    --    11     0    11    --    --    -- l-C3H2 False
# 249382.1752  0.0043 -1.9047     3  129.261    75    38   501   303    12     3    10    --    --    --    11     3     9    --    --    -- l-C3H2 False
# 249382.6753  0.0043 -1.9047     3  129.261    75    38   501   303    12     3     9    --    --    --    11     3     8    --    --    -- l-C3H2 False
#  249414.467  0.0044 -2.2693     3  82.8927    25    38   501   303    12     2    11    --    --    --    11     2    10    --    --    -- l-C3H2 False
# 249527.4587   0.004  -2.269     3  82.9021    25    38   501   303    12     2    10    --    --    --    11     2     9    --    --    -- l-C3H2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 251748.3275  0.0039 -1.7179     3 55.4766    75    38   501   303    12     1    11    --    --    --    11     1    10    --    --    -- l-C3H2 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 267718.841   0.008 -1.6452     3 62.8735    81    38   501   303    13     1    13    --    --    --    12     1    12    --    --    -- l-C3H2 True, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 268124.4962    14.8 -3.4614     3 800.6571    81    38   501   303    13     9     4    --    --    --    12     9     3    --    --    -- l-C3H2 False
# 268124.4962    14.8 -3.4614     3 800.6571    81    38   501   303    13     9     5    --    --    --    12     9     4    --    --    -- l-C3H2 False
# 268862.5433   6.591  -3.535     3 644.8829    27    38   501   303    13     8     5    --    --    --    12     8     4    --    --    -- l-C3H2 False
# 268862.5433   6.591  -3.535     3 644.8829    27    38   501   303    13     8     6    --    --    --    12     8     5    --    --    -- l-C3H2 False
# 269349.6552   2.522 -2.7112     3 507.0254    81    38   501   303    13     7     6    --    --    --    12     7     5    --    --    -- l-C3H2 False
# 269349.6552   2.522 -2.7112     3 507.0254    81    38   501   303    13     7     7    --    --    --    12     7     6    --    --    -- l-C3H2 False
# 269673.8313  0.7599 -2.8932     3 387.2435    27    38   501   303    13     6     7    --    --    --    12     6     6    --    --    -- l-C3H2 False
# 269673.8313  0.7599 -2.8932     3 387.2435    27    38   501   303    13     6     8    --    --    --    12     6     7    --    --    -- l-C3H2 False, <Table length=11>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ -----
# 269673.8313  0.7599 -2.8932     3 387.2435    27    38   501   303    13     6     7    --    --    --    12     6     6    --    --    -- l-C3H2 False
# 269673.8313  0.7599 -2.8932     3 387.2435    27    38   501   303    13     6     8    --    --    --    12     6     7    --    --    -- l-C3H2 False
# 269894.1119  0.1435 -2.1693     3 285.6715    81    38   501   303    13     5     8    --    --    --    12     5     7    --    --    -- l-C3H2 False
# 269894.1119  0.1435 -2.1693     3 285.6715    81    38   501   303    13     5     9    --    --    --    12     5     8    --    --    -- l-C3H2 False
#  270048.414    0.01 -2.4462     3 202.4203    27    38   501   303    13     4    10    --    --    --    12     4     9    --    --    -- l-C3H2  True
#  270048.414    0.01 -2.4462     3 202.4203    27    38   501   303    13     4     9    --    --    --    12     4     8    --    --    -- l-C3H2  True
#  270121.513   0.009 -2.0938     3  54.0814    27    38   501   303    13     0    13    --    --    --    12     0    12    --    --    -- l-C3H2  True
#  270161.558   0.008 -1.8142     3 137.5795    81    38   501   303    13     3    11    --    --    --    12     3    10    --    --    -- l-C3H2  True
#  270161.558   0.008 -1.8142     3 137.5795    81    38   501   303    13     3    10    --    --    --    12     3     9    --    --    -- l-C3H2  True
#  270190.016   0.011 -2.1813     3  91.2122    27    38   501   303    13     2    12    --    --    --    12     2    11    --    --    -- l-C3H2  True
#  270333.789   0.009 -2.1809     3  91.2254    27    38   501   303    13     2    11    --    --    --    12     2    10    --    --    -- l-C3H2  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l   name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64  str6  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------ ----
# 272716.158   0.009 -1.6314     3 63.8741    81    38   501   303    13     1    12    --    --    --    12     1    11    --    --    -- l-C3H2 True]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 1.8e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=10,
               nrows=2, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'l-C$_3$H$_2$',
               print_diag=False, extr_type="coord", crd=crd, show_2_sigma=True, EU_cutoff_K=50)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 1.5e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=10, 
                       nrows=2, ncols=4, parse_loc=False, line_by_line=True, name_for_plot=f'l-C$_3$H$_2$', 
                       extr_type="reg", show_2_sigma=True, return_freqs=True, EU_cutoff_K=50)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=15, fig_height=8, nrows=2, ncols=4, name_for_plot=f'l-C$_3$H$_2$')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=13*u.km/u.s, fig_width=15, fig_height=8, nrows=2, ncols=4, name_for_plot=f'l-C$_3$H$_2$')
