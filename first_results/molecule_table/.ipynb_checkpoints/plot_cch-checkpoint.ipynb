# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 25001 # 25501
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=5>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64  str5  str5
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 87284.156   0.003 -5.0204     2  0.0015     3 -25001   123 1 2 1 0 1 1
# 87316.925   0.004 -4.0285     2  0.0015     5 -25001   123 1 2 2 0 1 1
# 87328.624   0.006 -4.3311     2     0.0     3 -25001   123 1 2 1 0 1 0
# 87402.004   0.005 -4.3304     2  0.0015     3 -25001   123 1 1 1 0 1 1
# 87407.165   0.011 -4.7266     2  0.0015     1 -25001   123 1 1 0 0 1 1, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT  QN'   QN"
#    MHz      MHz   MHz nm2        1 / cm
#  float64  float64 float64 int64 float64 int64 int64  int64  str5  str5
# --------- ------- ------- ----- ------- ----- ------ ----- ----- -----
# 87446.512   0.023 -5.0188     2     0.0     3 -25001   123 1 1 1 0 1 0, <Table length=6>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT  QN'   QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64  str5  str5
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- -----
# 262004.2266  0.0307 -2.7339     2  8.7402     9 25001   123 3 4 4 2 3 3
# 262006.4034  0.0306 -2.8599     2  8.7392     7 25001   123 3 4 3 2 3 2
# 262064.8433  0.0314   -2.88     2   8.745     7 25001   123 3 3 3 2 2 2
# 262067.3312  0.0313 -3.0647     2  8.7454     5 25001   123 3 3 2 2 2 1
# 262078.7758  0.0317  -3.936     2   8.745     5 25001   123 3 3 2 2 2 2
# 262208.4388   0.035 -3.9713     2  8.7402     7 25001   123 3 3 3 2 3 3]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 6., N_tot = 1.2e+15, v_cen = 41.*u.km/u.s, v_disp = 1.*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=8, 
               nrows=2, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'CCH', extr_type="coord", crd=crd,
               aij_cutoff=-6, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 5., N_tot = 1.0e+15, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=8, 
                       nrows=2, ncols=5, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'CCH', extr_type="reg",
                       show_2_sigma=True, return_freqs=True, aij_cutoff=-6)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 5., N_tot = 9.0e+14, v_cen = 41.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=8, 
                       nrows=2, ncols=5, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'CCH', extr_type="reg",
                       show_2_sigma=True, return_freqs=True, aij_cutoff=-6)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=41.*u.km/u.s, fig_width=10, fig_height=5, nrows=2, ncols=5, name_for_plot=f'CCH')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=5, nrows=2, ncols=5, name_for_plot=f'CCH')
