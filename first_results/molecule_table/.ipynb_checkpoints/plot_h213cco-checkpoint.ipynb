# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 43506
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 96948.4985  0.0033 -3.8041     3 15.5505    33    43   506   303     5     1     5    --    --    --     4     1     4    --    --    -- H2C-13-CO False, <Table length=8>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 97766.1285  0.0029 -4.9835     3 151.6634    11    43   506   303     5     4     1    --    --    --     4     4     0    --    --    -- H2C-13-CO False
# 97766.1285  0.0029 -4.9835     3 151.6634    11    43   506   303     5     4     2    --    --    --     4     4     1    --    --    -- H2C-13-CO False
#  97799.156  0.0029  -4.124     3  88.2141    33    43   506   303     5     3     3    --    --    --     4     3     2    --    --    -- H2C-13-CO False
# 97799.1603  0.0029  -4.124     3  88.2141    33    43   506   303     5     3     2    --    --    --     4     3     1    --    --    -- H2C-13-CO False
# 97820.1659  0.0029 -4.3884     3  42.8476    11    43   506   303     5     2     4    --    --    --     4     2     3    --    --    -- H2C-13-CO False
# 97827.0166  0.0029 -4.3883     3  42.8478    11    43   506   303     5     2     3    --    --    --     4     2     2    --    --    -- H2C-13-CO False
# 97832.1584  0.0033 -4.2369     3    6.527    11    43   506   303     5     0     5    --    --    --     4     0     4    --    --    -- H2C-13-CO False
# 98717.5548  0.0033 -3.7887     3  15.6686    33    43   506   303     5     1     4    --    --    --     4     1     3    --    --    -- H2C-13-CO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 105995.3464  0.3281 -5.8857     3 203.0428   147    43   506   303    24     1    23    --    --    --    24     1    24    --    --    -- H2C-13-CO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 114808.2138  0.3933 -5.8674     3 219.1993   153    43   506   303    25     1    24    --    --    --    25     1    25    --    --    -- H2C-13-CO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 133477.7567  0.5512  -5.841     3 253.4475   165    43   506   303    27     1    26    --    --    --    27     1    27    --    --    -- H2C-13-CO False, <Table length=12>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 135723.5051   0.004 -3.3732     3   22.665    45    43   506   303     7     1     7    --    --    --     6     1     6    --    --    -- H2C-13-CO False
# 136734.8807  0.0055 -5.0715     3 339.7085    15    43   506   303     7     6     1    --    --    --     6     6     0    --    --    -- H2C-13-CO False
# 136734.8807  0.0055 -5.0715     3 339.7085    15    43   506   303     7     6     2    --    --    --     6     6     1    --    --    -- H2C-13-CO False
# 136810.6935  0.0039 -4.1206     3 240.3038    45    43   506   303     7     5     2    --    --    --     6     5     1    --    --    -- H2C-13-CO False
# 136810.6935  0.0039 -4.1206     3 240.3038    45    43   506   303     7     5     3    --    --    --     6     5     2    --    --    -- H2C-13-CO False
# 136871.1712  0.0038 -4.2894     3 158.8378    15    43   506   303     7     4     3    --    --    --     6     4     2    --    --    -- H2C-13-CO False
# 136871.1712  0.0038 -4.2894     3 158.8378    15    43   506   303     7     4     4    --    --    --     6     4     3    --    --    -- H2C-13-CO False
# 136917.9504  0.0037 -3.5963     3  95.3909    45    43   506   303     7     3     5    --    --    --     6     3     4    --    --    -- H2C-13-CO False
# 136917.9762  0.0037 -3.5963     3  95.3909    45    43   506   303     7     3     4    --    --    --     6     3     3    --    --    -- H2C-13-CO False
#  136944.582  0.0036 -3.9276     3   50.026    15    43   506   303     7     2     6    --    --    --     6     2     5    --    --    -- H2C-13-CO False
# 136953.2875  0.0041 -3.8149     3  13.7062    15    43   506   303     7     0     7    --    --    --     6     0     6    --    --    -- H2C-13-CO False
# 136963.7624  0.0036 -3.9274     3  50.0268    15    43   506   303     7     2     5    --    --    --     6     2     4    --    --    -- H2C-13-CO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 138199.9851   0.004 -3.3581     3 22.9128    45    43   506   303     7     1     6    --    --    --     6     1     5    --    --    -- H2C-13-CO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 143332.8366  0.6454 -5.8324     3 271.539   171    43   506   303    28     1    27    --    --    --    28     1    28    --    --    -- H2C-13-CO False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 153533.5918  0.7507 -5.8267     3 290.2752   177    43   506   303    29     1    28    --    --    --    29     1    29    --    --    -- H2C-13-CO False, <Table length=11>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
#  252017.349    0.02 -2.6412     3   59.5272    81    43   506   303    13     1    13    --    --    --    12     1    12    --    --    -- H2C-13-CO  True
# 252572.0011  0.7699 -5.4313     3 1138.8053    81    43   506   303    13    11     2    --    --    --    12    11     1    --    --    -- H2C-13-CO False
# 252572.0011  0.7699 -5.4313     3 1138.8053    81    43   506   303    13    11     3    --    --    --    12    11     2    --    --    -- H2C-13-CO False
# 252964.5606  0.3582 -5.3595     3  951.5324    27    43   506   303    13    10     3    --    --    --    12    10     2    --    --    -- H2C-13-CO False
# 252964.5606  0.3582 -5.3595     3  951.5324    27    43   506   303    13    10     4    --    --    --    12    10     3    --    --    -- H2C-13-CO False
# 253279.4794  0.1413 -4.4216     3   781.548    81    43   506   303    13     9     4    --    --    --    12     9     3    --    --    -- H2C-13-CO False
# 253279.4794  0.1413 -4.4216     3   781.548    81    43   506   303    13     9     5    --    --    --    12     9     4    --    --    -- H2C-13-CO False
#  253535.945  0.0417 -4.5034     3  629.0115    27    43   506   303    13     8     5    --    --    --    12     8     4    --    --    -- H2C-13-CO False
#  253535.945  0.0417 -4.5034     3  629.0115    27    43   506   303    13     8     6    --    --    --    12     8     5    --    --    -- H2C-13-CO False
#  253746.666    0.02 -3.6865     3  494.0679    81    43   506   303    13     7     6    --    --    --    12     7     5    --    --    -- H2C-13-CO  True
#  253746.666    0.02 -3.6865     3  494.0679    81    43   506   303    13     7     7    --    --    --    12     7     6    --    --    -- H2C-13-CO  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- ----
# 252017.349    0.02 -2.6412     3 59.5272    81    43   506   303    13     1    13    --    --    --    12     1    12    --    --    -- H2C-13-CO True, <Table length=13>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name   Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9   bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- ----
# 253746.666    0.02 -3.6865     3 494.0679    81    43   506   303    13     7     6    --    --    --    12     7     5    --    --    -- H2C-13-CO True
# 253746.666    0.02 -3.6865     3 494.0679    81    43   506   303    13     7     7    --    --    --    12     7     6    --    --    -- H2C-13-CO True
# 253920.084    0.02 -3.8742     3  376.847    27    43   506   303    13     6     7    --    --    --    12     6     6    --    --    -- H2C-13-CO True
# 253920.084    0.02 -3.8742     3  376.847    27    43   506   303    13     6     8    --    --    --    12     6     7    --    --    -- H2C-13-CO True
#  254061.85    0.02 -3.1551     3  277.463    81    43   506   303    13     5     8    --    --    --    12     5     7    --    --    -- H2C-13-CO True
#  254061.85    0.02 -3.1551     3  277.463    81    43   506   303    13     5     9    --    --    --    12     5     8    --    --    -- H2C-13-CO True
# 254176.247    0.02 -3.4359     3 196.0135    27    43   506   303    13     4    10    --    --    --    12     4     9    --    --    -- H2C-13-CO True
# 254176.247    0.02 -3.4359     3 196.0135    27    43   506   303    13     4     9    --    --    --    12     4     8    --    --    -- H2C-13-CO True
# 254232.968    0.02 -3.0902     3  50.8983    27    43   506   303    13     0    13    --    --    --    12     0    12    --    --    -- H2C-13-CO True
# 254267.972    0.02 -2.8069     3 132.5796    81    43   506   303    13     3    11    --    --    --    12     3    10    --    --    -- H2C-13-CO True
# 254268.518    0.02 -2.8069     3 132.5797    81    43   506   303    13     3    10    --    --    --    12     3     9    --    --    -- H2C-13-CO True
# 254291.758    0.02 -3.1761     3  87.2204    27    43   506   303    13     2    12    --    --    --    12     2    11    --    --    -- H2C-13-CO True
# 254416.327    0.02 -3.1757     3  87.2318    27    43   506   303    13     2    11    --    --    --    12     2    10    --    --    -- H2C-13-CO True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- ----
# 256614.289    0.02 -2.6276     3 60.4476    81    43   506   303    13     1    12    --    --    --    12     1    11    --    --    -- H2C-13-CO True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name   Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9   bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- ----
# 271393.514    0.02 -2.5625     3 67.9336    87    43   506   303    14     1    14    --    --    --    13     1    13    --    --    -- H2C-13-CO True, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
#  271393.514    0.02 -2.5625     3   67.9336    87    43   506   303    14     1    14    --    --    --    13     1    13    --    --    -- H2C-13-CO  True
# 271996.8384  0.8287 -5.2236     3 1147.2302    87    43   506   303    14    11     3    --    --    --    13    11     2    --    --    -- H2C-13-CO False
# 271996.8384  0.8287 -5.2236     3 1147.2302    87    43   506   303    14    11     4    --    --    --    13    11     3    --    --    -- H2C-13-CO False
# 272419.4667  0.3852 -5.2021     3  959.9704    29    43   506   303    14    10     4    --    --    --    13    10     3    --    --    -- H2C-13-CO False
# 272419.4667  0.3852 -5.2021     3  959.9704    29    43   506   303    14    10     5    --    --    --    13    10     4    --    --    -- H2C-13-CO False
# 272758.5264  0.1517 -4.2915     3  789.9965    87    43   506   303    14     9     5    --    --    --    13     9     4    --    --    -- H2C-13-CO False
# 272758.5264  0.1517 -4.2915     3  789.9965    87    43   506   303    14     9     6    --    --    --    13     9     5    --    --    -- H2C-13-CO False
# 273034.6841  0.0442 -4.3901     3  637.4686    29    43   506   303    14     8     6    --    --    --    13     8     5    --    --    -- H2C-13-CO False
# 273034.6841  0.0442 -4.3901     3  637.4686    29    43   506   303    14     8     7    --    --    --    13     8     6    --    --    -- H2C-13-CO False, <Table length=15>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l     name    Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str9    bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- --------- -----
# 273034.6841  0.0442 -4.3901     3 637.4686    29    43   506   303    14     8     6    --    --    --    13     8     5    --    --    -- H2C-13-CO False
# 273034.6841  0.0442 -4.3901     3 637.4686    29    43   506   303    14     8     7    --    --    --    13     8     6    --    --    -- H2C-13-CO False
#  273261.662    0.02 -3.5845     3  502.532    87    43   506   303    14     7     7    --    --    --    13     7     6    --    --    -- H2C-13-CO  True
#  273261.662    0.02 -3.5845     3  502.532    87    43   506   303    14     7     8    --    --    --    13     7     7    --    --    -- H2C-13-CO  True
#   273448.49    0.02 -3.7801     3 385.3169    29    43   506   303    14     6     8    --    --    --    13     6     7    --    --    -- H2C-13-CO  True
#   273448.49    0.02 -3.7801     3 385.3169    29    43   506   303    14     6     9    --    --    --    13     6     8    --    --    -- H2C-13-CO  True
#   273601.39    0.02 -3.0666     3 285.9375    87    43   506   303    14     5     9    --    --    --    13     5     8    --    --    -- H2C-13-CO  True
#   273601.39    0.02 -3.0666     3 285.9375    87    43   506   303    14     5    10    --    --    --    13     5     9    --    --    -- H2C-13-CO  True
#   273725.09    0.02 -3.3515     3 204.4919    29    43   506   303    14     4    11    --    --    --    13     4    10    --    --    -- H2C-13-CO  True
#   273725.09    0.02 -3.3515     3 204.4919    29    43   506   303    14     4    10    --    --    --    13     4     9    --    --    -- H2C-13-CO  True
#  273763.002    0.02 -3.0121     3  59.3786    29    43   506   303    14     0    14    --    --    --    13     0    13    --    --    -- H2C-13-CO  True
#  273824.945    0.02 -2.7253     3 141.0611    87    43   506   303    14     3    12    --    --    --    13     3    11    --    --    -- H2C-13-CO  True
#  273825.874    0.02 -2.7253     3 141.0611    87    43   506   303    14     3    11    --    --    --    13     3    10    --    --    -- H2C-13-CO  True
#  273844.452    0.02 -3.0965     3  95.7026    29    43   506   303    14     2    13    --    --    --    13     2    12    --    --    -- H2C-13-CO  True
#  274000.123    0.02  -3.096     3  95.7182    29    43   506   303    14     2    12    --    --    --    13     2    11    --    --    -- H2C-13-CO  True]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
               nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-5)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
                       nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-5)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
