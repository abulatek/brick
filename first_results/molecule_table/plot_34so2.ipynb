# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 66501 # 66002
cubes, tbl = fetch_cubes(cubefns, catalog='CDMS', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=4>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#   85710.72  0.1672 -8.2445     3 2234.5767   155    66   501   303    77    14    64    --    --    --    76    15    61    --    --    -- S-34-O2 False
#  85972.412  0.0046 -5.1895     3   368.051    67    66   501   303    33     3    31    --    --    --    32     4    28    --    --    -- S-34-O2 False
# 86473.9997  0.0894 -7.6771     3 1951.9375   145    66   501   303    72    13    59    --    --    --    71    14    58    --    --    -- S-34-O2 False
# 87293.8839  0.0437 -7.1507     3 1688.2496   135    66   501   303    67    12    56    --    --    --    66    13    53    --    --    -- S-34-O2 False, <Table length=4>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 88299.4727  0.0191 -6.6645     3 1443.5577   125    66   501   303    62    11    51    --    --    --    61    12    50    --    --    -- S-34-O2 False
# 88720.5639  0.0009 -4.7257     3   29.7235    15    66   501   303     7     3     5    --    --    --     8     2     6    --    --    -- S-34-O2 False
# 89041.0981  0.5787 -7.4838     3  1513.184   135    66   501   303    67     6    62    --    --    --    66     7    59    --    --    -- S-34-O2 False
# 89151.4736  0.0071 -6.2223     3 1217.9034   115    66   501   303    57    10    48    --    --    --    56    11    45    --    --    -- S-34-O2 False, <Table length=4>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 90196.8665   0.003 -4.9174     3  506.3789    75    66   501   303    37     6    32    --    --    --    36     7    29    --    --    -- S-34-O2  True
# 90463.2273  0.0367 -5.8046     3   682.867    91    66   501   303    45     4    42    --    --    --    44     5    39    --    --    -- S-34-O2 False
# 90765.1933  0.0028 -5.8159     3 1011.3235   105    66   501   303    52     9    43    --    --    --    51    10    42    --    --    -- S-34-O2 False
# 90864.2858  0.0018 -5.4681     3  823.8564    95    66   501   303    47     8    40    --    --    --    46     9    37    --    --    -- S-34-O2 False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- ----
# 92428.8728   0.003 -4.5074     3 248.9344    53    66   501   303    26     4    22    --    --    --    25     5    21    --    --    -- S-34-O2 True, <Table length=5>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 93852.0657   0.003 -4.4778     3   135.665    35    66   501   303    17     5    13    --    --    --    18     4    14    --    --    -- S-34-O2  True
# 94250.8406   0.003 -5.4887     3  140.8929    41    66   501   303    20     2    18    --    --    --    21     1    21    --    --    -- S-34-O2  True
#  94345.652  0.5654 -9.1008     3 2694.0618   165    66   501   303    82    18    64    --    --    --    83    17    67    --    --    -- S-34-O2 False
# 95242.6137   0.003 -5.1249     3  655.5243    85    66   501   303    42     7    35    --    --    --    41     8    34    --    --    -- S-34-O2  True
# 95249.9841  0.3484 -8.4726     3 2383.0899   155    66   501   303    77    17    61    --    --    --    78    16    62    --    --    -- S-34-O2 False, <Table length=10>
#    FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#    MHz       MHz   MHz nm2         1 / cm          u
#  float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ---------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 95810.4135   0.003 -5.3759     3    5.3115     5    66   501   303     2     2     0    --    --    --     3     1     3    --    --    -- S-34-O2  True
# 95922.8159   0.003 -4.4917     3   72.9155    25    66   501   303    12     4     8    --    --    --    13     3    11    --    --    -- S-34-O2  True
# 95999.3633  0.2048 -7.8871     3 2090.9942   145    66   501   303    72    16    56    --    --    --    73    15    59    --    --    -- S-34-O2 False
# 96075.2978   0.003 -4.5332     3   218.874    51    66   501   303    25     3    23    --    --    --    24     4    20    --    --    -- S-34-O2  True
# 96193.8592   0.003 -4.5099     3   217.518    45    66   501   303    22     6    16    --    --    --    23     5    19    --    --    -- S-34-O2  True
# 96204.0652   0.003 -4.6282     3  318.6828    55    66   501   303    27     7    21    --    --    --    28     6    22    --    --    -- S-34-O2  True
# 96598.7817  0.1138 -7.3444     3 1817.8244   135    66   501   303    67    15    53    --    --    --    68    14    54    --    --    -- S-34-O2 False
# 96987.7343   0.003  -4.796     3  439.0424    65    66   501   303    32     8    24    --    --    --    33     7    27    --    --    -- S-34-O2  True
# 97053.6201  0.0592 -6.8451     3 1563.6271   125    66   501   303    62    14    48    --    --    --    63    13    51    --    --    -- S-34-O2 False
# 97236.5286   0.003   -5.02     3  578.6196    75    66   501   303    37     9    29    --    --    --    38     8    30    --    --    -- S-34-O2  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 97580.4106  0.0076 -5.6122     3 915.2838    95    66   501   303    47    11    37    --    --    --    48    10    38    --    --    -- S-34-O2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- ----
# 102031.8784   0.003 -4.2159     3  1.9081     7    66   501   303     3     1     3    --    --    --     2     0     2    --    --    -- S-34-O2 True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- ----
# 102031.8784   0.003 -4.2159     3  1.9081     7    66   501   303     3     1     3    --    --    --     2     0     2    --    --    -- S-34-O2 True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- ----
# 102031.8784   0.003 -4.2159     3  1.9081     7    66   501   303     3     1     3    --    --    --     2     0     2    --    --    -- S-34-O2 True, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 104391.7061   0.003 -3.7543     3   34.4375    21    66   501   303    10     1     9    --    --    --    10     0    10    --    --    -- S-34-O2  True
# 104709.6134  0.5032  -9.423     3 2911.9313   177    66   501   303    88    16    72    --    --    --    87    17    71    --    --    -- S-34-O2 False
# 104914.6988   0.003 -4.8414     3  326.6035    63    66   501   303    31     3    29    --    --    --    30     4    26    --    --    -- S-34-O2  True, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  106301.485  0.1749 -8.1535     3 2283.7128   157    66   501   303    78    14    64    --    --    --    77    15    63    --    --    -- S-34-O2 False
# 106374.2616  0.0015 -4.5999     3  396.9863    67    66   501   303    33     5    29    --    --    --    32     6    26    --    --    -- S-34-O2 False
# 107227.5125   0.094 -7.5793     3 1997.9211   147    66   501   303    73    13    61    --    --    --    72    14    58    --    --    -- S-34-O2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  107567.842   0.003 -4.5539     3  376.3878    65    66   501   303    32     5    27    --    --    --    31     6    26    --    --    -- S-34-O2  True
# 108296.2923  0.0465 -7.0454     3 1731.0735   137    66   501   303    68    12    56    --    --    --    67    13    55    --    --    -- S-34-O2 False
#   109260.51   0.003 -4.5217     3  252.0175    55    66   501   303    27     3    25    --    --    --    26     4    22    --    --    -- S-34-O2  True, <Table length=1>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 110821.3845   0.008  -6.101     3 1254.3878   117    66   501   303    58    10    48    --    --    --    57    11    47    --    --    -- S-34-O2 False, <Table length=5>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- ----
# 111539.3201   0.003 -5.6972     3 1044.6313   107    66   501   303    53     9    45    --    --    --    52    10    42    --    --    -- S-34-O2 True
# 111902.7923   0.003  -4.433     3  301.1188    59    66   501   303    29     4    26    --    --    --    28     5    23    --    --    -- S-34-O2 True
# 112532.3159   0.003 -4.3937     3   64.6962    23    66   501   303    11     4     8    --    --    --    12     3     9    --    --    -- S-34-O2 True
# 112553.5831   0.003 -5.0255     3  682.4678    87    66   501   303    43     7    37    --    --    --    42     8    34    --    --    -- S-34-O2 True
# 112577.8993   0.003 -4.6249     3  287.9224    59    66   501   303    29     3    27    --    --    --    28     4    24    --    --    -- S-34-O2 True, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 112532.3159   0.003 -4.3937     3  64.6962    23    66   501   303    11     4     8    --    --    --    12     3     9    --    --    -- S-34-O2  True
# 112553.5831   0.003 -5.0255     3 682.4678    87    66   501   303    43     7    37    --    --    --    42     8    34    --    --    -- S-34-O2  True
# 112577.8993   0.003 -4.6249     3 287.9224    59    66   501   303    29     3    27    --    --    --    28     4    24    --    --    -- S-34-O2  True
# 113979.8444  0.5454 -8.8345     3 2641.178   163    66   501   303    81    18    64    --    --    --    82    17    65    --    --    -- S-34-O2 False, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 114311.9776   2.246 -8.9862     3   2306.85   165    66   501   303    82     8    74    --    --    --    83     7    77    --    --    -- S-34-O2 False
#  114574.439   0.003 -4.6154     3   24.3984    13    66   501   303     6     3     3    --    --    --     7     2     6    --    --    -- S-34-O2  True
# 114706.6849   0.003 -5.3184     3  853.9763    97    66   501   303    48     8    40    --    --    --    47     9    39    --    --    -- S-34-O2  True
# 115005.4001  0.3354 -8.2138     3 2333.3513   153    66   501   303    76    17    59    --    --    --    77    16    62    --    --    -- S-34-O2 False
# 115291.3883   0.003 -4.1181     3   91.4486    33    66   501   303    16     2    14    --    --    --    15     3    13    --    --    -- S-34-O2  True
# 115644.3295   1.379 -8.2091     3 1998.9615   155    66   501   303    77     7    71    --    --    --    76     8    68    --    --    -- S-34-O2 False
# 115722.1453   0.003 -4.3489     3  202.8013    43    66   501   303    21     6    16    --    --    --    22     5    17    --    --    -- S-34-O2  True
# 115744.6662   0.003 -4.3124     3  124.0723    33    66   501   303    16     5    11    --    --    --    17     4    14    --    --    -- S-34-O2  True
# 115867.3343  0.1967 -7.6357     3 2044.4086   143    66   501   303    71    16    56    --    --    --    72    15    57    --    --    -- S-34-O2 False, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 125921.0348   0.317 -8.7187     3 2641.3163   169    66   501   303    84    15    69    --    --    --    83    16    68    --    --    -- S-34-O2 False
#  126953.242   0.183 -8.0969     3 2333.4864   159    66   501   303    79    14    66    --    --    --    78    15    63    --    --    -- S-34-O2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  126953.242   0.183 -8.0969     3 2333.4864   159    66   501   303    79    14    66    --    --    --    78    15    63    --    --    -- S-34-O2 False
# 127127.3498    1.06 -7.8792     3 1782.0455   145    66   501   303    72     7    65    --    --    --    73     6    68    --    --    -- S-34-O2 False
# 128107.8497  0.0992 -7.5154     3 2044.5444   149    66   501   303    74    13    61    --    --    --    73    14    60    --    --    -- S-34-O2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 128668.7898  0.0014 -3.6074     3   25.4316    17    66   501   303     8     2     6    --    --    --     8     1     7    --    --    -- S-34-O2 False
# 129294.1685  0.0495 -6.9751     3 1774.5392   139    66   501   303    69    12    58    --    --    --    68    13    55    --    --    -- S-34-O2 False
#   129803.36     0.2 -3.3872     3   70.5389    29    66   501   303    14     2    12    --    --    --    14     1    13    --    --    -- S-34-O2  True, <Table length=5>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 130584.3043  0.0011 -4.6413     3   20.0377    11    66   501   303     5     3     3    --    --    --     6     2     4    --    --    -- S-34-O2 False
# 130732.7485  0.0242 -5.2781     3  625.4784    87    66   501   303    43     4    40    --    --    --    42     5    37    --    --    -- S-34-O2 False
# 130769.2571  0.0224 -6.4748     3 1523.5162   129    66   501   303    64    11    53    --    --    --    63    12    52    --    --    -- S-34-O2 False
# 131886.3104  0.0088 -6.0191     3 1291.5188   119    66   501   303    59    10    50    --    --    --    58    11    47    --    --    -- S-34-O2 False
# 131936.5261  0.0024 -4.6651     3  554.5268    79    66   501   303    39     6    34    --    --    --    38     7    31    --    --    -- S-34-O2 False, <Table length=6>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 131886.3104  0.0088 -6.0191     3 1291.5188   119    66   501   303    59    10    50    --    --    --    58    11    47    --    --    -- S-34-O2 False
# 131936.5261  0.0024 -4.6651     3  554.5268    79    66   501   303    39     6    34    --    --    --    38     7    31    --    --    -- S-34-O2 False
#   132114.04     0.2  -3.587     3   48.5636    25    66   501   303    12     1    11    --    --    --    12     0    12    --    --    -- S-34-O2  True
# 132262.6559  0.8244 -9.2513     3 2912.4469   171    66   501   303    85    19    67    --    --    --    86    18    68    --    --    -- S-34-O2 False
#   133471.47     0.2 -3.8004     3    6.3459    11    66   501   303     5     1     5    --    --    --     4     0     4    --    --    -- S-34-O2  True
# 133581.1562   0.526  -8.596     3 2588.9279   161    66   501   303    80    18    62    --    --    --    81    17    65    --    --    -- S-34-O2 False, <Table length=9>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 134018.2685  0.0025 -5.2381     3   884.753    99    66   501   303    49     8    42    --    --    --    48     9    39    --    --    -- S-34-O2 False
# 134398.2109  0.0039 -5.5973     3 1078.5833   109    66   501   303    54     9    45    --    --    --    53    10    44    --    --    -- S-34-O2 False
# 134417.5903  0.0043 -5.3376     3  167.7683    45    66   501   303    22     2    20    --    --    --    23     1    23    --    --    -- S-34-O2 False
# 134535.2528   0.001 -4.2931     3    56.942    21    66   501   303    10     4     6    --    --    --    11     3     9    --    --    -- S-34-O2 False
# 134703.2784  0.0011 -4.2023     3  113.2188    31    66   501   303    15     5    11    --    --    --    16     4    12    --    --    -- S-34-O2 False
# 134722.8123  0.3228 -7.9828     3 2284.2485   151    66   501   303    75    17    59    --    --    --    76    16    60    --    --    -- S-34-O2 False
# 134809.0494  0.4373 -6.9648     3 1324.1392   125    66   501   303    62     6    56    --    --    --    63     5    59    --    --    -- S-34-O2 False
#   134826.12     0.2 -3.7194     3   15.5404    13    66   501   303     6     2     4    --    --    --     6     1     5    --    --    -- S-34-O2  True
#   134873.84     0.2 -3.8371     3   48.4716    25    66   501   303    12     1    11    --    --    --    11     2    10    --    --    -- S-34-O2  True, <Table length=6>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#   135566.28     0.2 -4.0639     3  174.0474    45    66   501   303    22     3    19    --    --    --    21     4    18    --    --    -- S-34-O2  True
# 135691.9085  0.1889 -7.4121     3 1998.4607   141    66   501   303    70    16    54    --    --    --    71    15    57    --    --    -- S-34-O2 False
# 136343.6592  0.0013   -4.21     3  188.6928    41    66   501   303    20     6    14    --    --    --    21     5    17    --    --    -- S-34-O2 False
# 136492.0456  0.1044 -6.8843     3 1731.6134   131    66   501   303    65    15    51    --    --    --    66    14    52    --    --    -- S-34-O2 False
# 136847.9507  0.0014 -4.2991     3  283.4406    51    66   501   303    25     7    19    --    --    --    26     6    20    --    --    -- S-34-O2 False
#  137126.584  0.0542 -6.3997     3 1483.7519   121    66   501   303    60    14    46    --    --    --    61    13    49    --    --    -- S-34-O2 False, <Table length=8>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  137520.629  0.0015 -4.4479     3  397.4055    61    66   501   303    30     8    22    --    --    --    31     7    25    --    --    -- S-34-O2 False
# 137597.0814  0.0269 -5.9591     3 1254.9181   111    66   501   303    55    13    43    --    --    --    56    12    44    --    --    -- S-34-O2 False
# 137835.7614  0.0023 -4.6528     3  530.5867    71    66   501   303    35     9    27    --    --    --    36     8    28    --    --    -- S-34-O2 False
# 137906.9678  0.0136 -5.5629     3 1045.1508   101    66   501   303    50    12    38    --    --    --    51    11    41    --    --    -- S-34-O2 False
# 138041.0104  0.0043 -4.9082     3  682.9542    81    66   501   303    40    10    30    --    --    --    41     9    33    --    --    -- S-34-O2 False
# 138050.7085  0.0076 -5.2123     3  854.4857    91    66   501   303    45    11    35    --    --    --    46    10    36    --    --    -- S-34-O2 False
#   138208.06   0.013 -5.3668     3  355.0431    65    66   501   303    32     3    29    --    --    --    33     2    32    --    --    -- S-34-O2 False
#  138573.751  0.1495 -6.2356     3   933.477   105    66   501   303    52     5    47    --    --    --    53     4    50    --    --    -- S-34-O2 False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 139484.0216   0.042 -5.6953     3 610.3583    85    66   501   303    42     4    38    --    --    --    43     3    41    --    --    -- S-34-O2 False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#   141158.76     0.2 -3.8935     3   8.2702     9    66   501   303     4     2     2    --    --    --     4     1     3    --    --    -- S-34-O2  True
# 141195.7947  0.0016  -4.305     3  339.195    63    66   501   303    31     4    28    --    --    --    30     5    25    --    --    -- S-34-O2 False
# 141513.1678  0.0025 -4.8732     3 710.0416    89    66   501   303    44     7    37    --    --    --    43     8    36    --    --    -- S-34-O2 False
#   141653.16     0.2 -3.3143     3  90.5693    33    66   501   303    16     2    14    --    --    --    16     1    15    --    --    -- S-34-O2  True, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 144436.6626  0.0022 -4.4051     3  440.0757    71    66   501   303    35     5    31    --    --    --    34     6    28    --    --    -- S-34-O2 False
# 145309.8939  0.5412 -9.3624     3 3024.6646   181    66   501   303    90    16    74    --    --    --    89    17    73    --    --    -- S-34-O2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#   146020.42  0.0014  -4.273     3    3.6367     5    66   501   303     2     2     0    --    --    --     2     1     1    --    --    -- S-34-O2 False
# 146448.9603  0.3301 -8.6934     3 2694.8677   171    66   501   303    85    15    71    --    --    --    84    16    68    --    --    -- S-34-O2 False
# 146456.2734   2.888 -9.0997     3 2551.2784   175    66   501   303    87     8    80    --    --    --    86     9    77    --    --    -- S-34-O2 False, <Table length=2>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 147702.7408  0.1917 -8.0645     3 2383.8976   161    66   501   303    80    14    66    --    --    --    79    15    65    --    --    -- S-34-O2 False
# 149024.8714  0.1047 -7.4762     3 2091.8075   151    66   501   303    75    13    63    --    --    --    74    14    60    --    --    -- S-34-O2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 149024.8714  0.1047 -7.4762     3 2091.8075   151    66   501   303    75    13    63    --    --    --    74    14    60    --    --    -- S-34-O2 False
# 149209.9069  0.0018 -4.1244     3  282.9453    57    66   501   303    28     4    24    --    --    --    27     5    23    --    --    -- S-34-O2 False
# 150547.7317  0.0533 -6.9281     3 1818.6465   141    66   501   303    70    12    58    --    --    --    69    13    57    --    --    -- S-34-O2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 151712.2963  0.7962  -9.026     3 2857.6894   169    66   501   303    84    19    65    --    --    --    85    18    68    --    --    -- S-34-O2 False
# 151917.5595  0.0012 -4.7246     3   16.1398     9    66   501   303     4     3     1    --    --    --     5     2     4    --    --    -- S-34-O2 False
# 151938.6639  0.0246 -6.4225     3 1564.4616   131    66   501   303    65    11    55    --    --    --    64    12    52    --    --    -- S-34-O2 False, <Table length=4>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 152953.6452  0.0011 -4.2484     3   49.9468    19    66   501   303     9     4     6    --    --    --    10     3     7    --    --    -- S-34-O2 False
# 153015.0532  0.0013 -4.0184     3    5.3115     7    66   501   303     3     2     2    --    --    --     3     1     3    --    --    -- S-34-O2 False
# 153150.6693  0.5071  -8.378     3 2537.3116   159    66   501   303    79    18    62    --    --    --    80    17    63    --    --    -- S-34-O2 False
# 154133.3971  0.0109 -5.9547     3  1329.294   121    66   501   303    60    10    50    --    --    --    59    11    49    --    --    -- S-34-O2 False, <Table length=6>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 241894.7779  0.0082 -4.6155     3  826.8873    97    66   501   303    48     7    41    --    --    --    47     8    40    --    --    -- S-34-O2 False
# 241985.4494  0.0022 -3.2145     3   29.7235    17    66   501   303     8     3     5    --    --    --     8     2     6    --    --    -- S-34-O2 False
# 242466.9604  0.0281 -5.1777     3  441.5035    73    66   501   303    36     3    33    --    --    --    37     2    36    --    --    -- S-34-O2 False
#  242477.771  0.3832 -7.2887     3 1764.1303   143    66   501   303    71     9    63    --    --    --    72     6    66    --    --    -- S-34-O2 False
#  242796.872  0.0151 -5.4201     3 1258.0844   119    66   501   303    59     9    51    --    --    --    58    10    48    --    --    -- S-34-O2 False
# 243235.4208  0.0252 -5.8589     3 1486.8622   129    66   501   303    64    10    54    --    --    --    63    11    53    --    --    -- S-34-O2 False, <Table length=3>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  243936.052     0.1 -3.2211     3 104.8651    37    66   501   303    18     1    17    --    --    --    18     0    18    --    --    -- S-34-O2  True
# 244481.5166  0.0024 -2.8542     3  56.8593    29    66   501   303    14     0    14    --    --    --    13     1    13    --    --    -- S-34-O2 False
#  245178.587     0.1 -3.2012     3  74.3351    31    66   501   303    15     2    14    --    --    --    15     1    15    --    --    -- S-34-O2  True, <Table length=6>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#  245178.587     0.1 -3.2012     3   74.3351    31    66   501   303    15     2    14    --    --    --    15     1    15    --    --    -- S-34-O2  True
# 245283.7279  0.8792 -7.8287     3 2051.6986   155    66   501   303    77     9    69    --    --    --    78     6    72    --    --    -- S-34-O2 False
# 245302.2389  0.0021 -3.3384     3   20.0377    13    66   501   303     6     3     3    --    --    --     6     2     4    --    --    -- S-34-O2 False
# 246160.2158  0.8973 -9.0289     3 2642.0838   175    66   501   303    87    11    77    --    --    --    88     8    80    --    --    -- S-34-O2 False
# 246373.6696   1.019 -8.7414     3 2916.8587   169    66   501   303    84    20    64    --    --    --    85    19    67    --    --    -- S-34-O2 False
# 246686.1187  0.0021 -3.5733     3   12.9787     9    66   501   303     4     3     1    --    --    --     4     2     2    --    --    -- S-34-O2 False, <Table length=6>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 247127.3904  0.0021 -3.8243     3   10.4155     7    66   501   303     3     3     1    --    --    --     3     2     2    --    --    -- S-34-O2 False
#  247440.298  0.0021 -3.4305     3   16.1398    11    66   501   303     5     3     3    --    --    --     5     2     4    --    --    -- S-34-O2 False
# 248211.8282   0.299  -6.708     3 1473.3545   131    66   501   303    65     8    58    --    --    --    66     5    61    --    --    -- S-34-O2 False
#  248364.763     0.1 -3.2574     3   24.3984    15    66   501   303     7     3     5    --    --    --     7     2     6    --    --    -- S-34-O2  True
# 248572.1065   2.147 -9.1456     3  2724.339   179    66   501   303    89    10    80    --    --    --    90     7    83    --    --    -- S-34-O2 False
# 248582.3621  0.6646 -8.0882     3 2593.3837   159    66   501   303    79    19    61    --    --    --    80    18    62    --    --    -- S-34-O2 False, <Table length=10>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 248572.1065   2.147 -9.1456     3  2724.339   179    66   501   303    89    10    80    --    --    --    90     7    83    --    --    -- S-34-O2 False
# 248582.3621  0.6646 -8.0882     3 2593.3837   159    66   501   303    79    19    61    --    --    --    80    18    62    --    --    -- S-34-O2 False
#  248698.604     0.1 -2.8604     3   48.5636    27    66   501   303    13     1    13    --    --    --    12     0    12    --    --    -- S-34-O2  True
# 248780.1015    0.22 -6.5524     3  1390.258   127    66   501   303    63     8    56    --    --    --    64     5    59    --    --    -- S-34-O2 False
#  248855.711  0.0053 -4.9444     3  154.0023    43    66   501   303    21     3    19    --    --    --    22     0    22    --    --    -- S-34-O2 False
#  249099.352     0.1 -3.0349     3  318.2945    61    66   501   303    30     4    26    --    --    --    30     3    27    --    --    -- S-34-O2  True
#  249301.203     0.1 -4.4071     3   714.762    91    66   501   303    45     6    40    --    --    --    44     7    37    --    --    -- S-34-O2  True
# 250156.0486  0.0021 -4.7867     3   24.3936     9    66   501   303     4     4     0    --    --    --     5     3     3    --    --    -- S-34-O2 False
# 250213.9885  0.4089   -8.78     3 2972.1505   181    66   501   303    90    15    75    --    --    --    89    16    74    --    --    -- S-34-O2 False
#  250358.493     0.1 -3.1471     3   35.1802    19    66   501   303     9     3     7    --    --    --     9     2     8    --    --    -- S-34-O2  True, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
# ...
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 255386.9932   0.145 -7.4919     3 2337.7211   161    66   501   303    80    13    67    --    --    --    79    14    66    --    --    -- S-34-O2 False
# 255573.7433  0.8898 -6.9899     3 1803.1131   147    66   501   303    73     7    67    --    --    --    72     8    64    --    --    -- S-34-O2 False
# 255892.2937  0.0028  -3.769     3  193.2407    39    66   501   303    19     7    13    --    --    --    20     6    14    --    --    -- S-34-O2 False
# 256066.0249  0.3987 -6.8504     3  1558.693   135    66   501   303    67     8    60    --    --    --    68     5    63    --    --    -- S-34-O2 False
# 256120.9611  0.0419 -5.4611     3 1259.5078   109    66   501   303    54    14    40    --    --    --    55    13    43    --    --    -- S-34-O2 False
# 256213.3185  0.0134 -4.9757     3 1048.3519   109    66   501   303    54     8    46    --    --    --    53     9    45    --    --    -- S-34-O2 False
# 256864.3285  0.0029 -3.8363     3  288.0054    49    66   501   303    24     8    16    --    --    --    25     7    19    --    --    -- S-34-O2 False
# 256914.0297  0.0217 -5.0675     3 1049.7509    99    66   501   303    49    13    37    --    --    --    50    12    38    --    --    -- S-34-O2 False
# 257069.6249  0.1109 -5.9228     3 1060.1594   111    66   501   303    55     7    49    --    --    --    56     4    52    --    --    -- S-34-O2 False, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 257069.6249  0.1109 -5.9228     3 1060.1594   111    66   501   303    55     7    49    --    --    --    56     4    52    --    --    -- S-34-O2 False
# 257457.3732  0.0119   -4.72     3  859.0905    89    66   501   303    44    12    32    --    --    --    45    11    35    --    --    -- S-34-O2 False
# 257466.7274   0.003 -3.9736     3  401.9927    59    66   501   303    29     9    21    --    --    --    30     8    22    --    --    -- S-34-O2 False
# 257480.6188  0.0329 -4.6719     3  755.3912    95    66   501   303    47     5    43    --    --    --    46     6    40    --    --    -- S-34-O2 False
# 257740.7843  0.0071 -4.4201     3  687.5588    79    66   501   303    39    11    29    --    --    --    40    10    30    --    --    -- S-34-O2 False
# 257751.2338  0.0043 -4.1701     3  535.1844    69    66   501   303    34    10    24    --    --    --    35     9    27    --    --    -- S-34-O2 False
#  257898.353  0.0825 -6.9097     3 2048.8176   151    66   501   303    75    12    64    --    --    --    74    13    61    --    --    -- S-34-O2 False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 259617.2029  0.0025 -3.0077     3  64.2556    27    66   501   303    13     3    11    --    --    --    13     2    12    --    --    -- S-34-O2 False
# 259788.6667  0.0787 -5.7928     3 989.8642   107    66   501   303    53     7    47    --    --    --    54     4    50    --    --    -- S-34-O2 False
#  260326.997     0.1 -3.0268     3 194.2644    49    66   501   303    24     2    22    --    --    --    24     1    23    --    --    -- S-34-O2  True
# 260474.1397   0.015 -4.9179     3 436.2051    71    66   501   303    35     5    31    --    --    --    36     2    34    --    --    -- S-34-O2 False
# 261120.3088  0.0213 -4.4817     3 695.9107    91    66   501   303    45     5    41    --    --    --    44     6    38    --    --    -- S-34-O2 False, <Table length=8>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 261120.3088  0.0213 -4.4817     3  695.9107    91    66   501   303    45     5    41    --    --    --    44     6    38    --    --    -- S-34-O2 False
# 261569.7473  0.0349 -5.3195     3  714.3528    91    66   501   303    45     6    40    --    --    --    46     3    43    --    --    -- S-34-O2 False
# 261590.6069   0.285 -7.0753     3 1672.6806   139    66   501   303    69     9    61    --    --    --    70     6    64    --    --    -- S-34-O2 False
# 261814.5849  0.0489 -6.3644     3  1778.852   141    66   501   303    70    11    59    --    --    --    69    12    58    --    --    -- S-34-O2 False
#  261998.074   1.116 -7.9816     3 2152.0184   159    66   501   303    79     9    71    --    --    --    80     6    74    --    --    -- S-34-O2 False
# 262084.0937  0.0175 -4.9843     3  483.0689    75    66   501   303    37     5    33    --    --    --    38     2    36    --    --    -- S-34-O2 False
# 262324.9911  0.2614 -6.0491     3 1071.2258   113    66   501   303    56     5    51    --    --    --    57     4    54    --    --    -- S-34-O2 False
# 262833.5445  0.1543 -6.0428     3 1132.7103   115    66   501   303    57     7    51    --    --    --    58     4    54    --    --    -- S-34-O2 False, <Table length=5>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 262833.5445  0.1543 -6.0428     3 1132.7103   115    66   501   303    57     7    51    --    --    --    58     4    54    --    --    -- S-34-O2 False
# 263161.5693  0.0287 -5.8699     3 1527.8782   131    66   501   303    65    10    56    --    --    --    64    11    53    --    --    -- S-34-O2 False
# 263261.7406   1.463 -7.7005     3 1970.8143   153    66   501   303    76     7    69    --    --    --    77     6    72    --    --    -- S-34-O2 False
# 263436.0804  0.0086 -3.1119     3  403.4427    69    66   501   303    34     4    30    --    --    --    34     3    31    --    --    -- S-34-O2 False
# 263876.5417  0.2524 -5.8055     3 1262.3246   123    66   501   303    61     6    56    --    --    --    60     7    53    --    --    -- S-34-O2 False, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
#   264682.76     0.1 -3.4847     3  234.3329    53    66   501   303    26     3    23    --    --    --    25     4    22    --    --    -- S-34-O2  True
# 265032.4275  0.0144 -5.0135     3 1083.0664   111    66   501   303    55     8    48    --    --    --    54     9    45    --    --    -- S-34-O2 False
# 265163.9826  0.0493 -5.4148     3   774.076    95    66   501   303    47     6    42    --    --    --    48     3    45    --    --    -- S-34-O2 False
# 265429.0382  0.6644 -6.7857     3 1487.4414   133    66   501   303    66     6    60    --    --    --    67     5    63    --    --    -- S-34-O2 False
# 265488.6886  0.0074 -2.9316     3  243.1617    53    66   501   303    26     4    22    --    --    --    26     3    23    --    --    -- S-34-O2 False
# 265554.0506  0.0027 -3.2955     3   15.5404    15    66   501   303     7     2     6    --    --    --     6     1     5    --    --    -- S-34-O2 False
# 265572.5438   0.983 -8.5718     3   2862.75   167    66   501   303    83    20    64    --    --    --    84    19    65    --    --    -- S-34-O2 False, <Table length=5>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 266414.2501  0.0261 -5.2184     3  656.8991    87    66   501   303    43     6    38    --    --    --    44     3    41    --    --    -- S-34-O2 False
# 266469.7963  0.0072 -4.9525     3  182.0628    47    66   501   303    23     3    21    --    --    --    24     0    24    --    --    -- S-34-O2 False
# 267094.1515  0.0139 -4.8516     3  391.6253    67    66   501   303    33     5    29    --    --    --    34     2    32    --    --    -- S-34-O2 False
#   267871.06   0.003 -2.9604     3   82.5134    31    66   501   303    15     3    13    --    --    --    15     2    14    --    --    -- S-34-O2 False
#  267886.677    0.64 -7.9259     3 2542.4202   157    66   501   303    78    19    59    --    --    --    79    18    62    --    --    -- S-34-O2 False, <Table length=7>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 269958.5582  0.4032 -7.3221     3 2240.9318   147    66   501   303    73    18    56    --    --    --    74    17    57    --    --    -- S-34-O2 False
# 270153.7425  0.4705 -7.8578     3 2079.4798   155    66   501   303    77    10    68    --    --    --    78     7    71    --    --    -- S-34-O2 False
#  270229.555     0.1 -3.0313     3  309.2806    61    66   501   303    30     3    27    --    --    --    30     2    28    --    --    -- S-34-O2  True
# 270997.2666  0.0225 -5.0484     3  532.2274    79    66   501   303    39     5    35    --    --    --    40     2    38    --    --    -- S-34-O2 False
# 271111.3901  0.5218 -6.9834     3 1646.2877   139    66   501   303    69     8    62    --    --    --    70     5    65    --    --    -- S-34-O2 False
# 271174.9658  0.4279 -8.8248     3 3029.5117   183    66   501   303    91    15    77    --    --    --    90    16    74    --    --    -- S-34-O2 False
# 271410.2221  0.0029 -3.1397     3   94.1711    35    66   501   303    17     2    16    --    --    --    17     1    17    --    --    -- S-34-O2 False, <Table length=8>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 271410.2221  0.0029 -3.1397     3   94.1711    35    66   501   303    17     2    16    --    --    --    17     1    17    --    --    -- S-34-O2 False
# 271787.5952  0.2439 -6.7607     3 1958.3367   137    66   501   303    68    17    51    --    --    --    69    16    54    --    --    -- S-34-O2 False
#  271916.827  0.0024 -4.0355     3   55.0488    17    66   501   303     8     5     3    --    --    --     9     4     6    --    --    -- S-34-O2 False
# 272126.7048  0.0559 -5.6539     3  921.8091   103    66   501   303    51     7    45    --    --    --    52     4    48    --    --    -- S-34-O2 False
# 272289.0687  0.0223 -5.3926     3  1295.918   121    66   501   303    60     9    51    --    --    --    59    10    50    --    --    -- S-34-O2 False
# 272363.8674  0.0127 -4.8607     3  334.8197    63    66   501   303    31     4    28    --    --    --    32     1    31    --    --    -- S-34-O2 False
# 272625.7417  0.0023 -5.3723     3   34.4375    19    66   501   303     9     3     7    --    --    --    10     0    10    --    --    -- S-34-O2 False
# 272789.5215  0.0161 -5.1262     3  262.4184    57    66   501   303    28     2    26    --    --    --    29     1    29    --    --    -- S-34-O2 False, <Table length=4>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l    name   Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64   str7   bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------- -----
# 273372.2157  0.1406 -6.2423     3 1694.6829   127    66   501   303    63    16    48    --    --    --    64    15    49    --    --    -- S-34-O2 False
#    273930.1     0.1 -3.7777     3  108.1342    27    66   501   303    13     6     8    --    --    --    14     5     9    --    --    -- S-34-O2  True
# 273988.4848  0.2619 -8.1536     3 2699.7527   173    66   501   303    86    14    72    --    --    --    85    15    71    --    --    -- S-34-O2 False
# 274709.7171  0.0768 -5.7674     3 1450.0155   117    66   501   303    58    15    43    --    --    --    59    14    46    --    --    -- S-34-O2 False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.7e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=15, 
               nrows=3, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=f'$^{{34}}$SO$_2$', extr_type="coord", crd=crd,
               show_2_sigma=True, EU_cutoff_K=50)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 1.9e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='CDMS', fig_width=20, fig_height=15, 
                       nrows=3, ncols=5, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'$^{{34}}$SO$_2$', 
                       extr_type="reg", just_data=False, show_2_sigma=True, return_freqs=True, EU_cutoff_K=50)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=5, name_for_plot=f'$^{{34}}$SO$_2$')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=5, name_for_plot=f'$^{{34}}$SO$_2$')
