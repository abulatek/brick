# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 59503
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=5>
#    FREQ     ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name     Lab
#    MHz      MHz   MHz nm2        1 / cm          u
#  float64  float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12     bool
# --------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ ----
# 93692.459    0.02 -3.6689     3  54.4305    17    59   503   303     8     1     8    --    --    --     7     1     7    --    --    -- HNCS, a-type True
#  93830.05    0.02 -3.5703     3  10.9546    17    59   503   303     8     0     8    --    --    --     7     0     7    --    --    -- HNCS, a-type True
# 93863.182    0.02 -3.9319     3 171.2613    17    59   503   303     8     2     7    --    --    --     7     2     6    --    --    -- HNCS, a-type True
# 93863.182    0.02 -3.9319     3 171.2613    17    59   503   303     8     2     6    --    --    --     7     2     5    --    --    -- HNCS, a-type True
# 93995.194    0.02 -3.6662     3  54.4659    17    59   503   303     8     1     7    --    --    --     7     1     6    --    --    -- HNCS, a-type True, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name     Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12     bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ ----
# 105558.074    0.02 -3.4238     3  14.0844    19    59   503   303     9     0     9    --    --    --     8     0     8    --    --    -- HNCS, a-type True
# 105595.354    0.02 -3.7793     3 174.3922    19    59   503   303     9     2     8    --    --    --     8     2     7    --    --    -- HNCS, a-type True
# 105595.354    0.02 -3.7793     3 174.3922    19    59   503   303     9     2     7    --    --    --     8     2     6    --    --    -- HNCS, a-type True
# 105743.864    0.02 -3.5183     3  57.6012    19    59   503   303     9     1     8    --    --    --     8     1     7    --    --    -- HNCS, a-type True, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ -----
#  128824.102    0.02  -3.274     3  64.9782    23    59   503   303    11     1    11    --    --    --    10     1    10    --    --    -- HNCS, a-type  True
#  129013.249    0.02 -3.1786     3  21.5177    23    59   503   303    11     0    11    --    --    --    10     0    10    --    --    -- HNCS, a-type  True
#  129058.903    0.02 -3.5268     3 181.8281    23    59   503   303    11     2    10    --    --    --    10     2     9    --    --    -- HNCS, a-type  True
#  129058.903    0.02 -3.5268     3 181.8281    23    59   503   303    11     2     9    --    --    --    10     2     8    --    --    -- HNCS, a-type  True
# 129240.3561  0.0023 -3.2714     3  65.0476    23    59   503   303    11     1    10    --    --    --    10     1     9    --    --    -- HNCS, a-type False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name     Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12     bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ ----
# 140534.108    0.02 -3.1694     3 69.2753    25    59   503   303    12     1    12    --    --    --    11     1    11    --    --    -- HNCS, a-type True, <Table length=5>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name     Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12     bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ ----
# 140534.108    0.02 -3.1694     3 69.2753    25    59   503   303    12     1    12    --    --    --    11     1    11    --    --    -- HNCS, a-type True
# 140740.375    0.02 -3.0746     3 25.8211    25    59   503   303    12     0    12    --    --    --    11     0    11    --    --    -- HNCS, a-type True
# 140790.236    0.02 -3.4205     3 186.133    25    59   503   303    12     2    11    --    --    --    11     2    10    --    --    -- HNCS, a-type True
# 140790.236    0.02 -3.4205     3 186.133    25    59   503   303    12     2    10    --    --    --    11     2     9    --    --    -- HNCS, a-type True
# 140988.131    0.02 -3.1668     3 69.3586    25    59   503   303    12     1    11    --    --    --    11     1    10    --    --    -- HNCS, a-type True, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name     Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12     bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ ----
# 152243.736    0.02 -3.0749     3   73.963    27    59   503   303    13     1    13    --    --    --    12     1    12    --    --    -- HNCS, a-type True
#  152467.13    0.02 -2.9805     3  30.5157    27    59   503   303    13     0    13    --    --    --    12     0    12    --    --    -- HNCS, a-type True
# 152521.187    0.02 -3.3245     3 190.8293    27    59   503   303    13     2    12    --    --    --    12     2    11    --    --    -- HNCS, a-type True
# 152521.187    0.02 -3.3245     3 190.8293    27    59   503   303    13     2    11    --    --    --    12     2    10    --    --    -- HNCS, a-type True, <Table length=4>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name     Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12     bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ ----
#  152467.13    0.02 -2.9805     3  30.5157    27    59   503   303    13     0    13    --    --    --    12     0    12    --    --    -- HNCS, a-type True
# 152521.187    0.02 -3.3245     3 190.8293    27    59   503   303    13     2    12    --    --    --    12     2    11    --    --    -- HNCS, a-type True
# 152521.187    0.02 -3.3245     3 190.8293    27    59   503   303    13     2    11    --    --    --    12     2    10    --    --    -- HNCS, a-type True
# 152735.541    0.02 -3.0723     3  74.0614    27    59   503   303    13     1    12    --    --    --    12     1    11    --    --    -- HNCS, a-type True, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ -----
#  245905.016    0.02 -2.5592     3 125.5248    43    59   503   303    21     1    21    --    --    --    20     1    20    --    --    -- HNCS, a-type  True
#  246264.989    0.02 -2.4666     3  82.1531    43    59   503   303    21     0    21    --    --    --    20     0    20    --    --    -- HNCS, a-type  True
#  246352.927    0.02 -2.8042     3  242.485    43    59   503   303    21     2    20    --    --    --    20     2    19    --    --    -- HNCS, a-type  True
#  246353.941    0.02 -2.8042     3 242.4852    43    59   503   303    21     2    19    --    --    --    20     2    18    --    --    -- HNCS, a-type  True
# 246698.8942   0.004  -2.557     3 125.7898    43    59   503   303    21     1    20    --    --    --    20     1    19    --    --    -- HNCS, a-type False, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ -----
# 257610.2997  0.0042  -2.516     3 133.7273    45    59   503   303    22     1    22    --    --    --    21     1    21    --    --    -- HNCS, a-type False
# 257987.1819  0.0047 -2.4235     3  90.3676    45    59   503   303    22     0    22    --    --    --    21     0    21    --    --    -- HNCS, a-type False
#  258079.494  0.0051 -2.7608     3 250.7025    45    59   503   303    22     2    21    --    --    --    21     2    20    --    --    -- HNCS, a-type False
# 258080.6531  0.0051 -2.7608     3 250.7027    45    59   503   303    22     2    20    --    --    --    21     2    19    --    --    -- HNCS, a-type False
#  258441.858  0.0042 -2.5138     3 134.0188    45    59   503   303    22     1    21    --    --    --    21     1    20    --    --    -- HNCS, a-type False, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ -----
# 269314.9373  0.0043 -2.4763     3 142.3203    47    59   503   303    23     1    23    --    --    --    22     1    22    --    --    -- HNCS, a-type False
# 269708.7758  0.0048 -2.3839     3  98.9731    47    59   503   303    23     0    23    --    --    --    22     0    22    --    --    -- HNCS, a-type False, <Table length=4>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l      name      Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64    str12      bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ------------ -----
# 269708.7758  0.0048 -2.3839     3  98.9731    47    59   503   303    23     0    23    --    --    --    22     0    22    --    --    -- HNCS, a-type False
# 269805.4334  0.0053 -2.7209     3 259.3111    47    59   503   303    23     2    22    --    --    --    22     2    21    --    --    -- HNCS, a-type False
# 269806.7577  0.0053 -2.7209     3 259.3113    47    59   503   303    23     2    21    --    --    --    22     2    20    --    --    -- HNCS, a-type False
# 270184.1795  0.0043 -2.4742     3 142.6395    47    59   503   303    23     1    22    --    --    --    22     1    21    --    --    -- HNCS, a-type False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
               nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-5)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=10,
                       nrows=3, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-5)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
