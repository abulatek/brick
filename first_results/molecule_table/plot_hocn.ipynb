# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 43510
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 88402.9011   2.445 -5.6173     3 367.7497    63    43   510   303    31     1    30    --    --    --    31     1    31    --    --    -- HOCN False, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2        1 / cm          u
#  float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ---------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 94095.9508   2.899 -5.6233     3 390.0225    65    43   510   303    32     1    31    --    --    --    32     1    32    --    --    -- HOCN False, <Table length=1>
#    FREQ     ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz      MHz   MHz nm2        1 / cm          u
#  float64  float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# --------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 99965.537   3.406 -5.6319     3 412.9899    67    43   510   303    33     1    32    --    --    --    33     1    33    --    --    -- HOCN False, <Table length=8>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 104422.1742  0.0103   -2.89     3  29.3298    11    43   510   303     5     1     5    --    --    --     4     1     4    --    --    -- HOCN False
# 104762.2802  0.0637 -4.0055     3 361.6965    11    43   510   303     5     4     1    --    --    --     4     4     0    --    --    -- HOCN False
# 104762.2802  0.0637 -4.0055     3 361.6965    11    43   510   303     5     4     2    --    --    --     4     4     1    --    --    -- HOCN False
# 104813.0514  0.0322 -3.4336     3 207.3192    11    43   510   303     5     3     3    --    --    --     4     3     2    --    --    -- HOCN False
# 104813.0515  0.0322 -3.4336     3 207.3192    11    43   510   303     5     3     2    --    --    --     4     3     1    --    --    -- HOCN False
# 104847.9396  0.0143  -3.084     3  96.2897    11    43   510   303     5     2     4    --    --    --     4     2     3    --    --    -- HOCN False
#  104848.642  0.0144  -3.084     3  96.2897    11    43   510   303     5     2     3    --    --    --     4     2     2    --    --    -- HOCN False
# 104874.6777  0.0046 -2.8221     3   6.9966    11    43   510   303     5     0     5    --    --    --     4     0     4    --    --    -- HOCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 106011.5228    3.97 -5.6431     3 436.652    69    43   510   303    34     1    33    --    --    --    34     1    34    --    --    -- HOCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 112233.7655   4.595 -5.6569     3 461.0085    71    43   510   303    35     1    34    --    --    --    35     1    35    --    --    -- HOCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 112233.7655   4.595 -5.6569     3 461.0085    71    43   510   303    35     1    34    --    --    --    35     1    35    --    --    -- HOCN False, <Table length=12>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 125206.4216   6.038 -5.6919     3 511.8045    75    43   510   303    37     1    36    --    --    --    37     1    37    --    --    -- HOCN False
# 125305.4052  0.0118  -2.655     3  32.8129    13    43   510   303     6     1     6    --    --    --     5     1     5    --    --    -- HOCN False
# 125632.0589   0.151 -4.2575     3 561.9204    13    43   510   303     6     5     1    --    --    --     5     5     0    --    --    -- HOCN False
# 125632.0589   0.151 -4.2575     3 561.9204    13    43   510   303     6     5     2    --    --    --     5     5     1    --    --    -- HOCN False
# 125713.6568  0.0726 -3.5875     3  365.191    13    43   510   303     6     4     2    --    --    --     5     4     1    --    --    -- HOCN False
# 125713.6568  0.0726 -3.5875     3  365.191    13    43   510   303     6     4     3    --    --    --     5     4     2    --    --    -- HOCN False
# 125774.5963  0.0366 -3.1352     3 210.8154    13    43   510   303     6     3     4    --    --    --     5     3     3    --    --    -- HOCN False
# 125774.5965  0.0366 -3.1352     3 210.8154    13    43   510   303     6     3     3    --    --    --     5     3     2    --    --    -- HOCN False
# 125816.3445  0.0164 -2.8299     3   99.787    13    43   510   303     6     2     5    --    --    --     5     2     4    --    --    -- HOCN False
# 125817.5736  0.0164 -2.8299     3  99.7871    13    43   510   303     6     2     4    --    --    --     5     2     3    --    --    -- HOCN False
# 125848.0951  0.0053 -2.5925     3  10.4948    13    43   510   303     6     0     6    --    --    --     5     0     5    --    --    -- HOCN False
# 126376.4251  0.0124 -2.6478     3  32.9023    13    43   510   303     6     1     5    --    --    --     5     1     4    --    --    -- HOCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 131956.5198   6.866  -5.713     3 538.2436    77    43   510   303    38     1    37    --    --    --    38     1    38    --    --    -- HOCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 131956.5198   6.866  -5.713     3 538.2436    77    43   510   303    38     1    37    --    --    --    38     1    38    --    --    -- HOCN False, <Table length=13>
#     FREQ      ERR    LGINT    DR    ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm          u
#   float64   float64 float64 int64 float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- -------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 146187.9796  0.0129 -2.4603     3  36.9927    15    43   510   303     7     1     7    --    --    --     6     1     6    --    --    -- HOCN False
# 146447.0331  0.3501 -4.6237     3 804.0144    15    43   510   303     7     6     1    --    --    --     6     6     0    --    --    -- HOCN False
# 146447.0331  0.3501 -4.6237     3 804.0144    15    43   510   303     7     6     2    --    --    --     6     6     1    --    --    -- HOCN False
# 146569.2494  0.1687 -3.8612     3  566.111    15    43   510   303     7     5     2    --    --    --     6     5     1    --    --    -- HOCN False
# 146569.2494  0.1687 -3.8612     3  566.111    15    43   510   303     7     5     3    --    --    --     6     5     2    --    --    -- HOCN False
# 146664.4448  0.0794 -3.3125     3 369.3843    15    43   510   303     7     4     3    --    --    --     6     4     2    --    --    -- HOCN False
# 146664.4448  0.0794 -3.3125     3 369.3843    15    43   510   303     7     4     4    --    --    --     6     4     3    --    --    -- HOCN False
# 146735.5601  0.0399  -2.907     3 215.0107    15    43   510   303     7     3     5    --    --    --     6     3     4    --    --    -- HOCN False
# 146735.5606  0.0399  -2.907     3 215.0107    15    43   510   303     7     3     4    --    --    --     6     3     3    --    --    -- HOCN False
# 146784.1041   0.018 -2.6244     3 103.9838    15    43   510   303     7     2     6    --    --    --     6     2     5    --    --    -- HOCN False
# 146786.0706  0.0181 -2.6243     3 103.9839    15    43   510   303     7     2     5    --    --    --     6     2     4    --    --    -- HOCN False
# 146820.6846  0.0058 -2.4012     3  14.6927    15    43   510   303     7     0     7    --    --    --     6     0     6    --    --    -- HOCN False
# 147437.4511  0.0136 -2.4532     3  37.1177    15    43   510   303     7     1     6    --    --    --     6     1     5    --    --    -- HOCN False, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 147437.4511  0.0136 -2.4532     3 37.1177    15    43   510   303     7     1     6    --    --    --     6     1     5    --    --    -- HOCN False, <Table length=16>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 250450.6624    1.87  -4.909     3 1429.5301    25    43   510   303    12     8     4    --    --    --    11     8     3    --    --    -- HOCN False
# 250450.6624    1.87  -4.909     3 1429.5301    25    43   510   303    12     8     5    --    --    --    11     8     4    --    --    -- HOCN False
#  250587.149    0.03 -1.8211     3   68.3393    25    43   510   303    12     1    12    --    --    --    11     1    11    --    --    -- HOCN  True
# 250771.8952   1.024 -4.1743     3 1113.1801    25    43   510   303    12     7     5    --    --    --    11     7     4    --    --    -- HOCN False
# 250771.8952   1.024 -4.1743     3 1113.1801    25    43   510   303    12     7     6    --    --    --    11     7     5    --    --    -- HOCN False
# 251033.5922  0.4975 -3.5392     3  835.4167    25    43   510   303    12     6     6    --    --    --    11     6     5    --    --    -- HOCN False
# 251033.5922  0.4975 -3.5392     3  835.4167    25    43   510   303    12     6     7    --    --    --    11     6     6    --    --    -- HOCN False
# 251242.9542  0.2046 -3.0009     3  597.5395    25    43   510   303    12     5     7    --    --    --    11     5     6    --    --    -- HOCN False
# 251242.9542  0.2046 -3.0009     3  597.5395    25    43   510   303    12     5     8    --    --    --    11     5     7    --    --    -- HOCN False
# 251406.1191  0.0736  -2.559     3  400.8332    25    43   510   303    12     4     8    --    --    --    11     4     7    --    --    -- HOCN False
# 251406.1191  0.0736  -2.559     3  400.8332    25    43   510   303    12     4     9    --    --    --    11     4     8    --    --    -- HOCN False
# 251528.2694  0.0363 -2.2139     3  246.4749    25    43   510   303    12     3    10    --    --    --    11     3     9    --    --    -- HOCN False
# 251528.2778  0.0363 -2.2139     3  246.4749    25    43   510   303    12     3     9    --    --    --    11     3     8    --    --    -- HOCN False
#  251609.435    0.05 -1.9666     3  135.4583    25    43   510   303    12     2    11    --    --    --    11     2    10    --    --    -- HOCN  True
#  251619.513    0.05 -1.9666     3  135.4591    25    43   510   303    12     2    10    --    --    --    11     2     9    --    --    -- HOCN  True
#  251666.398    0.02 -1.7682     3   46.1747    25    43   510   303    12     0    12    --    --    --    11     0    11    --    --    -- HOCN  True, <Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4 bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- ----
# 252728.406    0.05 -1.8146     3 68.7323    25    43   510   303    12     1    11    --    --    --    11     1    10    --    --    -- HOCN True, <Table length=16>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 271316.4368    1.99 -4.7742     3 1437.8842    27    43   510   303    13     8     5    --    --    --    12     8     4    --    --    -- HOCN False
# 271316.4368    1.99 -4.7742     3 1437.8842    27    43   510   303    13     8     6    --    --    --    12     8     5    --    --    -- HOCN False
#  271463.505    0.02 -1.7345     3    76.698    27    43   510   303    13     1    13    --    --    --    12     1    12    --    --    -- HOCN  True
# 271664.3552    1.08 -4.0563     3 1121.5449    27    43   510   303    13     7     6    --    --    --    12     7     5    --    --    -- HOCN False
# 271664.3552    1.08 -4.0563     3 1121.5449    27    43   510   303    13     7     7    --    --    --    12     7     6    --    --    -- HOCN False
# 271947.7942  0.5155 -3.4322     3  843.7903    27    43   510   303    13     6     7    --    --    --    12     6     6    --    --    -- HOCN False
# 271947.7942  0.5155 -3.4322     3  843.7903    27    43   510   303    13     6     8    --    --    --    12     6     7    --    --    -- HOCN False
# 272174.5598  0.2023 -2.9015     3  605.9201    27    43   510   303    13     5     8    --    --    --    12     5     7    --    --    -- HOCN False
# 272174.5598  0.2023 -2.9015     3  605.9201    27    43   510   303    13     5     9    --    --    --    12     5     8    --    --    -- HOCN False
# 272351.3139  0.0642 -2.4649     3  409.2192    27    43   510   303    13     4     9    --    --    --    12     4     8    --    --    -- HOCN False
# 272351.3139  0.0642 -2.4649     3  409.2192    27    43   510   303    13     4    10    --    --    --    12     4     9    --    --    -- HOCN False
# 272483.7107   0.032 -2.1236     3   254.865    27    43   510   303    13     3    11    --    --    --    12     3    10    --    --    -- HOCN False
# 272483.7233   0.032 -2.1236     3   254.865    27    43   510   303    13     3    10    --    --    --    12     3     9    --    --    -- HOCN False
#  272571.095    0.05 -1.8787     3  143.8511    27    43   510   303    13     2    12    --    --    --    12     2    11    --    --    -- HOCN  True
#  272583.871    0.05 -1.8787     3  143.8523    27    43   510   303    13     2    11    --    --    --    12     2    10    --    --    -- HOCN  True
#  272631.095    0.02 -1.6822     3   54.5694    27    43   510   303    13     0    13    --    --    --    12     0    12    --    --    -- HOCN  True, <Table length=3>
#     FREQ      ERR    LGINT    DR     ELO     GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2         1 / cm          u
#   float64   float64 float64 int64  float64  int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- --------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 271316.4368    1.99 -4.7742     3 1437.8842    27    43   510   303    13     8     5    --    --    --    12     8     4    --    --    -- HOCN False
# 271316.4368    1.99 -4.7742     3 1437.8842    27    43   510   303    13     8     6    --    --    --    12     8     5    --    --    -- HOCN False
#  271463.505    0.02 -1.7345     3    76.698    27    43   510   303    13     1    13    --    --    --    12     1    12    --    --    -- HOCN  True, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str4  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 273783.0664  0.0119 -1.7282     3 77.1624    27    43   510   303    13     1    12    --    --    --    12     1    11    --    --    -- HOCN False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+13, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
               nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-5)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+13, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
                       nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-5)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
