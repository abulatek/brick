# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 42505
catalog = 'CDMS'
mol_str = f'null'
cubes, tbl = fetch_cubes(cubefns, catalog=catalog, mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=12>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str3  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 86277.8686  0.0391 -4.9391     2  1.4669     4    42   505   133     2     2     2    --    --    --     1     2     3    --    --    --  SiN False
#  86282.363  0.0547 -4.2428     2  1.4669     6    42   505   133     2     2     3    --    --    --     1     2     3    --    --    --  SiN False
# 86301.9508  0.0622 -4.8957     2   1.466     2    42   505   133     2     2     1    --    --    --     1     2     2    --    --    --  SiN False
# 86305.6745   0.031 -4.5039     2   1.466     4    42   505   133     2     2     2    --    --    --     1     2     2    --    --    --  SiN False
# 86310.1689  0.0285 -5.0738     2   1.466     6    42   505   133     2     2     3    --    --    --     1     2     2    --    --    --  SiN False
# 86324.6806  0.0791 -4.7665     2  1.4653     2    42   505   133     2     2     1    --    --    --     1     2     1    --    --    --  SiN False
# 86328.4043  0.0691 -4.9576     2  1.4653     4    42   505   133     2     2     2    --    --    --     1     2     1    --    --    --  SiN False
#  87041.628   0.051 -4.9091     2  1.4413     2    42   505   133     2     2     1    --    --    --     1     1     2    --    --    --  SiN False
#  87045.357    0.03 -3.9801     2  1.4413     4    42   505   133     2     2     2    --    --    --     1     1     2    --    --    --  SiN  True
#  87049.857    0.03 -3.4114     2  1.4413     6    42   505   133     2     2     3    --    --    --     1     1     2    --    --    --  SiN  True
#   87076.96    0.03 -3.9629     2  1.4402     2    42   505   133     2     2     1    --    --    --     1     1     1    --    --    --  SiN  True
#  87080.691    0.03 -3.8427     2  1.4402     4    42   505   133     2     2     2    --    --    --     1     1     1    --    --    --  SiN  True, <Table length=5>
#    FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#    MHz       MHz   MHz nm2        1 / cm         u
#  float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str3  bool
# ---------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 87539.6396  0.0472 -4.1024     2  1.4669     6    42   505   133     2     3     3    --    --    --     1     2     3    --    --    --  SiN False
# 87548.9121  0.0411 -4.1168     2   1.466     4    42   505   133     2     3     2    --    --    --     1     2     2    --    --    --  SiN False
#  87559.811    0.03 -3.2125     2  1.4669     8    42   505   133     2     3     4    --    --    --     1     2     3    --    --    --  SiN  True
#  87567.496    0.03 -3.4196     2   1.466     6    42   505   133     2     3     3    --    --    --     1     2     2    --    --    --  SiN  True
#  87571.654    0.03 -3.6448     2  1.4653     4    42   505   133     2     3     2    --    --    --     1     2     1    --    --    --  SiN  True, <Table length=5>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str3  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 129429.6521  0.0605 -4.0928     2  4.3876     8    42   505   133     3     3     4    --    --    --     2     3     4    --    --    --  SiN False
# 129431.2353  0.0457 -5.1274     2  4.3876     6    42   505   133     3     3     3    --    --    --     2     3     4    --    --    --  SiN False
# 129451.3161  0.0615 -5.0924     2   4.387     4    42   505   133     3     3     2    --    --    --     2     3     3    --    --    --  SiN False
#  129451.394  0.0341 -4.2298     2   4.387     6    42   505   133     3     3     3    --    --    --     2     3     3    --    --    --  SiN False
# 129469.8495  0.0754 -4.3497     2  4.3863     4    42   505   133     3     3     2    --    --    --     2     3     2    --    --    --  SiN False, <Table length=10>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str3  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
#  130707.096    0.03 -2.8694     2   4.345     8    42   505   133     3     3     4    --    --    --     2     2     3    --    --    --  SiN  True
# 130708.6707   0.032 -3.8136     2   4.345     6    42   505   133     3     3     3    --    --    --     2     2     3    --    --    --  SiN False
# 130713.0871  0.0383 -3.8071     2  4.3449     4    42   505   133     3     3     2    --    --    --     2     2     2    --    --    --  SiN False
#  130713.185    0.03   -3.07     2  4.3449     6    42   505   133     3     3     3    --    --    --     2     2     2    --    --    --  SiN  True
#  130716.834    0.03 -3.2979     2  4.3447     4    42   505   133     3     3     2    --    --    --     2     2     1    --    --    --  SiN  True
# 131197.0511  0.0456 -3.9065     2  4.3876     8    42   505   133     3     4     4    --    --    --     2     3     4    --    --    --  SiN False
# 131200.5819  0.0421 -3.9125     2   4.387     6    42   505   133     3     4     3    --    --    --     2     3     3    --    --    --  SiN False
#   131213.98    0.03 -2.7418     2  4.3876    10    42   505   133     3     4     5    --    --    --     2     3     4    --    --    --  SiN  True
#  131217.196    0.03 -2.8776     2   4.387     8    42   505   133     3     4     4    --    --    --     2     3     3    --    --    --  SiN  True
#  131219.097    0.03 -3.0167     2  4.3863     6    42   505   133     3     4     3    --    --    --     2     3     2    --    --    --  SiN  True, <Table length=2>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str3  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 258853.3163  0.0788 -3.8608     2 21.8861    14    42   505   133     6     6     7    --    --    --     5     6     7    --    --    --  SiN False
# 258873.8053  0.0584  -3.919     2 21.8856    12    42   505   133     6     6     6    --    --    --     5     6     6    --    --    --  SiN False, <Table length=10>
#     FREQ      ERR    LGINT    DR    ELO    GUP  MOLWT  TAG  QNFMT   Ju    Ku    vu   F1u   F2u   F3u    Jl    Kl    vl   F1l   F2l   F3l  name  Lab
#     MHz       MHz   MHz nm2        1 / cm         u
#   float64   float64 float64 int64 float64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 int64 str3  bool
# ----------- ------- ------- ----- ------- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ----- ---- -----
# 261649.3847  0.0055 -2.0111     2 21.7928    14    42   505   133     6     6     7    --    --    --     5     5     6    --    --    --  SiN False
# 261650.3187  0.0053 -2.0927     2  21.793    12    42   505   133     6     6     6    --    --    --     5     5     5    --    --    --  SiN False
# 261651.1708  0.0053 -2.1753     2 21.7931    10    42   505   133     6     6     5    --    --    --     5     5     4    --    --    --  SiN False
# 261654.3085  0.0413 -3.5678     2  21.793    10    42   505   133     6     6     5    --    --    --     5     5     5    --    --    --  SiN False
# 261655.9759  0.0358 -3.5693     2 21.7928    12    42   505   133     6     6     6    --    --    --     5     5     6    --    --    --  SiN False
#  262141.664  0.0417 -3.6207     2 21.8856    12    42   505   133     6     7     6    --    --    --     5     6     6    --    --    --  SiN False
# 262141.9777  0.0442 -3.6192     2 21.8861    14    42   505   133     6     7     7    --    --    --     5     6     7    --    --    --  SiN False
# 262155.0665  0.0064 -1.9453     2 21.8861    16    42   505   133     6     7     8    --    --    --     5     6     7    --    --    --  SiN False
# 262155.8755  0.0064  -2.014     2 21.8856    14    42   505   133     6     7     7    --    --    --     5     6     6    --    --    --  SiN False
# 262156.4144  0.0064 -2.0828     2 21.8851    12    42   505   133     6     7     6    --    --    --     5     6     5    --    --    --  SiN False]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 2.9e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
               nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str, extr_type="coord", crd=crd,
               show_2_sigma=True, LGINT_cutoff=-4)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 2.0e+12, v_cen = 12.*u.km/u.s, v_disp = 3.*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog=catalog, fig_width=20, fig_height=25,
                       nrows=8, ncols=5, parse_loc=False, line_by_line=True, name_for_plot=mol_str,
                       extr_type="reg", show_2_sigma=True, return_freqs=True, LGINT_cutoff=-4)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12.*u.km/u.s, fig_width=10, fig_height=8, nrows=3, ncols=4, name_for_plot=mol_str)
