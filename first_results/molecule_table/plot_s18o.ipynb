# %%
# Package imports
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.facecolor'] = 'w'
from astropy import log, constants, coordinates, units as u
import warnings
warnings.filterwarnings('ignore')
log.setLevel('ERROR')

# My functions
from mol_model import fetch_cubes, model_and_plot, list_mol_tags, get_cubes_from_mask, plot_mom0s

results = '/blue/adamginsburg/abulatek/brick/symlinks/imaging_results/contsub_smoothed_cubes_K/'
# Out:
# make: *** No targets specified and no makefile found.  Stop.

# %%
# Get list of all cubes
import glob
cubefns = glob.glob(f"{results}/source_ab_*.image.commonbeam.contsub.K.fits")

# %%
# Set coordinate of central source
crd = coordinates.SkyCoord("17:46:10.6339473267 -28:42:17.9807702398", frame='icrs', unit=(u.h, u.deg))

# %%
# Get only the cubes that have our line of interest in them
mol_tag = 50002 
cubes, tbl = fetch_cubes(cubefns, catalog='JPL', mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, parse_loc=False, ret_tbl=True)
# Out:
# [<Table length=1>
#    FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#    MHz       MHz   MHz nm2        1 / cm
#  float64   float64 float64 int64 float64 int64 int64 int64 str3 str3
# ---------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 87875.9734   3.441 -4.3613     2 22.5165     9 50002   102  5 4  4 4, <Table length=1>
#   FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#   MHz      MHz   MHz nm2        1 / cm
# float64  float64 float64 int64 float64 int64 int64  int64 str3 str3
# -------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 93267.27     0.2 -3.3603     2   2.947     7 -50002   102  2 3  1 2, <Table length=1>
#   FREQ     ERR    LGINT    DR    ELO    GUP   TAG   QNFMT QN'  QN"
#   MHz      MHz   MHz nm2        1 / cm
# float64  float64 float64 int64 float64 int64 int64  int64 str3 str3
# -------- ------- ------- ----- ------- ----- ------ ----- ---- ----
# 99803.32     0.3 -3.6081     2 10.9223     5 -50002   102  3 2  2 1, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 str3 str3
# ----------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 129065.9991  0.4217 -2.9583     2  6.0581     9 50002   102  3 4  2 3, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 str3 str3
# ----------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 145873.8078  1.1997 -3.0363     2 14.2514     7 50002   102  4 3  3 2, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 str3 str3
# ----------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 243039.9617  5.0457 -2.2006     2 22.7276    15 50002   102  6 7  5 6, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 str3 str3
# ----------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 245630.4505 27.7763 -4.9096     2  6.0581     5 50002   102  3 2  2 3, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 str3 str3
# ----------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 262438.2592 28.7761 -4.9482     2 10.3632     7 50002   102  4 3  3 4, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 str4 str3
# ----------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 265639.5882 32.4983 -3.9116     2 69.0435    19 50002   102 10 9  9 9, <Table length=1>
#     FREQ      ERR    LGINT    DR    ELO    GUP   TAG  QNFMT QN'  QN"
#     MHz       MHz   MHz nm2        1 / cm
#   float64   float64 float64 int64 float64 int64 int64 int64 str3 str3
# ----------- ------- ------- ----- ------- ----- ----- ----- ---- ----
# 273858.4444  9.4143 -2.1937     2 33.1953    13 50002   102  7 6  6 5]
#
# *** NOTE: Make sure you are capturing the cubes and tables into different variables!

# %%
# Generate the model and plot the model and data spectra
model_and_plot(cubes, temp = 50., N_tot = 5.7e+12, v_cen = 40.*u.km/u.s, v_disp = 1.5*u.km/u.s,
               mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=12, 
               nrows=2, ncols=3, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'S$^{{18}}$O', 
               extr_type="coord", crd=crd, show_2_sigma=True)

# %%
# Get subcubes based on mask
cubes_masked = get_cubes_from_mask("diffuse_regions.fits", 1, cubes, plot_region=False)

# %%
# Generate the model and plot the model and data spectra
freqs = model_and_plot(cubes_masked, temp = 50., N_tot = 5.1e+12, v_cen = 12.*u.km/u.s, v_disp = 3*u.km/u.s,
                       mol_name_pyspeckit=None, mol_tag_pyspeckit=mol_tag, catalog='JPL', fig_width=20, fig_height=12, 
                       nrows=2, ncols=3, parse_loc=False, ret_tbl=False, line_by_line=True, name_for_plot=f'S$^{{18}}$O', 
                       extr_type="reg", just_data=False, show_2_sigma=True, return_freqs=True)

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=40*u.km/u.s, fig_width=10, fig_height=8, nrows=2, ncols=3, name_for_plot=f'S$^{{18}}$O')

# %%
# Plot moment maps
plot_mom0s(cubes, freqs, v_cen=12*u.km/u.s, fig_width=10, fig_height=8, nrows=2, ncols=3, name_for_plot=f'S$^{{18}}$O')
