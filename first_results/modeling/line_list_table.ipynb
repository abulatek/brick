# %%
import pandas
pandas.set_option('display.max_rows', 1000)

data = pandas.read_csv("line_lists/brick_line_list.csv")

# %%
## Set up groups for each molecule
groups = {'29SiOv=0'      : 'SiO',
          'NH2D'          : 'NH$_2$D',
          'SiOv=1'        : 'SiO',
          'NH2CHO'        : 'NH$_2$CHO',
          'H13CO+'        : 'HCO+',
          'SiOv=0'        : 'SiO',
          'HN13C'         : 'HNC',
          'CCHv=0'        : 'CCH',
          'HNCOv=0'       : 'HNCO',
          'H13CCCNv=0'    : 'HCCCN',
          'HCNv=0'        : 'HCN',
          'HCO+v=0'       : 'HCO+',
          'C2H5OH'        : 'C$_2$H$_5$OH',
          'HNCv=0'        : 'HNC',
          'HC3Nv=0'       : 'HC$_3$N',
          '(CH3)2COv=0'   : '(CH$_3$)$_2$CO',
          'CH3CN'         : 'CH$_3$CN',
          '13CSv=0'       : 'CS',
          'N2H+v=0'       : 'N$_2$H+',
          'CH3OHvt=0-2'   : 'CH$_3$OH',
          'CH3CHOv=0,1&2' : 'CH$_3$CHO',
          'CCS'           : 'CCS',
          '13CH3OHvt=0'   : 'CH$_3$OH',
          'CH3OCHOv=0'    : 'CH$_3$OCHO',
          'O13CS'         : 'OCS',
          'OCSv=0'        : 'OCS',
          'H213CS'        : 'H$_2$CS',
          '34SO'          : 'SO',
          'CSv=0'         : 'CS',
          'CH3OCH3'       : 'CH$_3$OCH$_3$',
          'SO3&Sigma;v=0' : 'SO',
          'NH2CN'         : 'NH$_2$CN',
          'H2CS'          : 'H$_2$CS',
          'H2COH+'        : 'H$_2$COH+',
          'CH3CCHv=0'     : 'CH$_3$CCH',
          'SO2v=0'        : 'SO$_2$',
          '?'             : 'unknown origin',
          'UnidentifiedTransition': 'unknown origin',
          'CH2NH'         : 'CH$_2$NH',
          'HOCO+'         : 'HOCO+',
          'CH3CH213CN'    : 'CH$_3$CH$_2$CN',
          '13CN'          : 'CN',
          'C18O'          : 'CO',
          '13COv=0'       : 'CO',
          'CH313CN'       : 'CH$_3$CN',
          'C17O'          : 'CO',
          'CNv=0'         : 'CN',
          'COv=0'         : 'CO',
          'NS,v=0'        : 'NS',
          'CH3CNv=0'      : 'CH$_3$CN',
          'H213CO'        : 'H$_2$CO',
          'H2CO'          : 'H$_2$CO',
          'C34Sv=0'       : 'CS',
          'DCNv=0'        : 'DCN',
          'c-HCCCHv=0'    : 'c-HCCCH',
          'CH3NH2'        : 'CH$_3$NH$_2$',
          '34SO2v=0'      : 'SO$_2$',
          'OS17O'         : 'SO$_2$',
          'HC3Nv=0'       : 'HC$_3$N',
          'CH3CNv8=1'     : 'CH$_3$CN',
          'HC15Nv=0'      : 'HCN',
          'CH2CHCNv=0'    : 'CH$_2$CHCN',
          'H13CNv=0'      : 'HCN',
          'HDCO'          : 'HDCO',
          'HCNv2=1'       : 'HCN',
          'nan'           : 'unknown origin'
         }

# %%
## Make new column with group
data['Group']= data['Species'].map(groups)

# %%
## Set up formatting for species names
# for item in data['Species'].unique():
#     print(item)
formats = {'29SiOv=0'      : '$^{29}$SiO $v=0$', 
           'NH2D'          : 'NH$_2$D', 
           'SiOv=1'        : 'SiO $v=1$',
           'NH2CHO'        : 'NH$_2$CHO', 
           'H13CO+'        : 'H$^{13}$CO+', 
           'SiOv=0'        : 'SiO $v=0$',
           'HN13C'         : 'HN$^{13}$C',
           'CCHv=0'        : 'CCH $v=0$',
           'HNCOv=0'       : 'HNCO $v=0$',
           'H13CCCNv=0'    : 'H$^{13}$CCCN $v=0$',
           'HCNv=0'        : 'HCN $v=0$', 
           'HCO+v=0'       : 'HCO+ $v=0$', 
           'C2H5OH'        : 'C$_2$H$_5$OH', 
           'HNCv=0'        : 'HNC $v=0$', 
           'HC3Nv=0'       : 'HC$_3$N $v=0',
           '(CH3)2COv=0'   : '(CH$_3$)$_2$CO $v=0$',
           'CH3CN'         : 'CH$_3$CN $v=0$', # This exists in addition to one without v=0 (my fault), have combined by changing this one's mapping
           '13CSv=0'       : '$^{13}$CS $v=0$',
           'N2H+v=0'       : 'N$_2$H+ $v=0$',
           'CH3OHvt=0-2'   : 'CH$_3$OH $vt=0-2$', 
           'CH3CHOv=0,1&2' : 'CH$_3$CHO $vt=0,1,\&2$',
           'CCS'           : 'CCS',
           '13CH3OHvt=0'   : '$^{13}$CH$_3$OH $v=0$',
           'CH3OCHOv=0'    : 'CH$_3$OCHO $v=0$',
           'O13CS'         : 'O$^{13}$CS', 
           'OCSv=0'        : 'OCS $v=0$', 
           'H213CS'        : 'H$_2^{13}$CS', 
           '34SO'          : '$^{34}$SO',
           'CSv=0'         : 'CS $v=0$',
           'CH3OCH3'       : 'CH$_3$OCH$_3$',
           'SO3&Sigma;v=0' : 'SO $v=0$',
           'NH2CN'         : 'NH$_2$CN',
           'H2CS'          : 'H$_2$CS', 
           'H2COH+'        : 'H$_2$COH+',
           'CH3CCHv=0'     : 'CH$_3$CCH $v=0$',
           'SO2v=0'        : 'SO$_2$ $v=0$', 
           '?'             : '?',
           'UnidentifiedTransition' : 'Unidentified Transition',
           'CH2NH'         : 'CH$_2$NH',
           'HOCO+'         : 'HOCO+',
           'CH3CH213CN'    : 'CH$_3$CH$_2^{13}$CN',
           '13CN'          : '$^{13}$CN',
           'C18O'          : 'C$^{18}$O', 
           '13COv=0'       : '$^{13}$CO $v=0$', 
           'CH313CN'       : 'CH$_3^{13}$CN', 
           'C17O'          : 'C$^{17}$O', 
           'CNv=0'         : 'CN $v=0$', 
           'COv=0'         : 'CO $v=0$', 
           'NS,v=0'        : 'NS $v=0$',
           'CH3CNv=0'      : 'CH$_3$CN $v=0$', # This exists in addition to one without v=0 (my fault), see above
           'H213CO'        : 'H$_2^{13}$CO',
           'H2CO'          : 'H$_2$CO',
           'C34Sv=0'       : 'C$^{34}$S $v=0$',
           'DCNv=0'        : 'DCN $v=0$',
           'c-HCCCHv=0'    : 'c-HCCCH $v=0$',
           'CH3NH2'        : 'CH$_3$NH$_2$',
           '34SO2v=0'      : '$^{34}$SO$_2$ $v=0$', 
           'OS17O'         : 'OS$^{17}$O',
           'HC3Nv=0'       : 'HC$_3$N $v=0$',
           'CH3CNv8=1'     : 'CH$_3$CN $v8=1$', 
           'HC15Nv=0'      : 'HC$^{15}$N $v=0$',
           'CH2CHCNv=0'    : 'CH$_2$CHCN $v=0$',
           'H13CNv=0'      : 'H$^{13}CN $v=0$', 
           'HDCO'          : 'HDCO',
           'HCNv2=1'       : 'HCN $v2=1$', 
           'nan'           : 'nan',
          }

# %%
## Reformat species names
data.replace({'Species' : formats}, inplace = True)

# %%
data['QNs'] = data['QNs'].str.replace('-','–')

# %%
# data.sort_values(['Species', 'Frequency (GHz)'])
for species in data['Group'].unique():
    print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
                                                  column_format = 'cccc', header = True, index = False, longtable = False,
                                                  escape = False, caption = f"Transitions of {species} detected in The Brick."))
# Out:
# \begin{table}
# \centering
# \caption{Transitions of SiO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &          Species & QNs &  Velocity (km/s) \\
# \midrule
#        85.759188 & $^{29}$SiO $v=0$ & 2–1 &              9.0 \\
#        86.243370 &        SiO $v=1$ & 2–1 &             35.0 \\
#        86.846960 &        SiO $v=0$ & 2–1 &             13.0 \\
#       129.363240 &        SiO $v=1$ & 3-2 &             16.0 \\
#       130.268610 &        SiO $v=0$ & 3-2 &             69.0 \\
#       260.518020 &        SiO $v=0$ & 6-5 &             40.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of NH$_2$D detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) & Species &           QNs &  Velocity (km/s) \\
# \midrule
#        85.926263 & NH$_2$D & 1(1,1)-1(0,1) &             16.7 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of NH$_2$CHO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &   Species &                  QNs &  Velocity (km/s) \\
# \midrule
#        86.381831 & NH$_2$CHO & 7(1,6)-7(0,7), F=7-7 &            200.0 \\
#        87.848533 & NH$_2$CHO &  4(1,3)-3(1,2),F=4-4 &             39.0 \\
#       102.064263 & NH$_2$CHO &        5(1 5)–4(1 4) &             41.0 \\
#       106.541562 & NH$_2$CHO &  5(2,3)-4(2,2),F=4-4 &             35.0 \\
#       253.545519 & NH$_2$CHO &        8(2,7)-8(0,8) &             11.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of HCO+ detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &     Species &                    QNs &  Velocity (km/s) \\
# \midrule
#        86.754262 & H$^{13}$CO+ &                    1–0 &             68.0 \\
#        89.188525 &  HCO+ $v=0$ &                    1-0 &             41.0 \\
#       260.255275 & H$^{13}$CO+ & J=3-2,F1=5/2-5/2,F=3-3 &             41.0 \\
#       267.557626 &  HCO+ $v=0$ &                    3-2 &             63.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of HNC detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &    Species &         QNs &  Velocity (km/s) \\
# \midrule
#        87.090735 & HN$^{13}$C & J=1–0 F=0–1 &             36.0 \\
#        90.663562 &  HNC $v=0$ &       J=1-0 &             27.0 \\
#       261.263310 & HN$^{13}$C &       J=3-2 &             41.0 \\
#       271.981111 &  HNC $v=0$ &       J=3-2 &             51.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CCH detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &   Species &                   QNs &  Velocity (km/s) \\
# \midrule
#        87.284105 & CCH $v=0$ & N=1–0 J=3/2–1/2 F=1–1 &             41.0 \\
#        87.402004 & CCH $v=0$ &    1–0 −1–1/2 F = 1–1 &             44.0 \\
#        87.407165 & CCH $v=0$ &    1–0 −1–1/2 F = 0–1 &             42.0 \\
#        87.446512 & CCH $v=0$ & N=1-0,J=1/2-1/2,F=1-0 &             39.0 \\
#       262.004227 & CCH $v=0$ & N=3-2,J=7/2-5/2,F=4-3 &             41.0 \\
#       262.067331 & CCH $v=0$ & N=3-2,J=5/2-3/2,F=2-1 &             40.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of HNCO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &    Species &                 QNs &  Velocity (km/s) \\
# \midrule
#        87.924351 & HNCO $v=0$ & 4(0,4)-3(0,3),F=3-3 &             66.0 \\
#       109.904890 & HNCO $v=0$ & 5(0,5)-4(0,4),F=4-4 &             66.0 \\
#       131.884891 & HNCO $v=0$ & 6(0,6)-5(0,5),F=5-5 &             68.0 \\
#       153.818869 & HNCO $v=0$ &       7(2,6)-6(2,5) &             67.0 \\
#       263.748625 & HNCO $v=0$ &   12(0,12)-11(0,11) &             42.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of HCCCN detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &            Species &    QNs &  Velocity (km/s) \\
# \midrule
#        88.166832 & H$^{13}$CCCN $v=0$ & J=10-9 &             31.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of HCN detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &          Species &              QNs &  Velocity (km/s) \\
# \midrule
#        88.630416 &        HCN $v=0$ &      J=1-0,F=1-1 &             43.0 \\
#       258.156996 & HC$^{15}$N $v=0$ &              3-2 &             40.0 \\
#       259.011788 &  H$^{13}CN $v=0$ &            J=3-2 &             58.0 \\
#       265.852409 &       HCN $v2=1$ & J=3-2,F=3-2,l=1e &             39.0 \\
#       265.886180 &        HCN $v=0$ &            J=3-2 &             53.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of C$_2$H$_5$OH detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &      Species &           QNs &  Velocity (km/s) \\
# \midrule
#        90.117601 & C$_2$H$_5$OH & 4(1,4)-3(0,3) &             15.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of HC$_3$N detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &       Species &            QNs &  Velocity (km/s) \\
# \midrule
#        90.978984 & HC$_3$N $v=0$ &   J=10-9,F=9-8 &             20.0 \\
#       100.076382 & HC$_3$N $v=0$ & J=11-10,F=10-9 &             18.0 \\
#       109.173634 & HC$_3$N $v=0$ &        J=12-11 &             70.0 \\
#       127.367660 & HC$_3$N $v=0$ &        J=14-13 &             17.0 \\
#       127.820000 & HC$_3$N $v=0$ &              ? &              NaN \\
#       136.464403 & HC$_3$N $v=0$ &        J=15-14 &             16.0 \\
#       245.606310 & HC$_3$N $v=0$ &        J=27-26 &             41.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of (CH$_3$)$_2$CO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &              Species &             QNs &  Velocity (km/s) \\
# \midrule
#        91.659108 & (CH$_3$)$_2$CO $v=0$ & 8(1,7)-7(2,6)AA &             29.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_3$CN detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &         Species &             QNs &  Velocity (km/s) \\
# \midrule
#        91.941580 &  CH$_3$CN $v=0$ &       5(0)-4(0) &             25.0 \\
#       110.328870 &   CH$_3^{13}$CN &       6(0)-5(0) &             20.0 \\
#       128.779378 &  CH$_3$CN $v=0$ & 7(0)-6(0),F=8-7 &             12.0 \\
#       147.174588 &  CH$_3$CN $v=0$ &       8(0)-7(0) &             41.0 \\
#       258.132270 & CH$_3$CN $v8=1$ & 14(7)-13(7),l=1 &             11.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CS detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &         Species &             QNs &  Velocity (km/s) \\
# \midrule
#        92.494308 & $^{13}$CS $v=0$ &             2-1 &             28.0 \\
#        97.980953 &        CS $v=0$ &             2-1 &             21.0 \\
#       138.739183 & $^{13}$CS $v=0$ & J=3-2,F=5/2-5/2 &             39.0 \\
#       144.617101 & C$^{34}$S $v=0$ &             3-2 &             41.0 \\
#       146.969029 &        CS $v=0$ &             3-2 &              7.0 \\
#       244.935556 &        CS $v=0$ &             5-4 &             43.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of N$_2$H+ detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &       Species &                QNs &  Velocity (km/s) \\
# \midrule
#        93.171621 & N$_2$H+ $v=0$ & J=1-0,F1=1-1,F=0-1 &             16.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_3$OH detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &               Species &                  QNs &  Velocity (km/s) \\
# \midrule
#        93.196620 &     CH$_3$OH $vt=0-2$ &    1(0,1)-2(1,2)vt=1 &             46.0 \\
#        94.407129 & $^{13}$CH$_3$OH $v=0$ &      2(0,2)-1(0,1)A+ &             28.0 \\
#        94.420439 & $^{13}$CH$_3$OH $v=0$ &       2(1,1)-1(1,0)E &             21.0 \\
#        95.169516 &     CH$_3$OH $vt=0-2$ &      8(0,8)-7(1,7)++ &             45.0 \\
#        95.914310 &     CH$_3$OH $vt=0-2$ &      2(1,2)-1(1,1)++ &             28.0 \\
#        96.492152 &     CH$_3$OH $vt=0-2$ & 2(1,2)-1(1,1)++,vt=1 &            130.0 \\
#       107.013831 &     CH$_3$OH $vt=0-2$ &  3(1,3)-4(0,4)A,vt=0 &              9.0 \\
#       108.893929 &     CH$_3$OH $vt=0-2$ &       0(0,0)-1(-1,1) &             40.0 \\
#       132.890800 &     CH$_3$OH $vt=0-2$ &       6(-1,6)-5(0,5) &             20.0 \\
#       133.605385 &     CH$_3$OH $vt=0-2$ &      5(-2,4)-6(-1,6) &             52.0 \\
#       141.595449 & $^{13}$CH$_3$OH $v=0$ &       3(0,3)-2(0,2)E &              4.0 \\
#       143.865795 &     CH$_3$OH $vt=0-2$ &      3(1,3)-2(1,2)++ &             39.0 \\
#       145.093760 &     CH$_3$OH $vt=0-2$ &        3(0,3)-2(0,2) &             20.0 \\
#       145.097470 &     CH$_3$OH $vt=0-2$ &      3(-1,3)-2(-1,2) &             20.0 \\
#       145.131880 &     CH$_3$OH $vt=0-2$ &        3(1,2)-2(1,1) &             20.0 \\
#       145.133415 &     CH$_3$OH $vt=0-2$ &      3(2)+-2(2)+vt=0 &             20.0 \\
#       146.368342 &     CH$_3$OH $vt=0-2$ &      3(1,2)-2(1,1)-- &             38.0 \\
#       146.618697 &     CH$_3$OH $vt=0-2$ &       9(0,9)-8(1,8)A &             17.0 \\
#       147.427651 &     CH$_3$OH $vt=0-2$ &        7(0,7)-6(2,4) &             12.0 \\
#       150.884597 &     CH$_3$OH $vt=0-2$ &  12(-1,12)-11(-2,10) &             75.0 \\
#       241.700168 &     CH$_3$OH $vt=0-2$ &        5(0,5)-4(0,4) &             21.0 \\
#       243.915788 &     CH$_3$OH $vt=0-2$ &  5(1,4)-4(1,3)A,vt=0 &             65.0 \\
#       244.707804 & $^{13}$CH$_3$OH $v=0$ &       3(-2,2)-2(1,1) &             10.0 \\
#       250.507016 &     CH$_3$OH $vt=0-2$ &  11(0,11)-10(1,10)++ &             41.0 \\
#       265.289616 &     CH$_3$OH $vt=0-2$ &        6(1,5)-5(2,3) &             41.0 \\
#       266.838123 &     CH$_3$OH $vt=0-2$ &        5(2,3)-4(1,3) &             41.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_3$CHO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &                Species &              QNs &  Velocity (km/s) \\
# \midrule
#        93.580914 & CH$_3$CHO $vt=0,1,\&2$ & 5(1,5)-4(1,4)A++ &             38.0 \\
#        95.947439 & CH$_3$CHO $vt=0,1,\&2$ &   5(0,5)-4(0,4)E &             12.0 \\
#       133.830494 & CH$_3$CHO $vt=0,1,\&2$ &   7(0,7)-6(0,6)E &             42.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CCS detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) & Species &         QNs &  Velocity (km/s) \\
# \midrule
#        93.870098 &     CCS &     8,7-7,6 &             34.0 \\
#       106.347726 &     CCS & N=8-7,J=9-8 &             36.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_3$OCHO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &          Species &                QNs &  Velocity (km/s) \\
# \midrule
#        96.709210 & CH$_3$OCHO $v=0$ &     8(4,5)-8(3,6)A &              0.0 \\
#        98.875160 & CH$_3$OCHO $v=0$ &   11(4,8)-11(3,9)A &             76.0 \\
#       143.850434 & CH$_3$OCHO $v=0$ & 18(3,16)-18(2,17)A &              7.0 \\
#       152.598246 & CH$_3$OCHO $v=0$ & 17(2,16)-17(1,17)A &             20.0 \\
#       257.690306 & CH$_3$OCHO $v=0$ & 22(3,20)-21(3,19)E &              9.0 \\
#       262.088241 & CH$_3$OCHO $v=0$ &  16(10,6)-16(9,7)A &             68.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of OCS detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &    Species &   QNs &  Velocity (km/s) \\
# \midrule
#        96.988121 & O$^{13}$CS &   8-7 &             26.0 \\
#        97.301208 &  OCS $v=0$ &   8-7 &             27.0 \\
#       133.785897 &  OCS $v=0$ & 11-10 &             39.0 \\
#       145.946812 &  OCS $v=0$ & 12-11 &             17.0 \\
#       243.218036 &  OCS $v=0$ & 20-19 &             41.0 \\
#       255.374456 &  OCS $v=0$ & 21-20 &             41.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of H$_2$CS detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &      Species &           QNs &  Velocity (km/s) \\
# \midrule
#        97.632702 & H$_2^{13}$CS & 3(1,3)-2(1,2) &            100.0 \\
#       101.477620 &      H$_2$CS & 3(1,3)-2(1,2) &             27.0 \\
#       103.039990 &      H$_2$CS & 3(2 2)–2(2 1) &             37.0 \\
#       104.617040 &      H$_2$CS & 3(1,2)-2(1,1) &             38.0 \\
#       135.297811 &      H$_2$CS & 4(1,4)-3(1,3) &             38.0 \\
#       137.369170 &      H$_2$CS & 4(3,2)-3(3,1) &             37.0 \\
#       139.483410 &      H$_2$CS & 4(1,3)-3(1,2) &             43.0 \\
#       244.047840 &      H$_2$CS & 7(1,6)-6(1,5) &             40.0 \\
#       270.522020 &      H$_2$CS & 8(1,8)-7(1,7) &             41.0 \\
#       274.520870 &      H$_2$CS & 8(0,8)-7(0,7) &             45.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of SO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &   Species &       QNs &  Velocity (km/s) \\
# \midrule
#        97.715317 & $^{34}$SO & 3(2)-2(1) &             31.0 \\
#        99.299870 &  SO $v=0$ & 3(2)-2(1) &             -7.0 \\
#       109.252212 &  SO $v=0$ & 2(3)-1(2) &             36.0 \\
#       129.138923 &  SO $v=0$ & 3(3)-2(2) &             40.0 \\
#       138.178600 &  SO $v=0$ & 4(3)-3(2) &             20.0 \\
#       251.825770 &  SO $v=0$ & 5(6)-4(5) &             57.0 \\
#       258.255813 &  SO $v=0$ & 6(6)-5(5) &             40.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_3$OCH$_3$ detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &       Species &                 QNs &  Velocity (km/s) \\
# \midrule
#        99.299870 & CH$_3$OCH$_3$ &     4(1,4)-3(0,3)EE &             70.0 \\
#       241.946537 & CH$_3$OCH$_3$ & 13(1,13)-12(0,12)EE &             68.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of NH$_2$CN detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &  Species &               QNs &  Velocity (km/s) \\
# \midrule
#         100.6295 & NH$_2$CN & 5(1,4)-4(1,3),v=0 &             35.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of H$_2$COH+ detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &   Species &           QNs &  Velocity (km/s) \\
# \midrule
#       102.065856 & H$_2$COH+ & 4(0 4)–3(1 3) &             46.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_3$CCH detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &         Species &       QNs &  Velocity (km/s) \\
# \midrule
#       102.530346 & CH$_3$CCH $v=0$ & 6(3)–5(3) &             39.0 \\
#       102.547983 & CH$_3$CCH $v=0$ & 6(2)–5(2) &             12.0 \\
#       136.717560 & CH$_3$CCH $v=0$ & 8(2)-7(2) &             26.0 \\
#       153.790769 & CH$_3$CCH $v=0$ & 9(3)-8(3) &             42.0 \\
#       153.805457 & CH$_3$CCH $v=0$ & 9(2)-8(2) &             25.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of SO$_2$ detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &             Species &                     QNs &  Velocity (km/s) \\
# \midrule
#       104.029410 &        SO$_2$ $v=0$ &           3(1,3)-2(0,2) &             35.0 \\
#       135.696004 &        SO$_2$ $v=0$ &           5(1,5)-4(0,4) &             13.0 \\
#       251.758322 & $^{34}$SO$_2$ $v=0$ &       32(4,28)-32(3,29) &             64.0 \\
#       252.252165 &          OS$^{17}$O & 6(2,5)-5(1,4),F=7/2-5/2 &             62.0 \\
#       257.466727 & $^{34}$SO$_2$ $v=0$ &       29(9,21)-30(8,22) &             21.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of unknown origin detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &                 Species &      QNs &  Velocity (km/s) \\
# \midrule
#          104.460 &                       ? &        ? &              NaN \\
#          104.819 & Unidentified Transition & U-104819 &             64.0 \\
#              NaN &                       ? &        ? &              NaN \\
#              NaN &                       ? &        ? &              NaN \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_2$NH detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &  Species &                 QNs &  Velocity (km/s) \\
# \midrule
#       105.794057 & CH$_2$NH &       4(0,4)-3(1,3) &             42.0 \\
#       245.125790 & CH$_2$NH &       4(1,4)-3(1,3) &             41.0 \\
#       266.270894 & CH$_2$NH & 4(1,3)-3(1,2),F=4-4 &             57.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of HOCO+ detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) & Species &           QNs &  Velocity (km/s) \\
# \midrule
#       106.913524 &   HOCO+ & 5(0,5)-4(0,4) &             31.0 \\
#       128.295063 &   HOCO+ & 6(0,6)-5(0,5) &             40.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_3$CH$_2$CN detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &             Species &             QNs &  Velocity (km/s) \\
# \midrule
#       107.006772 & CH$_3$CH$_2^{13}$CN & 12(4,9)-11(4,8) &             21.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CN detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &   Species &                          QNs &  Velocity (km/s) \\
# \midrule
#       108.780201 & $^{13}$CN & N=1-0,J=3/2-1/2,F1=2-1,F=3-2 &             36.0 \\
#       113.123337 &  CN $v=0$ &    N=1-0,J=1/2-1/2,F=1/2-1/2 &             44.0 \\
#       113.488120 &  CN $v=0$ &    N=1-0,J=3/2-1/2,F=3/2-1/2 &             47.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &         Species &             QNs &  Velocity (km/s) \\
# \midrule
#       109.782173 &       C$^{18}$O &             1-0 &             69.0 \\
#       110.201322 & $^{13}$CO $v=0$ & J=1-0,F=1/2-1/2 &             41.0 \\
#       112.358777 &       C$^{17}$O & J=1-0,F=3/2-5/2 &             37.0 \\
#       115.271202 &        CO $v=0$ &             1-0 &             59.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of NS detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &  Species &                                    QNs &  Velocity (km/s) \\
# \midrule
#       115.556253 & NS $v=0$ &    J=5/2-3/2,&Omega;=1/2,F=7/2-5/2,l=f &             24.0 \\
#       253.968393 & NS $v=0$ & J=11/2-9/2,&Omega;=1/2,F=13/2-11/2,l=f &             41.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of H$_2$CO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &      Species &           QNs &  Velocity (km/s) \\
# \midrule
#       137.449950 & H$_2^{13}$CO & 2(1,2)-1(1,1) &             13.0 \\
#       140.839520 &      H$_2$CO & 2(1,2)-1(1,1) &             68.0 \\
#       145.602956 &      H$_2$CO & 2(0,2)-1(0,1) &             71.0 \\
#       150.498342 &      H$_2$CO & 2(1,1)-1(1,0) &             71.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of DCN detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &   Species &   QNs &  Velocity (km/s) \\
# \midrule
#       144.827996 & DCN $v=0$ & J=2-1 &             41.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of c-HCCCH detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &       Species &           QNs &  Velocity (km/s) \\
# \midrule
#       150.820665 & c-HCCCH $v=0$ & 4(0,4)-3(1,3) &             20.0 \\
#       150.851908 & c-HCCCH $v=0$ & 4(1,4)-3(0,3) &             20.0 \\
#       251.314348 & c-HCCCH $v=0$ & 7(0,7)-6(1,6) &             20.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_3$NH$_2$ detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &      Species &                     QNs &  Velocity (km/s) \\
# \midrule
#       244.276684 & CH$_3$NH$_2$ &     2(2)A2-2(1)A1,F=2-1 &             94.0 \\
#       247.255017 & CH$_3$NH$_2$ & 3(2)E2+1-3(1)E2-1,F=3-3 &             74.0 \\
#       248.273496 & CH$_3$NH$_2$ &     3(2)A2-3(1)A1,F=3-3 &            110.0 \\
#       251.500277 & CH$_3$NH$_2$ & 5(2)E2-1-5(1)E2-1,F=4-4 &              0.0 \\
#       251.963974 & CH$_3$NH$_2$ & 6(2)E2+1-6(1)E2-1,F=5-5 &             16.0 \\
#       265.757247 & CH$_3$NH$_2$ &     6(0)A1-5(0)A2,F=6-5 &             53.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of nan detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
# Empty DataFrame
# Columns: Index(['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'], dtype='object')
# Index: Int64Index([], dtype='int64') \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of CH$_2$CHCN detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) &          Species &               QNs &  Velocity (km/s) \\
# \midrule
#       258.285663 & CH$_2$CHCN $v=0$ & 27(3,24)-26(3,23) &             75.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \centering
# \caption{Transitions of HDCO detected in The Brick.}
# \begin{tabular}{cccc}
# \toprule
#  Frequency (GHz) & Species &           QNs &  Velocity (km/s) \\
# \midrule
#       259.034772 &    HDCO & 4(2,2)-3(2,1) &             69.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
# /scratch/local/46013646/ipykernel_66193/460429636.py:3: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(data[data['Group'] == species].to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],

# %%
# Big table
data.to_latex(columns = ['Frequency (GHz)', 'Species', 'QNs', 'Velocity (km/s)'],
              column_format = 'cccc', header = True, index = False, longtable = True, 
              caption = "List of molecule identifications in The Brick."))
